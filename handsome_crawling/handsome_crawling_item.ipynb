# %%
import time
from bs4 import BeautifulSoup
import pandas as pd
import requests
import json
import datetime


ITEMS_COUNT = 10

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36',
    
}

timeout_settings = (60, 60)

# %%
def get_response(url, headers):

    # GET 요청
    response = requests.get(url, headers=headers, timeout=timeout_settings)
    soup = BeautifulSoup(response.text, 'lxml')
    time.sleep(0.5)

    return soup

# %%
def get_small_categories():
    url = 'https://pcw.thehandsome.com/api/display/1/ko/category/categoryList?dispCtgNo=mainDispCtgNo'

    soup = get_response(url, headers)
    info = soup.string
    categories = json.loads(info)['payload']['lrgCtgList']
    category_index = []
    gender_type = ['여성', '남성']
    for i, gender in enumerate(gender_type):
        for j in range(1, len(categories[i]['midCtgList'])):
            middle_category_num = categories[i]['midCtgList'][j]['dispCtgNo']
            middle_category_name = categories[i]['midCtgList'][j]['dispCtgNm']

            if j == len(categories[i]['midCtgList']) - 1:
                start_num = 0
            else:
                start_num = 1
                
            for k in range(start_num, len(categories[i]['midCtgList'][j]['smlCtgList'])):
                small_category_num = categories[i]['midCtgList'][j]['smlCtgList'][k]['dispCtgNo']
                small_category_name = categories[i]['midCtgList'][j]['smlCtgList'][k]['dispCtgNm']
                category_index.append({'top': gender,'middle': [middle_category_num, middle_category_name], 'small': [small_category_num, small_category_name]})

    return category_index

# %%
test = get_small_categories()

# %%
test
# Out:
# [{'top': '여성', 'middle': ['367', '아우터'], 'small': ['388', '자켓']},
#  {'top': '여성', 'middle': ['367', '아우터'], 'small': ['461', '점퍼']},
#  {'top': '여성', 'middle': ['367', '아우터'], 'small': ['5008', '트렌치 코트']},
#  {'top': '여성', 'middle': ['367', '아우터'], 'small': ['2078', '가디건/베스트']},
#  {'top': '여성', 'middle': ['367', '아우터'], 'small': ['503', '코트']},
#  {'top': '여성', 'middle': ['367', '아우터'], 'small': ['513', '다운/패딩']},
#  {'top': '여성', 'middle': ['596', '탑'], 'small': ['972', '티셔츠']},
#  {'top': '여성', 'middle': ['596', '탑'], 'small': ['5001', '스웻셔츠']},
#  {'top': '여성', 'middle': ['596', '탑'], 'small': ['971', '블라우스']},
#  {'top': '여성', 'middle': ['596', '탑'], 'small': ['970', '셔츠']},
#  {'top': '여성', 'middle': ['596', '탑'], 'small': ['5002', '니트']},
#  {'top': '여성', 'middle': ['2074', '니트'], 'small': ['2082', '탑']},
#  {'top': '여성', 'middle': ['2074', '니트'], 'small': ['2081', '가디건/베스트']},
#  {'top': '여성', 'middle': ['2074', '니트'], 'small': ['14984', '팬츠']},
#  {'top': '여성', 'middle': ['2074', '니트'], 'small': ['14994', '드레스']},
#  {'top': '여성', 'middle': ['2074', '니트'], 'small': ['15004', '스커트']},
#  {'top': '여성', 'middle': ['595', '드레스'], 'small': ['984', '미니']},
#  {'top': '여성', 'middle': ['595', '드레스'], 'small': ['983', '미디']},
#  {'top': '여성', 'middle': ['595', '드레스'], 'small': ['5007', '롱/맥시']},
#  {'top': '여성', 'middle': ['980', '스커트'], 'small': ['988', '미니']},
#  {'top': '여성', 'middle': ['980', '스커트'], 'small': ['987', '펜슬']},
#  {'top': '여성', 'middle': ['980', '스커트'], 'small': ['986', '플레어']},
#  {'top': '여성', 'middle': ['980', '스커트'], 'small': ['5006', '롱/맥시']},
#  {'top': '여성', 'middle': ['981', '팬츠'], 'small': ['5003', '캐주얼']},
#  {'top': '여성', 'middle': ['981', '팬츠'], 'small': ['5004', '포멀']},
#  {'top': '여성', 'middle': ['981', '팬츠'], 'small': ['5005', '데님']},
#  {'top': '여성', 'middle': ['981', '팬츠'], 'small': ['990', '쇼츠']},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['8452', 'TIME : The TIME']},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['14784', "O'2nd : Brigitte Tanaka 콜라보"]},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['14166', "O'2nd : 24SS CROCHER PLAY"]},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['13492', "O'2nd : 24SS ONE-PIECE PLAY"]},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['12310', "O'2nd : 24SS DENIM PLAY"]},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['11472', "O'2nd : 24SS VOYAGEUR"]},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['14000', 'LÄTT : CONTEMPORARY ESSENTIAL']},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['11648', 'LÄTT : 24SS VISIONARY']},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['12132', 'SYSTEM : GLOBAL COLLECTION']},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['12758', 'the CASHMERE : 24SS CLUB15']},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['13524', 'LANVIN COLLECTION : 24SS LVC']},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['15026', 'SJSJ : "EDIT" ENTRY COLLECTION']},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['14156', 'SJSJ : CITY CAPSULE GRASSE']},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['8578', 'SJSJ : CITY CAPSULE MONACO']},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['14584', 'MINE : CODE MINE [Meaningful Moment]']},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['12468', 'MINE : STEADY MINE']},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['11880', 'MINE : CODE MINE [ETERNAL GRACE]']},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['14176', 'OBZEE : STUNNING MOMENT']},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['11586', 'OBZEE : 24SS ESSENTIAL']},
#  {'top': '여성',
#   'middle': ['1477', '캡슐 컬렉션*'],
#   'small': ['11212', 'OBZEE : 24SS ICONIC']},
#  {'top': '남성', 'middle': ['657', '아우터'], 'small': ['667', '재킷']},
#  {'top': '남성', 'middle': ['657', '아우터'], 'small': ['1013', '점퍼']},
#  {'top': '남성', 'middle': ['657', '아우터'], 'small': ['5013', '트렌치 코트']},
#  {'top': '남성', 'middle': ['657', '아우터'], 'small': ['1009', '가디건/베스트']},
#  {'top': '남성', 'middle': ['657', '아우터'], 'small': ['1011', '코트']},
#  {'top': '남성', 'middle': ['657', '아우터'], 'small': ['1010', '다운/패딩']},
#  {'top': '남성', 'middle': ['1004', '탑'], 'small': ['1016', '티셔츠']},
#  {'top': '남성', 'middle': ['1004', '탑'], 'small': ['5010', '스웻셔츠']},
#  {'top': '남성', 'middle': ['1004', '탑'], 'small': ['1015', '셔츠']},
#  {'top': '남성', 'middle': ['1004', '탑'], 'small': ['5011', '니트']},
#  {'top': '남성', 'middle': ['2080', '니트'], 'small': ['2093', '탑']},
#  {'top': '남성', 'middle': ['2080', '니트'], 'small': ['2092', '가디건/베스트']},
#  {'top': '남성', 'middle': ['2080', '니트'], 'small': ['15014', '팬츠']},
#  {'top': '남성', 'middle': ['1003', '팬츠'], 'small': ['1019', '루즈/테이퍼드']},
#  {'top': '남성', 'middle': ['1003', '팬츠'], 'small': ['1007', '슬림/스트레이트']},
#  {'top': '남성', 'middle': ['1003', '팬츠'], 'small': ['1006', '조거/트랙']},
#  {'top': '남성', 'middle': ['1003', '팬츠'], 'small': ['5012', '데님']},
#  {'top': '남성', 'middle': ['1003', '팬츠'], 'small': ['1008', '쇼츠']},
#  {'top': '남성', 'middle': ['1002', '수트'], 'small': ['5015', '수트재킷']},
#  {'top': '남성', 'middle': ['1002', '수트'], 'small': ['5016', '수트팬츠']},
#  {'top': '남성',
#   'middle': ['2224', '캡슐 컬렉션*'],
#   'small': ['12048', 'TIME HOMME : 24 SPRING EXCLUSIVE']},
#  {'top': '남성',
#   'middle': ['2224', '캡슐 컬렉션*'],
#   'small': ['12142', 'SYSTEM HOMME : GLOBAL COLLECTION']},
#  {'top': '남성',
#   'middle': ['2224', '캡슐 컬렉션*'],
#   'small': ['8368', 'TIME HOMME : 23 WINTER EXCLUSIVE']},
#  {'top': '남성',
#   'middle': ['2224', '캡슐 컬렉션*'],
#   'small': ['10164', 'TIME HOMME : 23 FALL EXCLUSIVE']},
#  {'top': '남성',
#   'middle': ['2224', '캡슐 컬렉션*'],
#   'small': ['8746', 'TIME HOMME : 23 SUMMER EXCLUSIVE']}]

# %%
def get_item_info(goods):
    # 상품 id
    goodsNo = goods['goodsNo']

    # 브랜드 명
    brandNm = goods['brandNm']

    # 정가
    norPrc = goods['norPrc']

    # 할인가
    salePrc = goods['salePrc']

    # 이미지    
    image_urls = []      
    try:    
        for i in range(len(goods['colorInfo'])):
            for j in range(len(goods['colorInfo'][i]['colorContInfo'])):
                check = goods['colorInfo'][i]['colorContInfo'][j]['imgGbCd']
                if 'P' in check:
                    colorContInfo = goods['colorInfo'][i]['colorContInfo'][j]['dispGoodsContUrl']
                    image_urls.append(colorContInfo)
    except:
        pass

    # 색상 정보
    colors = []
    try:
        for color in goods['colorInfo']:
            colors.append(color['optnNm'])
    except:
        pass

    # 사이즈 정보
    sizes = []
    for i in range(len(goods['colorInfo'][0]['colorSizeInfo'])):
        size_info = goods['colorInfo'][0]['colorSizeInfo'][i]['erpSzCd']
        sizes.append(size_info)


    data = {
        'product_id': goodsNo,
        'brand': brandNm,
        'fixed_price': norPrc,
        'discounted_price': salePrc,
        'url': image_urls,
        'colors': colors,
        'sizes': sizes,
    }

    return data

# %%
def get_rank_score(ranking, item_count):
    try:
        rank_score = 1 - ((ranking - 1) / (item_count - 1))
    except:
        rank_score = 1

    return rank_score

# %%
def get_items(index):
    small_category_num = index['small'][0]

    url = f'https://www.thehandsome.com/api/display/1/ko/category/categoryGoodsList?dispMediaCd=10&sortGbn=20&pageSize={ITEMS_COUNT}&pageNo=1&norOutletGbCd=J&dispCtgNo={small_category_num}&productListLayout=4&theditedYn=N'

    goods_info = []

    soup = get_response(url, headers)
    info = soup.string
    goods_in_page = json.loads(info)['payload']['goodsList']

    for rank, goods in enumerate(goods_in_page, 1):
        
        goods_data = get_item_info(goods)
        goods_data['rank_score'] = get_rank_score(int(rank), len(goods_in_page))
        goods_data['top'] = index['top']
        goods_data['middle'] = index['middle'][1]
        goods_data['small'] = index['small'][1]
        goods_info.append(goods_data)
        print(len(goods_info), goods_data)


    return goods_info

# %%
def get_additional_info(product_id):
    url = f'https://pcw.thehandsome.com/ko/PM/productDetail/{product_id}?itmNo=003'

    soup = get_response(url, headers=headers)

    # 브랜드2
    brand2 = soup.select('ul.prd-category > li > a')[0].text.strip()

    # 상품 설명
    try:
        product_info = soup.select('div.prd-desc-box')[0].text
    except:
        product_info = None

    # 피팅 정보
    try:
        fitting_info = soup.select('p.cmp-font')[0].text
    except:
        fitting_info = None

    # 상품 추가 정보
    try:
        additional_infos = soup.select('ul.cmp-list.list-dotType2.bottom6')
        additional_info_processed = []
        
        for info in additional_infos:
            additional_info_processed.append(info.text)
    except:
        additional_info_processed = None

    data = {
        'product_id': product_id,
        'product_info': product_info,
        'fitting_info': fitting_info,
        'additional_info': additional_info_processed,
        'brand2': brand2
        
    }
    
    return data

# %%
def main():
    category_index = get_small_categories()
    all_info = []
    for index in category_index:
        small_category_info = get_items(index)
        all_info += small_category_info

    id_list = [item['product_id'] for item in all_info]

    df_all_info = pd.DataFrame(all_info)
    
    all_additional_info = []
    for product_id in id_list:
        additional_info = get_additional_info(product_id)
        all_additional_info.append(additional_info)
        print(additional_info)

    df_all_additional_info = pd.DataFrame(all_additional_info)

    df_merged = pd.merge(df_all_info, df_all_additional_info, on='product_id', how='left')

    today = datetime.date.today()
    formatted_date = today.strftime('%Y%m%d')

    df_merged.to_csv(f'handsome_{formatted_date}.csv', index=False)

# %%
if __name__ == '__main__':
    main()
# Out:
# 1 {'product_id': 'MN2E5WJC483W', 'brand': 'MINE', 'fixed_price': 595000, 'discounted_price': 595000, 'url': ['/MN/2E/SS/MN2E5WJC483W_NL_W01.jpg?rs=684X1032', '/MN/2E/SS/MN2E5WJC483W_NL_W02.jpg?rs=684X1032', '/MN/2E/SS/MN2E5WJC483W_NL_W03.jpg?rs=684X1032', '/MN/2E/SS/MN2E5WJC483W_NL_W04.jpg?rs=684X1032', '/MN/2E/SS/MN2E5WJC483W_NL_W05.jpg?rs=684X1032', '/MN/2E/SS/MN2E5WJC483W_NL_W06.jpg?rs=684X1032', '/MN/2E/SS/MN2E5WJC483W_NL_W07.jpg?rs=684X1032', '/MN/2E/SS/MN2E5WJC483W_NL_W08.jpg?rs=684X1032', '/MN/2E/SS/MN2E5WJC483W_NL_W09.jpg?rs=684X1032'], 'colors': ['NEUTRAL'], 'sizes': ['76', '82', '88'], 'rank_score': 1.0, 'top': '여성', 'middle': '아우터', 'small': '자켓'}
# 2 {'product_id': 'SJ2E4WJC232W', 'brand': 'SJSJ', 'fixed_price': 475000, 'discounted_price': 475000, 'url': ['/SJ/2E/SS/SJ2E4WJC232W_DN_W01.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E4WJC232W_DN_W02.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E4WJC232W_DN_W03.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E4WJC232W_DN_W04.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E4WJC232W_DN_W05.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E4WJC232W_DN_W06.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E4WJC232W_DN_W07.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E4WJC232W_OW_W01.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E4WJC232W_OW_W02.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E4WJC232W_OW_W03.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E4WJC232W_OW_W04.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E4WJC232W_OW_W05.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E4WJC232W_OW_W06.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E4WJC232W_OW_W07.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E4WJC232W_OW_W08.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E4WJC232W_OW_W09.jpg?rs=684X1032'], 'colors': ['DARK NAVY', 'OFF WHITE'], 'sizes': ['76', '82', '88'], 'rank_score': 0.8888888888888888, 'top': '여성', 'middle': '아우터', 'small': '자켓'}
# 3 {'product_id': 'LC2E4WJC964W', 'brand': 'LANVIN COLLECTION', 'fixed_price': 795000, 'discounted_price': 795000, 'url': ['/LC/2E/SS/LC2E4WJC964W_OW_W01.jpg?rs=684X1032', '/LC/2E/SS/LC2E4WJC964W_OW_W02.jpg?rs=684X1032', '/LC/2E/SS/LC2E4WJC964W_OW_W03.jpg?rs=684X1032', '/LC/2E/SS/LC2E4WJC964W_OW_W04.jpg?rs=684X1032', '/LC/2E/SS/LC2E4WJC964W_OW_W05.jpg?rs=684X1032', '/LC/2E/SS/LC2E4WJC964W_OW_W06.jpg?rs=684X1032', '/LC/2E/SS/LC2E4WJC964W_OW_W07.jpg?rs=684X1032', '/LC/2E/SS/LC2E4WJC964W_OW_W08.jpg?rs=684X1032'], 'colors': ['OFF WHITE'], 'sizes': ['82', '88'], 'rank_score': 0.7777777777777778, 'top': '여성', 'middle': '아우터', 'small': '자켓'}
# 4 {'product_id': 'SJ2E1WJC216WM2', 'brand': 'SJSJ', 'fixed_price': 455000, 'discounted_price': 455000, 'url': ['/SJ/2E/SS/SJ2E1WJC216WM2_CR_W01.jpg?rs=684X1032', '/SJ/2E/SS/SJ2
jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_BL_W02.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_BL_W03.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_BL_W04.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_BL_W05.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_BL_W06.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_BL_W07.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_BL_W08.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_BL_W09.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_LE_W01.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_LE_W02.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_LE_W03.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_LE_W04.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_LE_W05.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_LE_W06.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_LE_W07.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_LE_W08.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E5WOTE01W_LE_W09.jpg?rs=684X1032'], 'colors': ['BLUE', 'LIGHT BEIGE'], 'sizes': ['76', '82', '88'], 'rank_score': 1.0, 'top': '여성', 'middle': '아우터', 'small': '점퍼'}
# 2 {'product_id': 'SY2E3WJMTE1WM2', 'brand': 'SYSTEM', 'fixed_price': 375000, 'discounted_price': 375000, 'url': ['/SY/2E/SS/SY2E3WJMTE1WM2_BK_W01.jpg?rs=684X1032', '/SY/2E/SS/SY2E3WJMTE1WM2_BK_W02.jpg?rs=684X1032', '/SY/2E/SS/SY2E3WJMTE1WM2_BK_W03.jpg?rs=684X1032', '/SY/2E/SS/SY2E3WJMTE1WM2_BK_W04.jpg?rs=684X1032', '/SY/2E/SS/SY2E3WJMTE1WM2_BK_W05.jpg?rs=684X1032', '/SY/2E/SS/SY2E3WJMTE1WM2_BK_W06.jpg?rs=684X1032', '/SY/2E/SS/SY2E3WJMTE1WM2_BK_W07.jpg?rs=684X1032'], 'colors': ['BLACK'], 'sizes': ['82'], 'rank_score': 0.8888888888888888, 'top': '여성', 'middle': '아우터', 'small': '점퍼'}
# 3 {'product_id': 'CM2E4WOT127W', 'brand': 'the CASHMERE', 'fixed_price': 545000, 'discounted_price': 545000, 'url': ['/CM/2E/SS/CM2E4WOT127W_RG_W01.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT127W_RG_W02.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT127W_RG_W03.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT127W_RG_W04.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT127W_RG_W05.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT127W_RG_W06.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT127W_RG_W07.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT127W_GE_W01.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT127W_GE_W02.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT127W_GE_W03.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT127W_GE_W04.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT127W_GE_W05.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT127W_GE_W06.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT127W_GE_W07.jpg?rs=684X1032'], 'colors': ['ANTHRACITE', 'GREIGE'], 'sizes': ['82', '88'], 'rank_score': 0.7777777777777778, 'top': '여성', 'middle': '아우터', 'small': '점퍼'}
jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT711WM_DE_W02.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT711WM_DE_W03.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT711WM_DE_W04.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT711WM_DE_W05.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT711WM_DE_W06.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT711WM_DE_W07.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT711WM_DE_W08.jpg?rs=684X1032'], 'colors': ['SAND BEIGE'], 'sizes': ['76', '82'], 'rank_score': 0.5555555555555556, 'top': '여성', 'middle': '아우터', 'small': '트렌치 코트'}
# 6 {'product_id': 'SJ2E1WCT715W', 'brand': 'SJSJ', 'fixed_price': 575000, 'discounted_price': 575000, 'url': ['/SJ/2E/SS/SJ2E1WCT715W_DN_W01.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715W_DN_W02.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715W_DN_W03.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715W_DN_W04.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715W_DN_W05.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715W_DN_W06.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715W_DN_W07.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715W_DN_W08.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715W_BG_W01.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715W_BG_W02.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715W_BG_W03.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715W_BG_W04.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715W_BG_W05.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715W_BG_W06.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715W_BG_W07.jpg?rs=684X1032'], 'colors': ['DARK NAVY', 'BEIGE'], 'sizes': ['76', '82', '88'], 'rank_score': 0.4444444444444444, 'top': '여성', 'middle': '아우터', 'small': '트렌치 코트'}
# 7 {'product_id': 'SJ2E1WCT715WM1', 'brand': 'SJSJ', 'fixed_price': 575000, 'discounted_price': 575000, 'url': ['/SJ/2E/SS/SJ2E1WCT715WM1_BG_W01.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715WM1_BG_W02.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715WM1_BG_W03.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715WM1_BG_W04.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715WM1_BG_W05.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715WM1_BG_W06.jpg?rs=684X1032', '/SJ/2E/SS/SJ2E1WCT715WM1_BG_W07.jpg?rs=684X1032'], 'colors': ['BEIGE'], 'sizes': ['76', '82', '88'], 'rank_score': 0.33333333333333337, 'top': '여성', 'middle': '아우터', 'small': '트렌치 코트'}
# 8 {'product_id': 'CM2E4WOT135W', 'brand': 'the CASHMERE', 'fixed_price': 695000, 'discounted_price': 695000, 'url': ['/CM/2E/SS/CM2E4WOT135W_TP_W01.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT135W_TP_W02.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT135W_TP_W03.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT135W_TP_W04.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT135W_TP_W05.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT135W_TP_W06.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT135W_TP_W07.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT135W_CR_W01.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT135W_CR_W02.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT135W_CR_W03.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT135W_CR_W04.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT135W_CR_W05.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT135W_CR_W06.jpg?rs=684X1032', '/CM/2E/SS/CM2E4WOT135W_CR_W07.jpg?rs=684X1032'], 'colors': ['TAUPE', 'CREAM'], 'sizes': ['82', '88'], 'rank_score': 0.2222222222222222, 'top': '여성', 'middle': '아우터', 'small': '트렌치 코트'}
# 10 {'product_id': 'LC2E1WCT122W', 'brand': 'LANVIN COLLECTION', 'fixed_price': 1350000, 'discounted_price': 1350000, 'url': ['/LC/2E/SS/LC2E1WCT122W_BK_W01.jpg?rs=684X1032', '/LC/2E/SS/LC2E1WCT122W_BK_W02.jpg?rs=684X1032', '/LC/2E/SS/LC2E1WCT122W_BK_W03.jpg?rs=684X1032', '/LC/2E/SS/LC2E1WCT122W_BK_W04.jpg?rs=684X1032', '/LC/2E/SS/LC2E1WCT122W_BK_W05.jpg?rs=684X1032', '/LC/2E/SS/LC2E1WCT122W_BK_W06.jpg?rs=684X1032', '/LC/2E/SS/LC2E1WCT122W_BK_W07.jpg?rs=684X1032'], 'colors': ['BLACK'], 'sizes': ['82', '88'], 'rank_score': 0.0, 'top': '여성', 'middle': '아우터', 'small': '코트'}
# 1 {'product_id': 'LC2E0QOT501W', 'brand': 'LANVIN COLLECTION', 'fixed_price': 985000, 'discounted_price': 985000, 'url': ['/LC/2E/SS/LC2E0QOT501W_BK_W01.jpg?rs=684X1032', '/LC/2E/SS/LC2E0QOT501W_BK_W02.jpg?rs=684X1032', '/LC/2E/SS/LC2E0QOT501W_BK_W03.jpg?rs=684X1032', '/LC/2E/SS/LC2E0QOT501W_BK_W04.jpg?rs=684X1032', '/LC/2E/SS/LC2E0QOT501W_BK_W05.jpg?rs=684X1032', '/LC/2E/SS/LC2E0QOT501W_BK_W06.jpg?rs=684X1032', '/LC/2E/SS/LC2E0QOT501W_BK_W07.jpg?rs=684X1032'], 'colors': ['BLACK'], 'sizes': ['82', '88'], 'rank_score': 1.0, 'top': '여성', 'middle': '아우터', 'small': '다운/패딩'}
# ...
# {'product_id': 'TH2E1WSH710N', 'product_info': '가볍고 쿨한 터치감의 100% 면 소재로 제작된 셔츠입니다. 가슴 한쪽에 큼직한 패치 포켓을 더했으며, 뒤 요크 라인 중심에 입체감 있는 박스 플리츠를 더해 자연스럽게 볼륨감 있는 백 실루엣을 완성했습니다. 밑단에 가볍게 라운드 지는 헴 라인으로 다양한 스타일 연출이 가능한 제품입니다. ', 'fitting_info': '187cm, 105 사이즈 모델이 105 사이즈 착용', 'additional_info': ['100% 면 소재', '앞면에 버튼 클로징', '가슴 한쪽에 포켓', '소맷단 버튼 여밈', '라운드헴 디자인'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2E1NPC682N', 'product_info': '감각적인 워싱 디테일의 데님 텍스처와 탄탄한 100% 면 소재가 어우러져 흐트러짐 없는 아웃핏과 스타일리시한 매력을 전해주는 팬츠입니다. 밑단까지 깔끔하게 떨어지는 와이드한 실루엣으로 다리 라인을 길어 보이게 해주며, 클래식한 5포켓 디자인으로 완성했습니다.', 'fitting_info': '[WIDE FIT] 힙에서부터 밑단까지 여유있는 트렌디한 실루엣으로 캐주얼한 라인189cm, 105 사이즈 모델이 86 사이즈 착용187cm, 105 사이즈 모델이 86 사이즈 착용', 'additional_info': ['100% 면 소재', '앞면에 버튼과 지퍼 클로징', '5포켓 디자인'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2E1WJM319N', 'product_info': '입체감 있는 와플 텍스처가 시선을 끄는 점퍼로 캐주얼한 분위기를 자아냅니다. 간결한 스탠드 칼라 디자인이며, 양방향으로 여며지는 투웨이 지퍼로 포인트를 주었습니다. 밑단 내부에 드로우스트링을 더해 실루엣 조절이 용이하며, 신축성 있는 면 혼방 소재를 사용했습니다. 여유로운 드롭 숄더 실루엣으로 다양한 이너 탑과 함께 두루 매치하기 좋은 아이템입니다.', 'fitting_info': '187cm, 105 사이즈 모델이 100 사이즈 착용', 'additional_info': ['면 혼방 소재', '앞면에 지퍼 클로징', '양옆에 포켓', '소맷단에 밴딩', '밑단 내부 양옆에 드로우스트링'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2E1WJM904N', 'product_info': '리얼 레더의 자연스러운 질감과 고급스러운 광택을 그대로 재현한 페이크 레더 소재로 제작된 칼라 자켓입니다. 드롭 숄더 디자인의 레귤러 실루엣이며, 밑단 양옆의 스냅 버튼 여밈 탭과 소맷단 지퍼 여밈으로 실루엣 조절이 용이합니다. 흔히 볼 수없는 컬러감으로 다양한 룩에 매치해 포인트를 주기 좋은 제품입니다.', 'fitting_info': '187cm, 105 사이즈 모델이 105 사이즈 착용', 'additional_info': ['앞면에 스냅 버튼 클로징', '양옆에 포켓과 내부에 1개의 인포켓', '소맷단 지퍼 여밈', '밑단 양옆에 스냅 버튼 여밈 탭'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2E1WJM904NP1', 'product_info': '부드럽고 고급스러운 스웨이드 텍스처로 완성한 외관이 돋보이는 칼라 자켓입니다. 드롭 숄더 디자인의 레귤러 실루엣이며, 스판 혼방 소재를 사용했습니다. 깔끔한 디자인으로 높은 활용도를 선보이며, 밑단 양옆에 스냅 버튼 여밈 탭과 소맷단 지퍼 여밈으로 실루엣 조절이 용이합니다.', 'fitting_info': '187cm, 105 사이즈 모델이 105 사이즈 착용', 'additional_info': ['스판 혼방 소재', '앞면에 스냅 버튼 클로징', '양옆에 포켓과 내부에 1개의 인포켓', '소맷단 지퍼 여밈', '밑단 양옆에 스냅 버튼 여밈 탭'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2E1KCD009N', 'product_info': '서로 다른 방향으로 짜여진 리브 니팅으로 이루어져 있는 디자인이 돋보이는 라운드넥 가디건입니다. 부드럽고 신축성 있는 면 혼방 소재를 사용했으며, 살짝 여유로운 드롭 숄더 실루엣으로 완성했습니다. 버튼 업 스타일로 버튼을 모두 여며 니트 탑처럼 연출하기에도 좋은 제품입니다. ', 'fitting_info': '187cm, 105 사이즈 모델이 105 사이즈 착용', 'additional_info': ['면 혼방 소재', '앞면에 버튼 클로징', '라운드넥 디자인'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2E1KJM038N', 'product_info': '볼드하고 입체적인 리브 짜임이 돋보이며, 후드 디자인으로 캐주얼하게 완성한 집업 니트 점퍼입니다. 투웨이 지퍼 클로징으로 한층 실용적이며, 다양한 스타일링이 가능합니다. 부드러운 면 혼방 소재를 사용하였으며, 여유로운 드롭 숄더 디자인으로 편안한 착용감을 전해줍니다. ', 'fitting_info': '187cm, 105 사이즈 모델이 100 사이즈 착용', 'additional_info': ['면 혼방 소재', '앞면에 투웨이 지퍼 클로징', '양옆에 포켓'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2E1WJM307N', 'product_info': '입체감 있는 크링클 텍스처로 완성한 외관이 시선을 사로잡는 후드 집업 점퍼입니다. 신축성 있는 소재로 편안한 착용감을 전해주며, 톤 온 톤 파이핑 디테일로 포인트를 주었습니다. 드롭 숄더 실루엣과 흔치 않은 컬러감으로 다양한 룩에 스타일리시한 매력을 더해줍니다. ', 'fitting_info': '187cm, 105 사이즈 모델이 105 사이즈 착용', 'additional_info': ['앞면에 양방향 지퍼 클로징', '양옆에 포켓', '후드 디자인'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2E1WJM310N', 'product_info': '규칙적으로 더해진 플리츠 디테일로 입체감 있는 외관을 자아내는 자켓입니다. 깔끔한 칼라 디자인이며, 집업 스타일로 간편한 착용이 가능합니다. 가슴 한쪽에 패치 포켓을 더해 포인트를 주었으며, 볼륨감 있는 슬리브 디자인이 특징입니다. 여유로운 드롭 숄더 실루엣으로 캐주얼한 분위기를 자아내며, 같은 소재의 플리츠 팬츠와 셋업 스타일링이 가능합니다.', 'fitting_info': '187cm, 105 사이즈 모델이 105 사이즈 착용', 'additional_info': ['앞면에 지퍼 클로징', '가슴 한쪽에 포켓', '밑단에 밴딩'], 'brand2': 'TIME HOMME'}
# {'product_id': 'SH2E3TRNTE3M', 'product_info': '여유로운 드롭 숄더 실루엣으로 편안하고 캐주얼한 매력이 돋보이는 티셔츠입니다. 가슴 한쪽과 뒷면에 로고 디자인을 더해 포인트를 주었으며, 넥라인에 리브 마감을 더해 섬세하게 완성했습니다. 신축성이 느껴지는 100% 면 소재를 사용했으며, 단독은 물론 다양한 아우터에 이너 탑으로 매치할 수 있는 아이템입니다.', 'fitting_info': '187cm, 100 사이즈 모델이 100 사이즈 착용', 'additional_info': ['100% 면 소재', '라운드넥 디자인', '넥라인 리브 마감', '하프 슬리브 디자인'], 'brand2': 'SYSTEM HOMME'}
# {'product_id': 'SH2E3TRNTE2MM', 'product_info': '앞면에 큼직한 프린팅을 더해 시스템 옴므만의 감각적인 디자인을 선보이는 티셔츠입니다. 넥라인을 리브 마감으로 섬세하게 완성했으며, 넥라인 뒷면에 시스템의 로고 디테을 더해 포인트를 주었습니다. 하프 슬리브 디자인으로 S/S 시즌 높은 활용도를 선보이며, 신축성 있는 면과 스판 혼방 소재를 사용했습니다.', 'fitting_info': '187cm, 100 사이즈 모델이 100 사이즈 착용', 'additional_info': ['면과 스판 혼방 소재', '라운드넥 디자인', '넥라인 리브 마감', '하프 슬리브 디자인'], 'brand2': 'SYSTEM HOMME'}
# {'product_id': 'SH2E1ACKT01M', 'product_info': '상단을 리브 짜임으로 완성했으며, 부드럽고 신축성 있는 면과 스판 혼방 소재로 제작된 양말입니다. 상단에 각기 다른 레터링 인타르시아로 포인트를 주었으며, 베이직한 컬러로 데일리 하게 착용하기 좋은 아이템입니다. ', 'fitting_info': None, 'additional_info': ['면과 스판 혼방 소재'], 'brand2': 'SYSTEM HOMME'}
# {'product_id': 'SH2E3TRNTE3MM', 'product_info': '여유로운 드롭 숄더 실루엣으로 편안하고 캐주얼한 매력이 돋보이는 티셔츠입니다. 가슴 한쪽과 뒷면에 로고 디자인을 더해 포인트를 주었으며, 넥라인에 리브 마감을 더해 섬세하게 완성했습니다. 신축성이 느껴지는 면 혼방 소재를 사용했으며, 단독은 물론 다양한 아우터에 이너 탑으로 매치할 수 있는 아이템입니다.', 'fitting_info': '187cm, 100 사이즈 모델이 100 사이즈 착용', 'additional_info': ['면 혼방 소재', '라운드넥 디자인', '넥라인 리브 마감', '하프 슬리브 디자인'], 'brand2': 'SYSTEM HOMME'}
# {'product_id': 'SH2E3TRNTE1M', 'product_info': '뒷면에 큼직한 프린팅을 더해 시스템 옴므만의 감각적인 디자인을 선보이는 티셔츠입니다. 가슴 한쪽에 로고 디테일을 더해 포인트를 주었으며, 부드럽고 신축성이 느껴지는 텍스처를 사용했습니다. 여유로운 드롭 숄더 실루엣으로 편안한 착용감을 전해주며, 단품만으로도 스타일리시한 룩을 완성하기 좋은 아이템입니다.', 'fitting_info': '187cm, 100 사이즈 모델이 100 사이즈 착용', 'additional_info': ['100% 면 소재', '라운드넥 디자인', '하프 슬리브 디자인'], 'brand2': 'SYSTEM HOMME'}
# {'product_id': 'SH2E3TRNTE2M', 'product_info': '앞면에 큼직한 프린팅을 더해 시스템 옴므만의 감각적인 디자인을 선보이는 티셔츠입니다. 넥라인을 리브 마감으로 섬세하게 완성했으며, 넥라인 뒷면에 시스템의 로고 디테을 더해 포인트를 주었습니다. 하프 슬리브 디자인으로 S/S 시즌 높은 활용도를 선보이며, 신축성 있는 면과 스판 혼방 소재를 사용했습니다.', 'fitting_info': '187cm, 100 사이즈 모델이 100 사이즈 착용', 'additional_info': ['면과 스판 혼방 소재', '라운드넥 디자인', '넥라인 리브 마감', '하프 슬리브 디자인'], 'brand2': 'SYSTEM HOMME'}
# {'product_id': 'SH2E1KCDT01M', 'product_info': '부분적으로 더해진 디스트로이드 디테일이 시선을 끄는 니트 가디건으로 시스템 옴므만의 스타일리시한 분위기가 돋보이는 아이템입니다. 바디에 자연스럽게 핏되는 레귤러 실루엣이며, 부드럽고 신축성 있는 울 혼방 소재를 사용했습니다. 각 끝단을 리브로 섬세하게 완성했으며, 버튼 업 디자인으로 버튼을 모두 클로징 하여 탑처럼 스타일링하기에도 좋은 제품입니다. ', 'fitting_info': '187cm, 100 사이즈 모델이 100 사이즈 착용', 'additional_info': ['울 혼방 소재', '앞면에 버튼 클로징', '각 끝단 리브 마감'], 'brand2': 'SYSTEM HOMME'}
# {'product_id': 'SH2E1KRNT01M', 'product_info': '시스템 옴므만의 감각적인 컬러 웨이가 돋보이는 니트 탑입니다. 부분적으로 성근 니트 짜임을 더해 은은한 비침이 느껴지며, 각 끝단을 리브 마감으로 섬세하게 완성했습니다. 부드럽고 신축성 있는 면 혼방 소재를 사용했으며, 여유로운 드롭 숄더 실루엣으로 편안한 착용감을 전해줍니다. 단품만으로도 캐주얼하면서 스타일리시한 룩을 완성하기 좋은 아이템입니다.', 'fitting_info': '187cm, 100 사이즈 모델이 100 사이즈 착용', 'additional_info': ['면 혼방 소재', '라운드넥 디자인', '각 끝단 리브 마감'], 'brand2': 'SYSTEM HOMME'}
# {'product_id': 'SH2E1NJMT05M', 'product_info': '간결한 칼라리스 디자인과 내추럴한 데님 텍스처가 특징인 자켓입니다. 앞면에 실버 톤의 버튼을 세팅했으며, 가슴에 버튼 여밈의 플랩 포켓을 더해 섬세하게 완성했습니다. 입체감 있는 솔기 라인과 촘촘한 배색 스티치 디테일이 돋보이며, 탄탄한 100% 면 소재를 사용해 구김이 적은 깔끔한 외관을 자아냅니다.', 'fitting_info': '187cm, 100 사이즈 모델이 100 사이즈 착용', 'additional_info': ['100% 면 소재', '앞면에 버튼 클로징', '가슴 양쪽과 양옆에 포켓', '소맷단 버튼 여밈', '뒷면 밑단에 버튼 여밈의 탭'], 'brand2': 'SYSTEM HOMME'}
# {'product_id': 'SH2E1WPCT02M', 'product_info': '허리 라인 앞면에 투턱을 잡아 입체감 있는 주름을 연출하며, 밑단까지 여유롭게 떨어지는 실루엣의 팬츠입니다. 내추럴한 컬러감이 돋보이며, 탄탄한 100% 면 소재를 사용하여 깔끔한 아웃핏을 자랑합니다. 베이직한 디자인으로 포멀과 캐주얼 경계 없이 연출하기 좋으며, 같은 소재의 오버사이즈 자켓과 함께 셋업 스타일링이 가능한 아이템입니다. ', 'fitting_info': 'WIDE : 허벅지와 밑단 폭이 넓으면서 실루엣이 자연스럽게 떨어지는 라인187cm, 100 사이즈 모델이 82 사이즈 착용', 'additional_info': ['100% 면 소재', '앞면에 버튼과 후크, 지퍼 클로징', '양옆과 힙에 포켓'], 'brand2': 'SYSTEM HOMME'}
# {'product_id': 'TH2D9KRN034N', 'product_info': '볼드한 리브 짜임으로 이루어져 입체감이 돋보이는 니트 탑으로 100% 울 소재를 사용하였습니다. 차분한 컬러감이 특징이며, 간결한 라운드넥으로 디자인하였습니다. 여유로운 드롭 숄더 실루엣으로 다양한 하의와 함께 두루 매치하기 좋은 아이템입니다.', 'fitting_info': '186cm, 105 사이즈 모델이 105 사이즈 착용', 'additional_info': ['100% 울 소재', '각 끝단 리브 마감', '라운드넥 디자인'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D9TPC591N', 'product_info': '밑단까지 여유롭게 떨어지는 실루엣의 트레이닝 팬츠로 밑단 양옆 내부에 드로우스트링이 있어 핏 조절이 가능한 아이템입니다. 군더더기 없이 캐주얼한 디자인으로 간편하게 착용하기 좋으며, 허리 라인에 밴딩과 드로우스트링이 있어 편안한 착용감을 자랑합니다. 중량감 있고 탄탄한 100% 면 소재를 사용하여 실루엣을 깔끔하게 연출해주며, 같은 소재의 후드 티셔츠와 함께 셋업하여 스타일링 하기 좋습니다.', 'fitting_info': '[WIDE FIT] 허벅지와 밑단 폭이 넓으면서 실루엣이 자연스럽게 떨어지는 라인186cm, 105 사이즈 모델이 86 사이즈 착용', 'additional_info': ['100% 면 소재', '허리 라인에 밴딩과 드로우스트링', '허리 앞면에 턱 디테일', '양옆과 힙에 포켓', '밑단 내부에 드로우스트링'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D9TTO644N', 'product_info': '자연스럽게 툭 떨어지는 드롭 숄더 디자인과 감각적인 오버사이즈 실루엣이 눈길을 끄는 후드 티셔츠입니다. 중량감이 있고 탄탄한 100% 면 소재를 사용하여 실루엣을 깔끔하게 완성해주며, 양옆 포켓에 부분적으로 미세한 디스트로이드 디테일을 더해 섬세하게 완성했습니다. 군더더기 없이 간결한 디자인으로 어떤 룩에나 두루 어울리며, 같은 소재의 트레이닝 팬츠와 함께 스타일링 하기 좋은 아이템입니다.', 'fitting_info': '186cm, 105 사이즈 모델이 105 사이즈 착용', 'additional_info': ['100% 면 소재', '넥라인에 스냅 버튼 여밈', '드롭 숄더 디자인', '양옆에 포켓', '소맷단과 밑단을 리브 마감'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D9WCT410N', 'product_info': None, 'fitting_info': '185cm, 100사이즈 모델, 3 사이즈 착용186cm, 105 사이즈 모델이 105 사이즈 착용', 'additional_info': ['램스 울과 캐시미어 혼방 소재', '앞면에 버튼 클로징', '양옆에 포켓', '뒷면 밑단 중심에 슬릿'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D9WJM328N', 'product_info': '램스 울과 캐시미어 혼방 소재를 사용하여 가볍고 포근한 터치감이 돋보이며, 핸드메이드로 제작하여 완성도 높은 퀄리티를 선보이는 점퍼입니다. 칼라와 버튼 업 디자인으로 깔끔하게 완성하였으며, 몸판 앞면에 포켓과 직선적인 패널을 장식하여 포인트를 주었습니다. 베이직한 컬러감과 살짝 여유로운 핏으로 어떤 룩에나 가볍게 걸쳐 스타일링 하기 좋은 아이템입니다.', 'fitting_info': '186cm, 105 사이즈 모델이 105 사이즈 착용', 'additional_info': ['램스 울과 캐시미어 혼방 소재', '앞면의 버튼 클로징', '몸판 앞면과 양옆에 포켓', '소맷단에 버튼 여밈', '뒷면 밑단에 버튼 여밈의 스트랩', '핸드메이드'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D9WPC590N', 'product_info': '탄탄한 트윌 텍스처가 돋보이는 팬츠로 100% 면 소재를 사용하였습니다. 허리 라인 양옆에 핀턱을 잡아 밑단까지 여유롭게 떨어지는 와이드 실루엣이며, 힙 양옆에 버튼 여밈의 포켓으로 섬세하게 완성했습니다. 차분한 컬러감으로 다양한 룩에 데일리 하게 활용하기 좋은 아이템입니다.', 'fitting_info': '[WIDE FIT] 힙에서부터 밑단까지 여유있는 트렌디한 실루엣으로 캐주얼한 라인186cm, 105 사이즈 모델이 86 사이즈 착용', 'additional_info': ['100% 면 소재', '앞면에 버튼과 지퍼 클로징', '양옆과 힙에 포켓'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D9WSH718N', 'product_info': '입체감 있는 부클 텍스처가 돋보이는 셔츠로 부드러운 터치감의 울과 면 혼방 소재를 사용했습니다. 깔끔한 칼라 디자인이며, 양옆에 큼직한 패치 포켓으로 포인트를 주었습니다. 여유로운 실루엣이며, 다양한 이너 탑과 함께 아우터처럼 스타일링하기에도 좋은 아이템입니다.', 'fitting_info': '186cm, 105 사이즈 모델이 105 사이즈 착용', 'additional_info': ['울과 면 혼방 소재', '앞면에 버튼 클로징', '양옆에 포켓', '소맷단 버튼 여밈'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2DAWJM342N', 'product_info': '멜란지한 컬러감의 헤링본 텍스처를 사용하여 F/W 시즌 무드와 고급스러운 분위기를 자아내는 점퍼입니다. 스냅 버튼 여밈의 하이넥 디자인이며, 살짝 여유로운 핏과 투웨이 지퍼 클로징으로 간편하게 걸쳐 입기 좋은 아이템입니다. 앙고라와 램스 울 혼방 소재를 사용하였으며, 내부에 얇은 패딩 충전재를 더한 퀼팅 안감이 있어 따뜻한 착용감을 전해줍니다.', 'fitting_info': '186cm, 105 사이즈 모델이 105 사이즈 착용', 'additional_info': ['앙고라와 램스 울 혼방 소재', '넥라인의 스냅 버튼과 앞면의 투웨이 지퍼 클로징', '양옆에 스냅 버튼 여밈의 포켓과 1개의 인 포켓', '소맷단에 버튼으로 조절 가능한 스트랩'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2DBKJM040N', 'product_info': '컬리한 덤블 텍스처로 이루어져 부드럽고 포근한 터치감을 자랑하는 니트 점퍼입니다. 후드 집업 디자인이며, 여유롭게 떨어지는 어깨 라인과 루즈한 실루엣으로 캐주얼한 매력이 돋보입니다. 베이직한 컬러감으로 어떤 상의에나 가볍게 걸쳐 스타일링 하기 좋은 활용도 높은 아이템입니다.', 'fitting_info': '186cm, 105 사이즈 모델이 105 사이즈 착용', 'additional_info': ['앞면의 지퍼 클로징', '후드형 디자인', '양옆에 포켓'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D9TTN645N', 'product_info': '볼드한 리브 짜임으로 이루어져 입체감이 돋보이며, 벨벳 터치감의 텍스처를 사용하여 부드럽고 편안한 착용감을 전해주는 칼라 탑입니다. 여유롭게 떨어지는 어깨 라인과 루즈한 실루엣이 어우러져 캐주얼한 룩을 완성해주며, 흔치 않은 컬러감이 눈길을 사로잡는 아이템입니다.', 'fitting_info': '186cm, 105 사이즈 모델이 105 사이즈 착용', 'additional_info': ['스판 혼방 소재', '넥라인의 버튼 클로징', '드롭 숄더 디자인', '밑단 양옆에 슬릿'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D8WJM315N', 'product_info': '자연스러운 주름이 돋보이는 페이크 레더 소재를 사용하여 가볍고 부드러운 터치감을 자랑하는 자켓입니다. 양옆에 스냅 버튼 여밈의 플랩 포켓으로 포인트를 주었으며, 살짝 여유로운 실루엣과 간편한 집업 디자인이 어우러져 편안하면서도 스타일리시한 룩을 완성해 주는 아이템입니다.', 'fitting_info': '187cm, 100 사이즈 모델이 100 사이즈 착용', 'additional_info': ['페이크 레더 소재', '앞면에 지퍼 클로징', '양옆에 포켓', '소맷단 버튼 여밈', '뒷면 밑단 밴딩 처리'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D9WSH717N', 'product_info': '부드럽고 입체감 있는 100% 면 소재와 앞뒤 기장이 다른 언밸런스 헴 디자인이 어우러진 셔츠입니다. 상단의 버튼을 오픈하였을 때 자연스러운 오픈 칼라를 연출해 주며, 소맷단과 백요크 하단에 턱을 잡아 볼륨감을 더해주었습니다. 여유로운 드롭 숄더 실루엣으로 디자인하였으며, 단독으로 스타일링하거나 다양한 이너 탑과 함께 아우터처럼 연출하기에 좋은 아이템입니다.', 'fitting_info': '187cm, 100 사이즈 모델이 100 사이즈 착용', 'additional_info': ['100% 면 소재', '앞면에 버튼 클로징', '소맷단 버튼 여밈', '언밸런스 헴 디자인'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D8KRN037N', 'product_info': '부드럽고 신축성 있는 100% 울 소재를 사용한 니트 탑입니다. 여유로운 드롭 숄더 실루엣으로 디자인하였으며, 각 끝단을 리브로 마감하였습니다. 솔리드한 컬러감과 베이직한 라운드넥 디자인으로 어디에나 두루 매치하여 스타일링하기 좋은 아이템입니다.', 'fitting_info': '187cm, 100 사이즈 모델이 100 사이즈 착용186cm, 105 사이즈 모델이 100사이즈 착용', 'additional_info': ['100% 울 소재', '각 끝단 리브 마감', '라운드넥 디자인'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D8KVT031N', 'product_info': '마치 손으로 직접 짠 듯한 크로셰 짜임과 두 가지 이상의 컬러를 믹스한 멜란지 텍스처가 어우러진 베스트입니다. 루즈한 실루엣으로 다양한 이너를 레이어하여 연출하기 좋으며, 부드럽고 입체적인 면과 울 혼방 소재를 사용하여 F/W 시즌에 활용하기 좋은 아이템입니다.', 'fitting_info': '187cm, 100 사이즈 모델이 100 사이즈 착용', 'additional_info': ['면과 울 혼방 소재', '베스트 디자인', '루즈한 실루엣'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D8NPC676N', 'product_info': '밑단까지 여유롭게 떨어지는 와이드 실루엣과 내추럴한 데님 텍스처가 어우러져 스타일리시한 매력이 돋보이는 팬츠입니다. 레그 라인 양옆에 부분적으로 턱을 잡아 볼륨감을 더해주었으며, 허리 라인 내부의 드로우스트링과 전체 밴딩으로 편안한 착용감을 전해줍니다. 탄탄한 100% 면 소재를 사용하여 흐트러짐 없는 아웃핏을 선보이는 아이템입니다.', 'fitting_info': '[WIDE FIT] 힙에서부터 밑단까지 여유있는 트렌디한 실루엣으로 캐주얼한 라인186cm, 105 사이즈 모델이 86 사이즈 착용187cm, 100 사이즈 모델이 86 사이즈 착용', 'additional_info': ['100% 면 소재', '앞면에 버튼과 지퍼 클로징', '허리 라인 내부에 드로우스트링과 전체 밴딩', '양옆과 힙에 포켓'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D8NPC676NP1', 'product_info': '밑단까지 여유롭게 떨어지는 와이드 실루엣과 내추럴한 데님 텍스처가 어우러져 스타일리시한 매력이 돋보이는 팬츠입니다. 레그 라인 양옆에 부분적으로 턱을 잡아 볼륨감을 더해주었으며, 허리 라인 내부의 드로우스트링과 전체 밴딩으로 편안한 착용감을 전해줍니다. 탄탄한 100% 면 소재를 사용하여 흐트러짐 없는 아웃핏을 선보이는 아이템입니다.', 'fitting_info': '[WIDE FIT] 힙에서부터 밑단까지 여유있는 트렌디한 실루엣으로 캐주얼한 라인187cm, 100 사이즈 모델이 82 사이즈 착용186cm, 105 사이즈 모델이 82 사이즈 착용', 'additional_info': ['100% 면 소재', '앞면에 버튼과 지퍼 클로징', '허리 라인 내부에 드로우스트링과 전체 밴딩', '양옆과 힙에 포켓'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D8NPC677N', 'product_info': '자연스러운 워싱 디테일과 밑단까지 여유롭게 떨어지는 와이드 실루엣이 어우러진 데님 팬츠입니다. 발등을 덮는 길이감이 특징이며, 약간의 신축성이 있는 면과 스판 혼방 소재를 사용하였습니다. 양옆과 힙에 총 5개의 포켓으로 클래식하게 디자인했습니다.', 'fitting_info': '[WIDE FIT] 힙에서부터 밑단까지 여유있는 트렌디한 실루엣으로 캐주얼한 라인187cm, 100 사이즈 모델이 86 사이즈 착용', 'additional_info': ['면과 스판 혼방 소재', '앞면에 버튼과 지퍼 클로징', '5포켓 디자인'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D8NPC680N', 'product_info': '자연스러운 워싱 디테일과 밑단까지 여유롭게 떨어지는 와이드 실루엣이 어우러진 데님 팬츠입니다. 발등을 덮는 길이감이 특징이며, 탄탄한 소재감의 100% 면 소재를 사용하였습니다. 앞면 레그 라인을 따라 주름을 더해 깔끔하게 완성했습니다. ', 'fitting_info': '[WIDE FIT] 힙에서부터 밑단까지 여유있는 트렌디한 실루엣으로 캐주얼한 라인187cm, 100 사이즈 모델이 86 사이즈 착용', 'additional_info': ['100% 면 소재', '앞면에 버튼과 지퍼 클로징', '양옆과 힙에 포켓'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D8TRN637N', 'product_info': '가슴 한쪽과 뒷면에 타임 옴므의 감각적인 컬러 프린팅이 돋보이는 티셔츠입니다. 부드럽고 신축성이 좋은 100% 면 소재를 사용하였으며, 여유로운 드롭 숄더 실루엣으로 완성했습니다. 밑단 양옆에 슬릿이 있으며, 넥라인과 소맷단을 리브 마감하였습니다.', 'fitting_info': '187cm, 100 사이즈 모델이 100 사이즈 착용186cm, 105 사이즈 모델이 100 사이즈 착용', 'additional_info': ['100% 면 소재', '가슴 한쪽과 뒷면에 프린팅', '드롭 숄더 실루엣'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D8TTO640N', 'product_info': '가슴 한쪽과 뒷면에 타임 옴므의 감각적인 컬러 프린팅이 돋보이는 티셔츠입니다. 부드럽고 신축성이 좋은 100% 면 소재를 사용하였으며, 여유로운 드롭 숄더 실루엣으로 완성했습니다. 캐주얼한 무드의 후드 디자인이며, 앞면 양옆에 입체적인 솔기 디테일을 더했습니다.', 'fitting_info': '187cm, 100 사이즈 모델이 105 사이즈 착용', 'additional_info': ['100% 면 소재', '가슴 한쪽과 뒷면에 프린팅', '드롭 숄더 실루엣'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D5TRN651N', 'product_info': '서로 다른 컬러의 원사를 섬세하게 믹스하여 마치 워싱한 듯한 외관을 선사하는 라운드넥 티셔츠입니다. 루즈한 실루엣이며, 내추럴한 100% 면 소재를 사용하였습니다. 유니크한 디자인으로 어디에나 포인트 아이템으로 연출하기 좋은 제품입니다. ', 'fitting_info': '189cm, 100 사이즈 모델이 105 사이즈 착용', 'additional_info': ['100% 면 소재', '라운드넥 디자인'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D3WSH722N', 'product_info': '내추럴한 조직감의 린넨 혼방 소재로 제작된 셔츠로 감각적인 컬러로 완성한 스트라이프 패턴이 시선을 끕니다. 백 요크 라인 중심과 소맷단에 턱을 잡아 자연스럽게 주름지는 실루엣을 연출하며, 언밸런스한 기장의 라운드 헴 디자인으로 디테일을 살렸습니다. ', 'fitting_info': '189cm, 100 사이즈 모델이 105 사이즈 착용', 'additional_info': ['린넨 혼방 소재', '앞면에 버튼 클로징', '소맷단 버튼 여밈', '라운드 헴 디자인'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D5TRN671N', 'product_info': '슬리브에 봉제 라인이 없어 자연스러운 실루엣을 연출하는 라운드넥 티셔츠입니다. 신축성 있는 면과 스판 혼방 소재를 사용하였으며, 독특하게 봉제한 어깨선과 밑단 양옆의 슬릿으로 포인트 디테일을 살렸습니다. 깔끔한 디자인과 차분하게 톤 다운된 컬러로 단품으로 입거나, 다양한 아우터에 이너로 연출할 수 있어 높은 활용도를 자랑하는 아이템입니다. ', 'fitting_info': '189cm, 100 사이즈 모델이 105 사이즈 착용', 'additional_info': ['면과 스판 혼방 소재', '밑단 양옆에 슬릿', '라운드넥 디자인'], 'brand2': 'TIME HOMME'}
# {'product_id': 'TH2D5WSH734N', 'product_info': '입체적인 텍스처와 체커보드 패턴이 어우러진 셔츠로 내부가 비치도록 디자인하였습니다. 가벼운 면 혼방 소재를 사용하였으며, 가슴 양옆에 큼직한 포켓을 더해 실용성을 겸비하였습니다. 여유롭게 떨어지는 드롭 숄더 실루엣이며, 루즈하게 디자인하여 이너를 입고 아우터처럼 가볍게 걸치기 좋은 아이템입니다.', 'fitting_info': '183m, 100 사이즈 모델이 105 사이즈 착용', 'additional_info': ['면 혼방 소재', '앞면에 버튼 클로징', '가슴 양옆에 포켓'], 'brand2': 'TIME HOMME'}

# %%
df = pd.read_csv("handsome_0504.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.read_csv("handsome_0504.csv")
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'handsome_0504.csv'

# %%
len(df)
# Out:
# 5628

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5628 entries, 0 to 5627
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_id        5628 non-null   object
#  1   brand             5628 non-null   object
#  2   fixed_price       5628 non-null   int64
#  3   discounted_price  5628 non-null   int64
#  4   url               5628 non-null   object
#  5   colors            5628 non-null   object
#  6   sizes             5628 non-null   object
#  7   rank_score        5628 non-null   float64
#  8   top               5628 non-null   object
#  9   middle            5628 non-null   object
#  10  small             5628 non-null   object
#  11  product_info      5624 non-null   object
#  12  fitting_info      5413 non-null   object
#  13  additional_info   5628 non-null   object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 615.7+ KB

# %%
df[(df['product_info'].isnull())]
# Out:
#         product_id       brand  fixed_price  discounted_price  \
# 4098  TH2D9WCT410N  TIME HOMME      1050000           1050000
# 4099  TH2D9WCT410N  TIME HOMME      1050000           1050000
# 5575  TH2D9WCT410N  TIME HOMME      1050000           1050000
# 5576  TH2D9WCT410N  TIME HOMME      1050000           1050000
#
#                                                     url  \
# 4098  ['/TH/2D/FW/TH2D9WCT410N_DN_C01.jpg', '/TH/2D/...
# 4099  ['/TH/2D/FW/TH2D9WCT410N_DN_C01.jpg', '/TH/2D/...
# 5575  ['/TH/2D/FW/TH2D9WCT410N_DN_C01.jpg', '/TH/2D/...
# 5576  ['/TH/2D/FW/TH2D9WCT410N_DN_C01.jpg', '/TH/2D/...
#
#                                          colors                 sizes  \
# 4098  ['DARK NAVY', 'DARK GRAY KHAKI', 'BLACK']  ['95', '100', '110']
# 4099  ['DARK NAVY', 'DARK GRAY KHAKI', 'BLACK']  ['95', '100', '110']
# 5575  ['DARK NAVY', 'DARK GRAY KHAKI', 'BLACK']  ['95', '100', '110']
# 5576  ['DARK NAVY', 'DARK GRAY KHAKI', 'BLACK']  ['95', '100', '110']
#
#       rank_score top   middle                             small product_info  \
# 4098      0.1000  남성      아우터                                코트          NaN
# 4099      0.1000  남성      아우터                                코트          NaN
# 5575      0.6875  남성  캡슐 컬렉션*  TIME HOMME : 23 WINTER EXCLUSIVE          NaN
# 5576      0.6875  남성  캡슐 컬렉션*  TIME HOMME : 23 WINTER EXCLUSIVE          NaN
#
#                                            fitting_info  \
# 4098  185cm, 100사이즈 모델, 3 사이즈 착용186cm, 105 사이즈 모델이 1...
# 4099  185cm, 100사이즈 모델, 3 사이즈 착용186cm, 105 사이즈 모델이 1...
# 5575  185cm, 100사이즈 모델, 3 사이즈 착용186cm, 105 사이즈 모델이 1...
# 5576  185cm, 100사이즈 모델, 3 사이즈 착용186cm, 105 사이즈 모델이 1...
#
#                                         additional_info
# 4098  ['램스 울과 캐시미어 혼방 소재', '앞면에 버튼 클로징', '양옆에 포켓', '...
# 4099  ['램스 울과 캐시미어 혼방 소재', '앞면에 버튼 클로징', '양옆에 포켓', '...
# 5575  ['램스 울과 캐시미어 혼방 소재', '앞면에 버튼 클로징', '양옆에 포켓', '...
# 5576  ['램스 울과 캐시미어 혼방 소재', '앞면에 버튼 클로징', '양옆에 포켓', '...

# %%
df['product_id'].value_counts()
# Out:
# TM2E5KCDC81WP1    9
# MN2E4KCD761WM     9
# CM2E4KOT531W      9
# CM2E3KCD917W      9
# TH2D8KVT031N      9
#                  ..
# MN2E0WSC902W      1
# O22E3WSC926W      1
# O22E4WSC931W      1
# OB2E1WSC405WP2    1
# TH2D9WSH717NM1    1
# Name: product_id, Length: 3267, dtype: int64

# %%
df[df['product_id'] == 'TH2D9WSH717NM1']
# Out:
#           product_id       brand  fixed_price  discounted_price  \
# 5623  TH2D9WSH717NM1  TIME HOMME       325000            325000
#
#                                                     url     colors  \
# 5623  ['/TH/2D/FW/TH2D9WSH717NM1_BG_C01.jpg', '/TH/2...  ['BEIGE']
#
#                      sizes  rank_score top   middle  \
# 5623  ['95', '100', '105']    0.058824  남성  캡슐 컬렉션*
#
#                                small  \
# 5623  TIME HOMME : 23 FALL EXCLUSIVE
#
#                                            product_info  \
# 5623  부드럽고 입체감 있는 100% 면 소재와 앞뒤 기장이 다른 언밸런스 헴 디자인이 어...
#
#                        fitting_info  \
# 5623  186cm, 105 사이즈 모델이 105 사이즈 착용
#
#                                         additional_info
# 5623  ['100% 면 소재', '앞면에 버튼 클로징', '소맷단 버튼 여밈', '언밸런스...
