# %%
import time
from bs4 import BeautifulSoup
import requests

# %%
ITEMS_COUNT = 100

# %%
# 사용자 에이전트
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:60.0) Gecko/20100101 Firefox/60.0',
    'Referer': 'https://www.musinsa.com/',
    'Accept-Language': 'en-US,en;q=0.5'
}

# %%
middle_category_nums = ['001006', '001004', '001005', '001010', '001002', '001003',
                        '001001', '001011', '001013', '001008', '002022', '002001',
                        '002002', '002025', '002017', '002003', '002020', '002019',
                        '002023', '002018', '002004', '002008', '002007', '002024',
                        '002009', '002013', '002012', '002016', '002021', '002014',
                        '002006', '002015', '003002', '003007', '003008', '003004',
                        '003009', '003005', '003010', '003011', '003006', '002006',
                        '002007', '002008', '022001', '022002', '022003']

# %%
def get_response(url, headers):

    # GET 요청
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'lxml')
    time.sleep(0.5)

    return soup

# %%
def get_items(num):
    
    url = f'https://www.musinsa.com/categories/item/{num}?d_cat_cd={num}&brand=&list_kind=small&sort=sale_high&sub_sort=1d&page=1&display_cnt=90&exclusive_yn=&sale_goods=&timesale_yn=&ex_soldout=&plusDeliveryYn=&kids=&color=&price1=&price2=&shoeSizeOption=&tags=&campaign_id=&includeKeywords=&measure='
    
    product_links = []
    flag = 0
    page = 1
    while flag == 0:
        
        soup = get_response(url, headers)

        products = soup.select('a.img-block')
        
        for product in products:
            product_links.append(product['href'].replace('//', 'https://'))
            if len(product_links) == ITEMS_COUNT:
                flag = 1
                break

        page += 1
        url = f'https://www.musinsa.com/categories/item/{num}?d_cat_cd={num}&brand=&list_kind=small&sort=sale_high&sub_sort=1d&page={page}&display_cnt=90&exclusive_yn=&sale_goods=&timesale_yn=&ex_soldout=&plusDeliveryYn=&kids=&color=&price1=&price2=&shoeSizeOption=&tags=&campaign_id=&includeKeywords=&measure='

    return product_links

# %%
def extract_one_review(review, product_num):
    # 댓글 단 사람
    name = review.select('p.review-profile__name')[0].text
    
    # 메타 데이터
    meta_dict = {}
    metas = review.select('li.review-evaluation--type3__item')
    for meta in metas:
        key, value = meta.text.split(' ', 1)  # 공백을 기준으로 처음 나오는 부분만 분리
        meta_dict[key] = value

    # 리뷰 내용
    content = review.select('div.review-contents__text')[0].text

    # 배지
    badge = review.select('span.review-evaluation-button--type3__count')

    # 도움돼요
    helpful = badge[0].text

    # 스타일 좋아요
    try:
        style_good = badge[1].text
        
    except:
        style_good = None

    # 별 개수
    star_percentage = review.select('span.review-list__rating__active')[0]['style']

    if star_percentage == 'width: 100%':
        star = 5
    elif star_percentage == 'width: 80%':
        star = 4
    elif star_percentage == 'width: 60%':
        star = 3
    elif star_percentage == 'width: 40%':
        star = 2
    elif star_percentage == 'width: 20%':
        star = 1
    else:
        star = 0

    data = {
        'product_num': product_num,
        'name': name,
        'meta_data': meta_dict,
        'content': content,
        'helpful': helpful,
        'style_good': style_good,
        'star': star
    }

    return data

# %%
def extract_page_review_info(soup, product_num):
    one_page_reviews = []
    reviews = soup.select('div.review-list')
    for review in reviews:
        review_dict = extract_one_review(review, product_num)
        one_page_reviews.append(review_dict)
        
    return one_page_reviews

# %%
def main():
    all_product_links = []
    for middle_category_num in middle_category_nums:
        product_links = get_items(middle_category_num)
        all_product_links += product_links
        print(len(all_product_links), all_product_links[-1]) 

    product_nums = [link.split('/')[-1] for link in all_product_links]

    all_reviews = []
    for product_num in product_nums:
        review_types = ['style', 'goods', 'photo']
        product_num = str(product_num)
        for review_type in review_types:
            page_num = 1

            while True:
                url = f'https://goods.musinsa.com/api/goods/v2/review/{review_type}/list?similarNo=0&sort=up_cnt_desc&selectedSimilarNo={product_num}&page={page_num}&goodsNo={product_num}&rvck=202404150551&_=1713416512533'
                soup = get_response(url, headers)
                
                if not soup.select('p.review-profile__name'):
                    break   

                one_page_reviews = extract_page_review_info(soup, product_num)
                for one_page_review in one_page_reviews:
                    all_reviews.append(one_page_review)
                    print(one_page_review)
                    
                page_num += 1

# %%
if __name__ == '__main__':
    main()
# Out:
# 100 https://www.musinsa.com/app/goods/3750552
# 200 https://www.musinsa.com/app/goods/3475627
# 300 https://www.musinsa.com/app/goods/2909082
# 400 https://www.musinsa.com/app/goods/3778444
# 500 https://www.musinsa.com/app/goods/3845644
# 600 https://www.musinsa.com/app/goods/3260631
# 700 https://www.musinsa.com/app/goods/3901798
# 800 https://www.musinsa.com/app/goods/3135351
# 900 https://www.musinsa.com/app/goods/3730341
# 1000 https://www.musinsa.com/app/goods/3207139
# 1100 https://www.musinsa.com/app/goods/3773904
# 1200 https://www.musinsa.com/app/goods/2371128
# 1300 https://www.musinsa.com/app/goods/3538550
# 1400 https://www.musinsa.com/app/goods/3739254
# 1500 https://www.musinsa.com/app/goods/3453039
# 1600 https://www.musinsa.com/app/goods/2398621
# 1700 https://www.musinsa.com/app/goods/4001392
# 1800 https://www.musinsa.com/app/goods/3924850
# 1900 https://www.musinsa.com/app/goods/3776428
# 2000 https://www.musinsa.com/app/goods/3815384
# 2100 https://www.musinsa.com/app/goods/3961797
# 2200 https://www.musinsa.com/app/goods/3964109
# 2300 https://www.musinsa.com/app/goods/3804677
# 2400 https://www.musinsa.com/app/goods/3731223
# 2500 https://www.musinsa.com/app/goods/3758729
# 2600 https://www.musinsa.com/app/goods/3716923
# 2700 https://www.musinsa.com/app/goods/3952918
# 2800 https://www.musinsa.com/app/goods/3827970
# 2900 https://www.musinsa.com/app/goods/4050048
# 3000 https://www.musinsa.com/app/goods/4002367
# 3100 https://www.musinsa.com/app/goods/3046674
# 3200 https://www.musinsa.com/app/goods/4007997
# 3300 https://www.musinsa.com/app/goods/1868151
# 3400 https://www.musinsa.com/app/goods/3920059
# 3500 https://www.musinsa.com/app/goods/2116434
# 3600 https://www.musinsa.com/app/goods/1538936
# 3700 https://www.musinsa.com/app/goods/1432206
# 3800 https://www.musinsa.com/app/goods/3876841
# 3900 https://www.musinsa.com/app/goods/4040031
# 4000 https://www.musinsa.com/app/goods/2502974
# 4100 https://www.musinsa.com/app/goods/3816455
# 4200 https://www.musinsa.com/app/goods/3046674
# 4300 https://www.musinsa.com/app/goods/3804677
# 4400 https://www.musinsa.com/app/goods/3964109
# 4500 https://www.musinsa.com/app/goods/3942772
# 4600 https://www.musinsa.com/app/goods/3165147
# 4700 https://www.musinsa.com/app/goods/3901380
# {'product_num': '2474966', 'name': 'LV.5 떵 주', 'meta_data': {'사이즈': '커요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '한여름에 입어도 되겠다는 글을 봤어요.벌받았으면 좋겠어요. 근데 이쁘긴해요. ', 'helpful': '0', 'style_good': '0', 'star': 4}
# {'product_num': '2474966', 'name': 'LV.4 뉴비_cbba72d7dfd2', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요'}, 'content': '꼭 사보시는걸 추천드립니다 실제로 사면 사진 보다 더 이쁘고 착용감이 예상보다 훨씬 부드럽고 편합니다!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 별콩아', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '형이랑 같이 입으려고 또 구매했어용 이번엔 다른 색상도 구매했습니다 굿 ', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 mrchef', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요'}, 'content': '원래 니트 까실까실해서 잘안입는데 촉감도 좋고 많이 얇진 않은데 시원하고 좋네요. 사이즈도 제 몸을 커버 할 정도로 넉넉하게 나와서 너무 좋네요~ 다른 색상도 사고 싶어요~', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 JuNe준', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '얇아요', '촉감': '부드러워요'}, 'content': '꽈배기니트라 더울줄알았는데 생각보다 괜찮아서 놀랬고 핏은 약간 널널한오버핏 기장만 좀 줄었으면 더좋았을거같고 원단이 튼튼하진 않아서 보관잘해야되요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.7 TOJIBF', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '여름용 반팔니트로 딱이에요 가격도 적당해서 잘 산 것 같습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 B깐도', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '옷이 아주 촥 감기네요 느낌도 좋고 재질도 보들보들하네염 ', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 qdqdq2', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '약간 두께감이 있어서 초여름에는 괜찮을 거 같은데 한여름에는 조금 열이많으면 더울듯해요ㅋㅋ 저는 참고로 열이 많슴다..ㅎ', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 한스브로', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '스트릿하게 입기에 무난해유. 케이블 디테일이 그냥 깔끔한 패턴이어서 데일리로 좋은거 같슴다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 패완얼이다이놈', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '무난하게 어디든 코디가능한 니트카라티 인거 같아요 ', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 영쮸니', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '생각보다 크긴 하지만 옷 자체는 이쁜 것 같아서 좋습니당', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.7 강한_남자', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '베이지 컬러 구매 후 블랙 컬러도 구매했는데 역시 이쁘군요! ', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 Freddd', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '사이즈도 적당하고 퀄리티가 좋습니다 잘입을게요~', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 준스브', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '평범해요'}, 'content': '옷 진짜 핏 너무 이쁘고 저는 하나 더 살려구해요 너무너무 마음에듭니다 ㅠㅠ', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 귀여미라고해라', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '나쁘지 않은 데일리 아이템입니아카야하 !!!?!!그춍잉', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 호뤵', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '케이블 패턴이 있어 심심하지 않고 무난하게 입을 수 있어요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 Wsdga', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '디자인도 이쁘고 가격도 적당해서 자주 입는중입니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 mon2347', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '사이즈도 아주 좋고 조금 도톰하긴 하지만 예쁩니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 이구다', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '옷이 너무 크지도 않고 작지도 않아서 스타일 원하는대로 잘 되어서 좋앟어요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 폴워니', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '평범해요'}, 'content': '두께는 두꺼운데 저는 한여름까지도 입을만 할 것 같아요단, 데오드란트는 필수', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 오영흔', 'meta_data': {'사이즈': '커요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '좀 두거꺼워 덥긴한데 부드라워서 괜찮네요 그냥 기본 이쁘네요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 qumber', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': 'M시켰다가 애매하게 커서 s시켰는데 딱 맞게 이쁩니다!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 P0s1', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '니트치고는 얇은 편인거같고 어떤 스타일로 입어도 잘어울려요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 토트넘 홋스퍼 FC', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '아쉬워요', '포장': '꼼꼼해요'}, 'content': '감사히 잘 입겠습니다 너무나 만족하고 있는 중인', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 1벨', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '이쁘긴한데 한여름에 입기는 많이 더울 것 같아요', 'helpful': '0', 'style_good': '0', 'star': 4}
# {'product_num': '2474966', 'name': 'LV.6 주식안함', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '원하던 느낌이 나서 맘에둘어요 넣입 안할거같아서 s로 갔는데 딱 적당하네요 잘입겠습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 Fdghgj', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요'}, 'content': '완전 깔끔하고 이쁨 내가 생각하던 핏 그대로고 좋음', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 Groenning', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '이쁩니다 가성비 대박 좋아요 ㅎㅎ 약간 더운 소재인 것은 아쉽 ㅠ', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 203501', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '얇아요', '촉감': '부드러워요'}, 'content': ' 3만원대에 가성비로는 입기 좋아요. 그런데 마감이 살짝 아쉽네요.', 'helpful': '0', 'style_good': '0', 'star': 3}
# {'product_num': '2474966', 'name': 'LV.6 마구로스시', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '디자인과 색상이 마음에 들고어디든 잘 어울리는 느낌이라서 좋아요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 ioung99', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요'}, 'content': '저한테 맞는 s를 살까 고민 많이했는데 m도 괜찮은것같아요 두께는 두꺼워서 여름에는 더웠어요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.7 로리악', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '원하던 제품 세일할때 잘 샀습니다. 이쁘게 잘 입겠습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 wogurs', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요'}, 'content': '장점 옷이이쁨 부드러움 퀄리티 좋음단점 아래단 힘이없음 길이가 너무 김 개더움실측 길이 70맞음 보통 티셔츠 다 70으로 입는데 이건 옷이 축 늘어나서인지 체감 75정도는 되는거 같음그렇다고 s사기에는 너무 딱맞을듯', 'helpful': '0', 'style_good': '0', 'star': 4}
# {'product_num': '2474966', 'name': 'LV.5 뉴비_c9f436d2', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요'}, 'content': '데일리로 입기도 너무 좋구 자주 입을 거 같아요 너무 더울 때는 무리지만 실내에서 있을 땐 좋아요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 뉴비_f41a934f12d8', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '정말 만족스럽고 언제든 입을 수 있어서 좋습니다!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 돼지불백집사장', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '꽈배기 디자인이 너무 과하게 들어있지 않아서 좋습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 내도신사', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '가벼웅 무게에 꽈배기 포인트가 너무 이쁘고 색깔도 다양한 하의랑 잘 어울릴것 같습니다.', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 창미니05', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '그냥 핏 미쳣어요 사세요 여름에 좀 덥긴 하지만 강추', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 시호찡', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '큰사이즈도 나와서 만족스럽고 엄청부드러워요.약간 두께감이 있지만 핏이 이쁩니다.근데 엄청 더워요..', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 MINOKIO', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '정말 맘에드는 니트 가격도 괜찮고 깔끔해서 어디에나 입기 좋음', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 MXTAPE', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '배송도 빠르고 사이즈도 딱 좋아요! 봄에 입기 너무 좋습니다~', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 마구창', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '얇아요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '진짜 옷핏 미쳤구요 너무 자주 애용하는 아이템이 되었습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 이코노미 진', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '굉장히 이쁩니다.옷 팔 부분 롤업해서 입으면 더 괜찮네요.(사진은 롤업 안 한 상태입니다)', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 PILEN', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '니트라서 엄청 두껍고 더울줄 알았는데 입을만해요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 HHyeok_', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '사알짝 두껍지만 한여름에도 입을만 합니다총장이 조금 긴 느낌있고 밑 시보리부분..? 짱짱하진 않아용', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 행크7', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '옷이 짱짱하고 사이즈도 적당해서 마음에 듭니다~', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 건아아아', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '처음 입는 반팔니트인데 제 스타일하고 맞는것같아서 좋습니다!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 pacing_pipe', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '운동열심히 해서 팔 키우는게 더 예쁠것 같네요 동기를 심어주는 옷이라 생각했습니다.', 'helpful': '0', 'style_good': '0', 'star': 3}
# {'product_num': '2474966', 'name': 'LV.5 그라가스장', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '세일해서 싸게 잘샀어요. 좀 더운 재질이라 티안입고 입을 것 같네요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 나멩이', 'meta_data': {'사이즈': '커요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '색상 적당하고 오버핏이라 핏이 예쁩니다 다만 한여름에는 힘들 것 같아요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 작은근육고릴라', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '옷도 짱짱 하고 핏이 이뻐요 두꺼운 느낌은 없어요 부드럽고 굳굳', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 뉴비_52a57d85', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '키가 작은데도 옷이 딱 맞아서 좋네요 여름에 입기 정말 좋을 거 같아요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 멤버_dac9a9df623e', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요'}, 'content': '까끌까끌한거 없이 부드럽고요 기장이 길어서 넣입 안했을때도 예쁠것 같네요 다만 단추를 전부 잠궜을때 저에게는 목넓이가 딱 맞았어요 그거 외엔 전부 만족 추천합니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 갓성운', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요'}, 'content': '음 핏이랑 촉감 다 좋은데 처음에 입을때생여름이라 살짝 두꺼워서 땀이 나는데그 옷에서 나오는 검은작은실? 그게 많이 나옴세탁 한 2~3번 해야 그런게 안나오더라구욥', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 뉴비_6a8fa46af0ca', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '좋아요 색감 좋고. 핏감 좋고. 편하게 입기 추천드립니다', 'helpful': '0', 'style_good': '0', 'star': 4}
# {'product_num': '2474966', 'name': 'LV.5 y0o0ung', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '부드러워요'}, 'content': '두꺼워서 딱 지금 날씨나 봄에 입기 좋을듯합니다 ', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.7 현승s', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '엑스톤즈 꽈배기 니트 마음에 들어요 디자인 이뻐요!', 'helpful': '0', 'style_good': '0', 'star': 4}
# {'product_num': '2474966', 'name': 'LV.6 권여붕', 'meta_data': {'사이즈': '커요', '밝기': '어두워요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '이정도면 그냥 휘뚜루 빠뚜루 입기 너무 좋아요인생 반팔니트 찾았습니다~', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.7 삑카츄', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '니트 재질도 좋고 굉장히 핏도 이쁘게 잘 나오네요 잘 입을게요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 무채색좋아용', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '생각보다 부드럽고 막 덥지는 않네요 나시입는게 나을듯', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 ZzxxccV', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요'}, 'content': '까칠 까칠 할줄알았는데 은근 쫀득하고 이뻐요 하지만 이날씨에 입긴 쫌 덥네요..', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 notbitc', 'meta_data': {'사이즈': '커요', '밝기': '밝아요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요'}, 'content': '단추색이 완전 하얀줄 알았는데 아니여서 아쉬운감이 없지않아 있었지만 그마저도 매우 만족스러울정도로 꽈베기 니트 포인트도 좋고 퀄리티랑 촉감도 매우 만족스러움 여름에 입기 좋음 매우 추천', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 촘촘한초코칩', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '예뻐요! 한여름에 입기는 덥겠지만 부드럽고 만족합니다:)', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 뉴비_408b6d26', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '반팔니트 꽤부드럽고 너무 예쁘네요 많이많이 입고 다닐듯! 살이 좀 있는 편인데 태를 좀 가려주는것 같아요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 gwx', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '옷이 전체적으로 이쁘고 질도 너무 부드럽고 입었을 때 편할 거 같다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 마이비호일', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '전체적으로 이쁘고 몸에 잘 맞아서 좋은거같아요앞으로도 이 브랜드에서 자주 애용할거같아요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 픽시말리온', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '옷이 좀 박시해서 한사이즈 작게 주문하면 핏이 딱 맞습니다! 밑의 밴드도 적당해요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 개굴성민', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '팔부분이 헐렁하지 않고 딱 맞는 핏이라 좋았습니다 ', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 Remak', 'meta_data': {'사이즈': '커요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '이것저것 무난하게 매치해서 입을수있는 카라니트인것같아요암홀이 조금만 더 타이트했으면 더욱 좋았을것같아요!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 ekc004', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '가격대비 핏이랑 색상 모두 마음에 들어요! 잘 입을게요!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 55555555555555', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '172기준 오버하게 잘 맞는것같아요. 잘 입을게요!!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 뉴비_d718c18a30bf', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '배송 빠르고 저렴하게 구매해서 좋아요 생각보다 잘 늘어날거 같은 재질이긴 한데 가격대비는 괜찮아요 ', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.7 참좋네유', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '촉감 부드럽고 핏도 이쁜 거 같아요꽈배기는 역시 엑톤', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 권차안', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '최근 입어보기도 하고 구매한 반팔 니트 중 원탑입니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 꼬끄루', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '이뻐서 여름에 잘 입고 다닐만해요 시원하고 근데 좀 흐물흐물거리긴하네요', 'helpful': '0', 'style_good': '0', 'star': 4}
# {'product_num': '2474966', 'name': 'LV.3 멤버_511589367c2e', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '목 테두리가 포인트인 깔끔하고 예쁜 니트에요.여름에 입으면 당연히 더울 수 있어요!꽈배기 특성상 그런거니 덥다는 다른리뷰는 믿지마세요 ㅎㅎ', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 CMXIV', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '이쁜데 한여름에 입으니까 꽤 더웠어요.. 초여름이나 늦여름 때 입으면 좋을 듯..!!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 지훗', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '옷 잘 못입는데도 꽤 괜찮은거같고 오래 입을거 같으려', 'helpful': '0', 'style_good': '0', 'star': 3}
# {'product_num': '2474966', 'name': 'LV.6 토트넘 홋스퍼 FC', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '아쉬워요', '포장': '꼼꼼해요'}, 'content': '감사히 잘 입겠습니다 너무나 만족하고 있는 중인 ', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 승원우띠', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '무난하게 잘 입으로 같아요 근데 생각보다 두껍네요 한 여름에 입으면 되게 더울거 같아요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 케이엠에이치', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '좀 크긴 한데 이쁩니다.건조기 한 번 싸악 돌리면 핏 야무질듯', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 Alisn', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '배송도 빠르고 좋아요 옷은 약간 두께감이 있어요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.7 십자상처', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '다른색 두번째 구매고, 핏과 디자인 모두 맘에 듭니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 2x506', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '아주 잘입고 다녀요사이즈교환 빠르고좋았습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 패션왕처링', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '너무 더워지기 전에 입을 수 있는 반팔 니트에요.루즈 핏이라 살짝 크긴한데 예쁘게 잘 입을 수 있을 것 같아요.!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.7 만년샤스', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '저렴하게 잘 구입했습니다 착용감도 좋고 적당한 두께여서 너무 덥지도 않아요!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 뉴비_e49a7e403833', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '저처럼 체형이 있으신 분들은 살짝 두께감 있어야 하잖아요근데 이거 ㄹㅇ 내 인생템입니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 이노1234', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '세일할때 구매했는데 이 가격에 잘산거같고 두께도 적당해서 딱 좋습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.7 새내이범', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '얇아요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '생각보다 얇아서 자주 입을 듯해요 좋습니다 다른 색도 살 듯', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.7 참붕어구이', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '소매랑 기장이 좀 길어요 나머지는 다 괜찮습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 뉴비_f82d26b49701', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '아쉬워요', '포장': '꼼꼼해요'}, 'content': '꾸안꾸 느낌 좋아요 그리고 크기는 딱 적당하고 이쁨', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 너를그린우주', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '시크하면서도 캐주얼한 느낌이 좋네요 잘 입겠습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 뉴비_360ec3cc6dab', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '전 남색 카키 다 샀는데 다른 건 약간 탄탄한데 뭔가 검정색만 흐물흐물한 느낌.. 그리고 검정만 뭔가 어깨쪽 꽈배기가 구멍처럼 보임..ㅠ 다른 색은 짱짱해서 구멍같이 안 보이는데 ㅠㅠ암튼 옷 자체는 이쁘고 팔 기장 길어서 한두번 접어 입음 이뻐요', 'helpful': '0', 'style_good': '0', 'star': 4}
# {'product_num': '2474966', 'name': 'LV.5 E루기', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '선명해요', '두께감': '얇아요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '반팔니트는 처음 구매했는데 괜찮은거 같아요 생각보다 얇았어요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 스노우 파우더', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '무난합니다. 좋은 선택이라고 생각해요.부담없이 구매추천드립니다.', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 뉴비_9f7c65718f61', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '어께도 넓어보이고, 길이감이 완전 좋습니다.너무 길면 다리가 짧아 보이는데 딱 적당해서 좋아요.안으로 접어 넣어입기도 좋고요.재질은 부들부들하고, 비침이 없습니다.너무 얇지도 너무 두껍지도 않아서 지금같은 날씨에 딱입니다.봄과 가을에 입기 좋을듯.와 진짜 대박 예쁨!!!!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 집에옷이없다', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '평범해요', '배송': '아쉬워요', '포장': '꼼꼼해요'}, 'content': '너무 좋습니다 근데 배송이 너무 느랴서 아쉽에요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.7 형원', 'meta_data': {'사이즈': '보통이에요', '밝기': '밝아요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '체감 100정도? 넉넉하니 좋네요 키가 작나서 기장이 살짝 애매한듯', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 노소네', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '선명해요', '두께감': '얇아요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '꽈배기 모양이 예쁘고 밑단을 잡아주는 디자인이라서 좋네요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 gkdldbb', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '사이즈 미스 안 나고 잘 맞아서 좋아요 ㅎㅎ 촉감이 엄척 부드럽고 두께도 막 두껍지 않고 적당합니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 Kdu0929', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '얇아요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '생각보다 되게 얇은데 사이즈가 애매할 거 같았는데 예쁘네요 마감은 조금…', 'helpful': '0', 'style_good': '0', 'star': 4}
# {'product_num': '2474966', 'name': 'LV.5 낚지덮밥', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '밑단이 생각한거보다 길게 내쳐와서 정리가 생각보다 어려워요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 도비는 외근중', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '아쉬워요'}, 'content': '길이가 살짝 애매해서 뜨거운 물로 세탁 한번 해야할 것 같네요 160초중반대 분들이 s사이즈 입으시면 딱 맞을듯 해요', 'helpful': '0', 'style_good': '0', 'star': 4}
# {'product_num': '2474966', 'name': 'LV.5 의수박', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '생각보다 제품이 쫀쫀하고 너무 마음에 드는 제품이에요!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 안녕하이용', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '어깨부분이 작아서 소매가 좀 올라가 있지만 그래도 꽈배기 니트이다 보니깐 잘 어울리네요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 맫오빠', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '평범해요'}, 'content': '옷도 투툼하고 원단도 좋아서 잘 입고다녔어요 한여름에는 더울거 같아요 선선한 가을까지도 가능할 듯', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 그릉빙이', 'meta_data': {'사이즈': '커요', '밝기': '어두워요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '부드러워요'}, 'content': '한여름에 입기에는 엄청 덥고 날씨 조금 선선한 봄이나 여름 막바지에 입으면 덥지도 않고 이쁘게 입을 수 있을 것 같습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 송민건', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요'}, 'content': '데일리로 입기도 좋고 꾸며입을때도 코디에 부담이 없어서 좋아요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 Kd5515', 'meta_data': {'사이즈': '커요', '밝기': '밝아요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '부드러워요'}, 'content': '맨살에 닿았을 때 부드럽긴 하나 사이즈가 좀 크고 피부에 좀 묻어나는 경향이 있어요 그래도 가격대비 만족합니다이 ~', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 멤버_65102f7ff140', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요'}, 'content': '너무 예뻐요. 검은색이어도 꽈배기 무늬 때문에 심심하지 않고 단추를 채울 수도, 오픈카라로도 활용이 가능해서 좋습니다. 밑에 시보리는 단단하지 않아서 넣입을 추천합니다.', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 Js101', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '핏 이쁘고 진짜 잘 입고 있습니다 다른색도 구매 하고싶어여', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 seo0320', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요'}, 'content': '여름에 입기는 조금 더운데 옷은 이쁘고 부드럽네요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 특수이모티콘', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '거칠어요'}, 'content': '많이 두꺼워요 그리고 좀 까칠거려서 입으면 몸이 근질 거려요근데 옷이 이뻐서 참아야죠', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 엉치살', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '아뻥용 긍데 8월엔 더우ㅗㅆ어용. 9눨에 입으면 좋을거같아용', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 연두색연두부', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '꽈배기 무늬가 상당히 귀엽고 핏이 너무 깜찍하게 잘나오네요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 whrop', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '남친룩같이 깔끔하고 이쁘네요.제가 어깨는 좀 있습니다.', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 뉴비_342259b', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '이쁘고 생각보다 얇아요! 근데 확실히 덥긴 하네요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 준현 김', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '패턴이 유니크하고 반팔니트 처음 사보는 데 핏적으로 아주 만족스러웠습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 로꼬츄츄유', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '생각보다 두꺼워서 지금은 입기 좀 더운 제품이구요 이쁘고 편합니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 Heesay', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '여름용 꽈배기 니트 한개 마련하고싶었는데 포멀한 형식보다 힙하게 라인이 빠져서 몸매보정도 잘되고 좋습니다. 완젼 쨍한 햇빛 아래아니면 다 ok일듯~', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 밍잉옹', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '평범해요'}, 'content': '쪼오오금 더워요 지금 입긴무엇보다 입고 땀 흘리면 털들이 몸에 붙어요..물론 옷은 진짜 예뻐용', 'helpful': '0', 'style_good': '0', 'star': 4}
# {'product_num': '2474966', 'name': 'LV.5 뉴비_3db83d7b', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '평범해요'}, 'content': '진짜 예쁘긴한데 여름에 입기는 조금 더워요 약간 머슬핏 나오는 거 같아요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 뉴비_bc8acf6f90ca', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요'}, 'content': '예쁨, 하지만 두께가 어느정도 있어서 날 잘못 고르면 땀 뻘뻘 납니다 봄 가을에도 입을 수 있을 것 같고 한데 저는 배송 받자마자 한 번 빨지도 않고 입엌더니 옷이 몸에 묻어나서 살짝 지저분해 보였었어요 ㅠ', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 도라에몽과짱구', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '아주 좋아요 이쁘고 편하고 재질 굿굳굿 추천해요 너무너무 이쁩니다요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 뉴비_3ce2c281', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '조금 딱맞게 떨어져서 아쉽긴하지만 그래도 핏은 좋아서 만족합니다!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 장지금', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '이뻐요 살만 좀 빼면 더 이쁠거 같아요 몸좋으신분들 입으면 이쁜듯', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 옷사러와써오키', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '이렇게 입으시면 이쁘실것 같아요!! 헤헿 살짝위 머슬핏이 있는것 같아요!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 범버범1', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '후기보면 많이 두꺼워보였으나 생각보다 얇음 뚜벅이 기준 한여름엔 더울거같음 자차는 상관없음팔기장이 생각보다 김', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.7 삑카츄', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '니트 재질도 그렇고 굉장히 맘에 들어요 진짜 이뻐요 올여름 이것만 입을거 같아요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.7 MAYA J', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요'}, 'content': '편한 착용감에 트렌디한 핏이라 자주 입을거 같습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 봉구z', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '부드러워요'}, 'content': '가격대비 정말 퀄리티 좋고 너무 예쁩니다다만 한여름에는 두깨감때문에 입기 어려울듯합니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 여기뭐야?', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '좋네요 사세여 추천드립니다 그냥 조용히 하시고 사세요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 웅어러앙', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '사이즈 적당하고 옷 이뻐요 어떤 바지하고도 잘 어울릴거같습니다 ', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 즈대', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '평범해요'}, 'content': '옷 이쁩니다~한여름 아니면 입고다니 좋을 것 같네요~', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 맞선남', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '평범해요'}, 'content': '생각보다 두껍구 저한테m사이즈가 크네요 깔끔하게 입으시려면 s사이즈가 이쁠거같안ㄱ', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 kjyjjj', 'meta_data': {'사이즈': '커요', '밝기': '어두워요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '평범해요'}, 'content': '완전 한야름엔 입기 힘들고요 초여름이나 초가을엔 괜찮아요 되게 이쁘긴해요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 봄사랑', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '디자인도 예쁘고 촉감도 조아용~ 길이가 좀만 더 짧았으면 좋겠음', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 민교형', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '평범해요'}, 'content': '너무 두꺼워서 한여름에는 못입어요 근데 옷은 이뻐용', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 뉴비_feed48bf', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '사진이랑 똑같고 생각보다 두꺼워 보이는데 얇아요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 행복한눈사람', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요'}, 'content': '고급집니다.매치하기도 편하고 니트소재지만 덥지않고 좋습니다.', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 져슷프라이데이', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '선선한 여름에는 입을 수 있겠네요 단정하고 이뻐요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 먕허', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '완전 이쁩니다. 가성비로도 좋고 저렴한티 안 나서 좋네요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 하루삼끼텐동쌉가능', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '평소 XL입어서 L사이즈 시켰는데 안맞을까 걱정했는데 딱 여유입게 입고있어요 요즘 날씨에 최고의 아이템', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 mmode1', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요'}, 'content': '길이가 엄청 길어요 참고해서 사야할듯 옷은 이뻐요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 뀨주띠', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '배송도 빠르고 무난해서 데일리로 입기 좋은것 같습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.7 DaQQ', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '좋아요사이즈가 약간 넉넉해서 편하게 입을 수 있어요', 'helpful': '0', 'style_good': '0', 'star': 4}
# {'product_num': '2474966', 'name': 'LV.4 신크리갓', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '얇아요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '미디움 사이즈는 좀 오버핏으로 입어야 할거같아서 정핏 원하시면 스몰 추천해요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 팽이가멈추지않아', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '미니멀하고  꽈배기로 포인트줄수있어서 좋네요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 투예나은', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '기본템으로 너무 좋네요  가성비 갑입니다  구매 고민하지마시고 지루셈', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 artyxchkokl1zg', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '네이비색 사고 만족해서 하나 더 구매합니다~ 좋아요~', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 뉴비_e963481c', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '선명해요', '두께감': '얇아요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '실물이 더 이쁘네요.느즈막히 사긴 했지만 내년 여름이 기대됩니다.', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 페데리코발베르데', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '아쉬워요', '포장': '꼼꼼해요'}, 'content': '두꺼운 니트라서 체형보정도 되고 좋네요 아주좋아용', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 173.66', 'meta_data': {'사이즈': '커요', '밝기': '어두워요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '기장이 긴 편이라 넣어서 입으니까 굉장히 이쁜거 같습니다. 옷은 두꺼운 편이라 가을 날씨에 입기 좋을거 같아요 꽈베기 무늬가 굉장히 이쁘네요. 만족합니다!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 람새다', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '팔부분이 조금 짧았으면 완벽했을텐데 아쉽지만 예뻐요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 노란공원', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '사이즈가 생각보다 살짝 크긴 하지만, 오히려 크게 입는게 더 핏이 잘 사는 것 같습니다. 니트라 살짝 덥긴 하지만 밖에서 활동 많이 안하시면 충분히 사도 후회는 안할 것 같아요!', 'helpful': '0', 'style_good': '0', 'star': 4}
# {'product_num': '2474966', 'name': 'LV.5 딱딱딱딱대', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '엑스톤즈의 XTK016 대퍼딜 꽈배기 니트는 전설이다...', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 초코수니맘', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '아들이 m구매한다는거 구매후기보고 s로 주문했어요.니트는 딱!맞게 입어야 예쁠거 같아서 그런데 딱!맞게 예뻐요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 국밧', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '입으면서 살짝 털이 뭍어나오긴 하지만 빨면 괜찮아지네요 잘 입겠습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 나천인학이야', 'meta_data': {'사이즈': '커요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '받고 뜯었을때 정말 만족했고 배송도 빠르게 잘 왔습니다 사이즈도 적당한것 같고 꼬임도 이뻐요 추천드립니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 센톰12', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '사이즈도 잘 맞고 부드러워서 좋네요꽈배기 무늬가 예뻐요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 Breadz', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '네이비색을 첫구매하고 너무 만족스러워서 블랙도 재주문했는데 핏도 잘떨어지고 옷자체가 이뻐서 두번 만족하네요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 dustrain_', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '여름에 입기 좋아요 근데 단품으로 안입으면 더움', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 MDO', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '사이즈가 생각보다커요 근데 부들부들하고 좋습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 hooch12', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '기장이나 폼은 생각보다 넉넉하고요, 초가을에 입기 좋을정도로 두껍습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.7 비비선', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '옷이 엄청 이쁘네요꽈배기 디테일이 들어가서 무난한 룩에 포인트 주기 좋습니다!', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 뉴비_31652ad295ed', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '이거 진짜 너무 이쁨 세탁 후 변형도 딱히 없어서 좋음', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 10분거리', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '디자인도 예쁘고 핏도 예쁘게 잘 떨어집니다. 다만 두께가 좀 있어서 한여름에는 조금 입기 어려울것 같습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 안뇽하세으', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '핏도 예쁘고 재질도 엄청 좋아요!! 예뻐서 손이 많이 갑니당', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 ddddolng', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '짜임 촘촘하고 핏도 만족스러웠습니다 두께는 조금 있어요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 지산사거리', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '너무 맘에들고 추천드려요 자주 손이 가는 제품들', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 기기찹찹', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '반팔 니트 첫구매하는데 핏도 너무 괜찮고 색감도 너무 잘 맞는 것 같아요 !!! 앞으로 자주 입고 애용 할 것 같습니다.', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 세미포그', 'meta_data': {'사이즈': '보통이에요', '밝기': '밝아요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '니트특성상 살짝 두꺼운감은 없진안치만 그만큼 원단이 탄탄하고 툭 떨어지는 맛은 있네요 ㅎㅎ 너무더운 한여름보다 요즘 날씨에 무심한듯 입기ㅜ좋아보입니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 worjs', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '너무 이쁘고 어떤 바지에 입어도 다 잘어울려요 팔기장이 쫌만 짧았으면 더 좋았을거같아용', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 게임접었어요', 'meta_data': {'사이즈': '커요', '밝기': '어두워요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '생각보다 사이즈가 크네용 근데 빨면 좀 줄어들 거 같으니 감안하고 입으면 괜찮을 거 같아요', 'helpful': '0', 'style_good': '0', 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 내일도심심해', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '한번 빨고 입으셔야 합니다 옷 안감이 피부에 묻어나오네요 그외에는 만족하면서 입었습니다', 'helpful': '0', 'style_good': '0', 'star': 5}
# ...
# {'product_num': '2474966', 'name': 'LV.5 폶', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '여름에 두껍지도 가볍지도 않은 두께감에 잘 입었습니다.', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 월간허수아비', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '반팔니트 꽈배기 모양이 맘에 들어서 사봤는데 나쁘지않았습니다 다만 관리가 조금 힘들겠네요 한여름엔 x', 'helpful': '0', 'style_good': None, 'star': 4}
# {'product_num': '2474966', 'name': 'LV.7 아르지오', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '색상도 핏도 디자인도 너무 예쁘네요~ 강력추천합니다.', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 ㅎㅎㅡㅎ', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '생각햇던거보단 크지만 색감도 좋고 꾸안꾸로 입기 좋을 거 같아유', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 뉴비_518a7cfb3ca1', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '좋아여 입기도 편하거 보기도 좋고 예쁘게 입을 수 있겠네여', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 커비낫', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '너무 잘입고 있어요 ㅎㅎ 한여름에는 좀 더울수 있지만 더위 많이 안타면 갠찮아요', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 thisizneverthat', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '약간 두껍지만 상태도 좋고 촉감이 되게 부드러워요 옷걸이 낄 때 조심', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 윤탕쓰', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '거칠어요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '옷이쁜데 생각보다 두꺼워요지금 날씨에 입기좋아요', 'helpful': '0', 'style_good': None, 'star': 4}
# {'product_num': '2474966', 'name': 'LV.5 020819', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '사진으로 보는 것보다 실물이 더 예뻐요. 저는 엄청 잘 입고 다니네요~', 'helpful': '0', 'style_good': None, 'star': 4}
# {'product_num': '2474966', 'name': 'LV.6 왜이거밖에안사', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '가성비 좋게 질 구매한것 같아요! 다음에도 구매의향 있습니다.', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 Shim_S', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '사진이 이뻐서 별생각없이 샀는데 상상 그 이상으로 매우 만족작합니다.', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.8 매콤블랙', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '낭낭한 핏에 무난하게 코디하기 편해요 촉감도 부드럽고 좋습니다!', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 뉴비_22be5a06ff0c', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '검은색 보푸라기 지옥 꼭 세탁 3번이상하고 입으세요', 'helpful': '0', 'style_good': None, 'star': 3}
# {'product_num': '2474966', 'name': 'LV.5 승수ㅗ', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '좀 길긴하고 여름에 좀 덥긴한데 ㄷ자인이랑 촉감은 너무 좋아요', 'helpful': '0', 'style_good': None, 'star': 4}
# {'product_num': '2474966', 'name': 'LV.4 뉴비_4d8f66a8', 'meta_data': {'사이즈': '커요', '밝기': '보통이에요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '약간 두꺼운 감이 있긴한데 옷이 너무 예쁘고 핏이 좋습니다', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 seoooooook', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '여름에 입기 편하고 디자인도 이쁘고 가격대도 괜찮고 좋네요', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 부엉이는부엉', 'meta_data': {'사이즈': '커요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '보풀이 많이 일어나고 생각한 사이즈보다 컸습니다', 'helpful': '0', 'style_good': None, 'star': 4}
# {'product_num': '2474966', 'name': 'LV.3 날죽여봐', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '아쉬워요', '포장': '꼼꼼해요'}, 'content': '배송은 느리긴 햇지만 너무 맘에 들어요!! 또 배송 생각하고 있어요', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 고물쥐', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '시보리가 짱짱하고 팔 위치가 높아서 운동좀 하신분들이 맛있을듯한 핏이 나옵니다 넣입하면 비율도 좋아보임', 'helpful': '0', 'style_good': None, 'star': 4}
# {'product_num': '2474966', 'name': 'LV.3 김도현0111', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '색감도 예쁘고 사이즈도 딱 맞아서 좋아요 배송도 빨라서 좋았어요', 'helpful': '0', 'style_good': None, 'star': 4}
# {'product_num': '2474966', 'name': 'LV.5 브론즈_d8c55f2381c', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '사이즈 잘 맞습니다. 맨살에 입어도 까끌거리지 않고 부드럽습니다.', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 D루피', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '두꺼워요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '새로 산 바지랑 같이 입으려고 구매했는데 괜찮네요', 'helpful': '0', 'style_good': None, 'star': 4}
# {'product_num': '2474966', 'name': 'LV.5 moooosinsa', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '세탁후에도 크기 변화없고 디자인도 이쁘고 맘에들어여', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 qkralsg', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '가성비가 좋고 옷도 깔끔합니다. 근데 팔이 조금 애매하게 길어요', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 aswefv', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '아쉬워요', '포장': '꼼꼼해요'}, 'content': '배송이 느려서 살짝 아쉬웠지만 옷 자체가 너무 예뻐서 좋았어요', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.3 뉴비_f2efe2d4', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '아쉬워요', '포장': '꼼꼼해요'}, 'content': '배송은 조금 아쉬운감이 있었고 이가격 이정도 퀄이면 살만 하다고 봅니다.', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 김해시 김찬호', 'meta_data': {'사이즈': '커요', '밝기': '어두워요', '색감': '선명해요', '두께감': '두꺼워요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '생각보다 많이 두꺼워서 한여름엔 절대 못 입을 거 같네요', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 아이유는 크런키를 좋아해', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '일단 맘에 들어요 다음에도 살게요 사랑해요~ 굿굿숫', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 뉴비_d5b040ad', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '평범해요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '데일리로 편하게 입기 딱 좋습니다 최근들어 자주 입어요', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 gwx', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '옷이 전체적으로 이쁘고 질도 너무 부드럽고 입었을 때 편할 거 같다', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.6 옷좀그만사랑', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '선명해요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '아쉬워요', '포장': '꼼꼼해요'}, 'content': '액스톤즈 답게 스트릿 무드가 한뺨 묻어있는 캐주얼 티입니다', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.5 돌채엔쉬바나', 'meta_data': {'사이즈': '보통이에요', '밝기': '보통이에요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '개인적으로는기장이좀길게느껴지지만괜찮아요', 'helpful': '0', 'style_good': None, 'star': 5}
# {'product_num': '2474966', 'name': 'LV.4 띵똥호', 'meta_data': {'사이즈': '보통이에요', '밝기': '어두워요', '색감': '보통이에요', '두께감': '보통이에요', '촉감': '부드러워요', '배송': '빨라요', '포장': '꼼꼼해요'}, 'content': '아직 밖에서 입어보지는 못했지만 시착해봤을때 느낌이 부드럽고 가을에 자주자주 입을 것 같은 삘이 딱 꽂히는 아주 예쁜 옷인거같아요!! 단정해서 아무데나 잘 매칭할 수 있을거같아 아주 마음에 듭니다', 'helpful': '0', 'style_good': None, 'star': 5}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 if __name__ == '__main__':
# ----> 2     main()
#
# Cell In[9], line 19, in main()
#      17 while True:
#      18     url = f'https://goods.musinsa.com/api/goods/v2/review/{review_type}/list?similarNo=0&sort=up_cnt_desc&selectedSimilarNo={product_num}&page={page_num}&goodsNo={product_num}&rvck=202404150551&_=1713416512533'
# ---> 19     soup = get_response(url, headers)
#      21     if not soup.select('p.review-profile__name'):
#      22         break
#
# Cell In[5], line 4, in get_response(url, headers)
#       1 def get_response(url, headers):
#       2
#       3     # GET 요청
# ----> 4     response = requests.get(url, headers=headers)
#       5     soup = BeautifulSoup(response.text, 'lxml')
#       6     time.sleep(0.5)
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     484     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#     502     raise ConnectionError(err, request=request)
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File c:\Users\songhow53\anaconda3\Lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File c:\Users\songhow53\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\songhow53\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\songhow53\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\songhow53\anaconda3\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\songhow53\anaconda3\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:
