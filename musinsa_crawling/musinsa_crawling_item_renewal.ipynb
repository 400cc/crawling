# %%
import time
from bs4 import BeautifulSoup
import pandas as pd
import requests
import json
import re
import datetime

# %%
ITEMS_COUNT = 100

# %%
middle_category_nums = ['001006', '001004', '001005', '001010', '001002', '001003',
                        '001001', '001011', '001013', '001008', '002022', '002001',
                        '002002', '002025', '002017', '002003', '002020', '002019',
                        '002023', '002018', '002004', '002008', '002007', '002024',
                        '002009', '002013', '002012', '002016', '002021', '002014',
                        '002006', '002015', '003002', '003007', '003008', '003004',
                        '003009', '003005', '003010', '003011', '003006', '020006',
                        '020007', '020008', '022001', '022002', '022003']

# %%
len(middle_category_nums)
# Out:
# 47

# %%
# 사용자 에이전트
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
}

timeout_settings = (60, 60)

# %%
def get_response(url, headers):

    # GET 요청
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'lxml')
    # time.sleep(0.5)

    return soup

# %%
import numpy as np

def get_items(num):
    
    url = f'https://display.musinsa.com/display/api/v2/categories/ITEM/goods?siteKindId=musinsa&sex=A&sortCode=1d&categoryCode={num}&size={ITEMS_COUNT}&page=1'
    
    response = requests.get(url, headers=headers)
    products = response.json()['data']['goodsList']
    product_links = []
    for product in products:
        product_link = product['linkUrl']
        product_links.append(product_link)
    
    

    product_links = np.array(product_links)

    rankings = np.arange(1, len(product_links) + 1)
    total_items_count = np.full(len(product_links), len(product_links))

    product_links = np.column_stack((product_links, rankings, total_items_count))

    return product_links.tolist()

# %%
def get_item_info(item_url):
    soup = get_response(item_url, headers)
    try:
        info = soup.find_all('script', {'type':'text/javascript'})[2]
    except:
        return
    info = info.string

    pattern = re.compile(r'window\.__MSS__\.product\.state\s*=\s*(\{.*?\});', re.DOTALL)
    match = pattern.search(info)
    info = match.group(1)
    
    return json.loads(info)

# %%
def extract_favorite_num(goodsNo):
    url = 'https://like.musinsa.com/like/api/v2/liketypes/goods/counts'
    data = {"relationIds":[str(goodsNo)]}
    response = requests.post(url, json=data)
    soup = BeautifulSoup(response.text, 'lxml')
    info = soup.string
    favorites = json.loads(info)['data']['contents']['items'][0]['count']

    return favorites

# %%
def extract_needs_info(item_info):
    # 무신사 상품번호
    product_id = item_info['goodsNo']

    # 대분류
    top = item_info['category']['categoryDepth1Title']

    # 중분류
    middle = item_info['category']['categoryDepth2Title']

    # 브랜드 명명
    brand = item_info['brand']

    # 품번
    product_num = item_info['styleNo']

    # 좋아요 수
    likes = extract_favorite_num(product_id)

    # 무신사 판매가
    fixed_price = item_info['goodsPrice']['originPrice']

    # 무신사 회원가
    discounted_price = item_info['goodsPrice']['minPrice']

    # 상품 이미지 : 리스트에 str로 저장. 필요하면 수정
    image_urls = []
    image_urls.append(item_info['thumbnailImageUrl'])
    goodsImages = item_info['goodsImages']
    for goodsImage in goodsImages:
        image_urls.append(goodsImage['imageUrl'])

    stat_url = f'https://goods-detail.musinsa.com/goods/{product_id}/stat'
    response = requests.get(stat_url, headers=headers, timeout=timeout_settings)
    try:
        add_data = response.json()
    except:
        pass
    
    # 누적 판매
    try:
        cumulative_sales = add_data['data']['purchase']['total']
    except:
        cumulative_sales = None

    # 나이
    try:
        ages = add_data['data']['purchase']['rates']
        ages = {key: f"{value}%" for key, value in ages.items()}
        under_18 = f"{ages['AGE_UNDER_18']}%"
        age_19_to_23 = f"{ages['AGE_19_TO_23']}%"
        age_24_to_28 = f"{ages['AGE_24_TO_28']}%"
        age_29_to_33 = f"{ages['AGE_29_TO_33']}%"
        age_34_to_39 = f"{ages['AGE_34_TO_39']}%"
        over_40 = f"{ages['AGE_OVER_40']}%"
    except:
        under_18, age_19_to_23, age_24_to_28, age_29_to_33, age_34_to_39, over_40 = None, None, None, None, None, None

    # 성비
    try:
        male = int(add_data['data']['purchase']['male'])
        female = int(add_data['data']['purchase']['female'])
        total_count = male + female
        male_percentage = int(round((male / total_count) * 100, -1))
        female_percentage = int(round((female / total_count) * 100, -1))

    except:
        male_percentage = None
        female_percentage = None

    # 대분류
    categoryDepth1Title = item_info['category']['categoryDepth1Title']

    # 중분류
    categoryDepth2Title = item_info['category']['categoryDepth2Title']


    data = {
        'product_id': product_id,
        'top': top,
        'middle': middle,
        'brand': brand,
        'product_num': product_num,
        'likes': likes,
        'fixed_price': fixed_price,
        'discounted_price': discounted_price,
        'categoryDepth1Title': categoryDepth1Title,
        'categoryDepth2Title': categoryDepth2Title,
        'url': image_urls,
        'cumulative_sales': cumulative_sales,
        'under_18': under_18,
        '19_to_23': age_19_to_23,
        '24_to_28': age_24_to_28,
        '29_to_33': age_29_to_33,
        '34_to_39': age_34_to_39,
        'over_40': over_40,
        'male_percentage': male_percentage,
        'female_percentage': female_percentage,   
    }

    return data

# %%
def get_rank_score(ranking, item_count):
    rank_score = 1 - ((ranking - 1) / (item_count - 1))

    return rank_score

# %%
def main():
    all_product_links = []
    
    for middle_category_num in middle_category_nums:
        product_links = get_items(middle_category_num)
        all_product_links += product_links
        print(len(all_product_links), product_links[-1])
    
    items_list = []

    for item_url in all_product_links:
        item_info = get_item_info(item_url[0])
        
        if item_info is None: # get_item_info로 해당 상품 정보 못 가져왔을 때. 
            continue          # 필요에 맞게 수정 필요.

        needs_info = extract_needs_info(item_info)
        needs_info['rank_score'] = get_rank_score(int(item_url[1]) , int(item_url[2]))
        items_list.append(needs_info)
        print(needs_info)
    
    df = pd.DataFrame(items_list)

    today = datetime.date.today()
    formatted_date = today.strftime('%Y%m%d')
    
    df.to_csv(f'musinsa_{formatted_date}.csv', index=False)

# %%
if __name__ == "__main__":
    main()
# Out:
# 100 ['https://www.musinsa.com/app/goods/4055987', '100', '100']
# 200 ['https://www.musinsa.com/app/goods/3832875', '100', '100']
# 300 ['https://www.musinsa.com/app/goods/3880776', '100', '100']
# 400 ['https://www.musinsa.com/app/goods/2114743', '100', '100']
# 500 ['https://www.musinsa.com/app/goods/3773940', '100', '100']
# 600 ['https://www.musinsa.com/app/goods/3998729', '100', '100']
# 700 ['https://www.musinsa.com/app/goods/3817044', '100', '100']
# 800 ['https://www.musinsa.com/app/goods/4059643', '100', '100']
# 900 ['https://www.musinsa.com/app/goods/4074796', '100', '100']
# 1000 ['https://www.musinsa.com/app/goods/3395835', '100', '100']
# 1100 ['https://www.musinsa.com/app/goods/4060175', '100', '100']
# 1200 ['https://www.musinsa.com/app/goods/4130903', '100', '100']
# 1300 ['https://www.musinsa.com/app/goods/4026347', '100', '100']
# 1400 ['https://www.musinsa.com/app/goods/3752831', '100', '100']
# 1500 ['https://www.musinsa.com/app/goods/4140393', '100', '100']
# 1600 ['https://www.musinsa.com/app/goods/2485017', '100', '100']
# 1700 ['https://www.musinsa.com/app/goods/4141664', '100', '100']
# 1800 ['https://www.musinsa.com/app/goods/2508695', '100', '100']
# 1900 ['https://www.musinsa.com/app/goods/3767140', '100', '100']
# 2000 ['https://www.musinsa.com/app/goods/4156112', '100', '100']
# 2100 ['https://www.musinsa.com/app/goods/3931677', '100', '100']
# 2200 ['https://www.musinsa.com/app/goods/3964189', '100', '100']
# 2300 ['https://www.musinsa.com/app/goods/3804673', '100', '100']
# 2400 ['https://www.musinsa.com/app/goods/3732750', '100', '100']
# 2500 ['https://www.musinsa.com/app/goods/3747776', '100', '100']
# 2600 ['https://www.musinsa.com/app/goods/3715421', '100', '100']
# 2700 ['https://www.musinsa.com/app/goods/4025220', '100', '100']
# 2800 ['https://www.musinsa.com/app/goods/3842279', '100', '100']
# 2900 ['https://www.musinsa.com/app/goods/4027967', '100', '100']
# 3000 ['https://www.musinsa.com/app/goods/3933204', '100', '100']
# 3100 ['https://www.musinsa.com/app/goods/4087694', '100', '100']
# 3200 ['https://www.musinsa.com/app/goods/3285979', '100', '100']
# 3300 ['https://www.musinsa.com/app/goods/4050700', '100', '100']
# 3400 ['https://www.musinsa.com/app/goods/2273535', '100', '100']
# 3500 ['https://www.musinsa.com/app/goods/3823289', '100', '100']
# 3600 ['https://www.musinsa.com/app/goods/3770573', '100', '100']
# 3700 ['https://www.musinsa.com/app/goods/3253762', '100', '100']
# 3800 ['https://www.musinsa.com/app/goods/3071528', '100', '100']
# 3900 ['https://www.musinsa.com/app/goods/4136617', '100', '100']
# 4000 ['https://www.musinsa.com/app/goods/4041040', '100', '100']
# 4100 ['https://www.musinsa.com/app/goods/3402015', '100', '100']
# 4200 ['https://www.musinsa.com/app/goods/4094028', '100', '100']
# 4300 ['https://www.musinsa.com/app/goods/3374283', '100', '100']
# 4400 ['https://www.musinsa.com/app/goods/3300699', '100', '100']
# 4500 ['https://www.musinsa.com/app/goods/4057204', '100', '100']
# 4600 ['https://www.musinsa.com/app/goods/4163916', '100', '100']
# 4700 ['https://www.musinsa.com/app/goods/3966349', '100', '100']
# {'product_id': 4060643, 'top': '상의', 'middle': '니트/스웨터', 'brand': 'againstallodds', 'product_num': 'YJSTN05', 'likes': 9225, 'fixed_price': 103600, 'discounted_price': 36668, 'categoryDepth1Title': '상의', 'categoryDepth2Title': '니트/스웨터', 'url': ['/images/goods_img/20240416/4060643/4060643_17161837841458_500.jpg', '/images/prd_img/20240416/4060643/detail_4060643_17153155009499_500.jpg', '/images/prd_img/20240416/4060643/detail_4060643_17153155047796_500.jpg', '/images/prd_img/20240416/4060643/detail_4060643_17153155089029_500.jpg', '/images/prd_img/20240416/4060643/detail_4060643_17153155126553_500.jpg', '/images/prd_img/20240416/4060643/detail_4060643_17153155173579_500.jpg',
 'top': '상의', 'middle': '니트/스웨터', 'brand': 'branded', 'product_num': 'BRWLKN04BK', 'likes': 445, 'fixed_price': 79000, 'discounted_price': 61075, 'categoryDepth1Title': '상의', 'categoryDepth2Title': '니트/스웨터', 'url': ['/images/goods_img/20240502/4101358/4101358_17150610472476_500.jpg', '/images/prd_img/20240502/4101358/detail_4101358_17150610533537_500.jpg', '/images/prd_img/20240502/4101358/detail_4101358_17150610547554_500.jpg', '/images/prd_img/20240502/4101358/detail_4101358_17150610554328_500.jpg', '/images/prd_img/20240502/4101358/detail_4101358_17150610560654_500.jpg'], 'cumulative_sales': 269, 'under_18': '1%%', '19_to_23': '6%%', '24_to_28': '29%%', '29_to_33': '43%%', '34_to_39': '15%%', 'over_40': '6%%', 'male_percentage': 90, 'female_percentage': 10, 'rank_score': 0.8686868686868687}
# {'product_id': 3143788, 'top': '상의', 'middle': '니트/스웨터', 'brand': 'kiimuir', 'product_num': 'KBCU3KS001', 'likes': 8778, 'fixed_price': 39000, 'discounted_price': 18370, 'categoryDepth1Title': '상의', 'categoryDepth2Title': '니트/스웨터', 'url': ['/images/goods_img/20230313/3143788/3143788_17159297698722_500.jpg'], 'cumulative_sales': 6451, 'under_18': '3%%', '19_to_23': '19%%', '24_to_28': '29%%', '29_to_33': '25%%', '34_to_39': '13%%', 'over_40': '11%%', 'male_percentage': 90, 'female_percentage': 10, 'rank_score': 0.8585858585858586}
# {'product_id': 4154372, 'top': '상의', 'middle': '니트/스웨터', 'brand': 'unionblue', 'product_num': 'UNION-KN07FO', 'likes': 254, 'fixed_price': 79000, 'discounted_price': 54996, 'categoryDepth1Title': '상의', 'categoryDepth2Title': '니트/스웨터', 'url': ['/images/goods_img/20240524/4154372/4154372_17174014990501_500.jpg'], 'cumulative_sales': 99, 'under_18': '0%%', '19_to_23': '3%%', '24_to_28': '31%%', '29_to_33': '39%%', '34_to_39': '21%%', 'over_40': '6%%', 'male_percentage': 100, 'female_percentage': 0, 'rank_score': 0.8484848484848485}
# {'product_id': 4078467, 'top': '상의', 'middle': '니트/스웨터', 'brand': 'unionblue', 'product_num': 'UNION-KN07MU', 'likes': 1814, 'fixed_price': 79000, 'discounted_price': 61711, 'categoryDepth1Title': '상의', 'categoryDepth2Title': '니트/스웨터', 'url': ['/images/goods_img/20240423/4078467/4078467_17140536755436_500.jpg'], 'cumulative_sales': 825, 'under_18': '0%%', '19_to_23': '6%%', '24_to_28': '33%%', '29_to_33': '38%%', '34_to_39': '17%%', 'over_40': '6%%', 'male_percentage': 100, 'female_percentage': 0, 'rank_score': 0.8383838383838383}
# {'product_id': 2474966, 'top': '상의', 'middle': '니트/스웨터', 'brand': 'xtonz', 'product_num': 'xtk016BK', 'likes': 19914, 'fixed_price': 49000, 'discounted_price': 42292, 'categoryDepth1Title': '상의', 'categoryDepth2Title': '니트/스웨터', 'url': ['/images/goods_img/20220407/2474966/2474966_1_500.jpg', '/images/prd_img/20220407/2474966/detail_2474966_1_500.jpg', '/images/prd_img/20220407/2474966/detail_2474966_2_500.jpg', '/images/prd_img/20220407/2474966/detail_2474966_3_500.jpg', '/images/prd_img/20220407/2474966/detail_2474966_4_500.jpg'], 'cumulative_sales': 6938, 'under_18': '10%%', '19_to_23': '35%%', '24_to_28': '30%%', '29_to_33': '13%%', '34_to_39': '3%%', 'over_40': '9%%', 'male_percentage': 90, 'female_percentage': 10, 'rank_score': 0.8282828282828283}
# {'product_id': 4137477, 'top': '상의', 'middle': '니트/스웨터', 'brand': 'corrs', 'product_num': '5010618928', 'likes': 339, 'fixed_price': 130000, 'discounted_price': 45858, 'categoryDepth1Title': '상의', 'categoryDepth2Title': '니트/스웨터', 'url': ['/images/goods_img/
 'categoryDepth1Title': '상의', 'categoryDepth2Title': '후드 티셔츠', 'url': ['/images/goods_img/20240131/3835854/3835854_17066778414028_500.jpg', '/images/prd_img/20240131/3835854/detail_3835854_17066785235225_500.jpg'], 'cumulative_sales': 56, 'under_18': '11%%', '19_to_23': '29%%', '24_to_28': '18%%', '29_to_33': '16%%', '34_to_39': '8%%', 'over_40': '18%%', 'male_percentage': 60, 'female_percentage': 40, 'rank_score': 0.010101010101010055}
# {'product_id': 3832875, 'top': '상의', 'middle': '후드 티셔츠', 'brand': 'afterpray12', 'product_num': '241WSH202_SK', 'likes': 448, 'fixed_price': 159000, 'discounted_price': 152640, 'categoryDepth1Title': '상의', 'categoryDepth2Title': '후드 티셔츠', 'url': ['/images/goods_img/20240130/3832875/3832875_17097038695577_500.jpg'], 'cumulative_sales': 70, 'under_18': '1%%', '19_to_23': '17%%', '24_to_28': '30%%', '29_to_33': '39%%', '34_to_39': '4%%', 'over_40': '9%%', 'male_percentage': 90, 'female_percentage': 10, 'rank_score': 0.0}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[26], line 17, in main()
#      14 if item_info is None: # get_item_info로 해당 상품 정보 못 가져왔을 때.
#      15     continue          # 필요에 맞게 수정 필요.
# ---> 17 needs_info = extract_needs_info(item_info)
#      18 needs_info['rank_score'] = get_rank_score(int(item_url[1]) , int(item_url[2]))
#      19 items_list.append(needs_info)
#
# Cell In[24], line 18, in extract_needs_info(item_info)
#      15 product_num = item_info['styleNo']
#      17 # 좋아요 수
# ---> 18 likes = extract_favorite_num(product_id)
#      20 # 무신사 판매가
#      21 fixed_price = item_info['goodsPrice']['originPrice']
#
# Cell In[23], line 4, in extract_favorite_num(goodsNo)
#       2 url = 'https://like.musinsa.com/like/api/v2/liketypes/goods/counts'
#       3 data = {"relationIds":[str(goodsNo)]}
# ----> 4 response = requests.post(url, json=data)
#       5 soup = BeautifulSoup(response.text, 'lxml')
#       6 info = soup.string
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     484     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#     502     raise ConnectionError(err, request=request)
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File c:\Users\songhow53\anaconda3\Lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File c:\Users\songhow53\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\songhow53\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\songhow53\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\songhow53\anaconda3\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\songhow53\anaconda3\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
pd.read_csv("D:\kwangwoon\\2024_1\산학\products\products_0504\musinsa_0504_2.csv")
# Out:
#       product_id          top                 middle         brand  \
# 0        4071027          ?곸쓽  ?덊듃/?ㅼ썾??lafudgestore    LA 2789478
# 1        3143788          ?곸쓽       ?덊듃/?ㅼ썾??kiimuir    KBCU3KS001
# 2        2474966          ?곸쓽         ?덊듃/?ㅼ썾??xtonz      xtk016BK
# 3        4078476          ?곸쓽     ?덊듃/?ㅼ썾??unionblue  UNION-KN07GP
# 4        3143446          ?곸쓽       ?덊듃/?ㅼ썾??kiimuir    KBDUUKS005
# ...          ...          ...                    ...           ...
# 4695     4014271  ?ㅼ빱??濡깆뒪而ㅽ듃           oceanpacific  WOPC6SCSKZ21
# 4696     4011404  ?ㅼ빱??濡깆뒪而ㅽ듃          dunstforwomen   UDSK4B228I2
# 4697     4004707  ?ㅼ빱??濡깆뒪而ㅽ듃              enzoblues  242SPLSKT015
# 4698     4002604  ?ㅼ빱??濡깆뒪而ㅽ듃                 chicks    5009911067
# 4699     3997444  ?ㅼ빱??濡깆뒪而ㅽ듃                  toinq   T240MSK905W
#
#      product_num   likes fixed_price discounted_price  \
# 0           1415   78000       38329              ?곸쓽
# 1           6806   39000       26603              ?곸쓽
# 2          16760   49000       42292              ?곸쓽
# 3           1579   79000       61711              ?곸쓽
# 4           6495   49000       33433              ?곸쓽
# ...          ...     ...         ...              ...
# 4695          15   69000       50860      ?ㅼ빱??濡깆뒪而ㅽ듃
# 4696          21  119000      103893      ?ㅼ빱??濡깆뒪而ㅽ듃
# 4697           3   99000       76131      ?ㅼ빱??濡깆뒪而ㅽ듃
# 4698         429   69800       31154      ?ㅼ빱??濡깆뒪而ㅽ듃
# 4699          43   99000       90981      ?ㅼ빱??濡깆뒪而ㅽ듃
#
#                                     categoryDepth1Title  \
# 0     ?덊듃/?ㅼ썾??['/images/goods_img/20240419/4071027/...
# 1     ?덊듃/?ㅼ썾??['/images/goods_img/20230313/3143788/...
# 2     ?덊듃/?ㅼ썾??"['/images/goods_img/20220407/2474966...
# 3     ?덊듃/?ㅼ썾??['/images/goods_img/20240423/4078476/...
# 4     ?덊듃/?ㅼ썾??['/images/goods_img/20230313/3143446/...
# ...                                                 ...
# 4695  ['/images/goods_img/20240402/4014271/4014271_1...
# 4696  ['/images/goods_img/20240401/4011404/4011404_1...
# 4697  ['/images/goods_img/20240329/4004707/4004707_1...
# 4698  ['/images/goods_img/20240328/4002604/4002604_1...
# 4699  ['/images/goods_img/20240327/3997444/3997444_1...
#
#                                     categoryDepth2Title  ... Unnamed: 36  \
# 0                                                   510  ...         NaN
# 1                                                  5575  ...         NaN
# 2      '/images/prd_img/20220407/2474966/detail_2474...  ...         NaN
# 3                                                   761  ...         NaN
# 4                                                  3211  ...         NaN
# ...                                                 ...  ...         ...
# 4695                                                NaN  ...         NaN
# 4696                                                NaN  ...         NaN
# 4697                                                NaN  ...         NaN
# 4698                                                 35  ...         NaN
# 4699                                                NaN  ...         NaN
#
#      Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 4695         NaN         NaN         NaN         NaN         NaN         NaN
# 4696         NaN         NaN         NaN         NaN         NaN         NaN
# 4697         NaN         NaN         NaN         NaN         NaN         NaN
# 4698         NaN         NaN         NaN         NaN         NaN         NaN
# 4699         NaN         NaN         NaN         NaN         NaN         NaN
#
#      Unnamed: 43 Unnamed: 44 Unnamed: 45
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN
# 2            NaN         NaN         NaN
# 3            NaN         NaN         NaN
# 4            NaN         NaN         NaN
# ...          ...         ...         ...
# 4695         NaN         NaN         NaN
# 4696         NaN         NaN         NaN
# 4697         NaN         NaN         NaN
# 4698         NaN         NaN         NaN
# 4699         NaN         NaN         NaN
#
# [4700 rows x 46 columns]
