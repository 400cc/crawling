# %%
import time
from bs4 import BeautifulSoup
import pandas as pd
import requests
import json
import re

ITEM_COUNTS = 100

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36',
    'Display-Api-Key': 'VWmkUPgs6g2fviPZ5JQFQ3pERP4tIXv/J2jppLqSRBk='
}

# %%
middle_category_nums = ['10101201', '10101202', '10101203', '10101204', '10101205',
                        '10101206', '10101207', '10101208', '10101209', '10101210',
                        '10101211', '10101212']

# %%
def get_item_cds(middle_category_num, gender):
    url = 'https://api-display.wconcept.co.kr/display/api/v2/best/products'

    if gender == 'men':
        genderType = 'men'
    else:
        genderType = 'women'

    data = {
    "custNo": "",
    "dateType": "daily",
    "domain": 'WOMEN',
    "genderType": genderType,
    "depth1Code": "10101",
    "depth2Code": middle_category_num,
    "pageNo": 1,
    "pageSize": ITEM_COUNTS
    }

    response = requests.post(url, headers=headers, json=data)

    soup = BeautifulSoup(response.text, 'lxml')
    info = soup.string
    info = json.loads(info)
    info = info['data']['content']

    item_cds = []

    for item in info:
        item_cds.append(item['itemCd'])
        

    return item_cds

# %%
def get_item_payloads(item_cd):
    url = 'https://www.wconcept.co.kr/Ajax/GetProductsInfo'

    data = {'itemcds': item_cd}

    response = requests.post(url, headers=headers, data=data)

    soup = BeautifulSoup(response.text, 'lxml')
    info = soup.string
    info = json.loads(info)[0]

    item_cd = info['itemCd']
    medium_cd = info['category'][0]['mediumCd']
    category_cd = info['category'][0]['categoryCd']
    itemtypecd = info['itemTypeCd']

    item_payloads = [item_cd, medium_cd, category_cd, itemtypecd]
    
    print(item_payloads)
    
    return item_payloads

# %%
def get_one_review(i, soup, itemCd):
    # 구매 옵션과 사이즈정보 빼내기 용
    review_info = soup.select('div.pdt_review_info')[i]

    # 리뷰 id
    review_id = soup.select('div.product_review_reaction > div > button.link_txt.open-layer.open-pop_review_report')[i]['data-idxnum']
    
    # 구매 옵션
    try:
        option = review_info.select('div.pdt_review_option > p')[0].text.strip()
        option = option.split(':')[1].strip()
    except:
        option = None

    # 사이즈 정보
    try:
        cust_size_info = review_info.select('div.pdt_review_option > p')[1].text.strip()
        cust_size_info = cust_size_info.split(':')[1].strip()
    except:
        cust_size_info = None

    # 사이즈, 색상, 소재 빼내기 용
    try:
        sku = soup.select('ul.product_review_evaluation')[i]       

        # 사이즈
        size = sku.select('ul.product_review_evaluation > li > div > em')[0].text

        # 색상
        color = sku.select('ul.product_review_evaluation > li > div > em')[1].text

        # 소재
        texture = sku.select('ul.product_review_evaluation > li > div > em')[2].text
    
    except:
        size, color, texture = None, None, None



    # user id
    user_id = soup.select('p.product_review_info_right > em')[i].text

    # 작성 시간
    time = soup.select('p.product_review_info_right > span')[i].text

    # 리뷰 내용
    content = soup.select('p.pdt_review_text')[i].text.strip()

    # rating 정보
    rating_pct = soup.select('div.star-grade > strong[style]')[i]
    rating = re.findall(r'\d+', str(rating_pct))[0]
    rating = int(int(rating) / 20)

    # 좋아요 개수
    favorite = soup.select('button.like.btn_review_recommend')[i].text


    data = {
        'itemCd': itemCd,
        'review_id': review_id,
        'option': option,
        'cust_size_info': cust_size_info,
        'size': size,
        'color': color,
        'texture': texture,
        'user_id': user_id,
        'time': time,
        'content': content,
        'rating': rating,
        'favorite': favorite
    }

    return data

# %%
def get_reviews(item_payload):
    url = 'https://www.wconcept.co.kr/Ajax/ProductReViewList'
    i = 1
    one_goods_reviews = []
    while True:
        data = {'itemcd': item_payload[0],
            'pageIndex': i,
            'order': 1,
            'IsPrdCombinOpt': 'N',
            'mediumcd': item_payload[1],
            'categorycd': item_payload[2],
            'itemtypecd': item_payload[3]
            }

        response = requests.post(url, headers=headers, data=data)
        soup = BeautifulSoup(response.text, 'lxml')

        review_count = len(soup.select('p.pdt_review_text'))

        if review_count == 0:
            break
        
        for j in range(review_count):
            review = get_one_review(j, soup, item_payload[0])
            one_goods_reviews.append(review)
            print(review)
        
        i += 1

    return one_goods_reviews

# %%
def main():
    item_cds_list = []
    for gender in ['men', 'women']:
        for middle_category_num in middle_category_nums:
            item_cds = get_item_cds(middle_category_num, gender)
            item_cds_list += item_cds
    print(item_cds_list)

    item_payloads_list = []
    for item_cd in item_cds_list:
        item_payloads_list.append(get_item_payloads(item_cd))


    all_reviews = []

    for item_payloads in item_payloads_list:
        review_per_goods = get_reviews(item_payloads)
        if len(review_per_goods) == 0:
            continue
        else:
            all_reviews += review_per_goods

# %%
if __name__ == '__main__':
    main()
# Out:
# ['301320113', '303889468', '305773501', '305789331', '301047578', '305189021', '300926876', '301656743', '304476372', '301877425', '303215137', '303215135', '302496409', '305732048', '302315836', '302710513', '302746077', '300316793', '305029986', '305823508', '305713133', '301669040', '305686988', '302187308', '301451839', '301641271', '305713217', '303597901', '300732486', '305685959', '305685958', '305831716', '304226304', '301691668', '301691660', '304708371', '305789811', '305686017', '305773509', '305685943', '305714583', '301669257', '305730927', '305814070', '305773504', '305789813', '302298904', '305701210', '302138310', '301706943', '304833359', '305828181', '305778236', '305681168', '305712064', '305785978', '303452844', '305721451', '305352957', '302187370', '305817711', '305295133', '305694512', '305694511', '305816881', '301668826', '304210309', '302278634', '305706870', '300884347', '301844368', '301706578', '304191134', '301611495', '301081598', '301540079', '301902528', '303355452', '301854221', '302314220', '305733727', '301685744', '305787703', '304277140', '301827119', '301263214', '301252088', '301252078', '305771126', '301090900', '305430643', '304312680', '301691467', '302935519', '303583328', '301592469', '302273862', '301619099', '300945582', '303170611', '305687841', '301656756', '305686510', '301804029', '303437256', '305728209', '302747005', '302995192', '305773493', '305813145', '305682450', '305830519', '305765494', '305686512', '305743608', '302302048', '302755251', '302906184', '303436717', '301481949', '301606902', '305682434', '305814302', '305701664', '305765877', '301794081', '305827663', '302746918', '305682334', '305813143', '303583334', '305813147', '305408459', '305798052', '302907984', '302746593', '302849742', '305743615', '303442148', '305780418', '305830517', '305816492', '305337167', '305036031', '301909831', '305690981', '305682443', '305757225', '305743793', '305817553', '305787224', '302303120', '303442336', '303442153', '302907983', '305714812', '305820110', '305765869', '305765867', '305822970', '305778100', '302757656', '305732484', '305830527', '305788500', '305773535', '305744164', '305700404', '301639250', '301639249', '305708260', '303545024', '301765087', '301765086', '302187319', '302187318', '305792231', '305792212', '305792155', '305681158', '305727090', '305794403', '301811546', '301909951', '305764244', '302281876', '302281073', '305805451', '305794408', '300329222', '305826926', '302940870', '305771649', '305771656', '305814298', '305816500', '305816494', '302330115', '302330113', '302805277', '300984192', '300968436', '301772908', '301694969', '303128662', '301654812', '301221211', '302546986', '300968441', '305690977', '303203441', '302837458', '305723305', '300984191', '302669567', '302520851', '300968403', '305776089', '301695334', '302546995', '305777706', '305830521', '305752339', '301716336', '303228259', '302669563', '305811392', '302437032', '302739596', '305779022', '301654815', '303159489', '302686044', '305801638', '301225795', '305805260', '305832281', '305831345', '302524731', '305780395', '301709375', '301333198', '305830524', '300984190', '301695289', '302752023', '305798139', '301221208', '305691482', '301685234', '305724125', '300459824', '305683846', '305752338', '305723118', '305769006', '302546472', '303572801', '305788456', '301423840', '305765489', '305774075', '300968453', '301825553', '303145284', '305795159', '303814527', '302752013', '305788457', '302546991', '305836903', '305836861', '305836854', '305790582', '305794301', '305823544', '305823543', '305743497', '305707170', '305824433', '305777708', '305801658', '305801649', '305773592', '301795195', '302546471', '302267737', '305801870', '305788458', '305773447', '303273781', '301579258', '302942570', '302709246', '305824527', '302725662', '305692897', '303117382', '303287515', '303780965', '305284076', '305788468', '305788467', '305779077', '305749106', '303355363', '302676394', '3051871 ...
# ['301320113', 'M83985861', '27', '15']
# ['303889468', 'M83985861', '33', '15']
# ['305773501', 'M83985861', '28', '15']
# ['305789331', 'M83985861', '28', '15']
# ['301047578', 'M83985861', '30', '15']
# ['305189021', 'M83985861', '152', '15']
# ['300926876', 'M83985861', '28', '15']
# ['301656743', 'M83985861', '28', '15']
# ['304476372', 'M83985861', '151', '15']
# ['301877425', 'M83985861', '32', '15']
# ['303215137', 'M83985861', '151', '15']
# ['303215135', 'M83985861', '151', '15']
# ['302496409', 'M83985861', '29', '15']
# ['305732048', 'M83985861', '32', '15']
# ['302315836', 'M83985861', '28', '15']
# ['302710513', 'M83985861', '28', '15']
# ['302746077', 'M83985861', '151', '15']
# ['300316793', 'M83985861', '28', '16']
# ['305029986', 'M83985861', '33', '15']
# ['305823508', 'M83985861', '32', '15']
# ['305713133', 'M83985861', '28', '15']
# ['301669040', 'M83985861', '28', '15']
# ['305686988', 'M83985861', '28', '15']
# ['302187308', 'M83985861', '33', '15']
# ['301451839', 'M83985861', '32', '15']
# ['301641271', 'M83985861', '32', '15']
# ['305713217', 'M83985861', '152', '15']
# ['303597901', 'M83985861', '33', '15']
# ['300732486', 'M83985861', '30', '15']
# ['305685959', 'M83985861', '28', '15']
# ['305685958', 'M83985861', '28', '15']
# ['305831716', 'M83985861', '32', '15']
# ['304226304', 'M83985861', '28', '15']
# ['301691668', 'M83985861', '28', '15']
# ['301691660', 'M83985861', '28', '15']
# ['304708371', 'M83985861', '28', '15']
# ['305789811', 'M83985861', '32', '15']
# ['305686017', 'M83985861', '28', '15']
# ['305773509', 'M83985861', '27', '17']
# ['305685943', 'M83985861', '28', '15']
# ['305714583', 'M83985861', '151', '15']
# ['301669257', 'M83985861', '28', '15']
# ['305730927', 'M83985861', '28', '15']
# ['305814070', 'M83985861', '28', '15']
# ['305773504', 'M83985861', '28', '15']
# ['305789813', 'M83985861', '32', '15']
# ['302298904', 'M83985861', '28', '17']
# ['305701210', 'M83985861', '32', '15']
# ['302138310', 'M83985861', '151', '15']
# ['301706943', 'M83985861', '151', '15']
# ['304833359', 'M83985861', '31', '15']
# ['305828181', 'M83985861', '32', '15']
# ['305778236', 'M83985861', '28', '15']
# ['305681168', 'M83985861', '152', '15']
# ['305712064', 'M83985861', '28', '15']
# ['305785978', 'M83985861', '28', '15']
# ['303452844', 'M83985861', '32', '15']
# ['305721451', 'M83985861', '27', '15']
# ['305352957', 'M83985861', '32', '15']
# ['302187370', 'M83985861', '28', '15']
# ['305817711', 'M83985861', '29', '15']
# ['305295133', 'M83985861', '32', '15']
# ['305694512', 'M83985861', '32', '15']
# ['305694511', 'M83985861', '32', '15']
# ['305816881', 'M83985861', '28', '15']
# ['301668826', 'M83985861', '152', '15']
# ['304210309', 'M83985861', '32', '15']
# ['302278634', 'M83985861', '152', '15']
# ['305706870', 'M83985861', '152', '15']
# ['300884347', 'M83985861', '28', '15']
# ['301844368', 'M83985861', '30', '15']
# ['301706578', 'M83985861', '151', '15']
# ['304191134', 'M83985861', '28', '15']
# ['301611495', 'M83985861', '28', '15']
# ['301081598', 'M83985861', '30', '15']
# ['301540079', 'M83985861', '32', '15']
# ['301902528', 'M83985861', '152', '15']
# ['303355452', 'M83985861', '32', '15']
# ['301854221', 'M83985861', '151', '15']
# ['302314220', 'M83985861', '152', '15']
# ['305733727', 'M83985861', '28', '15']
# ['301685744', 'M83985861', '28', '15']
# ['305787703', 'M83985861', '27', '15']
# ['304277140', 'M83985861', '31', '15']
# ['301827119', 'M83985861', '152', '15']
# ['301263214', 'M83985861', '32', '15']
# ['301252088', 'M83985861', '32', '15']
# ['301252078', 'M83985861', '32', '15']
# ['305771126', 'M83985861', '27', '15']
# ['301090900', 'M83985861', '31', '15']
# ['305430643', 'M83985861', '151', '15']
# ['304312680', 'M83985861', '28', '15']
# ['301691467', 'M83985861', '32', '15']
# ['302935519', 'M83985861', '28', '15']
# ['303583328', 'M83985861', '151', '15']
# ['301592469', 'M83985861', '152', '15']
# ['302273862', 'M83985861', '149', '15']
# ['301619099', 'M83985861', '151', '15']
# ['300945582', 'M83985861', '27', '15']
# ['303170611', 'M83985861', '27', '15']
# ['305687841', 'M83985861', '45', '15']
# ['301656756', 'M83985861', '154', '15']
# ['305686510', 'M83985861', '45', '17']
# ['301804029', 'M83985861', '44', '15']
# ['303437256', 'M83985861', '45', '15']
# ['305728209', 'M83985861', '154', '15']
# ['302747005', 'M83985861', '45', '15']
# ['302995192', 'M83985861', '44', '15']
# ['305773493', 'M83985861', '45', '15']
# ['305813145', 'M83985861', '45', '15']
# ['305682450', 'M83985861', '45', '15']
# ['305830519', 'M83985861', '45', '15']
# ['305765494', 'M83985861', '45', '15']
# ['305686512', 'M83985861', '45', '15']
# ['305743608', 'M83985861', '45', '15']
# ['302302048', 'M83985861', '45', '15']
# ['302755251', 'M83985861', '44', '15']
# ['302906184', 'M83985861', '44', '15']
# ['303436717', 'M83985861', '45', '15']
# ['301481949', 'M83985861', '45', '15']
# ['301606902', 'M83985861', '45', '15']
# ['305682434', 'M83985861', '45', '15']
# ['305814302', 'M83985861', '45', '15']
# ['305701664', 'M83985861', '45', '15']
# ['305765877', 'M83985861', '45', '15']
# ['301794081', 'M83985861', '45', '15']
# ['305827663', 'M83985861', '45', '15']
# ['302746918', 'M83985861', '45', '15']
# ['305682334', 'M83985861', '45', '17']
# ['305813143', 'M83985861', '45', '15']
# ['303583334', 'M83985861', '45', '15']
# ['305813147', 'M83985861', '45', '15']
# ['305408459', 'M83985861', '45', '15']
# ['305798052', 'M83985861', '44', '17']
# ['302907984', 'M83985861', '45', '15']
# ['302746593', 'M83985861', '44', '15']
# ['302849742', 'M83985861', '44', '15']
# ['305743615', 'M83985861', '45', '15']
# ['303442148', 'M83985861', '45', '15']
# ['305780418', 'M83985861', '44', '15']
# ['305830517', 'M83985861', '45', '15']
# ['305816492', 'M83985861', '44', '15']
# ['305337167', 'M83985861', '45', '15']
# ['305036031', 'M83985861', '45', '15']
# ['301909831', 'M83985861', '45', '15']
# ['305690981', 'M83985861', '45', '15']
# ['305682443', 'M83985861', '45', '15']
# ['305757225', 'M83985861', '44', '15']
# ['305743793', 'M83985861', '44', '15']
# ['305817553', 'M83985861', '44', '15']
# ['305787224', 'M83985861', '44', '15']
# ['302303120', 'M83985861', '45', '15']
# ['303442336', 'M83985861', '45', '15']
# ['303442153', 'M83985861', '45', '17']
# ['302907983', 'M83985861', '45', '15']
# ['305714812', 'M83985861', '45', '15']
# ['305820110', 'M83985861', '45', '15']
# ['305765869', 'M83985861', '45', '15']
# ['305765867', 'M83985861', '45', '15']
# ['305822970', 'M83985861', '45', '15']
# ['305778100', 'M83985861', '44', '15']
# ['302757656', 'M83985861', '44', '15']
# ['305732484', 'M83985861', '45', '15']
# ['305830527', 'M83985861', '44', '15']
# ['305788500', 'M83985861', '44', '15']
# ['305773535', 'M83985861', '44', '15']
# ['305744164', 'M83985861', '154', '15']
# ['305700404', 'M83985861', '44', '15']
# ['301639250', 'M83985861', '45', '15']
# ['301639249', 'M83985861', '45', '17']
# ['305708260', 'M83985861', '154', '15']
# ['303545024', 'M83985861', '45', '15']
# ['301765087', 'M83985861', '44', '15']
# ['301765086', 'M83985861', '44', '15']
# ['302187319', 'M83985861', '44', '15']
# ['302187318', 'M83985861', '44', '15']
# ['305792231', 'M83985861', '45', '15']
# ['305792212', 'M83985861', '45', '15']
# ['305792155', 'M83985861', '45', '15']
# ['305681158', 'M83985861', '45', '15']
# ['305727090', 'M83985861', '45', '15']
# ['305794403', 'M83985861', '44', '15']
# ['301811546', 'M83985861', '45', '15']
# ['301909951', 'M83985861', '45', '15']
# ['305764244', 'M83985861', '45', '17']
# ['302281876', 'M83985861', '154', '15']
# ['302281073', 'M83985861', '45', '15']
# ['305805451', 'M83985861', '45', '15']
# ['305794408', 'M83985861', '44', '15']
# ['300329222', 'M83985861', '44', '15']
# ['305826926', 'M83985861', '45', '15']
# ['302940870', 'M83985861', '45', '15']
# ['305771649', 'M83985861', '45', '15']
# ['305771656', 'M83985861', '45', '15']
# ['305814298', 'M83985861', '45', '15']
# ['305816500', 'M83985861', '44', '15']
# ['305816494', 'M83985861', '44', '15']
# ['302330115', 'M83985861', '45', '15']
# ['302330113', 'M83985861', '45', '15']
# ['302805277', 'M83985861', '44', '15']
# ['300984192', 'M83985861', '34', '15']
# ['300968436', 'M83985861', '34', '15']
# ['301772908', 'M83985861', '34', '15']
# ['301694969', 'M83985861', '34', '15']
# ['303128662', 'M83985861', '34', '15']
# ['301654812', 'M83985861', '34', '15']
# ['301221211', 'M83985861', '34', '15']
# ['302546986', 'M83985861', '34', '15']
# ['300968441', 'M83985861', '34', '15']
# ['305690977', 'M83985861', '34', '15']
# ['303203441', 'M83985861', '34', '15']
# ['302837458', 'M83985861', '34', '15']
# ['305723305', 'M83985861', '34', '15']
# ['300984191', 'M83985861', '34', '15']
# ['302669567', 'M83985861', '34', '15']
# ['302520851', 'M83985861', '155', '15']
# ['300968403', 'M83985861', '34', '15']
# ['305776089', 'M83985861', '34', '15']
# ['301695334', 'M83985861', '34', '22']
# ['302546995', 'M83985861', '34', '15']
# ['305777706', 'M83985861', '34', '15']
# ['305830521', 'M83985861', '34', '15']
# ['305752339', 'M83985861', '35', '17']
# ['301716336', 'M83985861', '34', '15']
# ['303228259', 'M83985861', '34', '15']
# ['302669563', 'M83985861', '34', '15']
# ['305811392', 'M83985861', '34', '15']
# ['302437032', 'M83985861', '34', '15']
# ['302739596', 'M83985861', '34', '15']
# ['305779022', 'M83985861', '34', '15']
# ['301654815', 'M83985861', '34', '15']
# ['303159489', 'M83985861', '34', '15']
# ['302686044', 'M83985861', '34', '15']
# ['305801638', 'M83985861', '34', '15']
# ['301225795', 'M83985861', '34', '15']
# ['305805260', 'M83985861', '34', '15']
# ['305832281', 'M83985861', '34', '15']
# ['305831345', 'M83985861', '34', '15']
# ['302524731', 'M83985861', '34', '15']
# ['305780395', 'M83985861', '34', '15']
# ['301709375', 'M83985861', '34', '15']
# ['301333198', 'M83985861', '34', '15']
# ['305830524', 'M83985861', '34', '15']
# ['300984190', 'M83985861', '34', '15']
# ['301695289', 'M83985861', '34', '15']
# ['302752023', 'M83985861', '34', '15']
# ['305798139', 'M83985861', '34', '17']
# ['301221208', 'M83985861', '34', '15']
# ['305691482', 'M83985861', '34', '15']
# ['301685234', 'M83985861', '34', '15']
# ['305724125', 'M83985861', '155', '15']
# ['300459824', 'M83985861', '34', '15']
# ['305683846', 'M83985861', '34', '15']
# ['305752338', 'M83985861', '35', '17']
# ['305723118', 'M83985861', '34', '15']
# ['305769006', 'M83985861', '34', '15']
# ['302546472', 'M83985861', '34', '15']
# ['303572801', 'M83985861', '35', '15']
# ['305788456', 'M83985861', '34', '17']
# ['301423840', 'M83985861', '36', '15']
# ['305765489', 'M83985861', '38', '15']
# ['305774075', 'M83985861', '34', '15']
# ['300968453', 'M83985861', '34', '15']
# ['301825553', 'M83985861', '35', '15']
# ['303145284', 'M83985861', '34', '15']
# ['305795159', 'M83985861', '34', '15']
# ['303814527', 'M83985861', '38', '15']
# ['302752013', 'M83985861', '34', '15']
# ['305788457', 'M83985861', '34', '15']
# ['302546991', 'M83985861', '34', '15']
# ['305836903', 'M83985861', '34', '15']
# ['305836861', 'M83985861', '34', '15']
# ['305836854', 'M83985861', '34', '15']
# ['305790582', 'M83985861', '34', '15']
# ['305794301', 'M83985861', '34', '15']
# ['305823544', 'M83985861', '34', '15']
# ['305823543', 'M83985861', '34', '15']
# ['305743497', 'M83985861', '34', '15']
# ['305707170', 'M83985861', '35', '15']
# ['305824433', 'M83985861', '34', '15']
# ['305777708', 'M83985861', '34', '15']
# ['305801658', 'M83985861', '34', '15']
# ['305801649', 'M83985861', '34', '15']
# ['305773592', 'M83985861', '34', '15']
# ['301795195', 'M83985861', '34', '15']
# ['302546471', 'M83985861', '34', '15']
# ['302267737', 'M83985861', '36', '15']
# ['305801870', 'M83985861', '34', '15']
# ['305788458', 'M83985861', '34', '15']
# ['305773447', 'M83985861', '34', '15']
# ['303273781', 'M83985861', '34', '15']
# ['301579258', 'M83985861', '155', '15']
# ['302942570', 'M83985861', '34', '15']
# ['302709246', 'M83985861', '34', '15']
# ['305824527', 'M83985861', '34', '15']
# ['302725662', 'M83985861', '34', '15']
# ['305692897', 'M83985861', '34', '15']
# ['303117382', 'M83985861', '34', '15']
# ['303287515', 'M83985861', '34', '15']
# ['303780965', 'M83985861', '36', '15']
# ['305284076', 'M83985861', '39', '15']
# ['305788468', 'M83985861', '39', '15']
# ['305788467', 'M83985861', '39', '15']
# ['305779077', 'M83985861', '39', '15']
# ['305749106', 'M83985861', '39', '15']
# ['303355363', 'M83985861', '39', '15']
# ['302676394', 'M83985861', '39', '15']
# ['305187165', 'M83985861', '39', '15']
# ['305818877', 'M83985861', '39', '15']
# ['305798480', 'M83985861', '39', '15']
# ['305798470', 'M83985861', '39', '15']
# ['305722066', 'M83985861', '39', '15']
# ['305798617', 'M83985861', '39', '15']
# ['302803709', 'M83985861', '39', '15']
# ['303355451', 'M83985861', '40', '15']
# ['302685194', 'M83985861', '39', '15']
# ['302300562', 'M83985861', '41', '15']
# ['305827163', 'M83985861', '39', '15']
# ['305827161', 'M83985861', '39', '15']
# ['305822991', 'M83985861', '39', '15']
# ['305792292', 'M83985861', '39', '15']
# ['305792303', 'M83985861', '39', '15']
# ['305788461', 'M83985861', '43', '15']
# ['303089422', 'M83985861', '39', '15']
# ['305798427', 'M83985861', '39', '15']
# ['305773512', 'M83985861', '39', '15']
# ['302578221', 'M83985861', '39', '15']
# ['302214315', 'M83985861', '43', '15']
# ['302228160', 'M83985861', '43', '15']
# ['305684910', 'M83985861', '43', '15']
# ['301904108', 'M83985861', '43', '15']
# ['305705503', 'M83985861', '39', '15']
# ['305706643', 'M83985861', '39', '15']
# ['303355381', 'M83985861', '43', '15']
# ['305715027', 'M83985861', '43', '15']
# ['305772675', 'M83985861', '39', '15']
# ['302057199', 'M83985861', '43', '15']
# ['305798372', 'M83985861', '39', '15']
# ['305798299', 'M83985861', '39', '17']
# ['305798197', 'M83985861', '39', '15']
# ['305798113', 'M83985861', '39', '15']
# ['305788460', 'M83985861', '43', '15']
# ['305788466', 'M83985861', '39', '15']
# ['305690992', 'M83985861', '43', '15']
# ['305717391', 'M83985861', '43', '15']
# ['301076222', 'M83985861', '43', '15']
# ['302962401', 'M83985861', '41', '15']
# ['302578233', 'M83985861', '39', '15']
# ['302962358', 'M83985861', '39', '15']
# ['301903243', 'M83985861', '43', '15']
# ['305813733', 'M83985861', '43', '15']
# ['301699534', 'M83985861', '41', '15']
# ['302726030', 'M83985861', '43', '15']
# ['302726028', 'M83985861', '43', '15']
# ['305797146', 'M83985861', '39', '15']
# ['305797138', 'M83985861', '39', '15']
# ['301306761', 'M83985861', '39', '15']
# ['305775289', 'M83985861', '41', '15']
# ['301765686', 'M83985861', '39', '15']
# ['305684909', 'M83985861', '43', '15']
# ['305683132', 'M83985861', '43', '15']
# ['301508862', 'M83985861', '39', '15']
# ['305823002', 'M83985861', '39', '15']
# ['305792294', 'M83985861', '39', '15']
# ['303355430', 'M83985861', '39', '15']
# ['302685195', 'M83985861', '39', '15']
# ['301657556', 'M83985861', '39', '15']
# ['302273933', 'M83985861', '43', '15']
# ['305792307', 'M83985861', '39', '15']
# ['305283907', 'M83985861', '39', '15']
# ['301674166', 'M83985861', '157', '15']
# ['302849046', 'M83985861', '49', '15']
# ['302745345', 'M83985861', '49', '15']
# ['305757236', 'M83985861', '158', '15']
# ['302746236', 'M83985861', '50', '15']
# ['301747053', 'M83985861', '50', '15']
# ['305710351', 'M83985861', '48', '15']
# ['302563197', 'M83985861', '157', '15']
# ['302563286', 'M83985861', '157', '15']
# ['302328138', 'M83985861', '49', '15']
# ['305763870', 'M83985861', '159', '15']
# ['302849729', 'M83985861', '49', '15']
# ['302256776', 'M83985861', '48', '15']
# ['305798454', 'M83985861', '50', '17']
# ['303541490', 'M83985861', '157', '15']
# ['301674092', 'M83985861', '158', '15']
# ['302563967', 'M83985861', '158', '15']
# ['302838956', 'M83985861', '123', '15']
# ['303355295', 'M83985861', '50', '15']
# ['305682387', 'M83985861', '50', '15']
# ['303229186', 'M83985861', '49', '15']
# ['301603045', 'M83985861', '158', '15']
# ['302496485', 'M83985861', '49', '15']
# ['302562937', 'M83985861', '157', '15']
# ['302745187', 'M83985861', '157', '15']
# ['305763887', 'M83985861', '49', '15']
# ['301494614', 'M83985861', '48', '15']
# ['305293740', 'M83985861', '50', '15']
# ['305744726', 'M83985861', '50', '15']
# ['305773528', 'M83985861', '49', '15']
# ['302180809', 'M83985861', '49', '15']
# ['303089353', 'M83985861', '48', '15']
# ['305728263', 'M83985861', '50', '15']
# ['305765639', 'M83985861', '50', '15']
# ['302247583', 'M83985861', '49', '15']
# ['305734104', 'M83985861', '49', '17']
# ['302814259', 'M83985861', '49', '15']
# ['305733764', 'M83985861', '49', '15']
# ['301639116', 'M83985861', '48', '15']
# ['302745357', 'M83985861', '49', '15']
# ['305823249', 'M83985861', '49', '15']
# ['300640347', 'M83985861', '48', '15']
# ['302701314', 'M83985861', '50', '15']
# ['303170858', 'M83985861', '123', '15']
# ['305794108', 'M83985861', '48', '15']
# ['301747848', 'M83985861', '49', '15']
# ['302936103', 'M83985861', '49', '15']
# ['301699562', 'M83985861', '49', '15']
# ['300917380', 'M83985861', '50', '15']
# ['305744803', 'M83985861', '48', '15']
# ['301351360', 'M83985861', '49', '15']
# ['305824557', 'M83985861', '49', '15']
# ['303136282', 'M83985861', '123', '15']
# ['305748200', 'M83985861', '50', '15']
# ['305750498', 'M83985861', '49', '15']
# ['305750491', 'M83985861', '49', '15']
# ['302563298', 'M83985861', '157', '15']
# ['301395049', 'M83985861', '49', '15']
# ['301882272', 'M83985861', '157', '15']
# ['303800868', 'M83985861', '48', '15']
# ['301839205', 'M83985861', '50', '15']
# ['303355279', 'M83985861', '123', '15']
# ['302329354', 'M83985861', '49', '15']
# ['300458909', 'M83985861', '50', '15']
# ['305825771', 'M83985861', '157', '15']
# ['303104290', 'M83985861', '49', '15']
# ['303931329', 'M83985861', '50', '15']
# ['305798027', 'M83985861', '49', '15']
# ['302749739', 'M83985861', '49', '15']
# ['301644211', 'M83985861', '49', '15']
# ['302996526', 'M83985861', '49', '15']
# ['302315093', 'M83985861', '50', '15']
# ['305832862', 'M83985861', '48', '15']
# ['302746855', 'M83985861', '50', '15']
# ['303229193', 'M83985861', '49', '15']
# ['305825743', 'M83985861', '49', '15']
# ['300089176', 'M83985861', '50', '15']
# ['300089043', 'M83985861', '50', '15']
# ['305713800', 'M83985861', '50', '15']
# ['301412143', 'M83985861', '48', '15']
# ['301395048', 'M83985861', '49', '15']
# ['301313790', 'M83985861', '50', '17']
# ['302745379', 'M83985861', '49', '15']
# ['301671752', 'M83985861', '158', '15']
# ['301805041', 'M83985861', '48', '15']
# ['305713793', 'M83985861', '50', '15']
# ['301450023', 'M83985861', '48', '15']
# ['301705903', 'M83985861', '49', '17']
# ['302834508', 'M83985861', '48', '15']
# ['302834477', 'M83985861', '48', '15']
# ['302834439', 'M83985861', '48', '15']
# ['304989131', 'M83985861', '50', '15']
# ['302060986', 'M83985861', '48', '15']
# ['303213582', 'M83985861', '48', '15']
# ['302745329', 'M83985861', '49', '15']
# ['305747839', 'M83985861', '48', '15']
# ['303355242', 'M83985861', '123', '15']
# ['301129328', 'M83985861', '50', '15']
# ['302676310', 'M83985861', '157', '15']
# ['305777690', 'M83985861', '123', '15']
# ['303355235', 'M83985861', '122', '15']
# ['300910111', 'M83985861', '53', '15']
# ['302332805', 'M83985861', '53', '15']
# ['301602376', 'M83985861', '122', '15']
# ['304569150', 'M83985861', '53', '15']
# ['305816520', 'M83985861', '122', '15']
# ['305816519', 'M83985861', '122', '15']
# ['305713152', 'M83985861', '53', '15']
# ['302206436', 'M83985861', '122', '15']
# ['301159112', 'M83985861', '53', '15']
# ['305742068', 'M83985861', '122', '15']
# ['302703112', 'M83985861', '53', '16']
# ['301630899', 'M83985861', '122', '15']
# ['301856653', 'M83985861', '53', '15']
# ['305792656', 'M83985861', '122', '15']
# ['301449281', 'M83985861', '53', '15']
# ['305816533', 'M83985861', '122', '15']
# ['303425818', 'M83985861', '122', '15']
# ['303425770', 'M83985861', '122', '15']
# ['304362442', 'M83985861', '122', '15']
# ['305816518', 'M83985861', '122', '15']
# ['302834187', 'M83985861', '53', '15']
# ['301602377', 'M83985861', '122', '15']
# ['302745402', 'M83985861', '122', '15']
# ['300984171', 'M83985861', '53', '15']
# ['302689405', 'M83985861', '53', '15']
# ['301138475', 'M83985861', '53', '15']
# ['305689536', 'M83985861', '122', '15']
# ['305834451', 'M83985861', '122', '15']
# ['301712324', 'M83985861', '53', '15']
# ['302710599', 'M83985861', '122', '15']
# ['305693883', 'M83985861', '122', '15']
# ['305408824', 'M83985861', '53', '15']
# ['303543506', 'M83985861', '122', '15']
# ['301748689', 'M83985861', '122', '15']
# ['302695083', 'M83985861', '122', '15']
# ['301428152', 'M83985861', '53', '15']
# ['301293915', 'M83985861', '122', '15']
# ['301437540', 'M83985861', '122', '15']
# ['305707712', 'M83985861', '122', '15']
# ['305768961', 'M83985861', '122', '15']
# ['301449277', 'M83985861', '53', '15']
# ['305712400', 'M83985861', '122', '15']
# ['301386788', 'M83985861', '53', '15']
# ['301138476', 'M83985861', '53', '15']
# ['302137940', 'M83985861', '53', '15']
# ['304054252', 'M83985861', '160', '15']
# ['301705699', 'M83985861', '160', '15']
# ['303870020', 'M83985861', '162', '15']
# ['302292845', 'M83985861', '160', '15']
# ['305791505', 'M83985861', '160', '15']
# ['303355466', 'M83985861', '160', '15']
# ['301745245', 'M83985861', '160', '15']
# ['305228689', 'M83985861', '160', '15']
# ['303355055', 'M83985861', '160', '15']
# ['303290336', 'M83985861', '160', '15']
# ['303779546', 'M83985861', '162', '15']
# ['301746894', 'M83985861', '160', '15']
# ['303104312', 'M83985861', '160', '15']
# ['301880204', 'M83985861', '161', '15']
# ['305241718', 'M83985861', '160', '15']
# ['305228692', 'M83985861', '160', '15']
# ['305237339', 'M83985861', '160', '15']
# ['302715135', 'M83985861', '160', '15']
# ['305716493', 'M83985861', '160', '15']
# ['302262171', 'M83985861', '161', '15']
# ['302862134', 'M83985861', '160', '15']
# ['305694559', 'M83985861', '160', '15']
# ['301885527', 'M83985861', '160', '15']
# ['302302821', 'M83985861', '160', '15']
# ['305711966', 'M83985861', '161', '15']
# ['301402363', 'M83985861', '164', '15']
# ['303838304', 'M83985861', '164', '15']
# ['305045256', 'M83985861', '164', '15']
# ['303697994', 'M83985861', '164', '15']
# ['301815761', 'M83985861', '164', '15']
# ['303257016', 'M83985861', '164', '15']
# ['303930085', 'M83985861', '164', '15']
# ['301402617', 'M83985861', '164', '15']
# ['305336096', 'M83985861', '164', '15']
# ['301661275', 'M83985861', '165', '15']
# ['305296647', 'M83985861', '163', '15']
# ['305311152', 'M83985861', '163', '15']
# ['301683248', 'M33439436', '7', '15']
# ['303894423', 'M33439436', '7', '17']
# ['305770545', 'M33439436', '7', '15']
# ['305721314', 'M33439436', '7', '17']
# ['302739441', 'M33439436', '7', '15']
# ['302729896', 'M33439436', '7', '17']
# ['305802637', 'M33439436', '7', '15']
# ['302699615', 'M33439436', '7', '17']
# ['305776185', 'M33439436', '7', '17']
# ['305788150', 'M33439436', '7', '17']
# ['305770543', 'M33439436', '7', '15']
# ['303894825', 'M33439436', '7', '17']
# ['302837555', 'M33439436', '7', '15']
# ['305812324', 'M33439436', '7', '22']
# ['305809527', 'M33439436', '7', '15']
# ['305796715', 'M33439436', '18', '15']
# ['305814006', 'M33439436', '7', '15']
# ['302301165', 'M33439436', '7', '15']
# ['305788159', 'M33439436', '7', '17']
# ['305812678', 'M33439436', '18', '17']
# ['305796730', 'M33439436', '7', '15']
# ['305721353', 'M33439436', '7', '17']
# ['305795045', 'M33439436', '7', '15']
# ['305796088', 'M33439436', '7', '15']
# ['305690945', 'M33439436', '21', '15']
# ['305812660', 'M33439436', '7', '17']
# ['302739440', 'M33439436', '7', '15']
# ['305794369', 'M33439436', '18', '17']
# ['302272667', 'M33439436', '7', '15']
# ['305744980', 'M33439436', '7', '15']
# ['302743883', 'M33439436', '7', '15']
# ['305721287', 'M33439436', '7', '17']
# ['305830944', 'M33439436', '7', '17']
# ['305802515', 'M33439436', '18', '17']
# ['305806852', 'M33439436', '7', '15']
# ['301217249', 'M33439436', '7', '15']
# ['305797064', 'M33439436', '7', '15']
# ['303894687', 'M33439436', '7', '15']
# ['302720728', 'M33439436', '7', '15']
# ['305726165', 'M33439436', '7', '17']
# ['305794462', 'M33439436', '7', '15']
# ['305740944', 'M33439436', '18', '15']
# ['305798209', 'M33439436', '7', '15']
# ['305830945', 'M33439436', '7', '17']
# ['305657006', 'M33439436', '7', '15']
# ['305731786', 'M33439436', '7', '15']
# ['302303800', 'M33439436', '18', '15']
# ['305715774', 'M33439436', '18', '15']
# ['302284695', 'M33439436', '7', '15']
# ['305309878', 'M33439436', '7', '17']
# ['305682541', 'M33439436', '7', '17']
# ['305814155', 'M33439436', '7', '17']
# ['305777285', 'M33439436', '7', '15']
# ['303051329', 'M33439436', '21', '17']
# ['302804952', 'M33439436', '7', '15']
# ['305727533', 'M33439436', '7', '15']
# ['305802327', 'M33439436', '7', '15']
# ['302298486', 'M33439436', '18', '15']
# ['305704901', 'M33439436', '7', '15']
# ['305813775', 'M33439436', '7', '15']
# ['302284294', 'M33439436', '153', '15']
# ['305716516', 'M33439436', '7', '15']
# ['303894549', 'M33439436', '153', '15']
# ['303894545', 'M33439436', '21', '15']
# ['305694025', 'M33439436', '7', '15']
# ['305309892', 'M33439436', '7', '17']
# ['302699667', 'M33439436', '7', '15']
# ['305812671', 'M33439436', '18', '15']
# ['305788157', 'M33439436', '7', '15']
# ['301459314', 'M33439436', '7', '17']
# ['302763757', 'M33439436', '7', '15']
# ['302699674', 'M33439436', '7', '15']
# ['305792182', 'M33439436', '7', '15']
# ['305796995', 'M33439436', '7', '15']
# ['301709817', 'M33439436', '7', '15']
# ['305809533', 'M33439436', '7', '15']
# ['302809970', 'M33439436', '7', '15']
# ['305364134', 'M33439436', '7', '17']
# ['301760213', 'M33439436', '7', '17']
# ['301702108', 'M33439436', '18', '15']
# ['305788161', 'M33439436', '7', '15']
# ['305810984', 'M33439436', '7', '17']
# ['305707465', 'M33439436', '7', '17']
# ['305409042', 'M33439436', '7', '15']
# ['305715775', 'M33439436', '18', '15']
# ['305796864', 'M33439436', '7', '15']
# ['305795933', 'M33439436', '7', '15']
# ['305773808', 'M33439436', '7', '15']
# ['302699673', 'M33439436', '7', '15']
# ['305734030', 'M33439436', '7', '15']
# ['305310051', 'M33439436', '7', '17']
# ['305773889', 'M33439436', '7', '15']
# ['305796084', 'M33439436', '7', '15']
# ['305794292', 'M33439436', '7', '15']
# ['305745577', 'M33439436', '7', '17']
# ['303243257', 'M33439436', '7', '15']
# ['303894544', 'M33439436', '21', '15']
# ['305722798', 'M33439436', '7', '15']
# ['305726260', 'M33439436', '7', '17']
# ['305833575', 'M33439436', '7', '17']
# ['305812017', 'M33439436', '35', '17']
# ['302765205', 'M33439436', '328', '15']
# ['301717249', 'M33439436', '35', '15']
# ['302580063', 'M33439436', '190', '15']
# ['301630715', 'M33439436', '190', '15']
# ['303894778', 'M33439436', '35', '15']
# ['305796936', 'M33439436', '190', '17']
# ['301325256', 'M33439436', '190', '17']
# ['305751640', 'M33439436', '35', '15']
# ['301722080', 'M33439436', '35', '15']
# ['300964338', 'M33439436', '190', '15']
# ['302768208', 'M33439436', '35', '15']
# ['302792038', 'M33439436', '35', '17']
# ['302791499', 'M33439436', '190', '15']
# ['305802085', 'M33439436', '34', '15']
# ['305797049', 'M33439436', '190', '17']
# ['305810758', 'M33439436', '35', '17']
# ['302906766', 'M33439436', '35', '17']
# ['300951066', 'M33439436', '35', '17']
# ['305720127', 'M33439436', '35', '17']
# ['305817886', 'M33439436', '35', '17']
# ['305727655', 'M33439436', '34', '15']
# ['302615720', 'M33439436', '35', '15']
# ['305768086', 'M33439436', '328', '17']
# ['305727534', 'M33439436', '34', '15']
# ['302721709', 'M33439436', '35', '17']
# ['302768203', 'M33439436', '35', '15']
# ['301630757', 'M33439436', '190', '17']
# ['305161080', 'M33439436', '35', '17']
# ['301798682', 'M33439436', '35', '17']
# ['305684626', 'M33439436', '35', '17']
# ['305720131', 'M33439436', '35', '17']
# ['301754804', 'M33439436', '35', '15']
# ['302715576', 'M33439436', '35', '15']
# ['302280495', 'M33439436', '35', '15']
# ['302548370', 'M33439436', '328', '15']
# ['301751943', 'M33439436', '35', '15']
# ['302686542', 'M33439436', '34', '15']
# ['305798093', 'M33439436', '35', '15']
# ['301017126', 'M33439436', '34', '15']
# ['305720028', 'M33439436', '35', '17']
# ['303263326', 'M33439436', '35', '15']
# ['303244117', 'M33439436', '328', '17']
# ['305797053', 'M33439436', '190', '17']
# ['305684822', 'M33439436', '35', '17']
# ['305812754', 'M33439436', '35', '15']
# ['301700983', 'M33439436', '35', '15']
# ['305817887', 'M33439436', '35', '15']
# ['305812804', 'M33439436', '35', '15']
# ['305792133', 'M33439436', '34', '15']
# ['304164349', 'M33439436', '190', '15']
# ['304027082', 'M33439436', '35', '15']
# ['301689853', 'M33439436', '35', '15']
# ['301795810', 'M33439436', '35', '15']
# ['302962691', 'M33439436', '35', '17']
# ['302809896', 'M33439436', '35', '15']
# ['302900644', 'M33439436', '35', '15']
# ['302623387', 'M33439436', '190', '15']
# ['305771596', 'M33439436', '190', '17']
# ['303770604', 'M33439436', '34', '15']
# ['302905529', 'M33439436', '35', '17']
# ['302920686', 'M33439436', '35', '15']
# ['305707868', 'M33439436', '328', '15']
# ['301630759', 'M33439436', '34', '15']
# ['305684673', 'M33439436', '35', '15']
# ['305691023', 'M33439436', '36', '15']
# ['301630734', 'M33439436', '190', '17']
# ['302986476', 'M33439436', '36', '15']
# ['305788024', 'M33439436', '35', '17']
# ['302121920', 'M33439436', '190', '15']
# ['300964354', 'M33439436', '190', '15']
# ['301449174', 'M33439436', '190', '15']
# ['305812097', 'M33439436', '34', '15']
# ['303195102', 'M33439436', '35', '17']
# ['302716880', 'M33439436', '34', '15']
# ['305830935', 'M33439436', '34', '15']
# ['305762436', 'M33439436', '34', '15']
# ['305729345', 'M33439436', '35', '17']
# ['305797016', 'M33439436', '190', '17']
# ['305830936', 'M33439436', '34', '15']
# ['305704323', 'M33439436', '190', '15']
# ['305764200', 'M33439436', '35', '15']
# ['301773846', 'M33439436', '190', '17']
# ['301788122', 'M33439436', '190', '15']
# ['300964307', 'M33439436', '190', '15']
# ['305817885', 'M33439436', '35', '15']
# ['301824178', 'M33439436', '34', '15']
# ['304843131', 'M33439436', '34', '15']
# ['305707746', 'M33439436', '35', '15']
# ['302616185', 'M33439436', '35', '15']
# ['305706900', 'M33439436', '35', '17']
# ['305796991', 'M33439436', '190', '17']
# ['303355753', 'M33439436', '35', '15']
# ['302746352', 'M33439436', '35', '15']
# ['301309660', 'M33439436', '190', '17']
# ['302917355', 'M33439436', '35', '15']
# ['303033654', 'M33439436', '36', '15']
# ['302362468', 'M33439436', '190', '15']
# ['302862176', 'M33439436', '35', '17']
# ['302562501', 'M33439436', '35', '15']
# ['305830858', 'M33439436', '32', '17']
# ['302715097', 'M33439436', '32', '17']
# ['305812703', 'M33439436', '32', '17']
# ['305717922', 'M33439436', '32', '17']
# ['303894439', 'M33439436', '32', '17']
# ['305830856', 'M33439436', '32', '17']
# ['305745024', 'M33439436', '32', '15']
# ['305409312', 'M33439436', '32', '17']
# ['302986393', 'M33439436', '32', '15']
# ['301829949', 'M33439436', '32', '15']
# ['305720708', 'M33439436', '32', '15']
# ['305776549', 'M33439436', '32', '15']
# ['305812700', 'M33439436', '32', '15']
# ['305747609', 'M33439436', '32', '15']
# ['305812347', 'M33439436', '32', '22']
# ['302763535', 'M33439436', '32', '17']
# ['305747633', 'M33439436', '32', '15']
# ['305734227', 'M33439436', '32', '17']
# ['302900718', 'M33439436', '32', '17']
# ['305783193', 'M33439436', '32', '17']
# ['305830883', 'M33439436', '32', '15']
# ['301842565', 'M33439436', '32', '15']
# ['305787223', 'M33439436', '32', '15']
# ['305657007', 'M33439436', '32', '15']
# ['305775522', 'M33439436', '32', '15']
# ['301085978', 'M33439436', '32', '15']
# ['305830884', 'M33439436', '32', '15']
# ['305740906', 'M33439436', '32', '15']
# ['305830864', 'M33439436', '32', '17']
# ['305721350', 'M33439436', '32', '17']
# ['305802429', 'M33439436', '32', '15']
# ['305409077', 'M33439436', '32', '17']
# ['301157179', 'M33439436', '32', '17']
# ['301085931', 'M33439436', '32', '15']
# ['305776320', 'M33439436', '32', '15']
# ['301795419', 'M33439436', '32', '15']
# ['301782401', 'M33439436', '32', '15']
# ['305719539', 'M33439436', '32', '17']
# ['305776364', 'M33439436', '32', '15']
# ['303640351', 'M33439436', '32', '15']
# ['305813934', 'M33439436', '32', '15']
# ['305720740', 'M33439436', '32', '15']
# ['305812102', 'M33439436', '32', '15']
# ['303437404', 'M33439436', '32', '17']
# ['302715091', 'M33439436', '32', '17']
# ['302764738', 'M33439436', '32', '15']
# ['302874183', 'M33439436', '32', '15']
# ['305787442', 'M33439436', '32', '17']
# ['305802235', 'M33439436', '32', '15']
# ['302686001', 'M33439436', '32', '15']
# ['301842683', 'M33439436', '32', '15']
# ['305830882', 'M33439436', '32', '17']
# ['305786877', 'M33439436', '32', '15']
# ['305747628', 'M33439436', '32', '15']
# ['305740905', 'M33439436', '32', '15']
# ['302796131', 'M33439436', '32', '15']
# ['305732958', 'M33439436', '32', '15']
# ['305812034', 'M33439436', '32', '15']
# ['302640082', 'M33439436', '32', '15']
# ['302262974', 'M33439436', '32', '15']
# ['305828187', 'M33439436', '32', '15']
# ['305792159', 'M33439436', '32', '15']
# ['305796970', 'M33439436', '32', '17']
# ['302953594', 'M33439436', '32', '17']
# ['305819765', 'M33439436', '32', '15']
# ['305719546', 'M33439436', '32', '17']
# ['305814141', 'M33439436', '32', '15']
# ['305773756', 'M33439436', '32', '17']
# ['305764289', 'M33439436', '32', '15']
# ['302730173', 'M33439436', '32', '15']
# ['301827414', 'M33439436', '32', '15']
# ['305802540', 'M33439436', '32', '15']
# ['305819343', 'M33439436', '32', '15']
# ['305809368', 'M33439436', '32', '15']
# ['302262983', 'M33439436', '32', '17']
# ['305732597', 'M33439436', '32', '17']
# ['305788121', 'M33439436', '32', '17']
# ['301843269', 'M33439436', '32', '15']
# ['305806764', 'M33439436', '32', '15']
# ['305732598', 'M33439436', '32', '17']
# ['301732581', 'M33439436', '32', '15']
# ['305624888', 'M33439436', '32', '15']
# ['305833145', 'M33439436', '32', '15']
# ['302933450', 'M33439436', '32', '15']
# ['305798571', 'M33439436', '32', '17']
# ['302961925', 'M33439436', '32', '17']
# ['305792176', 'M33439436', '32', '15']
# ['302641177', 'M33439436', '32', '15']
# ['302272504', 'M33439436', '32', '15']
# ['305802753', 'M33439436', '32', '17']
# ['305682232', 'M33439436', '32', '17']
# ['303595951', 'M33439436', '32', '15']
# ['302862858', 'M33439436', '32', '15']
# ['305747632', 'M33439436', '32', '15']
# ['305720707', 'M33439436', '32', '15']
# ['305802710', 'M33439436', '32', '17']
# ['302281125', 'M33439436', '32', '17']
# ['305764338', 'M33439436', '32', '15']
# ['301795460', 'M33439436', '32', '15']
# ['301826558', 'M33439436', '32', '15']
# ['302935627', 'M33439436', '33', '15']
# ['301494875', 'M33439436', '33', '17']
# ['301262356', 'M33439436', '33', '15']
# ['302212213', 'M33439436', '33', '15']
# ['305708118', 'M33439436', '33', '17']
# ['303894508', 'M33439436', '33', '15']
# ['305720567', 'M33439436', '33', '15']
# ['302298115', 'M33439436', '33', '17']
# ['303894792', 'M33439436', '33', '17']
# ['303894897', 'M33439436', '33', '15']
# ['305744997', 'M33439436', '33', '15']
# ['305688890', 'M33439436', '33', '15']
# ['305771060', 'M33439436', '33', '17']
# ['302630503', 'M33439436', '33', '15']
# ['302764780', 'M33439436', '33', '15']
# ['301724159', 'M33439436', '33', '15']
# ['302212216', 'M33439436', '33', '15']
# ['305796708', 'M33439436', '33', '15']
# ['305811620', 'M33439436', '33', '17']
# ['305721449', 'M33439436', '33', '15']
# ['301827855', 'M33439436', '33', '15']
# ['301482915', 'M33439436', '33', '15']
# ['305695377', 'M33439436', '33', '17']
# ['303894751', 'M33439436', '33', '15']
# ['305817487', 'M33439436', '33', '17']
# ['305729294', 'M33439436', '33', '17']
# ['303884331', 'M33439436', '33', '17']
# ['305826646', 'M33439436', '33', '15']
# ['301703521', 'M33439436', '33', '15']
# ['305827258', 'M33439436', '33', '15']
# ['305330120', 'M33439436', '33', '15']
# ['305812685', 'M33439436', '33', '15']
# ['305788122', 'M33439436', '33', '17']
# ['305792061', 'M33439436', '33', '17']
# ['305721351', 'M33439436', '33', '17']
# ['305686958', 'M33439436', '33', '15']
# ['303894791', 'M33439436', '33', '15']
# ['301634496', 'M33439436', '33', '15']
# ['305761458', 'M33439436', '33', '17']
# ['301757040', 'M33439436', '33', '15']
# ['305817807', 'M33439436', '33', '15']
# ['305691082', 'M33439436', '33', '15']
# ['305826659', 'M33439436', '33', '15']
# ['301709447', 'M33439436', '33', '15']
# ['305682197', 'M33439436', '33', '17']
# ['301545617', 'M33439436', '33', '17']
# ['304472901', 'M33439436', '33', '15']
# ['305731853', 'M33439436', '33', '15']
# ['305830878', 'M33439436', '33', '17']
# ['305714273', 'M33439436', '33', '15']
# ['305330119', 'M33439436', '33', '15']
# ['305782854', 'M33439436', '33', '15']
# ['305817866', 'M33439436', '33', '15']
# ['305714641', 'M33439436', '33', '17']
# ['302962399', 'M33439436', '33', '17']
# ['305833103', 'M33439436', '33', '15']
# ['305817758', 'M33439436', '33', '15']
# ['305768172', 'M33439436', '33', '17']
# ['305817818', 'M33439436', '33', '15']
# ['302792626', 'M33439436', '33', '15']
# ['305817882', 'M33439436', '33', '15']
# ['305817810', 'M33439436', '33', '15']
# ['301085988', 'M33439436', '33', '15']
# ['305817486', 'M33439436', '33', '17']
# ['305716380', 'M33439436', '33', '15']
# ['304488755', 'M33439436', '33', '15']
# ['305785624', 'M33439436', '33', '15']
# ['305830876', 'M33439436', '33', '15']
# ['305817820', 'M33439436', '33', '15']
# ['305817879', 'M33439436', '33', '15']
# ['305794414', 'M33439436', '33', '15']
# ['300709205', 'M33439436', '33', '15']
# ['305794895', 'M33439436', '33', '15']
# ['305825657', 'M33439436', '33', '15']
# ['302289707', 'M33439436', '33', '15']
# ['303436909', 'M33439436', '33', '17']
# ['305705819', 'M33439436', '33', '15']
# ['305706602', 'M33439436', '33', '15']
# ['305773873', 'M33439436', '33', '15']
# ['305822974', 'M33439436', '33', '15']
# ['305700229', 'M33439436', '33', '15']
# ['305363038', 'M33439436', '33', '15']
# ['305811616', 'M33439436', '33', '15']
# ['305817800', 'M33439436', '33', '15']
# ['305657322', 'M33439436', '33', '15']
# ['305647894', 'M33439436', '33', '15']
# ['301545108', 'M33439436', '33', '15']
# ['302932891', 'M33439436', '33', '17']
# ['302526989', 'M33439436', '33', '15']
# ['303103749', 'M33439436', '33', '15']
# ['305823800', 'M33439436', '33', '15']
# ['305782847', 'M33439436', '33', '15']
# ['305694857', 'M33439436', '33', '15']
# ['305721538', 'M33439436', '33', '15']
# ['305788112', 'M33439436', '33', '15']
# ['305722867', 'M33439436', '33', '17']
# ['305770578', 'M33439436', '33', '17']
# ['302646860', 'M33439436', '33', '15']
# ['302304830', 'M33439436', '33', '15']
# ['302953615', 'M33439436', '33', '15']
# ['305740887', 'M33439436', '30', '17']
# ['305764392', 'M33439436', '30', '15']
# ['301782553', 'M33439436', '30', '15']
# ['303894790', 'M33439436', '30', '17']
# ['301721947', 'M33439436', '30', '15']
# ['301697058', 'M33439436', '30', '17']
# ['305429773', 'M33439436', '30', '15']
# ['302550155', 'M33439436', '30', '17']
# ['302272297', 'M33439436', '30', '15']
# ['305769738', 'M33439436', '30', '17']
# ['302719550', 'M33439436', '30', '17']
# ['301730217', 'M33439436', '30', '17']
# ['305796861', 'M33439436', '30', '17']
# ['305768588', 'M33439436', '31', '15']
# ['305810752', 'M33439436', '30', '17']
# ['305812696', 'M33439436', '29', '15']
# ['305095802', 'M33439436', '30', '15']
# ['305625455', 'M33439436', '30', '17']
# ['305764393', 'M33439436', '30', '15']
# ['302647079', 'M33439436', '30', '17']
# ['305764395', 'M33439436', '30', '15']
# ['304472288', 'M33439436', '30', '15']
# ['305714835', 'M33439436', '30', '15']
# ['305740886', 'M33439436', '30', '17']
# ['305777754', 'M33439436', '30', '15']
# ['305804265', 'M33439436', '29', '15']
# ['305686873', 'M33439436', '30', '15']
# ['305802698', 'M33439436', '30', '17']
# ['303159413', 'M33439436', '30', '15']
# ['305707918', 'M33439436', '30', '17']
# ['305796898', 'M33439436', '30', '17']
# ['305296705', 'M33439436', '30', '17']
# ['305768589', 'M33439436', '31', '15']
# ['302739714', 'M33439436', '30', '15']
# ['302706182', 'M33439436', '29', '15']
# ['302763749', 'M33439436', '29', '17']
# ['305748712', 'M33439436', '30', '17']
# ['302763619', 'M33439436', '30', '17']
# ['304471543', 'M33439436', '30', '15']
# ['305330866', 'M33439436', '30', '15']
# ['301193006', 'M33439436', '30', '15']
# ['301218440', 'M33439436', '30', '15']
# ['305694019', 'M33439436', '30', '15']
# ['305796907', 'M33439436', '30', '17']
# ['305272066', 'M33439436', '27', '15']
# ['305827806', 'M33439436', '30', '17']
# ['301794918', 'M33439436', '30', '15']
# ['302332107', 'M33439436', '30', '15']
# ['305751477', 'M33439436', '30', '15']
# ['305795740', 'M33439436', '30', '15']
# ['305178087', 'M33439436', '30', '15']
# ['305830840', 'M33439436', '30', '17']
# ['305830841', 'M33439436', '30', '17']
# ['305719585', 'M33439436', '29', '17']
# ['301086000', 'M33439436', '29', '15']
# ['301662919', 'M33439436', '30', '17']
# ['302833688', 'M33439436', '29', '15']
# ['305770062', 'M33439436', '29', '15']
# ['305788430', 'M33439436', '30', '15']
# ['305714836', 'M33439436', '30', '15']
# ['301010413', 'M33439436', '30', '15']
# ['304472411', 'M33439436', '30', '15']
# ['305712833', 'M33439436', '30', '17']
# ['302304857', 'M33439436', '30', '15']
# ['305704765', 'M33439436', '30', '15']
# ['305830909', 'M33439436', '30', '17']
# ['301757092', 'M33439436', '30', '17']
# ['304471819', 'M33439436', '30', '15']
# ['303894889', 'M33439436', '31', '15']
# ['301723907', 'M33439436', '30', '15']
# ['301719763', 'M33439436', '29', '15']
# ['305812707', 'M33439436', '29', '15']
# ['301826653', 'M33439436', '30', '17']
# ['302606540', 'M33439436', '30', '15']
# ['305699610', 'M33439436', '30', '15']
# ['302739722', 'M33439436', '30', '15']
# ['301695429', 'M33439436', '30', '17']
# ['305704451', 'M33439436', '30', '17']
# ['305736724', 'M33439436', '30', '15']
# ['305682740', 'M33439436', '30', '15']
# ['300925966', 'M33439436', '30', '15']
# ['302669451', 'M33439436', '29', '15']
# ['305794793', 'M33439436', '27', '15']
# ['305804248', 'M33439436', '30', '15']
# ['304458266', 'M33439436', '30', '15']
# ['301384741', 'M33439436', '30', '15']
# ['305682689', 'M33439436', '27', '15']
# ['305336222', 'M33439436', '30', '15']
# ['305684878', 'M33439436', '30', '15']
# ['305719590', 'M33439436', '29', '17']
# ['305798485', 'M33439436', '30', '15']
# ['305698170', 'M33439436', '31', '17']
# ['302837424', 'M33439436', '30', '15']
# ['302640192', 'M33439436', '30', '15']
# ['305768584', 'M33439436', '31', '15']
# ['305720586', 'M33439436', '30', '17']
# ['305707922', 'M33439436', '30', '17']
# ['305095798', 'M33439436', '30', '15']
# ['305788433', 'M33439436', '30', '15']
# ['305703719', 'M33439436', '24', '17']
# ['305789707', 'M33439436', '24', '17']
# ['305713697', 'M33439436', '24', '17']
# ['305430068', 'M33439436', '24', '17']
# ['305812710', 'M33439436', '24', '15']
# ['305789722', 'M33439436', '23', '17']
# ['305733181', 'M33439436', '24', '15']
# ['305812208', 'M33439436', '23', '15']
# ['305792209', 'M33439436', '23', '15']
# ['305812026', 'M33439436', '23', '15']
# ['305430030', 'M33439436', '24', '17']
# ['305747606', 'M33439436', '24', '15']
# ['303242869', 'M33439436', '24', '15']
# ['305809409', 'M33439436', '23', '15']
# ['305812123', 'M33439436', '24', '15']
# ['301085943', 'M33439436', '23', '15']
# ['302242923', 'M33439436', '24', '17']
# ['305806792', 'M33439436', '24', '15']
# ['305787215', 'M33439436', '24', '17']
# ['305199815', 'M33439436', '23', '15']
# ['301351421', 'M33439436', '24', '15']
# ['305719843', 'M33439436', '24', '15']
# ['302706180', 'M33439436', '23', '15']
# ['301843171', 'M33439436', '23', '15']
# ['305688923', 'M33439436', '24', '15']
# ['305792210', 'M33439436', '23', '15']
# ['302685043', 'M33439436', '23', '17']
# ['303595555', 'M33439436', '23', '15']
# ['305779779', 'M33439436', '155', '15']
# ['305806785', 'M33439436', '23', '15']
# ['305296704', 'M33439436', '23', '15']
# ['305199812', 'M33439436', '24', '15']
# ['303894526', 'M33439436', '23', '15']
# ['305199810', 'M33439436', '24', '15']
# ['303242866', 'M33439436', '24', '15']
# ['305814362', 'M33439436', '23', '15']
# ['305714856', 'M33439436', '23', '17']
# ['305820227', 'M33439436', '23', '15']
# ['305199824', 'M33439436', '23', '15']
# ['303894553', 'M33439436', '155', '15']
# ['305731885', 'M33439436', '24', '15']
# ['305241730', 'M33439436', '23', '15']
# ['305702993', 'M33439436', '23', '15']
# ['305075263', 'M33439436', '24', '15']
# ['305828060', 'M33439436', '23', '15']
# ['305811974', 'M33439436', '24', '15']
# ['301085947', 'M33439436', '23', '15']
# ['302862385', 'M33439436', '24', '15']
# ['305694284', 'M33439436', '23', '15']
# ['305430492', 'M33439436', '23', '15']
# ['305776092', 'M33439436', '23', '15']
# ['305817802', 'M33439436', '24', '15']
# ['305812175', 'M33439436', '24', '15']
# ['305714944', 'M33439436', '24', '15']
# ['305710345', 'M33439436', '24', '15']
# ['305812116', 'M33439436', '24', '17']
# ['305791801', 'M33439436', '23', '15']
# ['305796701', 'M33439436', '24', '15']
# ['305430140', 'M33439436', '24', '17']
# ['305796111', 'M33439436', '23', '15']
# ['305714570', 'M33439436', '24', '15']
# ['303430271', 'M33439436', '24', '15']
# ['305715335', 'M33439436', '23', '17']
# ['301086043', 'M33439436', '23', '15']
# ['305310105', 'M33439436', '24', '15']
# ['305731879', 'M33439436', '23', '15']
# ['301730267', 'M33439436', '23', '17']
# ['305796395', 'M33439436', '23', '15']
# ['305431094', 'M33439436', '24', '15']
# ['303000636', 'M33439436', '24', '17']
# ['305684894', 'M33439436', '23', '15']
# ['305769082', 'M33439436', '23', '15']
# ['304514743', 'M33439436', '24', '15']
# ['305812121', 'M33439436', '24', '15']
# ...
# {'itemCd': '302849742', 'review_id': '9012179', 'option': 'BLACK, L', 'cust_size_info': '170cm,52kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'oo********', 'time': '2023.10.01', 'content': '좋아요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8939924', 'option': 'DEEP BEIGE, L', 'cust_size_info': '189cm,87kg', 'size': '적당함', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'ji********', 'time': '2023.09.19', 'content': '여름에 입기 좋고 통풍 잘돼요!', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8935395', 'option': 'DEEP BEIGE, L', 'cust_size_info': '168cm,56kg', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'fr********', 'time': '2023.09.18', 'content': '색도 차분해서 남편이 좋아했어요. 근데 한번 빨고 나니까 어깨쪽 구멍나서 수선 맡겼어여', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8935384', 'option': 'LIGHT BLUE, L', 'cust_size_info': '168cm,56kg', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'fr********', 'time': '2023.09.18', 'content': '편하게 입기에 좋았어요 내년에 재구매 각입니다', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8921616', 'option': 'DEEP BEIGE, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'oo********', 'time': '2023.09.15', 'content': '남편한테 사줬는데 너무 좋아해요!! 시원하고, 구김도 안가고, 세탁도 막 돌릴 수 있어서 편하고 좋습니다~', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8917464', 'option': 'DEEP BEIGE, L', 'cust_size_info': None, 'size': '적당함', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'ks********', 'time': '2023.09.14', 'content': '시원하고 좋아요 잘못해서 올나감 ㅜㅜ', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8915916', 'option': 'LIGHT BLUE, L', 'cust_size_info': '175cm,85kg,M/66,35inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'nm********', 'time': '2023.09.13', 'content': '배가나와서 널널한상의 찾다산건데 여름에입기 좋지만 안에 티셔츠입어야해요 심하게비침', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8909081', 'option': 'LIGHT BLUE, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ji********', 'time': '2023.09.12', 'content': '남자친구 사줬는데 얇고 시원하고 무엇보다 핏이 예뻐서 만족도가 높습니다~!!', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8900460', 'option': 'LIGHT BLUE, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '비슷함', 'user_id': 'it********', 'time': '2023.09.09', 'content': '캐주얼도 세미 포멀도 가능한 가성비템', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8900457', 'option': 'KHAKI, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '비슷함', 'user_id': 'it********', 'time': '2023.09.09', 'content': '캐주얼도 세미 포멀도 가능한 가성비템', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8894201', 'option': 'KHAKI, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'bl********', 'time': '2023.09.08', 'content': '남편 사줬는데 낙낙하게 잘맞았오요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8892751', 'option': 'NAVY, L', 'cust_size_info': '185cm,85kg,XL/88', 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'eu********', 'time': '2023.09.08', 'content': '건조기에 그냥 돌렸는데도 구김이 없었어요! 편하게 입기 쥬아요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8892749', 'option': 'LIGHT BLUE, L', 'cust_size_info': '185cm,85kg,XL/88', 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'eu********', 'time': '2023.09.08', 'content': '구김이 잘 없고 시원하게 입기 좋은것 같아요!!!', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8871658', 'option': 'BLACK, M', 'cust_size_info': '167cm,61kg', 'size': '작음', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'wn********', 'time': '2023.09.03', 'content': '남편사줫는데시원하고이뻐서그런지잘입네요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8870984', 'option': 'DEEP BEIGE, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '비슷함', 'user_id': 'wh********', 'time': '2023.09.02', 'content': '생각보다 린넨스러운데 주름이 잘 안가네요 ㅎㅎ만족합니다.', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8864291', 'option': 'KHAKI, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '비슷함', 'user_id': 'ph********', 'time': '2023.09.01', 'content': 'Áo màu sắc đẹp ạ, mặc vào cũng rất okie ạ, mình mua 2c liền luôn ạ', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8853144', 'option': 'LIGHT BLUE, M', 'cust_size_info': '176cm,73kg', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ek********', 'time': '2023.08.31', 'content': '시원한 소재라 여름에 입기 좋아요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8833373', 'option': 'NAVY, M', 'cust_size_info': None, 'size': '작음', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'su********', 'time': '2023.08.25', 'content': '가성비 괜찮아요 나쁘지 않습니다 만족해요 재구매 합니다', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8829163', 'option': 'BLACK, M', 'cust_size_info': None, 'size': '큼', 'color': '비슷함', 'texture': '다름', 'user_id': 'su********', 'time': '2023.08.24', 'content': '가성비 좋을거 같긴한데 좀더 입어봐야할거같아요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8828062', 'option': 'BLACK, L', 'cust_size_info': None, 'size': '작음', 'color': '같음', 'texture': '같음', 'user_id': 'wc********', 'time': '2023.08.24', 'content': '105, 110입는 남친에게는 어깨가 약간? 작아요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8822135', 'option': 'NAVY, L', 'cust_size_info': '158cm,50kg', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'wi********', 'time': '2023.08.23', 'content': '남편이 잘입고 있어요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8818691', 'option': 'NAVY, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ch********', 'time': '2023.08.22', 'content': '남편사줬는데 잘입어요 백키론데 안껴요 옷이 큰가봐요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8812782', 'option': 'LIGHT BLUE, M', 'cust_size_info': None, 'size': '큼', 'color': '비슷함', 'texture': '같음', 'user_id': 'no********', 'time': '2023.08.20', 'content': '남친선물로 샀어요.  얇고 시원한 재질이라 좋아요. 색도 그렇구요! 만족', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8808894', 'option': 'NAVY, L', 'cust_size_info': '163cm,57kg,S/55,28inch', 'size': '큼', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'fa********', 'time': '2023.08.19', 'content': '블랙구매하면서 네이비도 같이 구매했어요. 적당히 오버핏이라 더 좋은거 같아요. 얇은 재질입니다. 싸게 잘 구입했습니다', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8808889', 'option': 'BLACK, L', 'cust_size_info': '163cm,57kg,S/55,28inch', 'size': '큼', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'fa********', 'time': '2023.08.19', 'content': '사이즈 엘사이즈로 했는데  오히려 오버핏이라 날씬해보이고 원단 얇아서 시원해보이고 좋아요. 남편이 좋아하네요. 세일할때 싸게 잘샀어요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8805296', 'option': 'DEEP BEIGE, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'mi********', 'time': '2023.08.18', 'content': '남편한테 선물해쥤는데 좋아하네요!', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8797945', 'option': 'BLACK, M', 'cust_size_info': '170cm,65kg', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'by********', 'time': '2023.08.17', 'content': '시원하고 가성비 진짜 좋아요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8797944', 'option': 'WHITE, M', 'cust_size_info': '170cm,65kg', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'by********', 'time': '2023.08.17', 'content': '화이트는 진짜 다 비쳐요 ㅋㅋㅋ 너무 비쳐서 이너 입고 입어야되서 막상 한여름에는 못입을것같은 ㅜㅜ', 'rating': 4, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8797907', 'option': 'DEEP BEIGE, M', 'cust_size_info': '170cm,65kg', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'by********', 'time': '2023.08.17', 'content': '진짜 시원한 재질이고 색도 세련되게 예뻐요 습할때 제격', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8791868', 'option': 'NAVY, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'le********', 'time': '2023.08.16', 'content': '배송도 빠르고 핏듀 예뻐요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8785839', 'option': 'LIGHT BLUE, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '비슷함', 'user_id': 'wc********', 'time': '2023.08.16', 'content': '편하게 입기 좋아요.', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8770987', 'option': 'NAVY, L', 'cust_size_info': '160cm,56kg,M/66,28inch', 'size': '적당함', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'kk********', 'time': '2023.08.13', 'content': '신랑 입히려고 구매했어요 디자인이랑 소재가 맘에들어서 카키랑 네이비 둘다 구매했습니다 단정하게 코디해서 입히기 너무좋네요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8770974', 'option': 'KHAKI, L', 'cust_size_info': '160cm,56kg,M/66,28inch', 'size': '적당함', 'color': '같음', 'texture': '비슷함', 'user_id': 'kk********', 'time': '2023.08.13', 'content': '신랑이 열이 많아서 시원한 소재의 옷을 구매하게됐는디 아주 맘에들어하네요 잘입힐께요!', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8769203', 'option': 'BLACK, M', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'he********', 'time': '2023.08.13', 'content': '얇고 시원한 소재라 넘 좋아용', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8748333', 'option': 'NAVY, M', 'cust_size_info': '179cm,80kg,XL/88,34inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'to********', 'time': '2023.08.09', 'content': '달라붙지 않고 적당한 까슬거림….시원합니다.제 몸엔 잘 맞네요.', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8742161', 'option': 'LIGHT BLUE, M', 'cust_size_info': '150cm,43kg,XS/44,26inch', 'size': '적당함', 'color': '비슷함', 'texture': '같음', 'user_id': 'al********', 'time': '2023.08.08', 'content': '173 68키로  보통체격 M사이즈  오버핏으로 예쁘게 딱 떨어집니다 ㅎㅎ 시원해보여서좋아요 😆', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8737925', 'option': 'BLACK, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'yi********', 'time': '2023.08.07', 'content': '선물로줫습니다', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8731586', 'option': 'BLACK, M', 'cust_size_info': '165cm,57kg,M/66,28inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ga********', 'time': '2023.08.05', 'content': '마른편이지만  M사이즈 구매했어요.배송 빨리해주셔서 무더위에 잘 입고 다닐수 있겠네요.옷은 맘에 듭니다.', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8729546', 'option': 'KHAKI, M', 'cust_size_info': '158cm,51kg,M/66,26inch', 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'am********', 'time': '2023.08.05', 'content': '입어보고 시원해서 하나 더 구입했어요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8729521', 'option': 'NAVY, L', 'cust_size_info': '158cm,51kg,M/66,26inch', 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'am********', 'time': '2023.08.05', 'content': '일단 엄청 엄청 시원해서 잘 입어요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8726933', 'option': 'KHAKI, M', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'he********', 'time': '2023.08.04', 'content': '땀이워낙많아서 시원하게잘입도록할께요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8726034', 'option': 'LIGHT BLUE, L', 'cust_size_info': None, 'size': '적당함', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'ju********', 'time': '2023.08.04', 'content': '밝고 맑은 하늘색이라 색이 넘 예뻐요!좀 까쓸거리긴 한데 얇아서 시원해요.184에 78인데 잘맞아요!', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8706671', 'option': 'DEEP BEIGE, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'wc********', 'time': '2023.08.03', 'content': '남자친구 선물해줬어요 올여름 잘 입을 것 같아요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8701558', 'option': 'KHAKI, L', 'cust_size_info': '170cm,60kg,M/66,27inch', 'size': '적당함', 'color': '같음', 'texture': '비슷함', 'user_id': 'ea********', 'time': '2023.08.02', 'content': '질이 엄청 좋다기버다는 시원해서 한철입기 딱입니다 덩치 있는 편 아닌데 라지도 잘 맞았어요 재구매 각입니다 손 엄청 잘 간다네용 ㅋㅌ', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8700825', 'option': 'WHITE, L', 'cust_size_info': '176cm,75kg,XL/88,33inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ap********', 'time': '2023.08.02', 'content': '여름에 너무  어울리는  옷입니다  시원해서 좋고  드라이안해서  좋고', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8697446', 'option': 'NAVY, L', 'cust_size_info': None, 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'op********', 'time': '2023.08.02', 'content': '아버지것으로 구입했어요사이즈 잘 맞으실것 같아요깔끔하고 시원한 옷이에요예쁘구요♡', 'rating': 5, 'favorite': '1'}
# {'itemCd': '302849742', 'review_id': '8691708', 'option': 'NAVY, M', 'cust_size_info': '176cm,60kg', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'pa********', 'time': '2023.08.01', 'content': '생각보단 많이 얇아요근데 그것대로 시원해서 요즘같은 날씨에 잘입어질듯 합니다', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8686424', 'option': 'NAVY, L', 'cust_size_info': None, 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'ne********', 'time': '2023.07.30', 'content': '남편 사줘ㅆ는데 시원하다고 잘 입고 다녀요', 'rating': 5, 'favorite': '1'}
# {'itemCd': '302849742', 'review_id': '8683620', 'option': 'DEEP BEIGE, M', 'cust_size_info': '172cm,65kg,S/55,29inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'br********', 'time': '2023.07.29', 'content': '가격대비 소재며 디자인이며 참 마음에 듭니다.특히 색감이 정말 예뻐요!', 'rating': 5, 'favorite': '1'}
# {'itemCd': '302849742', 'review_id': '8682242', 'option': 'NAVY, M', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'hb********', 'time': '2023.07.29', 'content': '시원한소재입니다 무난하게 입기좋아요~', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8681648', 'option': 'NAVY, L', 'cust_size_info': None, 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'sh********', 'time': '2023.07.29', 'content': '사이즈가 좀 큰데 오버핏으로 좋네요 잴입을게요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8681279', 'option': 'DEEP BEIGE, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ju********', 'time': '2023.07.29', 'content': '빠른 배송 고맙습니다 무난해요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8669784', 'option': 'DEEP BEIGE, L', 'cust_size_info': None, 'size': '작음', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'ch********', 'time': '2023.07.26', 'content': '남표니 사줫는데 잘입고 다노요 배나온거 티 안나요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8664083', 'option': 'DEEP BEIGE, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'eu********', 'time': '2023.07.25', 'content': '남편 휴가룩으로 사줬는데 좋아하더라구요 소재도 얇아서 시원하게 입을수 있어요 잘 입을께요!', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8661013', 'option': 'BLACK, M', 'cust_size_info': '174cm,70kg,S/55,28inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': '01********', 'time': '2023.07.24', 'content': '남편 사줬는데 좋으흐네용', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8660526', 'option': 'LIGHT BLUE, L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '비슷함', 'user_id': 'fi********', 'time': '2023.07.24', 'content': '아직 입어보진 않았지만 소재가 시원해보이고 색상도 마음에 듭니다.', 'rating': 4, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8659891', 'option': 'WHITE, M', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'hb********', 'time': '2023.07.24', 'content': '좀 크다고 들어서 엠사이즈로 했는데 잘맞네요~ 시원해보여요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302849742', 'review_id': '8659812', 'option': 'DEEP BEIGE, M', 'cust_size_info': '168cm,53kg,S/55,26inch', 'size': '큼', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'sp********', 'time': '2023.07.24', 'content': '시원해보여 남편 사 줬어요. 페이크린넨이라 고급진 면은 없지만 툭 걸치면 시원해보이고 몸에 안 붙어 편하대요. 사진은 원색보다 밝게 나왔네요', 'rating': 5, 'favorite': '0'}
