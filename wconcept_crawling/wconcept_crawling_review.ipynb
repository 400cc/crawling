# %%
import time
from bs4 import BeautifulSoup
import pandas as pd
import requests
import json
import re

ITEM_COUNTS = 100

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36',
    'Display-Api-Key': 'VWmkUPgs6g2fviPZ5JQFQ3pERP4tIXv/J2jppLqSRBk='
}

# %%
middle_category_nums = ['10101201', '10101202', '10101203', '10101204', '10101205',
                        '10101206', '10101207', '10101208', '10101209', '10101210',
                        '10101211', '10101212']

# %%
def get_item_cds(middle_category_num, gender):
    url = 'https://api-display.wconcept.co.kr/display/api/v2/best/products'

    if gender == 'men':
        genderType = 'men'
    else:
        genderType = 'women'

    data = {
    "custNo": "",
    "dateType": "daily",
    "domain": 'WOMEN',
    "genderType": genderType,
    "depth1Code": "10101",
    "depth2Code": middle_category_num,
    "pageNo": 1,
    "pageSize": ITEM_COUNTS
    }

    response = requests.post(url, headers=headers, json=data)

    soup = BeautifulSoup(response.text, 'lxml')
    info = soup.string
    info = json.loads(info)
    info = info['data']['content']

    item_cds = []

    for item in info:
        item_cds.append(item['itemCd'])
        

    return item_cds

# %%
def get_item_payloads(item_cd):
    url = 'https://www.wconcept.co.kr/Ajax/GetProductsInfo'

    data = {'itemcds': item_cd}

    response = requests.post(url, headers=headers, data=data)

    soup = BeautifulSoup(response.text, 'lxml')
    info = soup.string
    info = json.loads(info)[0]

    item_cd = info['itemCd']
    medium_cd = info['category'][0]['mediumCd']
    category_cd = info['category'][0]['categoryCd']
    itemtypecd = info['itemTypeCd']

    item_payloads = [item_cd, medium_cd, category_cd, itemtypecd]
    
    print(item_payloads)
    
    return item_payloads

# %%
def get_one_review(i, soup, itemCd):
    # 구매 옵션과 사이즈정보 빼내기 용
    review_info = soup.select('div.pdt_review_info')[i]

    # 리뷰 id
    review_id = soup.select('div.product_review_reaction > div > button.link_txt.open-layer.open-pop_review_report')[i]['data-idxnum']
    
    # 구매 옵션
    try:
        option = review_info.select('div.pdt_review_option > p')[0].text.strip()
        option = option.split(':')[1].strip()
    except:
        option = None

    # 사이즈 정보
    try:
        cust_size_info = review_info.select('div.pdt_review_option > p')[1].text.strip()
        cust_size_info = cust_size_info.split(':')[1].strip()
    except:
        cust_size_info = None

    # 사이즈, 색상, 소재 빼내기 용
    try:
        sku = soup.select('ul.product_review_evaluation')[i]       

        # 사이즈
        size = sku.select('ul.product_review_evaluation > li > div > em')[0].text

        # 색상
        color = sku.select('ul.product_review_evaluation > li > div > em')[1].text

        # 소재
        texture = sku.select('ul.product_review_evaluation > li > div > em')[2].text
    
    except:
        size, color, texture = None, None, None



    # user id
    user_id = soup.select('p.product_review_info_right > em')[i].text

    # 작성 시간
    time = soup.select('p.product_review_info_right > span')[i].text

    # 리뷰 내용
    content = soup.select('p.pdt_review_text')[i].text.strip()

    # rating 정보
    rating_pct = soup.select('div.star-grade > strong[style]')[i]
    rating = re.findall(r'\d+', str(rating_pct))[0]
    rating = int(int(rating) / 20)

    # 좋아요 개수
    favorite = soup.select('button.like.btn_review_recommend')[i].text


    data = {
        'product_id': itemCd,
        'review_id': review_id,
        'purchase_option': option,
        'size_info': cust_size_info,
        'size': size,
        'color': color,
        'material': texture,
        'user_id': user_id,
        'written_time': time,
        'body': content,
        'rate': rating,
        'likes': favorite
    }

    return data

# %%
def get_reviews(item_payload):
    url = 'https://www.wconcept.co.kr/Ajax/ProductReViewList'
    i = 1
    one_goods_reviews = []
    while True:
        data = {'itemcd': item_payload[0],
            'pageIndex': i,
            'order': 1,
            'IsPrdCombinOpt': 'N',
            'mediumcd': item_payload[1],
            'categorycd': item_payload[2],
            'itemtypecd': item_payload[3]
            }

        response = requests.post(url, headers=headers, data=data)
        soup = BeautifulSoup(response.text, 'lxml')

        review_count = len(soup.select('p.pdt_review_text'))

        if review_count == 0:
            break
        
        for j in range(review_count):
            review = get_one_review(j, soup, item_payload[0])
            one_goods_reviews.append(review)
            print(review)
        
        i += 1

    return one_goods_reviews

# %%
def main():
    item_cds_list = []
    for gender in ['men', 'women']:
        for middle_category_num in middle_category_nums:
            item_cds = get_item_cds(middle_category_num, gender)
            item_cds_list += item_cds
    print(item_cds_list)

    item_payloads_list = []
    for item_cd in item_cds_list:
        item_payloads_list.append(get_item_payloads(item_cd))


    all_reviews = []

    for item_payloads in item_payloads_list:
        review_per_goods = get_reviews(item_payloads)
        if len(review_per_goods) == 0:
            continue
        else:
            all_reviews += review_per_goods


    df = pd.DataFrame(all_reviews)
    print(df['review_id'].value_counts())

# %%
if __name__ == '__main__':
    main()
# Out:
# ['301428924', '303194078', '305721273', '301081596', '302113108', '305696394', '301203422', '305782065', '305733706', '305686496', '301090900', '305771101', '301458840', '305814258', '305789815', '304990472', '302747776', '301872605', '305262259', '305408997', '303219498', '305713226', '305785971', '305727034', '305814256', '305703448', '305696085', '305681170', '305681161', '305801873', '305208795', '303732547', '304674084', '302668757', '305733727', '303788020', '304277140', '301451839', '305430643', '303425466', '302280268', '301523775', '303814529', '300875863', '301138700', '305733690', '303170611', '302746077', '302480746', '305706785', '305687841', '305682450', '302907984', '305817551', '301606902', '305830517', '305773685', '305682434', '305787271', '305829350', '305774576', '305831809', '301656756', '301737098', '301765087', '302187321', '305794400', '305775002', '303442148', '303437256', '305831182', '305771649', '305771656', '302907977', '303583334', '303442336', '303442153', '302685112', '305681153', '301692934', '305765877', '305825151', '305817963', '305687851', '305765867', '302746537', '302849742', '301714193', '302746918', '302752000', '302751986', '305814941', '305687850', '305822971', '305822970', '305779620', '302936481', '305706815', '301392184', '305825454', '300861598', '300854935', '304739578', '302281876', '302281875', '301880519', '301656755', '305627989', '305805469', '305701658', '305831102', '301837423', '305744798', '302995336', '302710208', '301721359', '302849718', '305737283', '305729431', '305813143', '305683021', '303302023', '302261248', '300984192', '300968436', '301654812', '301772908', '302837458', '301221211', '305725854', '302546986', '302437032', '302038215', '301694969', '303203020', '305734039', '300968453', '303145192', '302669563', '301716336', '305283906', '302546995', '305790582', '302669567', '301592541', '305690977', '303436347', '305830524', '302686044', '302912797', '305777706', '305409204', '301418111', '301795203', '302912430', '302752014', '301739296', '305752338', '305780395', '302986572', '300968441', '302767455', '305813183', '305823501', '305830523', '305830521', '305696590', '301654817', '301759925', '304155827', '301646542', '305752339', '305752337', '302849749', '303228259', '301709375', '302187317', '303208122', '303208119', '302816767', '301711726', '302249504', '301364725', '305801638', '301685234', '302279485', '302739596', '305602209', '303033907', '301423840', '305813742', '305688417', '303875445', '303875444', '305690976', '305717089', '305816273', '301854390', '303814519', '305813755', '303208272', '301772907', '305715852', '301654815', '305710299', '305779020', '302918655', '301527070', '305795159', '305261539', '301674094', '305743653', '305283613', '302709245', '301287109', '301004101', '303089277', '305750576', '302746795', '301650284', '301729657', '302114156', '302752013', '305792299', '305798116', '302955518', '302906195', '302134373', '303442174', '305797146', '305797122', '302746604', '305710442', '305797133', '302803709', '305716785', '305699885', '305699789', '302869217', '305814543', '303355381', '305806432', '301881426', '305809427', '303355430', '305284076', '305792309', '303589282', '303725809', '305687860', '302278579', '305684910', '305798550', '302685194', '302483260', '305749308', '305788470', '305798126', '305744810', '301902843', '301639240', '301792970', '301279461', '302726039', '302726030', '305797138', '305798480', '305798476', '303089422', '305805457', '302615545', '302288137', '303287734', '303355451', '303355363', '302483304', '305822991', '305792294', '301839690', '300931474', '302906214', '305792301', '302849046', '301674166', '302745345', '302180809', '305682387', '301747053', '305757236', '303800866', '302328138', '300917380', '301759938', '305798449', '305710351', '302562937', '302187383', '303355295', '305823496', '305706967', '305602517', '302563286', '302563197', '305794234', '305771566', '302838956', '303192903', '3056811 ...
# ['301428924', 'M83985861', '28', '15']
# ['303194078', 'M83985861', '151', '15']
# ['305721273', 'M83985861', '32', '15']
# ['301081596', 'M83985861', '30', '15']
# ['302113108', 'M83985861', '152', '15']
# ['305696394', 'M83985861', '32', '15']
# ['301203422', 'M83985861', '32', '15']
# ['305782065', 'M83985861', '28', '15']
# ['305733706', 'M83985861', '28', '15']
# ['305686496', 'M83985861', '151', '15']
# ['301090900', 'M83985861', '31', '15']
# ['305771101', 'M83985861', '27', '15']
# ['301458840', 'M83985861', '28', '15']
# ['305814258', 'M83985861', '27', '15']
# ['305789815', 'M83985861', '32', '15']
# ['304990472', 'M83985861', '152', '15']
# ['302747776', 'M83985861', '28', '15']
# ['301872605', 'M83985861', '28', '15']
# ['305262259', 'M83985861', '27', '15']
# ['305408997', 'M83985861', '27', '15']
# ['303219498', 'M83985861', '28', '15']
# ['305713226', 'M83985861', '27', '15']
# ['305785971', 'M83985861', '28', '15']
# ['305727034', 'M83985861', '32', '15']
# ['305814256', 'M83985861', '27', '15']
# ['305703448', 'M83985861', '32', '15']
# ['305696085', 'M83985861', '28', '15']
# ['305681170', 'M83985861', '32', '15']
# ['305681161', 'M83985861', '152', '15']
# ['305801873', 'M83985861', '29', '15']
# ['305208795', 'M83985861', '28', '15']
# ['303732547', 'M83985861', '28', '15']
# ['304674084', 'M83985861', '31', '15']
# ['302668757', 'M83985861', '28', '15']
# ['305733727', 'M83985861', '28', '15']
# ['303788020', 'M83985861', '32', '15']
# ['304277140', 'M83985861', '31', '15']
# ['301451839', 'M83985861', '32', '15']
# ['305430643', 'M83985861', '151', '15']
# ['303425466', 'M83985861', '28', '15']
# ['302280268', 'M83985861', '28', '15']
# ['301523775', 'M83985861', '32', '15']
# ['303814529', 'M83985861', '151', '15']
# ['300875863', 'M83985861', '151', '15']
# ['301138700', 'M83985861', '28', '15']
# ['305733690', 'M83985861', '151', '15']
# ['303170611', 'M83985861', '27', '15']
# ['302746077', 'M83985861', '151', '15']
# ['302480746', 'M83985861', '27', '15']
# ['305706785', 'M83985861', '154', '15']
# ['305687841', 'M83985861', '45', '15']
# ['305682450', 'M83985861', '45', '15']
# ['302907984', 'M83985861', '45', '15']
# ['305817551', 'M83985861', '44', '15']
# ['301606902', 'M83985861', '45', '15']
# ['305830517', 'M83985861', '45', '15']
# ['305773685', 'M83985861', '45', '15']
# ['305682434', 'M83985861', '45', '15']
# ['305787271', 'M83985861', '45', '15']
# ['305829350', 'M83985861', '45', '15']
# ['305774576', 'M83985861', '44', '15']
# ['305831809', 'M83985861', '44', '15']
# ['301656756', 'M83985861', '154', '15']
# ['301737098', 'M83985861', '44', '17']
# ['301765087', 'M83985861', '44', '15']
# ['302187321', 'M83985861', '44', '15']
# ['305794400', 'M83985861', '44', '15']
# ['305775002', 'M83985861', '45', '15']
# ['303442148', 'M83985861', '45', '15']
# ['303437256', 'M83985861', '45', '15']
# ['305831182', 'M83985861', '44', '15']
# ['305771649', 'M83985861', '45', '15']
# ['305771656', 'M83985861', '45', '15']
# ['302907977', 'M83985861', '45', '15']
# ['303583334', 'M83985861', '45', '15']
# ['303442336', 'M83985861', '45', '15']
# ['303442153', 'M83985861', '45', '17']
# ['302685112', 'M83985861', '44', '15']
# ['305681153', 'M83985861', '45', '15']
# ['301692934', 'M83985861', '45', '15']
# ['305765877', 'M83985861', '45', '15']
# ['305825151', 'M83985861', '44', '15']
# ['305817963', 'M83985861', '44', '15']
# ['305687851', 'M83985861', '45', '15']
# ['305765867', 'M83985861', '45', '15']
# ['302746537', 'M83985861', '45', '15']
# ['302849742', 'M83985861', '44', '15']
# ['301714193', 'M83985861', '45', '15']
# ['302746918', 'M83985861', '45', '15']
# ['302752000', 'M83985861', '44', '15']
# ['302751986', 'M83985861', '44', '15']
# ['305814941', 'M83985861', '45', '15']
# ['305687850', 'M83985861', '44', '15']
# ['305822971', 'M83985861', '45', '15']
# ['305822970', 'M83985861', '45', '15']
# ['305779620', 'M83985861', '44', '15']
# ['302936481', 'M83985861', '44', '15']
# ['305706815', 'M83985861', '154', '15']
# ['301392184', 'M83985861', '44', '15']
# ['305825454', 'M83985861', '44', '15']
# ['300861598', 'M83985861', '45', '15']
# ['300854935', 'M83985861', '45', '15']
# ['304739578', 'M83985861', '45', '15']
# ['302281876', 'M83985861', '154', '15']
# ['302281875', 'M83985861', '154', '15']
# ['301880519', 'M83985861', '45', '15']
# ['301656755', 'M83985861', '154', '15']
# ['305627989', 'M83985861', '45', '15']
# ['305805469', 'M83985861', '154', '15']
# ['305701658', 'M83985861', '45', '15']
# ['305831102', 'M83985861', '44', '15']
# ['301837423', 'M83985861', '45', '15']
# ['305744798', 'M83985861', '44', '15']
# ['302995336', 'M83985861', '44', '15']
# ['302710208', 'M83985861', '45', '15']
# ['301721359', 'M83985861', '44', '15']
# ['302849718', 'M83985861', '45', '15']
# ['305737283', 'M83985861', '45', '15']
# ['305729431', 'M83985861', '45', '15']
# ['305813143', 'M83985861', '45', '15']
# ['305683021', 'M83985861', '45', '15']
# ['303302023', 'M83985861', '45', '15']
# ['302261248', 'M83985861', '45', '15']
# ['300984192', 'M83985861', '34', '15']
# ['300968436', 'M83985861', '34', '15']
# ['301654812', 'M83985861', '34', '15']
# ['301772908', 'M83985861', '34', '15']
# ['302837458', 'M83985861', '34', '15']
# ['301221211', 'M83985861', '34', '15']
# ['305725854', 'M83985861', '155', '15']
# ['302546986', 'M83985861', '34', '15']
# ['302437032', 'M83985861', '34', '15']
# ['302038215', 'M83985861', '34', '15']
# ['301694969', 'M83985861', '34', '15']
# ['303203020', 'M83985861', '34', '15']
# ['305734039', 'M83985861', '34', '15']
# ['300968453', 'M83985861', '34', '15']
# ['303145192', 'M83985861', '34', '15']
# ['302669563', 'M83985861', '34', '15']
# ['301716336', 'M83985861', '34', '15']
# ['305283906', 'M83985861', '35', '15']
# ['302546995', 'M83985861', '34', '15']
# ['305790582', 'M83985861', '34', '15']
# ['302669567', 'M83985861', '34', '15']
# ['301592541', 'M83985861', '36', '15']
# ['305690977', 'M83985861', '34', '15']
# ['303436347', 'M83985861', '36', '15']
# ['305830524', 'M83985861', '34', '15']
# ['302686044', 'M83985861', '34', '15']
# ['302912797', 'M83985861', '34', '17']
# ['305777706', 'M83985861', '34', '15']
# ['305409204', 'M83985861', '37', '15']
# ['301418111', 'M83985861', '35', '15']
# ['301795203', 'M83985861', '34', '15']
# ['302912430', 'M83985861', '34', '17']
# ['302752014', 'M83985861', '34', '15']
# ['301739296', 'M83985861', '34', '15']
# ['305752338', 'M83985861', '35', '17']
# ['305780395', 'M83985861', '34', '15']
# ['302986572', 'M83985861', '34', '15']
# ['300968441', 'M83985861', '34', '15']
# ['302767455', 'M83985861', '34', '15']
# ['305813183', 'M83985861', '34', '15']
# ['305823501', 'M83985861', '34', '15']
# ['305830523', 'M83985861', '34', '15']
# ['305830521', 'M83985861', '34', '15']
# ['305696590', 'M83985861', '35', '15']
# ['301654817', 'M83985861', '34', '15']
# ['301759925', 'M83985861', '34', '15']
# ['304155827', 'M83985861', '36', '15']
# ['301646542', 'M83985861', '34', '15']
# ['305752339', 'M83985861', '35', '17']
# ['305752337', 'M83985861', '35', '17']
# ['302849749', 'M83985861', '34', '15']
# ['303228259', 'M83985861', '34', '15']
# ['301709375', 'M83985861', '34', '15']
# ['302187317', 'M83985861', '37', '15']
# ['303208122', 'M83985861', '35', '15']
# ['303208119', 'M83985861', '35', '15']
# ['302816767', 'M83985861', '34', '15']
# ['301711726', 'M83985861', '34', '15']
# ['302249504', 'M83985861', '36', '15']
# ['301364725', 'M83985861', '34', '15']
# ['305801638', 'M83985861', '34', '15']
# ['301685234', 'M83985861', '34', '15']
# ['302279485', 'M83985861', '38', '15']
# ['302739596', 'M83985861', '34', '15']
# ['305602209', 'M83985861', '36', '15']
# ['303033907', 'M83985861', '34', '15']
# ['301423840', 'M83985861', '36', '15']
# ['305813742', 'M83985861', '34', '15']
# ['305688417', 'M83985861', '34', '15']
# ['303875445', 'M83985861', '35', '15']
# ['303875444', 'M83985861', '35', '15']
# ['305690976', 'M83985861', '34', '15']
# ['305717089', 'M83985861', '34', '15']
# ['305816273', 'M83985861', '34', '15']
# ['301854390', 'M83985861', '35', '15']
# ['303814519', 'M83985861', '38', '15']
# ['305813755', 'M83985861', '34', '15']
# ['303208272', 'M83985861', '34', '15']
# ['301772907', 'M83985861', '34', '15']
# ['305715852', 'M83985861', '34', '15']
# ['301654815', 'M83985861', '34', '15']
# ['305710299', 'M83985861', '34', '15']
# ['305779020', 'M83985861', '34', '15']
# ['302918655', 'M83985861', '34', '15']
# ['301527070', 'M83985861', '38', '15']
# ['305795159', 'M83985861', '34', '15']
# ['305261539', 'M83985861', '38', '15']
# ['301674094', 'M83985861', '36', '15']
# ['305743653', 'M83985861', '34', '15']
# ['305283613', 'M83985861', '38', '15']
# ['302709245', 'M83985861', '34', '15']
# ['301287109', 'M83985861', '34', '15']
# ['301004101', 'M83985861', '34', '15']
# ['303089277', 'M83985861', '34', '15']
# ['305750576', 'M83985861', '34', '15']
# ['302746795', 'M83985861', '34', '15']
# ['301650284', 'M83985861', '35', '15']
# ['301729657', 'M83985861', '34', '15']
# ['302114156', 'M83985861', '36', '15']
# ['302752013', 'M83985861', '34', '15']
# ['305792299', 'M83985861', '39', '15']
# ['305798116', 'M83985861', '39', '15']
# ['302955518', 'M83985861', '43', '15']
# ['302906195', 'M83985861', '39', '15']
# ['302134373', 'M83985861', '43', '15']
# ['303442174', 'M83985861', '43', '15']
# ['305797146', 'M83985861', '39', '15']
# ['305797122', 'M83985861', '39', '15']
# ['302746604', 'M83985861', '39', '15']
# ['305710442', 'M83985861', '39', '15']
# ['305797133', 'M83985861', '39', '15']
# ['302803709', 'M83985861', '39', '15']
# ['305716785', 'M83985861', '43', '15']
# ['305699885', 'M83985861', '43', '15']
# ['305699789', 'M83985861', '43', '15']
# ['302869217', 'M83985861', '43', '15']
# ['305814543', 'M83985861', '39', '15']
# ['303355381', 'M83985861', '43', '15']
# ['305806432', 'M83985861', '41', '15']
# ['301881426', 'M83985861', '39', '15']
# ['305809427', 'M83985861', '39', '15']
# ['303355430', 'M83985861', '39', '15']
# ['305284076', 'M83985861', '39', '15']
# ['305792309', 'M83985861', '39', '15']
# ['303589282', 'M83985861', '41', '15']
# ['303725809', 'M83985861', '41', '15']
# ['305687860', 'M83985861', '39', '15']
# ['302278579', 'M83985861', '39', '15']
# ['305684910', 'M83985861', '43', '15']
# ['305798550', 'M83985861', '39', '15']
# ['302685194', 'M83985861', '39', '15']
# ['302483260', 'M83985861', '41', '15']
# ['305749308', 'M83985861', '39', '15']
# ['305788470', 'M83985861', '39', '15']
# ['305798126', 'M83985861', '39', '15']
# ['305744810', 'M83985861', '39', '15']
# ['301902843', 'M83985861', '43', '15']
# ['301639240', 'M83985861', '43', '15']
# ['301792970', 'M83985861', '39', '15']
# ['301279461', 'M83985861', '39', '15']
# ['302726039', 'M83985861', '43', '15']
# ['302726030', 'M83985861', '43', '15']
# ['305797138', 'M83985861', '39', '15']
# ['305798480', 'M83985861', '39', '15']
# ['305798476', 'M83985861', '39', '15']
# ['303089422', 'M83985861', '39', '15']
# ['305805457', 'M83985861', '43', '15']
# ['302615545', 'M83985861', '43', '15']
# ['302288137', 'M83985861', '43', '15']
# ['303287734', 'M83985861', '39', '15']
# ['303355451', 'M83985861', '40', '15']
# ['303355363', 'M83985861', '39', '15']
# ['302483304', 'M83985861', '41', '15']
# ['305822991', 'M83985861', '39', '15']
# ['305792294', 'M83985861', '39', '15']
# ['301839690', 'M83985861', '39', '15']
# ['300931474', 'M83985861', '39', '15']
# ['302906214', 'M83985861', '39', '15']
# ['305792301', 'M83985861', '39', '15']
# ['302849046', 'M83985861', '49', '15']
# ['301674166', 'M83985861', '157', '15']
# ['302745345', 'M83985861', '49', '15']
# ['302180809', 'M83985861', '49', '15']
# ['305682387', 'M83985861', '50', '15']
# ['301747053', 'M83985861', '50', '15']
# ['305757236', 'M83985861', '158', '15']
# ['303800866', 'M83985861', '48', '15']
# ['302328138', 'M83985861', '49', '15']
# ['300917380', 'M83985861', '50', '15']
# ['301759938', 'M83985861', '49', '15']
# ['305798449', 'M83985861', '50', '17']
# ['305710351', 'M83985861', '48', '15']
# ['302562937', 'M83985861', '157', '15']
# ['302187383', 'M83985861', '50', '15']
# ['303355295', 'M83985861', '50', '15']
# ['305823496', 'M83985861', '50', '15']
# ['305706967', 'M83985861', '158', '15']
# ['305602517', 'M83985861', '50', '15']
# ['302563286', 'M83985861', '157', '15']
# ['302563197', 'M83985861', '157', '15']
# ['305794234', 'M83985861', '50', '15']
# ['305771566', 'M83985861', '50', '15']
# ['302838956', 'M83985861', '123', '15']
# ['303192903', 'M83985861', '49', '15']
# ['305681136', 'M83985861', '48', '15']
# ['301674092', 'M83985861', '158', '15']
# ['301763589', 'M83985861', '49', '15']
# ['301129327', 'M83985861', '50', '15']
# ['301613106', 'M83985861', '49', '15']
# ['302668849', 'M83985861', '49', '15']
# ['305786790', 'M83985861', '49', '15']
# ['305777693', 'M83985861', '123', '15']
# ['301714768', 'M83985861', '49', '15']
# ['305741294', 'M83985861', '50', '15']
# ['303355242', 'M83985861', '123', '15']
# ['302261051', 'M83985861', '48', '15']
# ['301412143', 'M83985861', '48', '15']
# ['305682305', 'M83985861', '50', '15']
# ['302746829', 'M83985861', '49', '15']
# ['305682366', 'M83985861', '48', '15']
# ['302745379', 'M83985861', '49', '15']
# ['301638984', 'M83985861', '48', '15']
# ['300458909', 'M83985861', '50', '15']
# ['302749739', 'M83985861', '49', '15']
# ['305706499', 'M83985861', '48', '15']
# ['301747979', 'M83985861', '49', '15']
# ['302546514', 'M83985861', '123', '15']
# ['303136282', 'M83985861', '123', '15']
# ['303355260', 'M83985861', '50', '15']
# ['301129328', 'M83985861', '50', '15']
# ['301351360', 'M83985861', '49', '15']
# ['305798102', 'M83985861', '49', '15']
# ['301421067', 'M83985861', '48', '15']
# ['305809477', 'M83985861', '157', '15']
# ['303257000', 'M83985861', '158', '15']
# ['301599675', 'M83985861', '49', '15']
# ['301601454', 'M83985861', '49', '15']
# ['305781517', 'M83985861', '49', '15']
# ['301639266', 'M83985861', '123', '15']
# ['301805041', 'M83985861', '48', '15']
# ['302258532', 'M83985861', '123', '15']
# ['304162185', 'M83985861', '158', '15']
# ['304515066', 'M83985861', '50', '15']
# ['301744242', 'M83985861', '50', '15']
# ['302247583', 'M83985861', '49', '15']
# ['301712393', 'M83985861', '158', '15']
# ['301229356', 'M83985861', '50', '15']
# ['305770261', 'M83985861', '49', '15']
# ['305744805', 'M83985861', '48', '15']
# ['302547754', 'M83985861', '48', '15']
# ['305826721', 'M83985861', '49', '15']
# ['305805644', 'M83985861', '49', '15']
# ['303136281', 'M83985861', '123', '15']
# ['305734104', 'M83985861', '49', '17']
# ['305771480', 'M83985861', '49', '15']
# ['305750491', 'M83985861', '49', '15']
# ['302563298', 'M83985861', '157', '15']
# ['302760600', 'M83985861', '123', '15']
# ['303170858', 'M83985861', '123', '15']
# ['305625613', 'M83985861', '157', '15']
# ['305798463', 'M83985861', '49', '15']
# ['301753744', 'M83985861', '49', '15']
# ['305829805', 'M83985861', '48', '15']
# ['305817408', 'M83985861', '48', '15']
# ['302800707', 'M83985861', '49', '15']
# ['305644362', 'M83985861', '158', '15']
# ['305644356', 'M83985861', '158', '15']
# ['301910775', 'M83985861', '48', '15']
# ['305798092', 'M83985861', '49', '15']
# ['301640160', 'M83985861', '50', '15']
# ['305821784', 'M83985861', '158', '15']
# ['302284924', 'M83985861', '49', '15']
# ['305777690', 'M83985861', '123', '15']
# ['302834611', 'M83985861', '50', '15']
# ['305839414', 'M83985861', '49', '15']
# ['303248848', 'M83985861', '49', '15']
# ['302647248', 'M83985861', '49', '15']
# ['305817368', 'M83985861', '48', '15']
# ['305784779', 'M83985861', '48', '15']
# ['302332805', 'M83985861', '53', '15']
# ['303355235', 'M83985861', '122', '15']
# ['301138475', 'M83985861', '53', '15']
# ['305708072', 'M83985861', '122', '15']
# ['305755597', 'M83985861', '122', '15']
# ['301449281', 'M83985861', '53', '15']
# ['301602376', 'M83985861', '122', '15']
# ['301758040', 'M83985861', '53', '15']
# ['302281885', 'M83985861', '122', '15']
# ['300984170', 'M83985861', '53', '15']
# ['302689405', 'M83985861', '53', '15']
# ['301873450', 'M83985861', '53', '15']
# ['305706658', 'M83985861', '53', '15']
# ['301885559', 'M83985861', '122', '15']
# ['301692512', 'M83985861', '122', '15']
# ['301682549', 'M83985861', '53', '15']
# ['305816534', 'M83985861', '122', '15']
# ['301586684', 'M83985861', '53', '15']
# ['305816520', 'M83985861', '122', '15']
# ['305816519', 'M83985861', '122', '15']
# ['302482259', 'M83985861', '122', '15']
# ['303355230', 'M83985861', '122', '15']
# ['300086967', 'M83985861', '53', '15']
# ['304013402', 'M83985861', '160', '15']
# ['302715135', 'M83985861', '160', '15']
# ['303869811', 'M83985861', '162', '15']
# ['305694869', 'M83985861', '160', '15']
# ['305241718', 'M83985861', '160', '15']
# ['302749911', 'M83985861', '160', '15']
# ['302219266', 'M83985861', '160', '15']
# ['301851284', 'M83985861', '160', '15']
# ['305337522', 'M83985861', '160', '15']
# ['301883516', 'M83985861', '160', '15']
# ['303103417', 'M83985861', '160', '15']
# ['303870029', 'M83985861', '162', '15']
# ['302862118', 'M83985861', '160', '15']
# ['305694786', 'M83985861', '160', '15']
# ['305694653', 'M83985861', '160', '15']
# ['305188904', 'M83985861', '160', '15']
# ['305694865', 'M83985861', '160', '15']
# ['305694805', 'M83985861', '160', '15']
# ['305694778', 'M83985861', '160', '15']
# ['302793798', 'M83985861', '162', '15']
# ['302793350', 'M83985861', '162', '15']
# ['302793348', 'M83985861', '162', '15']
# ['303279085', 'M83985861', '164', '15']
# ['305297890', 'M83985861', '164', '15']
# ['305030609', 'M83985861', '164', '15']
# ['305030599', 'M83985861', '164', '15']
# ['305795204', 'M83985861', '165', '15']
# ['301683248', 'M33439436', '7', '15']
# ['305770545', 'M33439436', '7', '15']
# ['302729896', 'M33439436', '7', '17']
# ['303894423', 'M33439436', '7', '17']
# ['305690945', 'M33439436', '21', '15']
# ['303894825', 'M33439436', '7', '17']
# ['305796730', 'M33439436', '7', '15']
# ['305814006', 'M33439436', '7', '15']
# ['302809947', 'M33439436', '18', '15']
# ['305770543', 'M33439436', '7', '15']
# ['302739441', 'M33439436', '7', '15']
# ['305795045', 'M33439436', '7', '15']
# ['305721353', 'M33439436', '7', '17']
# ['302699615', 'M33439436', '7', '17']
# ['305721352', 'M33439436', '7', '17']
# ['302837555', 'M33439436', '7', '15']
# ['302284695', 'M33439436', '7', '15']
# ['305721288', 'M33439436', '7', '15']
# ['305707465', 'M33439436', '7', '17']
# ['305788150', 'M33439436', '7', '17']
# ['305802637', 'M33439436', '7', '15']
# ['305715774', 'M33439436', '18', '15']
# ['302804952', 'M33439436', '7', '15']
# ['305309878', 'M33439436', '7', '17']
# ['302272588', 'M33439436', '18', '17']
# ['305812678', 'M33439436', '18', '15']
# ['305657006', 'M33439436', '7', '15']
# ['302285005', 'M33439436', '7', '15']
# ['305797064', 'M33439436', '7', '15']
# ['305796995', 'M33439436', '7', '15']
# ['305309892', 'M33439436', '7', '17']
# ['305721287', 'M33439436', '7', '17']
# ['303626547', 'M33439436', '7', '15']
# ['301760213', 'M33439436', '7', '17']
# ['305809527', 'M33439436', '7', '17']
# ['305788159', 'M33439436', '7', '17']
# ['305788157', 'M33439436', '7', '15']
# ['305802327', 'M33439436', '7', '15']
# ['301750223', 'M33439436', '18', '15']
# ['305812660', 'M33439436', '7', '17']
# ['301899904', 'M33439436', '7', '15']
# ['302301165', 'M33439436', '7', '15']
# ['305812671', 'M33439436', '18', '15']
# ['305715818', 'M33439436', '7', '15']
# ['301822657', 'M33439436', '7', '17']
# ['302743880', 'M33439436', '7', '15']
# ['301873680', 'M33439436', '18', '15']
# ['302699667', 'M33439436', '7', '15']
# ['305773809', 'M33439436', '7', '15']
# ['305704901', 'M33439436', '7', '17']
# ['305814156', 'M33439436', '7', '17']
# ['301217239', 'M33439436', '7', '15']
# ['305833576', 'M33439436', '7', '17']
# ['305710422', 'M33439436', '7', '15']
# ['305798209', 'M33439436', '7', '15']
# ['305806849', 'M33439436', '7', '15']
# ['302810370', 'M33439436', '7', '15']
# ['302284280', 'M33439436', '7', '15']
# ['302245187', 'M33439436', '7', '15']
# ['305794292', 'M33439436', '7', '15']
# ['302699674', 'M33439436', '7', '15']
# ['305810993', 'M33439436', '7', '17']
# ['305809533', 'M33439436', '7', '15']
# ['303894549', 'M33439436', '153', '15']
# ['305812324', 'M33439436', '7', '22']
# ['305814152', 'M33439436', '7', '17']
# ['305727533', 'M33439436', '7', '15']
# ['302809888', 'M33439436', '7', '15']
# ['305740944', 'M33439436', '18', '15']
# ['301459314', 'M33439436', '7', '17']
# ['305606599', 'M33439436', '7', '15']
# ['305719610', 'M33439436', '7', '15']
# ['304473418', 'M33439436', '7', '15']
# ['305744980', 'M33439436', '7', '15']
# ['305830945', 'M33439436', '7', '17']
# ['301702108', 'M33439436', '18', '15']
# ['301827750', 'M33439436', '220', '15']
# ['302760574', 'M33439436', '7', '15']
# ['305691312', 'M33439436', '18', '15']
# ['305794462', 'M33439436', '7', '15']
# ['305802515', 'M33439436', '18', '17']
# ['303587348', 'M33439436', '18', '15']
# ['305776185', 'M33439436', '7', '17']
# ['305696494', 'M33439436', '7', '15']
# ['305716516', 'M33439436', '7', '15']
# ['302306912', 'M33439436', '7', '15']
# ['305791938', 'M33439436', '7', '15']
# ['305727712', 'M33439436', '7', '15']
# ['305819773', 'M33439436', '7', '17']
# ['301634550', 'M33439436', '7', '15']
# ['305715775', 'M33439436', '18', '15']
# ['305625407', 'M33439436', '18', '15']
# ['305603742', 'M33439436', '7', '15']
# ['301851502', 'M33439436', '18', '15']
# ['305708999', 'M33439436', '7', '15']
# ['305792201', 'M33439436', '7', '15']
# ['301709817', 'M33439436', '7', '15']
# ['305706527', 'M33439436', '7', '15']
# ['302255822', 'M33439436', '7', '15']
# ['305830944', 'M33439436', '7', '17']
# ['301630715', 'M33439436', '190', '15']
# ['305812017', 'M33439436', '35', '17']
# ['302792038', 'M33439436', '35', '17']
# ['302765205', 'M33439436', '328', '15']
# ['301722080', 'M33439436', '35', '15']
# ['304891098', 'M33439436', '35', '15']
# ['302791499', 'M33439436', '190', '15']
# ['305796936', 'M33439436', '190', '17']
# ['301630734', 'M33439436', '190', '17']
# ['302580063', 'M33439436', '190', '15']
# ['304891095', 'M33439436', '34', '15']
# ['300964338', 'M33439436', '190', '15']
# ['301717249', 'M33439436', '35', '15']
# ['301325256', 'M33439436', '190', '17']
# ['303894778', 'M33439436', '35', '15']
# ['301751943', 'M33439436', '35', '15']
# ['305684626', 'M33439436', '35', '17']
# ['302615720', 'M33439436', '35', '15']
# ['301754804', 'M33439436', '35', '15']
# ['301798682', 'M33439436', '35', '17']
# ['305812754', 'M33439436', '35', '15']
# ['305751640', 'M33439436', '35', '15']
# ['305810758', 'M33439436', '35', '17']
# ['305802085', 'M33439436', '34', '15']
# ['301700983', 'M33439436', '35', '15']
# ['300951066', 'M33439436', '35', '17']
# ['302795732', 'M33439436', '190', '15']
# ['305727534', 'M33439436', '34', '15']
# ['305768086', 'M33439436', '328', '17']
# ['305797049', 'M33439436', '190', '17']
# ['301333521', 'M33439436', '190', '15']
# ['301630757', 'M33439436', '190', '17']
# ['302904785', 'M33439436', '36', '15']
# ['305707746', 'M33439436', '35', '15']
# ['305720127', 'M33439436', '35', '17']
# ['302962691', 'M33439436', '35', '17']
# ['302721709', 'M33439436', '35', '17']
# ['302365565', 'M33439436', '190', '15']
# ['303195252', 'M33439436', '35', '15']
# ['302768208', 'M33439436', '35', '15']
# ['305817887', 'M33439436', '35', '15']
# ['305810730', 'M33439436', '36', '15']
# ['302768203', 'M33439436', '35', '15']
# ['305792066', 'M33439436', '190', '15']
# ['305161080', 'M33439436', '35', '17']
# ['302899501', 'M33439436', '34', '17']
# ['303303587', 'M33439436', '190', '15']
# ['302906766', 'M33439436', '35', '17']
# ['302616185', 'M33439436', '35', '15']
# ['302917355', 'M33439436', '35', '15']
# ['303195243', 'M33439436', '35', '15']
# ['305792065', 'M33439436', '190', '15']
# ['301449174', 'M33439436', '190', '15']
# ['305720028', 'M33439436', '35', '17']
# ['300964307', 'M33439436', '190', '15']
# ['301824178', 'M33439436', '34', '15']
# ['305792133', 'M33439436', '34', '15']
# ['302726715', 'M33439436', '34', '15']
# ['301722059', 'M33439436', '34', '15']
# ['305817886', 'M33439436', '35', '17']
# ['301646210', 'M33439436', '190', '15']
# ['305771596', 'M33439436', '190', '17']
# ['305720073', 'M33439436', '35', '17']
# ['301071779', 'M33439436', '190', '15']
# ['303099900', 'M33439436', '35', '15']
# ['302746352', 'M33439436', '35', '15']
# ['305767232', 'M33439436', '190', '15']
# ['302743822', 'M33439436', '35', '15']
# ['302126548', 'M33439436', '35', '15']
# ['305691023', 'M33439436', '36', '15']
# ['305720131', 'M33439436', '35', '17']
# ['305724602', 'M33439436', '35', '15']
# ['302962110', 'M33439436', '35', '15']
# ['302862176', 'M33439436', '35', '17']
# ['302276571', 'M33439436', '35', '15']
# ['302685167', 'M33439436', '35', '15']
# ['305796671', 'M33439436', '35', '15']
# ['302280495', 'M33439436', '35', '15']
# ['301671296', 'M33439436', '190', '17']
# ['303701945', 'M33439436', '34', '17']
# ['305704323', 'M33439436', '190', '15']
# ['305787440', 'M33439436', '35', '17']
# ['302809896', 'M33439436', '35', '15']
# ['305810709', 'M33439436', '35', '15']
# ['305764203', 'M33439436', '35', '15']
# ['303244117', 'M33439436', '328', '17']
# ['304881609', 'M33439436', '35', '15']
# ['305795885', 'M33439436', '190', '15']
# ['303099866', 'M33439436', '35', '15']
# ['301594489', 'M33439436', '190', '17']
# ['305727655', 'M33439436', '34', '15']
# ['301017126', 'M33439436', '34', '15']
# ['305702848', 'M33439436', '35', '15']
# ['305797053', 'M33439436', '190', '17']
# ['302955508', 'M33439436', '36', '15']
# ['305733663', 'M33439436', '34', '15']
# ['305603836', 'M33439436', '34', '15']
# ['305788024', 'M33439436', '35', '17']
# ['305747601', 'M33439436', '34', '15']
# ['305294907', 'M33439436', '190', '15']
# ['305830858', 'M33439436', '32', '17']
# ['305409312', 'M33439436', '32', '17']
# ['302715097', 'M33439436', '32', '17']
# ['305717922', 'M33439436', '32', '17']
# ['305812703', 'M33439436', '32', '17']
# ['303894439', 'M33439436', '32', '17']
# ['305409077', 'M33439436', '32', '15']
# ['302986393', 'M33439436', '32', '15']
# ['305720708', 'M33439436', '32', '17']
# ['305776549', 'M33439436', '32', '17']
# ['301829949', 'M33439436', '32', '15']
# ['305812700', 'M33439436', '32', '15']
# ['301795419', 'M33439436', '32', '15']
# ['302686001', 'M33439436', '32', '15']
# ['305775522', 'M33439436', '32', '15']
# ['305776320', 'M33439436', '32', '15']
# ['305802429', 'M33439436', '32', '15']
# ['305783193', 'M33439436', '32', '17']
# ['305747633', 'M33439436', '32', '15']
# ['302763535', 'M33439436', '32', '17']
# ['305747609', 'M33439436', '32', '15']
# ['305786877', 'M33439436', '32', '15']
# ['305745024', 'M33439436', '32', '15']
# ['305830856', 'M33439436', '32', '17']
# ['301673790', 'M33439436', '32', '15']
# ['305682232', 'M33439436', '32', '17']
# ['305657007', 'M33439436', '32', '15']
# ['301842565', 'M33439436', '32', '15']
# ['305787223', 'M33439436', '32', '15']
# ['302862858', 'M33439436', '32', '15']
# ['305624888', 'M33439436', '32', '15']
# ['305747632', 'M33439436', '32', '15']
# ['305773756', 'M33439436', '32', '17']
# ['301782401', 'M33439436', '32', '15']
# ['301085978', 'M33439436', '32', '15']
# ['302933328', 'M33439436', '32', '17']
# ['305747628', 'M33439436', '32', '15']
# ['300951085', 'M33439436', '32', '17']
# ['301085931', 'M33439436', '32', '15']
# ['305776364', 'M33439436', '32', '15']
# ['305814141', 'M33439436', '32', '15']
# ['302730173', 'M33439436', '32', '15']
# ['303640351', 'M33439436', '32', '15']
# ['302900718', 'M33439436', '32', '17']
# ['302373329', 'M33439436', '32', '15']
# ['303780814', 'M33439436', '32', '15']
# ['305802235', 'M33439436', '32', '15']
# ['303884804', 'M33439436', '32', '15']
# ['301842683', 'M33439436', '32', '15']
# ['302276702', 'M33439436', '32', '15']
# ['305802540', 'M33439436', '32', '15']
# ['302641177', 'M33439436', '32', '15']
# ['305720707', 'M33439436', '32', '17']
# ['305762346', 'M33439436', '32', '15']
# ['302715091', 'M33439436', '32', '17']
# ['302272504', 'M33439436', '32', '15']
# ['305830883', 'M33439436', '32', '15']
# ['305819343', 'M33439436', '32', '15']
# ['305787442', 'M33439436', '32', '17']
# ['302764738', 'M33439436', '32', '15']
# ['305809337', 'M33439436', '32', '15']
# ['305814142', 'M33439436', '32', '15']
# ['305830882', 'M33439436', '32', '17']
# ['302293954', 'M33439436', '32', '15']
# ['305740906', 'M33439436', '32', '15']
# ['301827414', 'M33439436', '32', '15']
# ['305823829', 'M33439436', '32', '15']
# ['305719546', 'M33439436', '32', '17']
# ['301157179', 'M33439436', '32', '17']
# ['302284436', 'M33439436', '32', '15']
# ['302812262', 'M33439436', '32', '17']
# ['305720740', 'M33439436', '32', '15']
# ['305764338', 'M33439436', '32', '15']
# ['305696908', 'M33439436', '32', '15']
# ['305734227', 'M33439436', '32', '17']
# ['305792176', 'M33439436', '32', '15']
# ['305796970', 'M33439436', '32', '17']
# ['305719539', 'M33439436', '32', '17']
# ['305732958', 'M33439436', '32', '15']
# ['302262983', 'M33439436', '32', '17']
# ['305732596', 'M33439436', '32', '17']
# ['305690494', 'M33439436', '32', '17']
# ['303243303', 'M33439436', '32', '15']
# ['301843185', 'M33439436', '32', '15']
# ['305733517', 'M33439436', '32', '15']
# ['301594523', 'M33439436', '32', '15']
# ['302953594', 'M33439436', '32', '17']
# ['305787118', 'M33439436', '32', '15']
# ['305830863', 'M33439436', '32', '17']
# ['305817816', 'M33439436', '32', '15']
# ['305772857', 'M33439436', '32', '15']
# ['305752353', 'M33439436', '32', '15']
# ['303243316', 'M33439436', '32', '15']
# ['301625204', 'M33439436', '32', '15']
# ['301795460', 'M33439436', '32', '15']
# ['305830884', 'M33439436', '32', '15']
# ['302874183', 'M33439436', '32', '15']
# ['301843269', 'M33439436', '32', '15']
# ['301720112', 'M33439436', '32', '15']
# ['305796037', 'M33439436', '32', '15']
# ['301494875', 'M33439436', '33', '17']
# ['305708118', 'M33439436', '33', '17']
# ['301262356', 'M33439436', '33', '15']
# ['302935627', 'M33439436', '33', '15']
# ['305792061', 'M33439436', '33', '17']
# ['303894508', 'M33439436', '33', '15']
# ['302298115', 'M33439436', '33', '17']
# ['301720010', 'M33439436', '33', '15']
# ['303884331', 'M33439436', '33', '17']
# ['303894897', 'M33439436', '33', '15']
# ['303894792', 'M33439436', '33', '17']
# ['301945124', 'M33439436', '33', '15']
# ['305330120', 'M33439436', '33', '15']
# ['304488755', 'M33439436', '33', '15']
# ['302257727', 'M33439436', '33', '15']
# ['305729294', 'M33439436', '33', '17']
# ['305720567', 'M33439436', '33', '15']
# ['305688890', 'M33439436', '33', '15']
# ['305788122', 'M33439436', '33', '17']
# ['301703521', 'M33439436', '33', '15']
# ['305691082', 'M33439436', '33', '15']
# ['303894901', 'M33439436', '33', '15']
# ['305811620', 'M33439436', '33', '17']
# ['305657322', 'M33439436', '33', '15']
# ['301482915', 'M33439436', '33', '15']
# ['305714641', 'M33439436', '33', '17']
# ['305715787', 'M33439436', '33', '15']
# ['302764780', 'M33439436', '33', '15']
# ['305827258', 'M33439436', '33', '15']
# ['305771060', 'M33439436', '33', '17']
# ['302289712', 'M33439436', '33', '15']
# ['305822974', 'M33439436', '33', '15']
# ['305721449', 'M33439436', '33', '15']
# ['305729311', 'M33439436', '33', '17']
# ['305744997', 'M33439436', '33', '15']
# ['305700229', 'M33439436', '33', '15']
# ['305720687', 'M33439436', '33', '15']
# ['301545617', 'M33439436', '33', '17']
# ['305796708', 'M33439436', '33', '15']
# ['302932891', 'M33439436', '33', '17']
# ['301724159', 'M33439436', '33', '15']
# ['305716380', 'M33439436', '33', '15']
# ['305735488', 'M33439436', '33', '15']
# ['305682197', 'M33439436', '33', '17']
# ['302284309', 'M33439436', '33', '15']
# ['305721351', 'M33439436', '33', '17']
# ['302304830', 'M33439436', '33', '15']
# ['301761517', 'M33439436', '33', '15']
# ['303145715', 'M33439436', '33', '15']
# ['305725340', 'M33439436', '33', '15']
# ['305727245', 'M33439436', '33', '17']
# ['305822032', 'M33439436', '33', '15']
# ['303894791', 'M33439436', '33', '15']
# ['302630503', 'M33439436', '33', '15']
# ['301634496', 'M33439436', '33', '15']
# ['303894511', 'M33439436', '33', '15']
# ['305761458', 'M33439436', '33', '17']
# ['301827855', 'M33439436', '33', '15']
# ['305710241', 'M33439436', '33', '15']
# ['304193885', 'M33439436', '33', '15']
# ['305751763', 'M33439436', '33', '15']
# ['305773966', 'M33439436', '33', '15']
# ['302164104', 'M33439436', '33', '15']
# ['301614981', 'M33439436', '33', '15']
# ['302164105', 'M33439436', '33', '15']
# ['305363038', 'M33439436', '33', '15']
# ['305296714', 'M33439436', '33', '15']
# ['304265040', 'M33439436', '33', '15']
# ['302329088', 'M33439436', '33', '17']
# ['305788204', 'M33439436', '33', '15']
# ['305693996', 'M33439436', '33', '15']
# ['302212216', 'M33439436', '33', '15']
# ['305791448', 'M33439436', '33', '15']
# ['302315176', 'M33439436', '33', '15']
# ['302646860', 'M33439436', '33', '15']
# ['303894751', 'M33439436', '33', '15']
# ['301327012', 'M33439436', '33', '15']
# ['303894506', 'M33439436', '33', '15']
# ['305682516', 'M33439436', '33', '15']
# ['301910806', 'M33439436', '33', '15']
# ['305779223', 'M33439436', '33', '15']
# ['305729278', 'M33439436', '33', '17']
# ['305812685', 'M33439436', '33', '15']
# ['305785624', 'M33439436', '33', '15']
# ['305817487', 'M33439436', '33', '17']
# ['303329087', 'M33439436', '33', '15']
# ['305760894', 'M33439436', '33', '15']
# ['304472718', 'M33439436', '33', '15']
# ['305693515', 'M33439436', '33', '15']
# ['305749655', 'M33439436', '33', '15']
# ['305817807', 'M33439436', '33', '15']
# ['302935606', 'M33439436', '33', '15']
# ['302871724', 'M33439436', '33', '15']
# ['305330119', 'M33439436', '33', '15']
# ['302260130', 'M33439436', '33', '15']
# ['305686966', 'M33439436', '33', '15']
# ['305742049', 'M33439436', '33', '15']
# ['305705530', 'M33439436', '33', '15']
# ['305771001', 'M33439436', '33', '17']
# ['302190508', 'M33439436', '33', '15']
# ['305764392', 'M33439436', '30', '15']
# ['301782553', 'M33439436', '30', '15']
# ['305740887', 'M33439436', '30', '17']
# ['305429773', 'M33439436', '30', '15']
# ['301721947', 'M33439436', '30', '15']
# ['303894790', 'M33439436', '30', '17']
# ['301697058', 'M33439436', '30', '17']
# ['302272297', 'M33439436', '30', '15']
# ['305768588', 'M33439436', '31', '15']
# ['305769738', 'M33439436', '30', '17']
# ['305768589', 'M33439436', '31', '15']
# ['305796861', 'M33439436', '30', '17']
# ['305095802', 'M33439436', '30', '15']
# ['305777754', 'M33439436', '30', '15']
# ['305810752', 'M33439436', '30', '17']
# ['304471819', 'M33439436', '30', '15']
# ['304472288', 'M33439436', '30', '15']
# ['302550155', 'M33439436', '30', '17']
# ['305764395', 'M33439436', '30', '15']
# ['305625455', 'M33439436', '30', '17']
# ['305764393', 'M33439436', '30', '15']
# ['302719550', 'M33439436', '30', '17']
# ['305802698', 'M33439436', '30', '17']
# ['304471543', 'M33439436', '30', '15']
# ['305707918', 'M33439436', '30', '17']
# ['305804265', 'M33439436', '29', '15']
# ['305272066', 'M33439436', '27', '15']
# ['302291233', 'M33439436', '30', '15']
# ['301730217', 'M33439436', '30', '17']
# ['304472411', 'M33439436', '30', '15']
# ['302739714', 'M33439436', '30', '15']
# ['303159413', 'M33439436', '30', '15']
# ['305694019', 'M33439436', '30', '15']
# ['305330866', 'M33439436', '30', '15']
# ['305796898', 'M33439436', '30', '17']
# ['305768571', 'M33439436', '31', '15']
# ['305296705', 'M33439436', '30', '17']
# ['305686873', 'M33439436', '30', '15']
# ['302332107', 'M33439436', '30', '15']
# ['302763749', 'M33439436', '29', '17']
# ['302763619', 'M33439436', '30', '17']
# ['305794793', 'M33439436', '27', '15']
# ['304482671', 'M33439436', '27', '15']
# ['301218440', 'M33439436', '30', '15']
# ['305734037', 'M33439436', '30', '15']
# ['302647079', 'M33439436', '30', '17']
# ['305812696', 'M33439436', '29', '15']
# ['305748712', 'M33439436', '30', '17']
# ['305795740', 'M33439436', '30', '15']
# ['304472376', 'M33439436', '30', '17']
# ['301757092', 'M33439436', '30', '17']
# ['305740886', 'M33439436', '30', '17']
# ['305768584', 'M33439436', '31', '15']
# ['305827806', 'M33439436', '30', '17']
# ['304458229', 'M33439436', '30', '17']
# ['301086000', 'M33439436', '29', '15']
# ['305796846', 'M33439436', '30', '15']
# ['305694034', 'M33439436', '30', '15']
# ['301794918', 'M33439436', '30', '17']
# ['305796907', 'M33439436', '30', '17']
# ['301695429', 'M33439436', '30', '17']
# ['301662919', 'M33439436', '30', '17']
# ['305688798', 'M33439436', '31', '15']
# ['301010413', 'M33439436', '30', '15']
# ['305714835', 'M33439436', '30', '15']
# ['305716043', 'M33439436', '30', '15']
# ['301692454', 'M33439436', '30', '15']
# ['304471482', 'M33439436', '30', '15']
# ['302706182', 'M33439436', '29', '15']
# ['305770062', 'M33439436', '29', '15']
# ['301723907', 'M33439436', '30', '17']
# ['305812707', 'M33439436', '29', '15']
# ['305682689', 'M33439436', '27', '15']
# ['305768867', 'M33439436', '30', '15']
# ['305704765', 'M33439436', '30', '15']
# ['305776130', 'M33439436', '30', '17']
# ['305788430', 'M33439436', '30', '15']
# ['302606540', 'M33439436', '30', '15']
# ['305748699', 'M33439436', '30', '17']
# ['302304857', 'M33439436', '30', '15']
# ['303894889', 'M33439436', '31', '15']
# ['305789775', 'M33439436', '30', '17']
# ['305178087', 'M33439436', '30', '15']
# ['301826653', 'M33439436', '30', '17']
# ['301193006', 'M33439436', '30', '15']
# ['305707922', 'M33439436', '30', '17']
# ['305720586', 'M33439436', '30', '17']
# ['305830840', 'M33439436', '30', '17']
# ['305776142', 'M33439436', '30', '15']
# ['301640052', 'M33439436', '30', '15']
# ['305777717', 'M33439436', '30', '15']
# ['305658667', 'M33439436', '30', '15']
# ['305336222', 'M33439436', '30', '15']
# ['304055735', 'M33439436', '27', '17']
# ['305719585', 'M33439436', '29', '17']
# ['301760176', 'M33439436', '30', '17']
# ['302666836', 'M33439436', '30', '17']
# ['305804248', 'M33439436', '30', '15']
# ['304458266', 'M33439436', '30', '15']
# ['305715791', 'M33439436', '29', '15']
# ['305703719', 'M33439436', '24', '17']
# ['305789707', 'M33439436', '24', '17']
# ['305789722', 'M33439436', '23', '17']
# ['305713697', 'M33439436', '24', '17']
# ['305747606', 'M33439436', '24', '15']
# ['305430030', 'M33439436', '24', '17']
# ['305430068', 'M33439436', '24', '17']
# ['305812710', 'M33439436', '24', '15']
# ['305719843', 'M33439436', '24', '15']
# ['305812175', 'M33439436', '24', '15']
# ['305812208', 'M33439436', '23', '15']
# ['301085943', 'M33439436', '23', '15']
# ['305695347', 'M33439436', '24', '17']
# ['305792209', 'M33439436', '23', '15']
# ['305779779', 'M33439436', '155', '15']
# ['305710345', 'M33439436', '24', '15']
# ['302242923', 'M33439436', '24', '17']
# ['305665643', 'M33439436', '24', '15']
# ['303242869', 'M33439436', '24', '15']
# ['303595555', 'M33439436', '23', '15']
# ['305430140', 'M33439436', '24', '17']
# ['305809409', 'M33439436', '23', '15']
# ['305812026', 'M33439436', '23', '15']
# ['305688923', 'M33439436', '24', '15']
# ['305431094', 'M33439436', '24', '15']
# ['305703654', 'M33439436', '24', '17']
# ['305787215', 'M33439436', '24', '17']
# ['303894553', 'M33439436', '155', '15']
# ['305710191', 'M33439436', '23', '17']
# ['305707060', 'M33439436', '24', '17']
# ['305075263', 'M33439436', '24', '15']
# ['302647184', 'M33439436', '24', '15']
# ['305806792', 'M33439436', '24', '15']
# ['305774133', 'M33439436', '24', '15']
# ['302305398', 'M33439436', '23', '15']
# ['305796396', 'M33439436', '23', '15']
# ['305646172', 'M33439436', '23', '15']
# ['305735095', 'M33439436', '24', '15']
# ['302706180', 'M33439436', '23', '15']
# ['305796481', 'M33439436', '24', '15']
# ['305096482', 'M33439436', '23', '15']
# ['305710186', 'M33439436', '23', '15']
# ['305715335', 'M33439436', '23', '17']
# ['301351421', 'M33439436', '24', '15']
# ['305812123', 'M33439436', '24', '15']
# ['305814362', 'M33439436', '23', '15']
# ['302837529', 'M33439436', '23', '17']
# ['305404562', 'M33439436', '23', '15']
# ['305295127', 'M33439436', '24', '15']
# ['301086043', 'M33439436', '23', '15']
# ['301606036', 'M33439436', '24', '15']
# ['305769082', 'M33439436', '23', '15']
# ['305199815', 'M33439436', '23', '15']
# ['305296704', 'M33439436', '23', '15']
# ['304514743', 'M33439436', '24', '15']
# ['305667698', 'M33439436', '24', '15']
# ['304134954', 'M33439436', '155', '17']
# ['305828999', 'M33439436', '24', '15']
# ['302058947', 'M33439436', '24', '15']
# ['302327583', 'M33439436', '23', '15']
# ['303430271', 'M33439436', '24', '15']
# ['301843171', 'M33439436', '23', '15']
# ['305707636', 'M33439436', '24', '15']
# ['303242866', 'M33439436', '24', '15']
# ['302810689', 'M33439436', '23', '15']
# ['305737546', 'M33439436', '155', '17']
# ['305807180', 'M33439436', '23', '15']
# ['305714820', 'M33439436', '23', '15']
# ['305814738', 'M33439436', '23', '17']
# ['302746276', 'M33439436', '24', '15']
# ['305812264', 'M33439436', '155', '15']
# ['301689854', 'M33439436', '24', '15']
# ['303894526', 'M33439436', '23', '15']
# ['305733181', 'M33439436', '24', '15']
# ['301652851', 'M33439436', '23', '15']
# ['305776092', 'M33439436', '23', '15']
# ['305766019', 'M33439436', '23', '15']
# ['304659044', 'M33439436', '155', '15']
# ['305772925', 'M33439436', '23', '15']
# ['302720544', 'M33439436', '24', '15']
# ['305792210', 'M33439436', '23', '15']
# ['305310105', 'M33439436', '24', '15']
# ['301730267', 'M33439436', '23', '17']
# ['305199824', 'M33439436', '23', '15']
# ['303355238', 'M33439436', '23', '15']
# ['305798455', 'M33439436', '23', '15']
# ['303000636', 'M33439436', '24', '17']
# ['305796395', 'M33439436', '23', '15']
# ['305817808', 'M33439436', '24', '15']
# ['305795110', 'M33439436', '24', '15']
# ['305684894', 'M33439436', '23', '15']
# ['302916206', 'M33439436', '23', '17']
# ['303355799', 'M33439436', '23', '15']
# ['305804972', 'M33439436', '23', '15']
# ['305817864', 'M33439436', '155', '15']
# ['305756548', 'M33439436', '24', '15']
# ['304156801', 'M33439436', '23', '15']
# ['305784882', 'M33439436', '24', '15']
# ['305719792', 'M33439436', '24', '15']
# ['305751578', 'M33439436', '23', '15']
# ['302759819', 'M33439436', '46', '15']
# ['302729897', 'M33439436', '46', '17']
# ['305812712', 'M33439436', '47', '17']
# ['303329265', 'M33439436', '47', '17']
# ['302179908', 'M33439436', '47', '15']
# ['305812718', 'M33439436', '47', '15']
# ['305727638', 'M33439436', '46', '15']
# ['305795831', 'M33439436', '47', '17']
# ['302986262', 'M33439436', '47', '17']
# ['305588419', 'M33439436', '47', '17']
# ['302764974', 'M33439436', '47', '15']
# ['301843214', 'M33439436', '47', '15']
# ['305688723', 'M33439436', '45', '15']
# ['305724208', 'M33439436', '47', '15']
# ['305789790', 'M33439436', '45', '17']
# ['305710338', 'M33439436', '47', '15']
# ['302795550', 'M33439436', '47', '17']
# ['305810909', 'M33439436', '47', '17']
# ['305812723', 'M33439436', '46', '15']
# ['305785393', 'M33439436', '45', '15']
# ['305729284', 'M33439436', '47', '15']
# ['302730175', 'M33439436', '46', '15']
# ['305690068', 'M33439436', '47', '15']
# ['305766990', 'M33439436', '47', '16']
# ['305797058', 'M33439436', '46', '15']
# ['302933261', 'M33439436', '45', '17']
# ['305733628', 'M33439436', '47', '15']
# ['305812717', 'M33439436', '47', '15']
# ['305364351', 'M33439436', '45', '15']
# ['303544392', 'M33439436', '46', '15']
# ['305703821', 'M33439436', '45', '17']
# ['305624929', 'M33439436', '45', '15']
# ['303425730', 'M33439436', '47', '15']
# ['305707333', 'M33439436', '46', '15']
# ['302292097', 'M33439436', '47', '15']
# ['305810994', 'M33439436', '46', '17']
# ['305716368', 'M33439436', '46', '15']
# ['305691734', 'M33439436', '47', '15']
# ['305816245', 'M33439436', '45', '17']
# ['302714648', 'M33439436', '47', '15']
# ['305817766', 'M33439436', '45', '15']
# ['305747698', 'M33439436', '45', '15']
# ['305785397', 'M33439436', '45', '17']
# ['301858818', 'M33439436', '47', '15']
# ['305829605', 'M33439436', '47', '15']
# ['305776339', 'M33439436', '45', '15']
# ['302996072', 'M33439436', '45', '15']
# ['305819252', 'M33439436', '47', '15']
# ['301851635', 'M33439436', '47', '15']
# ['305773209', 'M33439436', '45', '15']
# ['302258972', 'M33439436', '45', '17']
# ['301652866', 'M33439436', '45', '15']
# ['305703534', 'M33439436', '45', '15']
# ['305362977', 'M33439436', '47', '15']
# ['305762609', 'M33439436', '46', '15']
# ['305749485', 'M33439436', '45', '17']
# ['305703033', 'M33439436', '45', '17']
# ['305733969', 'M33439436', '46', '15']
# ['305742085', 'M33439436', '46', '15']
# ['305787200', 'M33439436', '47', '15']
# ['305690067', 'M33439436', '47', '17']
# ['305768914', 'M33439436', '47', '15']
# ['305588404', 'M33439436', '45', '15']
# ['305806941', 'M33439436', '45', '15']
# ['301709256', 'M33439436', '47', '15']
# ['305709653', 'M33439436', '47', '15']
# ['305692238', 'M33439436', '45', '15']
# ['301263298', 'M33439436', '47', '15']
# ['305813910', 'M33439436', '46', '17']
# ['305133046', 'M33439436', '47', '15']
# ['303893624', 'M33439436', '45', '15']
# ['301098532', 'M33439436', '47', '15']
# ['303423628', 'M33439436', '46', '15']
# ['305807692', 'M33439436', '46', '15']
# ['302899529', 'M33439436', '47', '15']
# ['305588477', 'M33439436', '47', '15']
# ['305691015', 'M33439436', '45', '15']
# ['305813505', 'M33439436', '47', '15']
# ['305684347', 'M33439436', '47', '15']
# ['305813912', 'M33439436', '46', '15']
# ['305714805', 'M33439436', '47', '15']
# ['302759827', 'M33439436', '46', '15']
# ['303359302', 'M33439436', '47', '15']
# ['305783165', 'M33439436', '46', '15']
# ['305681626', 'M33439436', '47', '17']
# ['303243498', 'M33439436', '47', '15']
# ['301643158', 'M33439436', '47', '15']
# ['305773733', 'M33439436', '46', '17']
# ['305805559', 'M33439436', '47', '15']
# ['305752546', 'M33439436', '47', '15']
# ['301659478', 'M33439436', '45', '15']
# ['305409877', 'M33439436', '45', '15']
# ['305703770', 'M33439436', '45', '15']
# ['305802675', 'M33439436', '47', '17']
# ['305720008', 'M33439436', '47', '15']
# ...
# {'itemCd': '302114156', 'review_id': '10183739', 'option': 'BLACK, XL', 'cust_size_info': '173cm,64kg,L/77,30inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ak********', 'time': '2024.04.23', 'content': '기모가 들어가 있어서 한겨울에도 잘입을것 같아요. 스말일 포인트가 아주 귀엽네요. 싸게 잘샀어요.', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302114156', 'review_id': '10165047', 'option': 'NAVY, XL', 'cust_size_info': None, 'size': '큼', 'color': '같음', 'texture': '비슷함', 'user_id': 'hw********', 'time': '2024.04.18', 'content': '95키로 176 cm.남편 사줬는데 오버핏이엇어요 힙해보이고 이뻥노 소재도 좋은듯 합니다 튀는거 안좋아하는 남편이라 이정도 팔꿈치 포인트는 좋아하더라고요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302114156', 'review_id': '10097833', 'option': 'BLACK, M', 'cust_size_info': None, 'size': '적당함', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'hy********', 'time': '2024.04.03', 'content': '편해요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302114156', 'review_id': '10076131', 'option': 'NAVY, M', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': '38********', 'time': '2024.03.29', 'content': '세일 덕분에 웬만한 보세보다 저렴히 득템했어요^^ 재질도 좋고~ 프린팅 귀엽네요 ㅎㅎㅎ 근데 한 싸이즈 더 큰거 사도 괜찮았을 것 같은 느낌 ㅎㅎ', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302114156', 'review_id': '10049056', 'option': 'BLACK, XL', 'cust_size_info': '160cm,55kg,M/66,28inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'wc********', 'time': '2024.03.22', 'content': '배송도 빠르고 상품도 좋아요!', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302114156', 'review_id': '6961780', 'option': 'CREAM, L', 'cust_size_info': None, 'size': '적당함', 'color': '다름', 'texture': '같음', 'user_id': 'pl********', 'time': '2022.12.07', 'content': '기대했던 대로 가볍고 적당한 기모에 따뜻하게 잘 입을 수 있을거 같아요.색상은 기대한것보다 좀 톤다운 된 느낌..크림인데 밝은 베이지 색상같은..ㅠㅠ', 'rating': 4, 'favorite': '0'}
# {'itemCd': '302114156', 'review_id': '6919357', 'option': 'NAVY, M', 'cust_size_info': None, 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'wl********', 'time': '2022.12.05', 'content': '하트티 넘잘입어서 요것도 귀엽길래 사봤어요 ㅎㅎ', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302114156', 'review_id': '6739938', 'option': 'NAVY, S', 'cust_size_info': None, 'size': None, 'color': None, 'texture': None, 'user_id': 'em********', 'time': '2022.11.18', 'content': '소재도 좋고 귀엽고 예뻐요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '10134531', 'option': 'NAVY_XL', 'cust_size_info': '165cm,63kg,M/66,29inch', 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'on********', 'time': '2024.04.11', 'content': '남친주려 샀어요 마니 오버빗입니다원단 좋아요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '10130093', 'option': 'NAVY_L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'km********', 'time': '2024.04.10', 'content': '남자친구 선물로 산건데 사이즈 잘맞아서 좋아요~오버핏 디자인이어서 XL샀으면 너무 컸을 것 같아요!앞쪽 디테일도 예쁘고 색도 무난해서 잘입을 것 같아 만족합니다 :)', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '10111441', 'option': 'NAVY_XL', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'or********', 'time': '2024.04.06', 'content': '실물이 더 이쁨 만족', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '10101039', 'option': 'NAVY_XL', 'cust_size_info': None, 'size': '큼', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'kb********', 'time': '2024.04.03', 'content': '체격이큰편인데 넉넉하니 잘맞아요!!!!', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '10100320', 'option': 'NAVY_XL', 'cust_size_info': '180cm,100kg', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'km********', 'time': '2024.04.03', 'content': '예뻐요 ㅎㅎ 세탁해도 목 안늘어나면 좋겠어요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '10081417', 'option': 'NAVY_L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'be********', 'time': '2024.03.30', 'content': '남편한테 사이즈도 잘 맞고 색도 이뻐요 그리고 입기 편해서 어디든 매치하기도 좋네요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '10005866', 'option': 'NAVY_XL', 'cust_size_info': '155cm,53kg,M/66,27inch', 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'hy********', 'time': '2024.03.13', 'content': '조금 넉넉하게 이쁘게 잘 나온 것 같아용', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '9232256', 'option': 'NAVY_L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'fr********', 'time': '2023.10.20', 'content': '두께감 있는 소재라 한여름에 입기에는 덥지만 무난하면서도 포인트 있는 디자인이 마음에 들어요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '8993847', 'option': 'NAVY_L', 'cust_size_info': '164cm,52kg', 'size': '적당함', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'jm********', 'time': '2023.09.25', 'content': '패치가 멋스럽고 좋아요 ㅎㅎ', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '8993843', 'option': 'NAVY_XL', 'cust_size_info': '164cm,52kg', 'size': '적당함', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'jm********', 'time': '2023.09.25', 'content': '선물했는데 좋아해용 ㅎㅎㅎ', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '8993840', 'option': 'NAVY_L', 'cust_size_info': '164cm,52kg', 'size': '적당함', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'jm********', 'time': '2023.09.25', 'content': '심플하고 예쁩니당 ㅎㅎ', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '8925378', 'option': 'NAVY_XL', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'js********', 'time': '2023.09.16', 'content': '선물했어요!마음에 든데요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '8910411', 'option': 'NAVY_L', 'cust_size_info': '162cm', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'tj********', 'time': '2023.09.12', 'content': '남편선물해줬는데 맘에들어햇어요 아주 편하고 빨아도 늘어남없어서 잘입는중', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '8876734', 'option': 'NAVY_L', 'cust_size_info': '165cm,52kg', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'tp********', 'time': '2023.09.04', 'content': '173 남편 편하게 잘 입고 있어요.', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '8651187', 'option': 'NAVY_L', 'cust_size_info': '182cm,85kg', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'li********', 'time': '2023.07.22', 'content': '남편 편하게 입는 용으로 마침 세일하길래 저렴하게 구매했어요~~ 전체적으로 오버핏이고 탄탄해서 맘에 듭니도~~~', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '8613988', 'option': 'NAVY_L', 'cust_size_info': '178cm,82kg,XL/88,34inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'tm********', 'time': '2023.07.15', 'content': '깨끗한 옷이 배송되었네요~살짝 마감포인트준게 힙하고 멋있네요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '8028785', 'option': 'NAVY_L', 'cust_size_info': '178cm,75kg,L/77,32inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'am********', 'time': '2023.06.13', 'content': '남자친구 사줬는데 잘 어울리네용! 근데 더울 때는 못 입을 것 같아요ㅠㅠ 너무 두꺼워서', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '8015950', 'option': 'NAVY_L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'gp********', 'time': '2023.06.11', 'content': '얇은데 시원한 재질이라 만족해요!앞으로 잘 입고 다닐거같습니다', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '8001105', 'option': 'NAVY_XL', 'cust_size_info': None, 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'yo********', 'time': '2023.06.07', 'content': '시티브리즈 옷 자주 구매하는데요, 시티브리즈 맨이 있는걸 처음 알고 남편옷도 구입해봤습니다! 디자인 너무 만족스럽고 재질 좋아요! 다만 생각보다 사이즈가 조금 큽니당 ㅎㅎ', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '7969331', 'option': 'NAVY_L', 'cust_size_info': '158cm,46kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'hy********', 'time': '2023.05.31', 'content': '님자친구꺼 샀어요  마음에 드네요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302752013', 'review_id': '7831497', 'option': 'NAVY_L', 'cust_size_info': '180cm,91kg', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'so********', 'time': '2023.05.06', 'content': '남편사줬는데 맘에 들어하네요레터링이 이뻐요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '10114463', 'option': 'L', 'cust_size_info': None, 'size': '큼', 'color': '같음', 'texture': '비슷함', 'user_id': 'la********', 'time': '2024.04.06', 'content': '약간 큰것 같은데 세탁후 약간 줄어들것 생각하면 나쁘진 않은듯 ..색상은 이쁘게 잘빠지고 귀엽.재질은 수건 복슬복슬 느낌이랄까', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '10081138', 'option': 'M', 'cust_size_info': None, 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'cy********', 'time': '2024.03.30', 'content': '색도 너무 예쁘고 두께도 도톰해요. 완전 오버핏이네요  오버핏 좋아하면 무조건입니다ㅎㅎ', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '10007191', 'option': 'L', 'cust_size_info': '163cm,49kg,S/55,26inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'so********', 'time': '2024.03.14', 'content': '색상도 화사하고 소재도 괜찮아요.남편 입히려고 샀는데 제가 라지 사이즈 입어봐도 오버핏 느낌으로 이쁩니다.', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '9971406', 'option': 'L', 'cust_size_info': '184cm,88kg,XL/88,34inch', 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'no********', 'time': '2024.03.10', 'content': '살짝 큰 사이즈감입니다 색감 좋고 데님에 입으면 좋을거같습니다', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '9940482', 'option': 'M', 'cust_size_info': None, 'size': '큼', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'de********', 'time': '2024.03.01', 'content': '오버핏 예상은 했지만, 팔길이 부분은 소매걷어도 여자가 입기는 많이 길어요~톡톡한 소재와 산뜻한 연두에 초록빛이 조금 더해진 색상이고요 예뻐서 만족합니다 :)', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '9899136', 'option': 'L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'zz********', 'time': '2024.02.20', 'content': '색이너무이쁘고 꽤따뜻해요 체격도좋아보이네요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '9845147', 'option': 'M', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ma********', 'time': '2024.02.04', 'content': '175 68키로 기준 살짝 여유있게 맞아서 안에 니트 입고 입어도 핏 좋아요 낑기는 느낌 없고 소매는 길어요너무 예뻐요', 'rating': 5, 'favorite': '1'}
# {'itemCd': '302134373', 'review_id': '9824435', 'option': 'L', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': '12********', 'time': '2024.01.30', 'content': '편하고 초봄에 잘입겠어요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '9771996', 'option': 'M', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'jw********', 'time': '2024.01.16', 'content': '선물했는데 다행이 제품도 빠르게 오고 맘에들어했어요~', 'rating': 5, 'favorite': '1'}
# {'itemCd': '302134373', 'review_id': '9733014', 'option': 'M', 'cust_size_info': '173cm,58kg,L/77,30inch', 'size': '적당함', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'am********', 'time': '2024.01.05', 'content': '사이즈 적당하고 핏이나 소재도 착용하기좋습니다. 겨울에도 입기 편하지만 봄가을에 입기 좋을듯하네요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '9617838', 'option': 'L', 'cust_size_info': '170cm,67kg,L/77,32inch', 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'hy********', 'time': '2023.12.12', 'content': '받자마자 입어봤어요좋은데요팔크기만 좀 크지만 커보이지 않아요편안해보일 듯너무 예뻐요마감처리가 좋고 따뜻하겠네요', 'rating': 5, 'favorite': '1'}
# {'itemCd': '302134373', 'review_id': '9611479', 'option': 'L', 'cust_size_info': '178cm,80kg,L/77,32inch', 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'wt********', 'time': '2023.12.10', 'content': '색감도 이쁘고 소재도 부드러운데 사이즈가 많이 크게 나와서 평소에 라지 입는분도 M으로 가셔야할듯', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '9508967', 'option': 'L', 'cust_size_info': '186cm,89kg', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ki********', 'time': '2023.11.27', 'content': 'unaffected! 꾸미지 않아도 자연스러운 가디건입니다. 팔은 길고 기장은 엉덩이를 덮지 않은 스타일 !  오버사이즈라 슬림한 패딩조끼를 안에 입을 수 있네요!심플하고 색감예뻐서 어느장소나 데일리로 가능할것 같아요.', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '9498991', 'option': 'M', 'cust_size_info': '168cm,54kg,S/55,26inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'rl********', 'time': '2023.11.25', 'content': '남자친구거 사고 너무 예뻐서같이 입으려고 작은 사이즈로 하나 더 샀어욤:)너무 예뻐요!', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '9343765', 'option': 'L', 'cust_size_info': '172cm', 'size': '큼', 'color': '비슷함', 'texture': '같음', 'user_id': 'an********', 'time': '2023.11.08', 'content': '남편꺼 주문하느라 라지 샀는데 저도 충분히툭 걸치기 좋아서 같이 입고 있어요! 추천합니다!', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '9219919', 'option': 'L', 'cust_size_info': '168cm,52kg,S/55,26inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'rl********', 'time': '2023.10.18', 'content': '남친 입히려고 샀는데색감 너무 예뻐요...!', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '9143151', 'option': 'M', 'cust_size_info': '169cm,62kg', 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'hb********', 'time': '2023.10.14', 'content': '엄청 오버핏이라서 놀랐어요ㅎㅎ 무난하게 입기에 정말 좋아요 트레이닝복이나 청바지 모두 어울리고 두께감 있어서 좋아요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '9018030', 'option': 'M', 'cust_size_info': None, 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'be********', 'time': '2023.10.04', 'content': '사이즈표를 보고 예상하긴 했지만 제법 큽니다. 추운날씨에 따뜻하게 잘 입고 다닐게요~', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '9018028', 'option': 'L', 'cust_size_info': None, 'size': '큼', 'color': '같음', 'texture': '같음', 'user_id': 'be********', 'time': '2023.10.04', 'content': '제꺼 사고 아빠도 탐내길래 큰사이즈로 삽니다. 도톰하니이뻐요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '302134373', 'review_id': '8872317', 'option': 'L', 'cust_size_info': None, 'size': '적당함', 'color': '비슷함', 'texture': '같음', 'user_id': 'jr********', 'time': '2023.09.03', 'content': '엄청 부드럽고 하나도 안까끌거립니다뮤겁지도 않거 적당히 축 떨어져서입으면 이쁘네요', 'rating': 5, 'favorite': '1'}
# {'itemCd': '302134373', 'review_id': '6751774', 'option': 'M', 'cust_size_info': None, 'size': None, 'color': None, 'texture': None, 'user_id': 'tk********', 'time': '2022.11.21', 'content': '탄탄하고 좋아요!', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303442174', 'review_id': '10156104', 'option': 'NAVY_F', 'cust_size_info': '163cm,51kg,XS/44,26inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ai********', 'time': '2024.04.17', 'content': '예뻐요. 날이 더워저서 아쉽 ㅠㅜㅜ', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303442174', 'review_id': '10115538', 'option': 'NAVY_F', 'cust_size_info': 'L/77,34inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'he********', 'time': '2024.04.07', 'content': '남자친구 선물해줬어요.디자인이 흔하지 않고 색배합도 잘어울려서 너무 이뻐요!남자친구도 마음에 들었는지 잘 입고 다니네용ㅎㅎ', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303442174', 'review_id': '9865062', 'option': 'NAVY_F', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '비슷함', 'user_id': 'bb********', 'time': '2024.02.11', 'content': '약간 까슬하기는 하지만 이뻐서 반품안하고 입으려구요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303442174', 'review_id': '9713723', 'option': 'NAVY_F', 'cust_size_info': '168cm,62kg,M/66,28inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'kl********', 'time': '2024.01.03', 'content': '패알못 오빠 선물용으로 구입했습니다.알파카랑 울이 많이 섞여있어서 따뜻할것 같아요 모델컷처럼 티셔츠랑 입어도 이쁠듯요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303442174', 'review_id': '9557435', 'option': 'NAVY_F', 'cust_size_info': '160cm,48kg,XS/44,26inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'wc********', 'time': '2023.12.02', 'content': '너무 이뻐요!!!!! 딱 원하던 느낌입니다ㅎㅎ', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303442174', 'review_id': '8930445', 'option': 'NAVY_F', 'cust_size_info': '174cm,82kg,L/77,32inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ok********', 'time': '2023.09.17', 'content': '사진과 똑같아요', 'rating': 5, 'favorite': '0'}
# 9971420    1
# 6418195    1
# 6630557    1
# 6630554    1
# 6625983    1
#           ..
# 6039660    1
# 6038470    1
# 6038463    1
# 6038461    1
# 8930445    1
# Name: review_id, Length: 10003, dtype: int64
