# %%
import time
from bs4 import BeautifulSoup
import pandas as pd
import requests
import json
import re

ITEM_COUNTS = 100

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36',
    'Display-Api-Key': 'VWmkUPgs6g2fviPZ5JQFQ3pERP4tIXv/J2jppLqSRBk='
}

# %%
middle_category_nums = ['10101201', '10101202', '10101203', '10101204', '10101205',
                        '10101206', '10101207', '10101208', '10101209', '10101210',
                        '10101211', '10101212']

# %%
def get_item_cds(middle_category_num, gender):
    url = 'https://api-display.wconcept.co.kr/display/api/v2/best/products'

    if gender == 'men':
        genderType = 'men'
    else:
        genderType = 'women'

    data = {
    "custNo": "",
    "dateType": "daily",
    "domain": 'WOMEN',
    "genderType": genderType,
    "depth1Code": "10101",
    "depth2Code": middle_category_num,
    "pageNo": 1,
    "pageSize": ITEM_COUNTS
    }

    response = requests.post(url, headers=headers, json=data)

    soup = BeautifulSoup(response.text, 'lxml')
    info = soup.string
    info = json.loads(info)
    info = info['data']['content']

    item_cds = []

    for item in info:
        item_cds.append(item['itemCd'])
        

    return item_cds

# %%
def get_item_payloads(item_cd):
    url = 'https://www.wconcept.co.kr/Ajax/GetProductsInfo'

    data = {'itemcds': item_cd}

    response = requests.post(url, headers=headers, data=data)

    soup = BeautifulSoup(response.text, 'lxml')
    info = soup.string
    info = json.loads(info)[0]

    item_cd = info['itemCd']
    medium_cd = info['category'][0]['mediumCd']
    category_cd = info['category'][0]['categoryCd']
    itemtypecd = info['itemTypeCd']

    item_payloads = [item_cd, medium_cd, category_cd, itemtypecd]
    
    print(item_payloads)
    
    return item_payloads

# %%
def get_one_review(i, soup, itemCd):
    # 구매 옵션과 사이즈정보 빼내기 용
    review_info = soup.select('div.pdt_review_info')[i]
    
    # 구매 옵션
    try:
        option = review_info.select('div.pdt_review_option > p')[0].text.strip()
        option = option.split(':')[1].strip()
    except:
        option = None

    # 사이즈 정보
    try:
        cust_size_info = review_info.select('div.pdt_review_option > p')[1].text.strip()
        cust_size_info = cust_size_info.split(':')[1].strip()
    except:
        cust_size_info = None

    # 사이즈, 색상, 소재 빼내기 용
    try:
        sku = soup.select('ul.product_review_evaluation')[i]       

        # 사이즈
        size = sku.select('ul.product_review_evaluation > li > div > em')[0].text

        # 색상
        color = sku.select('ul.product_review_evaluation > li > div > em')[1].text

        # 소재
        texture = sku.select('ul.product_review_evaluation > li > div > em')[2].text
    
    except:
        size, color, texture = None, None, None



    # user id
    user_id = soup.select('p.product_review_info_right > em')[i].text

    # 작성 시간
    time = soup.select('p.product_review_info_right > span')[i].text

    # 리뷰 내용
    content = soup.select('p.pdt_review_text')[i].text.strip()

    # rating 정보
    rating_pct = soup.select('div.star-grade > strong[style]')[i]
    rating = re.findall(r'\d+', str(rating_pct))[0]
    rating = int(int(rating) / 20)

    # 좋아요 개수
    favorite = soup.select('button.like.btn_review_recommend')[i].text


    data = {
        'itemCd': itemCd,
        'option': option,
        'cust_size_info': cust_size_info,
        'size': size,
        'color': color,
        'texture': texture,
        'user_id': user_id,
        'time': time,
        'content': content,
        'rating': rating,
        'favorite': favorite
    }

    return data

# %%
def get_reviews(item_payload):
    url = 'https://www.wconcept.co.kr/Ajax/ProductReViewList'
    i = 1
    one_goods_reviews = []
    while True:
        data = {'itemcd': item_payload[0],
            'pageIndex': i,
            'order': 1,
            'IsPrdCombinOpt': 'N',
            'mediumcd': item_payload[1],
            'categorycd': item_payload[2],
            'itemtypecd': item_payload[3]
            }

        response = requests.post(url, headers=headers, data=data)
        soup = BeautifulSoup(response.text, 'lxml')

        review_count = len(soup.select('p.pdt_review_text'))

        if review_count == 0:
            break
        
        for j in range(review_count):
            review = get_one_review(j, soup, item_payload[0])
            one_goods_reviews.append(review)
            print(review)
        
        i += 1

    return one_goods_reviews

# %%
def main():
    item_cds_list = []
    for gender in ['men', 'women']:
        for middle_category_num in middle_category_nums:
            item_cds = get_item_cds(middle_category_num, gender)
            item_cds_list += item_cds
    print(item_cds_list)

    item_payloads_list = []
    for item_cd in item_cds_list:
        item_payloads_list.append(get_item_payloads(item_cd))


    all_reviews = []

    for item_payloads in item_payloads_list:
        review_per_goods = get_reviews(item_payloads)
        if len(review_per_goods) == 0:
            continue
        else:
            all_reviews += review_per_goods

# %%
if __name__ == '__main__':
    main()
# Out:
# ['301515278', '300605081', '303279261', '305788464', '305780130', '305776033', '300515072', '303355452', '305777670', '302280251', '302746077', '302138248', '301705854', '301269588', '302480752', '304473041', '305691740', '305727041', '301712935', '305811864', '305773508', '305773506', '303665161', '302251100', '305691723', '305785974', '302247616', '305694537', '305785964', '305727031', '301876557', '304473119', '305408927', '305408925', '303452844', '301047578', '305352957', '305743625', '302256748', '303355449', '305782065', '305821486', '303788016', '305771126', '301840142', '304204656', '301857136', '305430643', '302329396', '302496378', '305716777', '305283795', '305283705', '305283667', '302329389', '302745862', '305686510', '305741222', '305682443', '301656756', '301286692', '302746672', '302800679', '305773539', '305719357', '305733541', '303545024', '303583334', '302751987', '302793560', '305736864', '303187502', '301419452', '303437256', '302725849', '302906184', '302717027', '305769800', '301467917', '305816921', '301293873', '303442148', '305816500', '305816497', '302849718', '305694497', '303737970', '305817945', '301267515', '301451981', '305771146', '302480272', '305682450', '302918634', '302689279', '301692934', '305765877', '305765864', '301690993', '303604864', '305682434', '302258692', '305773536', '305809472', '301795233', '302746593', '305813762', '303543402', '305773485', '305823504', '305823503', '305792231', '305792212', '305706785', '302281876', '302281875', '302686372', '305826926', '303149880', '301601954', '305764220', '305805469', '301650297', '305806874', '302907984', '303738230', '302211767', '301794081', '303442153', '305687841', '305816492', '301688816', '301721359', '305755107', '305826937', '305826838', '305826808', '305813220', '305765875', '305765873', '305765867', '302746537', '305817388', '305813217', '302746918', '305072022', '302815265', '305771164', '300984192', '301694969', '301654812', '305824529', '300968436', '305795159', '301695334', '301221211', '301426169', '305789680', '303436347', '301644572', '300984191', '305816417', '301709375', '300968453', '302849749', '303780965', '305723305', '305801974', '301415048', '302669563', '305819794', '302546986', '305768879', '301674164', '305734039', '302330075', '301221208', '305706632', '305794353', '305733561', '305790582', '300968403', '303704893', '301592541', '305813738', '305707051', '305692278', '302950045', '305823541', '305816425', '303203441', '301423840', '301543209', '302546471', '305816437', '305691482', '301729324', '301729314', '305816429', '302837458', '300656505', '305713491', '302546472', '301507669', '305768794', '305768731', '302546971', '302184942', '302546995', '302437001', '301410928', '302524731', '305123767', '302669567', '305283624', '302833799', '302695114', '305818862', '302750131', '302546979', '302437030', '305755564', '305777703', '305777699', '301356285', '301709416', '302846808', '305752985', '301662517', '302496371', '301311300', '302752027', '302752013', '305798492', '302767452', '301681980', '301366980', '302563366', '305826854', '303128662', '302767459', '301753753', '300968441', '305689677', '301221219', '300968430', '305691473', '301490367', '302685194', '305284076', '302803724', '305710461', '305710460', '305788460', '305684909', '302803702', '303355381', '305748215', '305818880', '300931476', '300931474', '300931470', '305283907', '305788469', '301863439', '305684910', '302833596', '303355363', '305788470', '305602895', '303725809', '303279129', '302714305', '305788467', '305408888', '301685336', '305778645', '302578221', '302726039', '305797122', '305820041', '305820040', '305805456', '302578247', '302251000', '305818876', '305683131', '302866339', '305176435', '305684907', '301585596', '301160380', '302299020', '305809427', '303450919', '301474505', '304136299', '301445981', '305792302', '305792300', '301674166', '302849046', '305741240', '303355295', '302261025', '303355242', '302746855', '3057103 ...
# ['301515278', 'M83985861', '28', '15']
# ['300605081', 'M83985861', '28', '15']
# ['303279261', 'M83985861', '30', '15']
# ['305788464', 'M83985861', '32', '15']
# ['305780130', 'M83985861', '28', '15']
# ['305776033', 'M83985861', '27', '15']
# ['300515072', 'M83985861', '32', '15']
# ['303355452', 'M83985861', '32', '15']
# ['305777670', 'M83985861', '28', '15']
# ['302280251', 'M83985861', '28', '15']
# ['302746077', 'M83985861', '151', '15']
# ['302138248', 'M83985861', '28', '15']
# ['301705854', 'M83985861', '28', '15']
# ['301269588', 'M83985861', '28', '15']
# ['302480752', 'M83985861', '27', '15']
# ['304473041', 'M83985861', '28', '15']
# ['305691740', 'M83985861', '32', '15']
# ['305727041', 'M83985861', '32', '15']
# ['301712935', 'M83985861', '32', '15']
# ['305811864', 'M83985861', '32', '15']
# ['305773508', 'M83985861', '27', '15']
# ['305773506', 'M83985861', '32', '15']
# ['303665161', 'M83985861', '149', '15']
# ['302251100', 'M83985861', '28', '15']
# ['305691723', 'M83985861', '32', '15']
# ['305785974', 'M83985861', '28', '15']
# ['302247616', 'M83985861', '32', '15']
# ['305694537', 'M83985861', '32', '15']
# ['305785964', 'M83985861', '28', '15']
# ['305727031', 'M83985861', '32', '15']
# ['301876557', 'M83985861', '151', '15']
# ['304473119', 'M83985861', '29', '15']
# ['305408927', 'M83985861', '28', '15']
# ['305408925', 'M83985861', '28', '15']
# ['303452844', 'M83985861', '32', '15']
# ['301047578', 'M83985861', '30', '15']
# ['305352957', 'M83985861', '32', '15']
# ['305743625', 'M83985861', '32', '15']
# ['302256748', 'M83985861', '28', '15']
# ['303355449', 'M83985861', '32', '15']
# ['305782065', 'M83985861', '28', '15']
# ['305821486', 'M83985861', '28', '17']
# ['303788016', 'M83985861', '32', '15']
# ['305771126', 'M83985861', '27', '15']
# ['301840142', 'M83985861', '151', '15']
# ['304204656', 'M83985861', '29', '15']
# ['301857136', 'M83985861', '28', '15']
# ['305430643', 'M83985861', '151', '15']
# ['302329396', 'M83985861', '32', '15']
# ['302496378', 'M83985861', '28', '15']
# ['305716777', 'M83985861', '32', '15']
# ['305283795', 'M83985861', '28', '15']
# ['305283705', 'M83985861', '28', '15']
# ['305283667', 'M83985861', '28', '15']
# ['302329389', 'M83985861', '32', '15']
# ['302745862', 'M83985861', '32', '15']
# ['305686510', 'M83985861', '45', '17']
# ['305741222', 'M83985861', '44', '15']
# ['305682443', 'M83985861', '45', '15']
# ['301656756', 'M83985861', '154', '15']
# ['301286692', 'M83985861', '44', '15']
# ['302746672', 'M83985861', '45', '15']
# ['302800679', 'M83985861', '44', '15']
# ['305773539', 'M83985861', '44', '15']
# ['305719357', 'M83985861', '45', '15']
# ['305733541', 'M83985861', '45', '15']
# ['303545024', 'M83985861', '45', '15']
# ['303583334', 'M83985861', '45', '15']
# ['302751987', 'M83985861', '44', '15']
# ['302793560', 'M83985861', '45', '15']
# ['305736864', 'M83985861', '45', '15']
# ['303187502', 'M83985861', '44', '15']
# ['301419452', 'M83985861', '45', '15']
# ['303437256', 'M83985861', '45', '15']
# ['302725849', 'M83985861', '45', '15']
# ['302906184', 'M83985861', '44', '15']
# ['302717027', 'M83985861', '45', '15']
# ['305769800', 'M83985861', '45', '15']
# ['301467917', 'M83985861', '45', '15']
# ['305816921', 'M83985861', '44', '15']
# ['301293873', 'M83985861', '44', '15']
# ['303442148', 'M83985861', '45', '15']
# ['305816500', 'M83985861', '44', '15']
# ['305816497', 'M83985861', '44', '15']
# ['302849718', 'M83985861', '45', '15']
# ['305694497', 'M83985861', '45', '15']
# ['303737970', 'M83985861', '45', '15']
# ['305817945', 'M83985861', '44', '15']
# ['301267515', 'M83985861', '44', '15']
# ['301451981', 'M83985861', '45', '15']
# ['305771146', 'M83985861', '44', '15']
# ['302480272', 'M83985861', '44', '15']
# ['305682450', 'M83985861', '45', '15']
# ['302918634', 'M83985861', '44', '15']
# ['302689279', 'M83985861', '44', '15']
# ['301692934', 'M83985861', '45', '15']
# ['305765877', 'M83985861', '45', '15']
# ['305765864', 'M83985861', '45', '15']
# ['301690993', 'M83985861', '44', '15']
# ['303604864', 'M83985861', '45', '15']
# ['305682434', 'M83985861', '45', '15']
# ['302258692', 'M83985861', '45', '15']
# ['305773536', 'M83985861', '44', '15']
# ['305809472', 'M83985861', '45', '15']
# ['301795233', 'M83985861', '44', '15']
# ['302746593', 'M83985861', '44', '15']
# ['305813762', 'M83985861', '44', '15']
# ['303543402', 'M83985861', '45', '15']
# ['305773485', 'M83985861', '45', '15']
# ['305823504', 'M83985861', '44', '15']
# ['305823503', 'M83985861', '44', '15']
# ['305792231', 'M83985861', '45', '15']
# ['305792212', 'M83985861', '45', '15']
# ['305706785', 'M83985861', '154', '15']
# ['302281876', 'M83985861', '154', '15']
# ['302281875', 'M83985861', '154', '15']
# ['302686372', 'M83985861', '44', '15']
# ['305826926', 'M83985861', '45', '15']
# ['303149880', 'M83985861', '45', '15']
# ['301601954', 'M83985861', '154', '15']
# ['305764220', 'M83985861', '45', '15']
# ['305805469', 'M83985861', '154', '15']
# ['301650297', 'M83985861', '45', '15']
# ['305806874', 'M83985861', '45', '15']
# ['302907984', 'M83985861', '45', '15']
# ['303738230', 'M83985861', '45', '15']
# ['302211767', 'M83985861', '45', '15']
# ['301794081', 'M83985861', '45', '15']
# ['303442153', 'M83985861', '45', '17']
# ['305687841', 'M83985861', '45', '15']
# ['305816492', 'M83985861', '44', '15']
# ['301688816', 'M83985861', '44', '17']
# ['301721359', 'M83985861', '44', '15']
# ['305755107', 'M83985861', '45', '15']
# ['305826937', 'M83985861', '45', '15']
# ['305826838', 'M83985861', '45', '15']
# ['305826808', 'M83985861', '45', '15']
# ['305813220', 'M83985861', '45', '15']
# ['305765875', 'M83985861', '45', '15']
# ['305765873', 'M83985861', '45', '15']
# ['305765867', 'M83985861', '45', '15']
# ['302746537', 'M83985861', '45', '15']
# ['305817388', 'M83985861', '45', '15']
# ['305813217', 'M83985861', '45', '15']
# ['302746918', 'M83985861', '45', '15']
# ['305072022', 'M83985861', '45', '15']
# ['302815265', 'M83985861', '44', '15']
# ['305771164', 'M83985861', '44', '15']
# ['300984192', 'M83985861', '34', '15']
# ['301694969', 'M83985861', '34', '15']
# ['301654812', 'M83985861', '34', '15']
# ['305824529', 'M83985861', '34', '15']
# ['300968436', 'M83985861', '34', '15']
# ['305795159', 'M83985861', '34', '15']
# ['301695334', 'M83985861', '34', '22']
# ['301221211', 'M83985861', '34', '15']
# ['301426169', 'M83985861', '34', '15']
# ['305789680', 'M83985861', '37', '15']
# ['303436347', 'M83985861', '36', '15']
# ['301644572', 'M83985861', '36', '15']
# ['300984191', 'M83985861', '34', '15']
# ['305816417', 'M83985861', '34', '15']
# ['301709375', 'M83985861', '34', '15']
# ['300968453', 'M83985861', '34', '15']
# ['302849749', 'M83985861', '34', '15']
# ['303780965', 'M83985861', '36', '15']
# ['305723305', 'M83985861', '34', '15']
# ['305801974', 'M83985861', '34', '17']
# ['301415048', 'M83985861', '35', '15']
# ['302669563', 'M83985861', '34', '15']
# ['305819794', 'M83985861', '34', '15']
# ['302546986', 'M83985861', '34', '15']
# ['305768879', 'M83985861', '34', '15']
# ['301674164', 'M83985861', '34', '15']
# ['305734039', 'M83985861', '34', '15']
# ['302330075', 'M83985861', '34', '15']
# ['301221208', 'M83985861', '34', '15']
# ['305706632', 'M83985861', '34', '15']
# ['305794353', 'M83985861', '34', '15']
# ['305733561', 'M83985861', '34', '15']
# ['305790582', 'M83985861', '34', '15']
# ['300968403', 'M83985861', '34', '15']
# ['303704893', 'M83985861', '36', '15']
# ['301592541', 'M83985861', '36', '15']
# ['305813738', 'M83985861', '34', '15']
# ['305707051', 'M83985861', '35', '15']
# ['305692278', 'M83985861', '38', '15']
# ['302950045', 'M83985861', '34', '15']
# ['305823541', 'M83985861', '34', '15']
# ['305816425', 'M83985861', '34', '15']
# ['303203441', 'M83985861', '34', '15']
# ['301423840', 'M83985861', '36', '15']
# ['301543209', 'M83985861', '155', '15']
# ['302546471', 'M83985861', '34', '15']
# ['305816437', 'M83985861', '34', '15']
# ['305691482', 'M83985861', '34', '15']
# ['301729324', 'M83985861', '34', '15']
# ['301729314', 'M83985861', '34', '15']
# ['305816429', 'M83985861', '34', '15']
# ['302837458', 'M83985861', '34', '15']
# ['300656505', 'M83985861', '155', '15']
# ['305713491', 'M83985861', '36', '15']
# ['302546472', 'M83985861', '34', '15']
# ['301507669', 'M83985861', '38', '15']
# ['305768794', 'M83985861', '34', '15']
# ['305768731', 'M83985861', '34', '15']
# ['302546971', 'M83985861', '34', '15']
# ['302184942', 'M83985861', '34', '15']
# ['302546995', 'M83985861', '34', '15']
# ['302437001', 'M83985861', '34', '15']
# ['301410928', 'M83985861', '34', '15']
# ['302524731', 'M83985861', '34', '15']
# ['305123767', 'M83985861', '38', '15']
# ['302669567', 'M83985861', '34', '15']
# ['305283624', 'M83985861', '36', '15']
# ['302833799', 'M83985861', '155', '15']
# ['302695114', 'M83985861', '34', '15']
# ['305818862', 'M83985861', '34', '17']
# ['302750131', 'M83985861', '34', '15']
# ['302546979', 'M83985861', '34', '15']
# ['302437030', 'M83985861', '34', '15']
# ['305755564', 'M83985861', '34', '15']
# ['305777703', 'M83985861', '34', '15']
# ['305777699', 'M83985861', '34', '15']
# ['301356285', 'M83985861', '34', '15']
# ['301709416', 'M83985861', '34', '15']
# ['302846808', 'M83985861', '155', '15']
# ['305752985', 'M83985861', '34', '15']
# ['301662517', 'M83985861', '34', '15']
# ['302496371', 'M83985861', '34', '15']
# ['301311300', 'M83985861', '34', '15']
# ['302752027', 'M83985861', '34', '15']
# ['302752013', 'M83985861', '34', '15']
# ['305798492', 'M83985861', '34', '15']
# ['302767452', 'M83985861', '34', '15']
# ['301681980', 'M83985861', '34', '15']
# ['301366980', 'M83985861', '34', '15']
# ['302563366', 'M83985861', '36', '15']
# ['305826854', 'M83985861', '34', '15']
# ['303128662', 'M83985861', '34', '15']
# ['302767459', 'M83985861', '34', '15']
# ['301753753', 'M83985861', '37', '15']
# ['300968441', 'M83985861', '34', '15']
# ['305689677', 'M83985861', '34', '15']
# ['301221219', 'M83985861', '34', '15']
# ['300968430', 'M83985861', '34', '15']
# ['305691473', 'M83985861', '35', '15']
# ['301490367', 'M83985861', '36', '15']
# ['302685194', 'M83985861', '39', '15']
# ['305284076', 'M83985861', '39', '15']
# ['302803724', 'M83985861', '39', '15']
# ['305710461', 'M83985861', '43', '17']
# ['305710460', 'M83985861', '43', '17']
# ['305788460', 'M83985861', '43', '15']
# ['305684909', 'M83985861', '43', '15']
# ['302803702', 'M83985861', '39', '15']
# ['303355381', 'M83985861', '43', '15']
# ['305748215', 'M83985861', '39', '15']
# ['305818880', 'M83985861', '39', '15']
# ['300931476', 'M83985861', '39', '15']
# ['300931474', 'M83985861', '39', '15']
# ['300931470', 'M83985861', '39', '15']
# ['305283907', 'M83985861', '39', '15']
# ['305788469', 'M83985861', '39', '15']
# ['301863439', 'M83985861', '39', '15']
# ['305684910', 'M83985861', '43', '15']
# ['302833596', 'M83985861', '39', '15']
# ['303355363', 'M83985861', '39', '15']
# ['305788470', 'M83985861', '39', '15']
# ['305602895', 'M83985861', '43', '15']
# ['303725809', 'M83985861', '41', '15']
# ['303279129', 'M83985861', '41', '15']
# ['302714305', 'M83985861', '39', '15']
# ['305788467', 'M83985861', '39', '15']
# ['305408888', 'M83985861', '39', '15']
# ['301685336', 'M83985861', '43', '15']
# ['305778645', 'M83985861', '39', '15']
# ['302578221', 'M83985861', '39', '15']
# ['302726039', 'M83985861', '43', '15']
# ['305797122', 'M83985861', '39', '15']
# ['305820041', 'M83985861', '39', '15']
# ['305820040', 'M83985861', '39', '15']
# ['305805456', 'M83985861', '43', '15']
# ['302578247', 'M83985861', '39', '15']
# ['302251000', 'M83985861', '39', '15']
# ['305818876', 'M83985861', '43', '17']
# ['305683131', 'M83985861', '43', '15']
# ['302866339', 'M83985861', '43', '17']
# ['305176435', 'M83985861', '40', '15']
# ['305684907', 'M83985861', '39', '15']
# ['301585596', 'M83985861', '39', '15']
# ['301160380', 'M83985861', '39', '15']
# ['302299020', 'M83985861', '39', '15']
# ['305809427', 'M83985861', '39', '15']
# ['303450919', 'M83985861', '43', '15']
# ['301474505', 'M83985861', '41', '15']
# ['304136299', 'M83985861', '39', '15']
# ['301445981', 'M83985861', '43', '15']
# ['305792302', 'M83985861', '39', '15']
# ['305792300', 'M83985861', '39', '15']
# ['301674166', 'M83985861', '157', '15']
# ['302849046', 'M83985861', '49', '15']
# ['305741240', 'M83985861', '123', '15']
# ['303355295', 'M83985861', '50', '15']
# ['302261025', 'M83985861', '157', '15']
# ['303355242', 'M83985861', '123', '15']
# ['302746855', 'M83985861', '50', '15']
# ['305710352', 'M83985861', '48', '15']
# ['301869474', 'M83985861', '158', '15']
# ['303355260', 'M83985861', '50', '15']
# ['302745367', 'M83985861', '157', '15']
# ['301674092', 'M83985861', '158', '15']
# ['302563286', 'M83985861', '157', '15']
# ['305293742', 'M83985861', '50', '15']
# ['305801833', 'M83985861', '123', '15']
# ['305776730', 'M83985861', '48', '15']
# ['302745357', 'M83985861', '49', '15']
# ['302815258', 'M83985861', '49', '15']
# ['302752035', 'M83985861', '48', '15']
# ['302701306', 'M83985861', '50', '15']
# ['302563197', 'M83985861', '157', '15']
# ['305751028', 'M83985861', '48', '15']
# ['304223585', 'M83985861', '123', '15']
# ['305713845', 'M83985861', '157', '15']
# ['305712882', 'M83985861', '49', '15']
# ['305725332', 'M83985861', '48', '15']
# ['305724885', 'M83985861', '48', '15']
# ['305692271', 'M83985861', '157', '15']
# ['305076963', 'M83985861', '158', '15']
# ['302329148', 'M83985861', '123', '15']
# ['303170858', 'M83985861', '123', '15']
# ['302838956', 'M83985861', '123', '15']
# ['305644325', 'M83985861', '123', '15']
# ['305627999', 'M83985861', '123', '15']
# ['302290674', 'M83985861', '157', '15']
# ['301351358', 'M83985861', '49', '15']
# ['305353524', 'M83985861', '50', '15']
# ['302752062', 'M83985861', '49', '15']
# ['301633812', 'M83985861', '50', '15']
# ['301839202', 'M83985861', '50', '15']
# ['302261051', 'M83985861', '48', '15']
# ['305731538', 'M83985861', '157', '15']
# ['301691113', 'M83985861', '48', '15']
# ['303248848', 'M83985861', '49', '15']
# ['305733696', 'M83985861', '157', '15']
# ['302668849', 'M83985861', '49', '15']
# ['303287748', 'M83985861', '158', '15']
# ['305713833', 'M83985861', '157', '15']
# ['301395048', 'M83985861', '49', '15']
# ['301313790', 'M83985861', '50', '17']
# ['305713793', 'M83985861', '50', '15']
# ['301367980', 'M83985861', '48', '15']
# ['302745379', 'M83985861', '49', '15']
# ['301674163', 'M83985861', '157', '15']
# ['301638984', 'M83985861', '48', '15']
# ['301810565', 'M83985861', '48', '15']
# ['302745345', 'M83985861', '49', '15']
# ['302247017', 'M83985861', '50', '18']
# ['305750491', 'M83985861', '49', '15']
# ['302562937', 'M83985861', '157', '15']
# ['301747053', 'M83985861', '50', '15']
# ['302995080', 'M83985861', '158', '15']
# ['301129328', 'M83985861', '50', '15']
# ['305812856', 'M83985861', '50', '15']
# ['301351360', 'M83985861', '49', '15']
# ['305778567', 'M83985861', '158', '15']
# ['305731104', 'M83985861', '158', '15']
# ['303229186', 'M83985861', '49', '15']
# ['303923068', 'M83985861', '48', '15']
# ['303226067', 'M83985861', '157', '15']
# ['302301994', 'M83985861', '50', '15']
# ['302242230', 'M83985861', '158', '15']
# ['305788495', 'M83985861', '48', '15']
# ['301395049', 'M83985861', '49', '15']
# ['302300825', 'M83985861', '157', '15']
# ['301414334', 'M83985861', '48', '15']
# ['301209802', 'M83985861', '50', '15']
# ['302329426', 'M83985861', '50', '15']
# ['305682387', 'M83985861', '50', '15']
# ['305682305', 'M83985861', '50', '15']
# ['305816368', 'M83985861', '157', '15']
# ['305770647', 'M83985861', '49', '15']
# ['305733758', 'M83985861', '123', '15']
# ['302299393', 'M83985861', '123', '15']
# ['305805648', 'M83985861', '50', '17']
# ['305698543', 'M83985861', '48', '15']
# ['305726632', 'M83985861', '49', '15']
# ['303005163', 'M83985861', '48', '15']
# ['305726817', 'M83985861', '123', '15']
# ['301795295', 'M83985861', '157', '15']
# ['302795687', 'M83985861', '49', '15']
# ['305798503', 'M83985861', '123', '15']
# ['305733764', 'M83985861', '49', '15']
# ['302919259', 'M83985861', '123', '15']
# ['302919250', 'M83985861', '49', '15']
# ['305816447', 'M83985861', '49', '15']
# ['305816444', 'M83985861', '49', '15']
# ['305816441', 'M83985861', '49', '15']
# ['302953296', 'M83985861', '49', '15']
# ['305725088', 'M83985861', '157', '15']
# ['305706594', 'M83985861', '53', '15']
# ['302288377', 'M83985861', '122', '15']
# ['305764245', 'M83985861', '53', '15']
# ['303355235', 'M83985861', '122', '15']
# ['303118536', 'M83985861', '122', '15']
# ['305344460', 'M83985861', '53', '15']
# ['302792062', 'M83985861', '122', '15']
# ['305771681', 'M83985861', '53', '15']
# ['305408824', 'M83985861', '53', '15']
# ['305816519', 'M83985861', '122', '15']
# ['302240908', 'M83985861', '122', '15']
# ['305712397', 'M83985861', '122', '15']
# ['305768982', 'M83985861', '122', '15']
# ['301449281', 'M83985861', '53', '15']
# ['301138475', 'M83985861', '53', '17']
# ['303355230', 'M83985861', '122', '15']
# ['302281883', 'M83985861', '122', '15']
# ['301159112', 'M83985861', '53', '17']
# ['303728269', 'M83985861', '122', '15']
# ['303208023', 'M83985861', '53', '15']
# ['303814437', 'M83985861', '53', '15']
# ['302198980', 'M83985861', '122', '15']
# ['302270843', 'M83985861', '122', '15']
# ['301877746', 'M83985861', '122', '15']
# ['301024215', 'M83985861', '122', '15']
# ['301721373', 'M83985861', '53', '15']
# ['305687509', 'M83985861', '53', '15']
# ['305706670', 'M83985861', '53', '15']
# ['301758052', 'M83985861', '122', '15']
# ['305706646', 'M83985861', '53', '15']
# ['302792130', 'M83985861', '122', '15']
# ['301649535', 'M83985861', '53', '15']
# ['302282219', 'M83985861', '122', '15']
# ['302281885', 'M83985861', '122', '15']
# ['305799588', 'M83985861', '122', '15']
# ['305816534', 'M83985861', '122', '15']
# ['305816531', 'M83985861', '122', '15']
# ['305712401', 'M83985861', '122', '15']
# ['305712400', 'M83985861', '122', '15']
# ['305816523', 'M83985861', '122', '15']
# ['305816521', 'M83985861', '122', '15']
# ['305816518', 'M83985861', '122', '15']
# ['305741318', 'M83985861', '122', '15']
# ['302834187', 'M83985861', '53', '15']
# ['301602377', 'M83985861', '122', '15']
# ['301602376', 'M83985861', '122', '15']
# ['305682326', 'M83985861', '53', '15']
# ['302745402', 'M83985861', '122', '15']
# ['305682346', 'M83985861', '122', '15']
# ['303870295', 'M83985861', '160', '15']
# ['302828711', 'M83985861', '160', '15']
# ['305188782', 'M83985861', '160', '15']
# ['305741326', 'M83985861', '160', '15']
# ['302560907', 'M83985861', '161', '15']
# ['304071507', 'M83985861', '160', '15']
# ['303355063', 'M83985861', '160', '15']
# ['303351133', 'M83985861', '160', '15']
# ['303870294', 'M83985861', '160', '15']
# ['304054252', 'M83985861', '160', '15']
# ['305694786', 'M83985861', '160', '15']
# ['301737684', 'M83985861', '160', '15']
# ['301746920', 'M83985861', '160', '15']
# ['302629778', 'M83985861', '160', '15']
# ['305189829', 'M83985861', '160', '15']
# ['305189361', 'M83985861', '160', '15']
# ['305694653', 'M83985861', '160', '15']
# ['305188904', 'M83985861', '160', '15']
# ['303779546', 'M83985861', '162', '15']
# ['301885527', 'M83985861', '160', '15']
# ['303358900', 'M83985861', '160', '15']
# ['304817789', 'M83985861', '160', '15']
# ['303351893', 'M83985861', '160', '15']
# ['303351247', 'M83985861', '160', '15']
# ['301737973', 'M83985861', '160', '15']
# ['305336096', 'M83985861', '164', '15']
# ['305016091', 'M83985861', '164', '15']
# ['303279090', 'M83985861', '165', '15']
# ['305740816', 'M83985861', '164', '15']
# ['305587520', 'M83985861', '164', '15']
# ['300878013', 'M83985861', '165', '15']
# ['303697993', 'M83985861', '164', '15']
# ['305714665', 'M83985861', '164', '15']
# ['303697994', 'M83985861', '164', '15']
# ['305770545', 'M33439436', '7', '15']
# ['302729896', 'M33439436', '7', '17']
# ['305796730', 'M33439436', '7', '15']
# ['301683248', 'M33439436', '7', '15']
# ['302284695', 'M33439436', '7', '15']
# ['302739441', 'M33439436', '7', '15']
# ['302837555', 'M33439436', '7', '15']
# ['305796715', 'M33439436', '18', '15']
# ['305721314', 'M33439436', '7', '17']
# ['305776185', 'M33439436', '7', '17']
# ['303894423', 'M33439436', '7', '17']
# ['305690945', 'M33439436', '21', '15']
# ['303423626', 'M33439436', '7', '15']
# ['305814006', 'M33439436', '7', '15']
# ['305770543', 'M33439436', '7', '15']
# ['302272667', 'M33439436', '7', '15']
# ['305773119', 'M33439436', '18', '15']
# ['302815337', 'M33439436', '7', '15']
# ['305797064', 'M33439436', '7', '15']
# ['305625407', 'M33439436', '18', '15']
# ['305309892', 'M33439436', '7', '17']
# ['305296574', 'M33439436', '18', '17']
# ['305604056', 'M33439436', '7', '15']
# ['302301165', 'M33439436', '7', '15']
# ['305309878', 'M33439436', '7', '17']
# ['305715818', 'M33439436', '7', '15']
# ['305721353', 'M33439436', '7', '17']
# ['305734030', 'M33439436', '7', '15']
# ['305726165', 'M33439436', '7', '17']
# ['302739440', 'M33439436', '7', '15']
# ['305788150', 'M33439436', '7', '17']
# ['302255822', 'M33439436', '7', '15']
# ['305810751', 'M33439436', '7', '15']
# ['305409042', 'M33439436', '7', '15']
# ['305802515', 'M33439436', '18', '15']
# ['305364131', 'M33439436', '7', '17']
# ['302330081', 'M33439436', '7', '22']
# ['302255842', 'M33439436', '7', '15']
# ['305809527', 'M33439436', '7', '15']
# ['305715327', 'M33439436', '18', '15']
# ['302699615', 'M33439436', '7', '15']
# ['305796723', 'M33439436', '7', '15']
# ['301772945', 'M33439436', '7', '17']
# ['302804952', 'M33439436', '7', '15']
# ['305310051', 'M33439436', '7', '17']
# ['305796088', 'M33439436', '7', '15']
# ['305773889', 'M33439436', '7', '15']
# ['302720728', 'M33439436', '7', '15']
# ['305309924', 'M33439436', '21', '17']
# ['305808266', 'M33439436', '7', '15']
# ['303894545', 'M33439436', '21', '15']
# ['305802637', 'M33439436', '7', '17']
# ['305798209', 'M33439436', '7', '17']
# ['301217244', 'M33439436', '7', '15']
# ['301617674', 'M33439436', '7', '15']
# ['305625390', 'M33439436', '18', '15']
# ['301822657', 'M33439436', '7', '17']
# ['302284280', 'M33439436', '7', '15']
# ['305791938', 'M33439436', '7', '15']
# ['305694744', 'M33439436', '220', '15']
# ['305773083', 'M33439436', '7', '17']
# ['302686513', 'M33439436', '7', '15']
# ['303894541', 'M33439436', '7', '15']
# ['301133668', 'M33439436', '21', '15']
# ['302279449', 'M33439436', '7', '15']
# ['305805595', 'M33439436', '7', '15']
# ['305721523', 'M33439436', '7', '15']
# ['305819148', 'M33439436', '18', '15']
# ['303430132', 'M33439436', '18', '15']
# ['305710539', 'M33439436', '7', '15']
# ['303443918', 'M33439436', '7', '15']
# ['305715775', 'M33439436', '18', '15']
# ['305709587', 'M33439436', '7', '15']
# ['305797033', 'M33439436', '7', '15']
# ['305689009', 'M33439436', '7', '15']
# ['303898507', 'M33439436', '7', '15']
# ['301022920', 'M33439436', '7', '15']
# ['301217249', 'M33439436', '7', '15']
# ['305682541', 'M33439436', '7', '17']
# ['305794292', 'M33439436', '7', '17']
# ['305689008', 'M33439436', '7', '15']
# ['305707465', 'M33439436', '7', '17']
# ['302809978', 'M33439436', '18', '15']
# ['303894687', 'M33439436', '7', '15']
# ['305603742', 'M33439436', '7', '15']
# ['305706400', 'M33439436', '7', '15']
# ['303626547', 'M33439436', '7', '15']
# ['301764526', 'M33439436', '7', '17']
# ['305810891', 'M33439436', '18', '15']
# ['305719515', 'M33439436', '7', '15']
# ['302272588', 'M33439436', '18', '17']
# ['301659217', 'M33439436', '7', '15']
# ['305726050', 'M33439436', '18', '15']
# ['301872861', 'M33439436', '191', '15']
# ['305327685', 'M33439436', '7', '15']
# ['305796995', 'M33439436', '7', '15']
# ['303572282', 'M33439436', '7', '15']
# ['305796864', 'M33439436', '7', '17']
# ['305804555', 'M33439436', '7', '15']
# ['301824089', 'M33439436', '7', '15']
# ['301798682', 'M33439436', '35', '17']
# ['305810758', 'M33439436', '35', '15']
# ['304891095', 'M33439436', '34', '15']
# ['301630715', 'M33439436', '190', '17']
# ['302765205', 'M33439436', '328', '15']
# ['301630734', 'M33439436', '190', '17']
# ['300964338', 'M33439436', '190', '15']
# ['304891098', 'M33439436', '35', '15']
# ['302580063', 'M33439436', '190', '15']
# ['302906766', 'M33439436', '35', '17']
# ['302899501', 'M33439436', '34', '17']
# ['305751640', 'M33439436', '35', '15']
# ['305771596', 'M33439436', '190', '15']
# ['305796936', 'M33439436', '190', '15']
# ['302615720', 'M33439436', '35', '15']
# ['301773846', 'M33439436', '190', '15']
# ['302616185', 'M33439436', '35', '15']
# ['305797049', 'M33439436', '190', '15']
# ['302791499', 'M33439436', '190', '17']
# ['303195239', 'M33439436', '35', '17']
# ['301689814', 'M33439436', '34', '15']
# ['301630757', 'M33439436', '190', '17']
# ['305161080', 'M33439436', '35', '17']
# ['302899498', 'M33439436', '34', '17']
# ['303195102', 'M33439436', '35', '17']
# ['302905529', 'M33439436', '35', '17']
# ['305788089', 'M33439436', '35', '17']
# ['301325256', 'M33439436', '190', '17']
# ['305804661', 'M33439436', '34', '15']
# ['305727534', 'M33439436', '34', '15']
# ['302962110', 'M33439436', '35', '17']
# ['305815503', 'M33439436', '35', '15']
# ['305706875', 'M33439436', '35', '17']
# ['302792038', 'M33439436', '35', '17']
# ['305684626', 'M33439436', '35', '15']
# ['305720127', 'M33439436', '35', '17']
# ['305720131', 'M33439436', '35', '17']
# ['305707746', 'M33439436', '35', '15']
# ['301824178', 'M33439436', '34', '15']
# ['305734547', 'M33439436', '34', '17']
# ['303099866', 'M33439436', '35', '15']
# ['302768208', 'M33439436', '35', '15']
# ['305708747', 'M33439436', '34', '17']
# ['305729353', 'M33439436', '190', '17']
# ['305797053', 'M33439436', '190', '17']
# ['301754804', 'M33439436', '35', '15']
# ['305056560', 'M33439436', '35', '15']
# ['301017126', 'M33439436', '34', '15']
# ['303303587', 'M33439436', '190', '15']
# ['305727655', 'M33439436', '34', '15']
# ['301795810', 'M33439436', '35', '15']
# ['302292911', 'M33439436', '34', '15']
# ['305747601', 'M33439436', '34', '15']
# ['305797016', 'M33439436', '190', '17']
# ['305687334', 'M33439436', '35', '17']
# ['303894778', 'M33439436', '35', '17']
# ['301221808', 'M33439436', '190', '15']
# ['302721709', 'M33439436', '35', '17']
# ['303770604', 'M33439436', '34', '15']
# ['305797715', 'M33439436', '35', '17']
# ['303443412', 'M33439436', '35', '17']
# ['300951066', 'M33439436', '35', '17']
# ['305762436', 'M33439436', '34', '15']
# ['305802848', 'M33439436', '190', '15']
# ['302837502', 'M33439436', '36', '15']
# ['305764203', 'M33439436', '35', '15']
# ['301449174', 'M33439436', '190', '15']
# ['305795885', 'M33439436', '190', '15']
# ['305810709', 'M33439436', '35', '15']
# ['302726715', 'M33439436', '34', '17']
# ['304164253', 'M33439436', '35', '15']
# ['305706900', 'M33439436', '35', '17']
# ['301696437', 'M33439436', '35', '15']
# ['301696672', 'M33439436', '35', '15']
# ['301764817', 'M33439436', '35', '15']
# ['302768203', 'M33439436', '35', '15']
# ['305704323', 'M33439436', '190', '15']
# ['303195041', 'M33439436', '35', '15']
# ['302980530', 'M33439436', '35', '15']
# ['301709655', 'M33439436', '35', '15']
# ['305809384', 'M33439436', '36', '17']
# ['300964307', 'M33439436', '190', '15']
# ['305810692', 'M33439436', '35', '15']
# ['302816441', 'M33439436', '190', '15']
# ['301722080', 'M33439436', '35', '17']
# ['305812097', 'M33439436', '34', '15']
# ['301322776', 'M33439436', '190', '15']
# ['302914916', 'M33439436', '35', '15']
# ['305771586', 'M33439436', '190', '15']
# ['305735716', 'M33439436', '190', '15']
# ['305684728', 'M33439436', '35', '15']
# ['303033654', 'M33439436', '36', '15']
# ['303263326', 'M33439436', '35', '15']
# ['305712092', 'M33439436', '34', '15']
# ['305707868', 'M33439436', '328', '15']
# ['305771600', 'M33439436', '190', '15']
# ['305729358', 'M33439436', '190', '15']
# ['305684822', 'M33439436', '35', '17']
# ['301309660', 'M33439436', '190', '15']
# ['302715576', 'M33439436', '35', '15']
# ['305747633', 'M33439436', '32', '15']
# ['305409312', 'M33439436', '32', '17']
# ['301842565', 'M33439436', '32', '15']
# ['301829949', 'M33439436', '32', '15']
# ['305720708', 'M33439436', '32', '15']
# ['305802753', 'M33439436', '32', '15']
# ['305734227', 'M33439436', '32', '17']
# ['302715097', 'M33439436', '32', '17']
# ['302900718', 'M33439436', '32', '17']
# ['305776549', 'M33439436', '32', '15']
# ['301085978', 'M33439436', '32', '15']
# ['302986393', 'M33439436', '32', '15']
# ['302686001', 'M33439436', '32', '15']
# ['302862858', 'M33439436', '32', '15']
# ['305624888', 'M33439436', '32', '15']
# ['305717922', 'M33439436', '32', '17']
# ['301157179', 'M33439436', '32', '17']
# ['305735492', 'M33439436', '32', '17']
# ['302763535', 'M33439436', '32', '15']
# ['305747609', 'M33439436', '32', '15']
# ['301085931', 'M33439436', '32', '15']
# ['305740906', 'M33439436', '32', '15']
# ['301673790', 'M33439436', '32', '15']
# ['305802759', 'M33439436', '32', '17']
# ['305747628', 'M33439436', '32', '15']
# ['305747632', 'M33439436', '32', '15']
# ['305720707', 'M33439436', '32', '15']
# ['302874183', 'M33439436', '32', '15']
# ['305775522', 'M33439436', '32', '15']
# ['305797008', 'M33439436', '32', '15']
# ['301544569', 'M33439436', '32', '17']
# ['305657007', 'M33439436', '32', '15']
# ['301720112', 'M33439436', '32', '15']
# ['301842683', 'M33439436', '32', '15']
# ['305701072', 'M33439436', '32', '17']
# ['302272504', 'M33439436', '32', '15']
# ['305696908', 'M33439436', '32', '15']
# ['305715644', 'M33439436', '32', '15']
# ['302641177', 'M33439436', '32', '15']
# ['303243303', 'M33439436', '32', '15']
# ['303640351', 'M33439436', '32', '15']
# ['300954610', 'M33439436', '32', '15']
# ['305775171', 'M33439436', '32', '15']
# ['302623418', 'M33439436', '32', '15']
# ['305783193', 'M33439436', '32', '17']
# ['305809338', 'M33439436', '32', '17']
# ['302730173', 'M33439436', '32', '15']
# ['305742243', 'M33439436', '32', '17']
# ['303894439', 'M33439436', '32', '17']
# ['305682232', 'M33439436', '32', '17']
# ['305787210', 'M33439436', '32', '17']
# ['302262983', 'M33439436', '32', '17']
# ['305697919', 'M33439436', '32', '15']
# ['305732598', 'M33439436', '32', '17']
# ['305660962', 'M33439436', '32', '15']
# ['305732958', 'M33439436', '32', '15']
# ['305230423', 'M33439436', '32', '15']
# ['303884804', 'M33439436', '32', '15']
# ['303595951', 'M33439436', '32', '15']
# ['305809339', 'M33439436', '32', '17']
# ['305684435', 'M33439436', '32', '17']
# ['305776320', 'M33439436', '32', '15']
# ['305798571', 'M33439436', '32', '17']
# ['302821414', 'M33439436', '32', '15']
# ['305792159', 'M33439436', '32', '15']
# ['301782401', 'M33439436', '32', '15']
# ['305787223', 'M33439436', '32', '17']
# ['305731018', 'M33439436', '32', '15']
# ['302149929', 'M33439436', '32', '15']
# ['302276702', 'M33439436', '32', '15']
# ['302291452', 'M33439436', '32', '15']
# ['305747629', 'M33439436', '32', '15']
# ['305809337', 'M33439436', '32', '15']
# ['301795419', 'M33439436', '32', '15']
# ['305812108', 'M33439436', '32', '17']
# ['305819348', 'M33439436', '32', '15']
# ['305719539', 'M33439436', '32', '15']
# ['305717319', 'M33439436', '32', '15']
# ['305714886', 'M33439436', '32', '15']
# ['305812102', 'M33439436', '32', '17']
# ['303304594', 'M33439436', '32', '15']
# ['301827414', 'M33439436', '32', '15']
# ['305742449', 'M33439436', '32', '15']
# ['305689143', 'M33439436', '32', '15']
# ['305722554', 'M33439436', '32', '15']
# ['305809368', 'M33439436', '32', '15']
# ['302760636', 'M33439436', '32', '17']
# ['305786877', 'M33439436', '32', '15']
# ['305692952', 'M33439436', '32', '15']
# ['303582486', 'M33439436', '32', '15']
# ['303195087', 'M33439436', '32', '15']
# ['305624897', 'M33439436', '32', '15']
# ['305694510', 'M33439436', '32', '15']
# ['302953594', 'M33439436', '32', '17']
# ['302258962', 'M33439436', '32', '15']
# ['302933328', 'M33439436', '32', '17']
# ['305802710', 'M33439436', '32', '15']
# ['301739623', 'M33439436', '32', '17']
# ['305796970', 'M33439436', '32', '17']
# ['305819345', 'M33439436', '32', '17']
# ['301262356', 'M33439436', '33', '15']
# ['301494875', 'M33439436', '33', '17']
# ['301945124', 'M33439436', '33', '15']
# ['302298115', 'M33439436', '33', '17']
# ['305708118', 'M33439436', '33', '17']
# ['305682197', 'M33439436', '33', '17']
# ['305771060', 'M33439436', '33', '17']
# ['302812497', 'M33439436', '33', '15']
# ['305720567', 'M33439436', '33', '15']
# ['305330120', 'M33439436', '33', '15']
# ['302630503', 'M33439436', '33', '15']
# ['303884331', 'M33439436', '33', '17']
# ['305817487', 'M33439436', '33', '17']
# ['305330119', 'M33439436', '33', '15']
# ['305761458', 'M33439436', '33', '17']
# ['305729294', 'M33439436', '33', '17']
# ['305792061', 'M33439436', '33', '17']
# ['302212213', 'M33439436', '33', '15']
# ['303894897', 'M33439436', '33', '15']
# ['305210025', 'M33439436', '33', '15']
# ['301634496', 'M33439436', '33', '15']
# ['303894508', 'M33439436', '33', '15']
# ['301606093', 'M33439436', '33', '15']
# ['305657322', 'M33439436', '33', '17']
# ['301757040', 'M33439436', '33', '15']
# ['302304830', 'M33439436', '33', '15']
# ['305695377', 'M33439436', '33', '17']
# ['302792626', 'M33439436', '33', '15']
# ['301482915', 'M33439436', '33', '17']
# ['305719587', 'M33439436', '33', '17']
# ['305694857', 'M33439436', '33', '15']
# ['302246207', 'M33439436', '33', '15']
# ['305811616', 'M33439436', '33', '15']
# ['305810760', 'M33439436', '33', '15']
# ['305688890', 'M33439436', '33', '15']
# ['305782854', 'M33439436', '33', '15']
# ['305742049', 'M33439436', '33', '15']
# ['305742048', 'M33439436', '33', '15']
# ['305708073', 'M33439436', '33', '15']
# ['303894751', 'M33439436', '33', '15']
# ['305330117', 'M33439436', '33', '15']
# ['303103749', 'M33439436', '33', '17']
# ['305751929', 'M33439436', '33', '15']
# ['305720700', 'M33439436', '33', '15']
# ['301085838', 'M33439436', '33', '15']
# ['305721347', 'M33439436', '33', '15']
# ['305721482', 'M33439436', '33', '15']
# ['305811620', 'M33439436', '33', '17']
# ['301217286', 'M33439436', '33', '15']
# ['305721351', 'M33439436', '33', '17']
# ['305815912', 'M33439436', '33', '17']
# ['302932893', 'M33439436', '33', '15']
# ['305720604', 'M33439436', '33', '15']
# ['302255861', 'M33439436', '33', '17']
# ['305751516', 'M33439436', '33', '15']
# ['301827855', 'M33439436', '33', '15']
# ['305766755', 'M33439436', '33', '15']
# ['301724159', 'M33439436', '33', '15']
# ['305709511', 'M33439436', '33', '15']
# ['305714641', 'M33439436', '33', '17']
# ['305761443', 'M33439436', '33', '15']
# ['302935627', 'M33439436', '33', '15']
# ['305710862', 'M33439436', '33', '15']
# ['305729278', 'M33439436', '33', '17']
# ['301652825', 'M33439436', '33', '15']
# ['305709646', 'M33439436', '33', '17']
# ['304472718', 'M33439436', '33', '15']
# ['305763773', 'M33439436', '33', '15']
# ['305605093', 'M33439436', '33', '15']
# ['305270464', 'M33439436', '33', '15']
# ['302239090', 'M33439436', '33', '17']
# ['305777208', 'M33439436', '33', '15']
# ['305330116', 'M33439436', '33', '15']
# ['305707852', 'M33439436', '33', '15']
# ['302953615', 'M33439436', '33', '17']
# ['301634501', 'M33439436', '33', '15']
# ['305757204', 'M33439436', '33', '15']
# ['304488755', 'M33439436', '33', '15']
# ['305686958', 'M33439436', '33', '17']
# ['305715787', 'M33439436', '33', '15']
# ['305364301', 'M33439436', '33', '17']
# ['305771001', 'M33439436', '33', '17']
# ['305688840', 'M33439436', '33', '15']
# ['301085988', 'M33439436', '33', '15']
# ['305775510', 'M33439436', '33', '15']
# ['305773247', 'M33439436', '33', '17']
# ['302182673', 'M33439436', '33', '15']
# ['302246796', 'M33439436', '33', '15']
# ['303884317', 'M33439436', '33', '17']
# ['305775449', 'M33439436', '33', '15']
# ['305716380', 'M33439436', '33', '15']
# ['303545045', 'M33439436', '33', '17']
# ['305689238', 'M33439436', '33', '15']
# ['302326137', 'M33439436', '33', '15']
# ['303436909', 'M33439436', '33', '17']
# ['305701300', 'M33439436', '33', '15']
# ['305682516', 'M33439436', '33', '15']
# ['305620529', 'M33439436', '33', '15']
# ['305715271', 'M33439436', '33', '15']
# ['305724027', 'M33439436', '33', '15']
# ['305764392', 'M33439436', '30', '15']
# ['301782553', 'M33439436', '30', '15']
# ['305735254', 'M33439436', '31', '15']
# ['305735263', 'M33439436', '29', '15']
# ['305429773', 'M33439436', '30', '15']
# ['302550155', 'M33439436', '30', '17']
# ['301697058', 'M33439436', '30', '17']
# ['305769738', 'M33439436', '30', '17']
# ['303894790', 'M33439436', '30', '17']
# ['301218440', 'M33439436', '30', '15']
# ['301721947', 'M33439436', '30', '15']
# ['305770062', 'M33439436', '29', '15']
# ['302739714', 'M33439436', '30', '17']
# ['302272297', 'M33439436', '30', '17']
# ['305764393', 'M33439436', '30', '15']
# ['305330866', 'M33439436', '30', '15']
# ['305707918', 'M33439436', '30', '17']
# ['304471819', 'M33439436', '30', '15']
# ['305272066', 'M33439436', '27', '15']
# ['303443286', 'M33439436', '30', '15']
# ['305764395', 'M33439436', '30', '15']
# ['305802698', 'M33439436', '30', '15']
# ['301730217', 'M33439436', '30', '17']
# ['304472288', 'M33439436', '30', '15']
# ['305625455', 'M33439436', '30', '17']
# ['305698170', 'M33439436', '31', '17']
# ['305740887', 'M33439436', '30', '17']
# ['305810752', 'M33439436', '30', '17']
# ['302281064', 'M33439436', '30', '15']
# ['301695429', 'M33439436', '30', '17']
# ['302304857', 'M33439436', '30', '15']
# ['303443296', 'M33439436', '30', '15']
# ['302647079', 'M33439436', '30', '17']
# ['305796861', 'M33439436', '30', '15']
# ['302763619', 'M33439436', '30', '17']
# ['305719585', 'M33439436', '29', '17']
# ['305804265', 'M33439436', '29', '15']
# ['304472411', 'M33439436', '30', '15']
# ['302720527', 'M33439436', '29', '15']
# ['305694019', 'M33439436', '30', '17']
# ['302190412', 'M33439436', '27', '15']
# ['305178087', 'M33439436', '30', '15']
# ['301757104', 'M33439436', '30', '17']
# ['304471543', 'M33439436', '30', '15']
# ['304482671', 'M33439436', '27', '15']
# ['301010413', 'M33439436', '30', '15']
# ['305694034', 'M33439436', '30', '15']
# ['305694028', 'M33439436', '30', '15']
# ['303203443', 'M33439436', '30', '15']
# ['305296705', 'M33439436', '30', '17']
# ['301757092', 'M33439436', '30', '17']
# ['301207919', 'M33439436', '29', '17']
# ['305682689', 'M33439436', '27', '15']
# ['305796907', 'M33439436', '30', '15']
# ['304458266', 'M33439436', '30', '15']
# ['305764374', 'M33439436', '29', '15']
# ['305777754', 'M33439436', '30', '15']
# ['304656602', 'M33439436', '31', '15']
# ['301333826', 'M33439436', '30', '15']
# ['305816154', 'M33439436', '27', '15']
# ['305736724', 'M33439436', '30', '17']
# ['305749010', 'M33439436', '30', '17']
# ['305716043', 'M33439436', '30', '15']
# ['303097550', 'M33439436', '30', '17']
# ['302304159', 'M33439436', '27', '15']
# ['305688798', 'M33439436', '31', '15']
# ['302120753', 'M33439436', '27', '15']
# ['305684878', 'M33439436', '30', '15']
# ['305686873', 'M33439436', '30', '17']
# ['302739718', 'M33439436', '30', '15']
# ['305768867', 'M33439436', '30', '15']
# ['305720586', 'M33439436', '30', '15']
# ['305761183', 'M33439436', '29', '17']
# ['304471722', 'M33439436', '30', '15']
# ['305364309', 'M33439436', '31', '15']
# ['305627196', 'M33439436', '30', '15']
# ['301846082', 'M33439436', '27', '15']
# ['304473161', 'M33439436', '27', '15']
# ['305810705', 'M33439436', '30', '15']
# ['301207759', 'M33439436', '30', '15']
# ['302666836', 'M33439436', '30', '17']
# ['305682667', 'M33439436', '31', '15']
# ['305811414', 'M33439436', '30', '15']
# ['302291233', 'M33439436', '30', '15']
# ['304055735', 'M33439436', '27', '17']
# ['305741904', 'M33439436', '31', '15']
# ['301193006', 'M33439436', '30', '15']
# ['305690905', 'M33439436', '31', '15']
# ['303159413', 'M33439436', '30', '15']
# ['301594456', 'M33439436', '30', '15']
# ['305704451', 'M33439436', '30', '17']
# ['305729247', 'M33439436', '30', '15']
# ['302833688', 'M33439436', '29', '15']
# ['305769739', 'M33439436', '30', '17']
# ['305708028', 'M33439436', '31', '17']
# ['305783209', 'M33439436', '30', '17']
# ['305802180', 'M33439436', '27', '15']
# ['301649485', 'M33439436', '31', '15']
# ['305329394', 'M33439436', '27', '15']
# ['305662562', 'M33439436', '30', '17']
# ['305733181', 'M33439436', '24', '15']
# ['305713697', 'M33439436', '24', '15']
# ['303242869', 'M33439436', '24', '15']
# ['305789707', 'M33439436', '24', '17']
# ['304134922', 'M33439436', '155', '17']
# ['305703719', 'M33439436', '24', '17']
# ['305747606', 'M33439436', '24', '15']
# ['305715335', 'M33439436', '23', '17']
# ['302242923', 'M33439436', '24', '15']
# ['303595555', 'M33439436', '23', '15']
# ['301086043', 'M33439436', '23', '15']
# ['305714570', 'M33439436', '24', '15']
# ['305430030', 'M33439436', '24', '17']
# ['305682446', 'M33439436', '24', '15']
# ['305228896', 'M33439436', '23', '15']
# ['303355799', 'M33439436', '23', '15']
# ['305694284', 'M33439436', '23', '15']
# ['305695347', 'M33439436', '24', '17']
# ['305096482', 'M33439436', '23', '15']
# ['303242866', 'M33439436', '24', '15']
# ['305808087', 'M33439436', '24', '17']
# ['305665643', 'M33439436', '24', '15']
# ['305710345', 'M33439436', '24', '17']
# ['302706180', 'M33439436', '23', '15']
# ['305075263', 'M33439436', '24', '15']
# ['305729094', 'M33439436', '23', '17']
# ['305602996', 'M33439436', '24', '15']
# ['303355804', 'M33439436', '23', '15']
# ['305701714', 'M33439436', '23', '15']
# ['305310105', 'M33439436', '24', '15']
# ['302327583', 'M33439436', '23', '15']
# ['305431094', 'M33439436', '24', '15']
# ['303000636', 'M33439436', '24', '15']
# ['305646172', 'M33439436', '23', '15']
# ['305430068', 'M33439436', '24', '15']
# ['301843171', 'M33439436', '23', '15']
# ['305707060', 'M33439436', '24', '17']
# ['301085943', 'M33439436', '23', '15']
# ['305657697', 'M33439436', '24', '15']
# ['305603336', 'M33439436', '24', '15']
# ['305806899', 'M33439436', '24', '15']
# ['305228898', 'M33439436', '23', '15']
# ['305714944', 'M33439436', '24', '15']
# ['305199815', 'M33439436', '23', '15']
# ['305682298', 'M33439436', '24', '15']
# ['305177611', 'M33439436', '23', '15']
# ['305747608', 'M33439436', '24', '15']
# ['305409869', 'M33439436', '23', '15']
# ['303894526', 'M33439436', '23', '15']
# ['305796491', 'M33439436', '23', '15']
# ['305787215', 'M33439436', '24', '17']
# ['305796481', 'M33439436', '24', '15']
# ['302304844', 'M33439436', '23', '15']
# ['302333336', 'M33439436', '155', '17']
# ['305753164', 'M33439436', '23', '15']
# ['305765835', 'M33439436', '24', '15']
# ['303290904', 'M33439436', '24', '15']
# ['305729216', 'M33439436', '23', '15']
# ['303028511', 'M33439436', '24', '17']
# ['301606036', 'M33439436', '24', '15']
# ['302252691', 'M33439436', '24', '15']
# ['305707636', 'M33439436', '24', '15']
# ['305682282', 'M33439436', '23', '15']
# ['305789690', 'M33439436', '24', '15']
# ['305689549', 'M33439436', '23', '15']
# ['305721952', 'M33439436', '24', '17']
# ['305812026', 'M33439436', '23', '15']
# ['305772925', 'M33439436', '23', '15']
# ['305809327', 'M33439436', '23', '15']
# ['305814027', 'M33439436', '23', '15']
# ['305717307', 'M33439436', '23', '15']
# ['301036944', 'M33439436', '23', '15']
# ['305710921', 'M33439436', '24', '17']
# ['301085947', 'M33439436', '23', '15']
# ['301737391', 'M33439436', '155', '15']
# ['305209452', 'M33439436', '23', '15']
# ['305682304', 'M33439436', '24', '15']
# ['302810689', 'M33439436', '23', '15']
# ['302647239', 'M33439436', '23', '15']
# ['301659540', 'M33439436', '24', '15']
# ['305430492', 'M33439436', '23', '15']
# ['305755259', 'M33439436', '23', '15']
# ['303894516', 'M33439436', '24', '15']
# ['301351421', 'M33439436', '24', '15']
# ['305796395', 'M33439436', '23', '15']
# ['302305398', 'M33439436', '23', '15']
# ['305697012', 'M33439436', '24', '15']
# ['305199812', 'M33439436', '24', '15']
# ['305697027', 'M33439436', '23', '15']
# ['305784880', 'M33439436', '24', '15']
# ['305430140', 'M33439436', '24', '17']
# ['305712487', 'M33439436', '24', '15']
# ['305754794', 'M33439436', '23', '15']
# ['305719746', 'M33439436', '24', '15']
# ['305784883', 'M33439436', '24', '15']
# ['302305684', 'M33439436', '23', '15']
# ['305816218', 'M33439436', '24', '17']
# ['302190400', 'M33439436', '23', '15']
# ['305748602', 'M33439436', '24', '15']
# ['305789722', 'M33439436', '23', '17']
# ['302729897', 'M33439436', '46', '17']
# ['302759819', 'M33439436', '46', '17']
# ['303329265', 'M33439436', '47', '17']
# ['302179908', 'M33439436', '47', '15']
# ['302258972', 'M33439436', '45', '17']
# ['301799105', 'M33439436', '47', '15']
# ['305766990', 'M33439436', '47', '16']
# ['302986262', 'M33439436', '47', '17']
# ['305681626', 'M33439436', '47', '17']
# ['302292097', 'M33439436', '47', '17']
# ['305588389', 'M33439436', '45', '17']
# ['305742085', 'M33439436', '46', '15']
# ['305710338', 'M33439436', '47', '15']
# ['301210617', 'M33439436', '47', '15']
# ['305707345', 'M33439436', '46', '15']
# ['301843214', 'M33439436', '47', '15']
# ['305688723', 'M33439436', '45', '15']
# ['305727638', 'M33439436', '46', '15']
# ['304474790', 'M33439436', '47', '15']
# ['305709653', 'M33439436', '47', '15']
# ['305720575', 'M33439436', '47', '15']
# ['305749485', 'M33439436', '45', '17']
# ['305773209', 'M33439436', '45', '15']
# ['305661404', 'M33439436', '47', '15']
# ['305724212', 'M33439436', '47', '17']
# ['301844145', 'M33439436', '47', '15']
# ['302764974', 'M33439436', '47', '15']
# ['302730175', 'M33439436', '46', '15']
# ['301508347', 'M33439436', '47', '15']
# ['305790334', 'M33439436', '46', '15']
# ['305795831', 'M33439436', '47', '17']
# ['302714648', 'M33439436', '47', '15']
# ['303423628', 'M33439436', '46', '15']
# ['305796712', 'M33439436', '45', '15']
# ['305812900', 'M33439436', '46', '15']
# ['305729284', 'M33439436', '47', '15']
# ['301545186', 'M33439436', '46', '17']
# ['305690068', 'M33439436', '47', '15']
# ['305661511', 'M33439436', '47', '15']
# ['305703033', 'M33439436', '45', '17']
# ['305702857', 'M33439436', '47', '17']
# ['305802675', 'M33439436', '47', '15']
# ['305704456', 'M33439436', '47', '17']
# ...
# {'itemCd': '303355363', 'option': 'NAVY, FREE', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'rl********', 'time': '2023.11.18', 'content': '질도 좋고 무게가 좀 있어서 따뜻할거같아요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'IVORY, FREE', 'cust_size_info': None, 'size': '큼', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'eu********', 'time': '2023.11.18', 'content': '사이즈가 여유 있어서 더 예쁘네요~', 'rating': 5, 'favorite': '1'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': '158cm,S/55,26inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'wc********', 'time': '2023.11.18', 'content': '편하게 외출할때 입을수 있는 옷이예요^^색상도 이쁘고, 간편하네요~~♡', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'BLACK, FREE', 'cust_size_info': '170cm,57kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ha********', 'time': '2023.11.17', 'content': '블랙색상과 그레이 두개 샀네요 무난히 괜찮아요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': '170cm,57kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ha********', 'time': '2023.11.17', 'content': '남편꺼 산거구요 무난하게 잘입을듯해요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'NAVY, FREE', 'cust_size_info': '166cm,52kg,S/55,26inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'am********', 'time': '2023.11.17', 'content': '남편 며찰전에 그레이 사 주고 너무 마음에 들어하길래 그날 바로 네이비도 주문했어요 네이비도 남편이 딱 좋아하는 네이비라면서 마음에 들어 하네요 보풀도 잘 안날 거 같은 재질이고 남편이 좋아하는 톡톡한 원단이에요 가성비 진짜 좋은 옷이에요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'NAVY, FREE', 'cust_size_info': '167cm,61kg,M/66,27inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'wc********', 'time': '2023.11.17', 'content': '남편이 하나 더 사달래서 주문했어요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': '169cm,56kg,S/55,26inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'da********', 'time': '2023.11.16', 'content': '남편 사줬어요세탁에 큰 변화없고 예뻐요옷은 좀 묵직한 편입니다', 'rating': 4, 'favorite': '1'}
# {'itemCd': '303355363', 'option': 'BEIGE, FREE', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'tn********', 'time': '2023.11.15', 'content': '조아요 남동생이 잘 입었어요 마음에 든대여', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': '168cm,60kg,M/66,29inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'js********', 'time': '2023.11.15', 'content': '남편 사줬는데사이즈 잘 맞아요~~남푠도 좋아하네요~~', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ja********', 'time': '2023.11.15', 'content': '코디대로 구매했는데 깔끔해서 좋아요.신랑이 자주 손갈거같다고 하네요.', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ji********', 'time': '2023.11.15', 'content': '사이즈 프리라 고민하다 주문했는데 너무 마음에 들어요~ 구매하고 나서 할인이 더 돼서 좀 아쉽지만 배송도 빠르고 색상 예쁘구요! 평소 105사이즈 입는데도 약간 여유있게 잘 맞네요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': None, 'size': '적당함', 'color': '비슷함', 'texture': '같음', 'user_id': 'bb********', 'time': '2023.11.15', 'content': '사진보다는 조금더 어두운 그레인데 깔끔합니다', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': '185cm,80kg', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'wc********', 'time': '2023.11.15', 'content': '20일만에 받았네요^^그래도 맘에 들고 워낙 저렴해서 좋아용', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': '166cm,52kg,S/55,26inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'am********', 'time': '2023.11.15', 'content': '남편 사줬는데 너무 만족하네요 180에 76 사이즈 잘 맞구요 가성비갑입니다 색상도 이쁘고 보풀도 안날 거 같아요 그래서 바로 네이비 하나 더 주문했습니다', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'BEIGE, FREE', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'ko********', 'time': '2023.11.15', 'content': '옷 생각보다 괜찮아요사이즈 프리라 고민했는데 적당히 맞네요색도 맘에 들고 잘 입어질것 같아요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'wn********', 'time': '2023.11.14', 'content': '가격대비 질이 좋아요 부드럽고 적당히 도톰해서 무겁지 않아요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'BEIGE, FREE', 'cust_size_info': '172cm,79kg,XL/88', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'kt********', 'time': '2023.11.14', 'content': '확실히 제 핏에는 큰 사이즈 들이 정말 좋네요. ㅎㅎㅎ 감사드립니다.', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': '172cm,79kg,XL/88', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'kt********', 'time': '2023.11.14', 'content': '만족도 높은 옷. 강추.', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': '158cm,51kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'wc********', 'time': '2023.11.14', 'content': '질두좋구 편해요 사이즈도좋아요 잘입을께요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'NAVY, FREE', 'cust_size_info': '172cm,79kg,XL/88', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'kt********', 'time': '2023.11.14', 'content': '와우 너무 예뻐요.', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': '170cm,85kg,L/77,33inch', 'size': '큼', 'color': '비슷함', 'texture': '비슷함', 'user_id': 'rh********', 'time': '2023.11.14', 'content': '생각보다 두껍고 무겁습니다. 착용 이미지는 비슷한 듯 합니다. 아들도 맘에 들어 하구요.', 'rating': 4, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'BEIGE, FREE', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'lo********', 'time': '2023.11.14', 'content': '몸이 좋아보여요 ㅎㅎ 프리사이즈인데 180/72 남편한테 딱 예쁘게 맞아요', 'rating': 5, 'favorite': '1'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'lo********', 'time': '2023.11.14', 'content': '여러개 샀는데 이 제품이 가장 예쁜 것 같아요 생각보다 저렴해보이지 않아요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'BLACK, FREE', 'cust_size_info': None, 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'lo********', 'time': '2023.11.14', 'content': '남편 선물했는데 보들보들 하다고 엄청 좋아해요 ㅎㅎ', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': '155cm,46kg,S/55,26inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'hm********', 'time': '2023.11.14', 'content': '남편 사줬는데  배송은 너무~ 느렸지만 옷은 기본템으로 어디든 잘어울리고 좋네요다른 색상도 구매하고 싶어요! 많이파세요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': '159cm,47kg,S/55,26inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'hy********', 'time': '2023.11.14', 'content': '남자친구 선물로 줫어요 맘에 들어하네요 많이 파세요', 'rating': 5, 'favorite': '0'}
# {'itemCd': '303355363', 'option': 'GRAY, FREE', 'cust_size_info': '162cm,52kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'texture': '같음', 'user_id': 'or********', 'time': '2023.11.14', 'content': '175/75에 넉넉하게 잘 맞고 니트도 생각보다 두꺼워서 좋아요. 재질도 보풀 잘 안날 것 같아요 잘 산 것 같아요~!', 'rating': 5, 'favorite': '0'}
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\songhow53\anaconda3\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File c:\Users\songhow53\anaconda3\Lib\socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File c:\Users\songhow53\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\urllib3\connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\urllib3\connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000001F4C13F4950>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\urllib3\connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.wconcept.co.kr', port=443): Max retries exceeded with url: /Ajax/ProductReViewList (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001F4C13F4950>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[88], line 2
#       1 if __name__ == '__main__':
# ----> 2     main()
#
# Cell In[87], line 17, in main()
#      14 all_reviews = []
#      16 for item_payloads in item_payloads_list:
# ---> 17     review_per_goods = get_reviews(item_payloads)
#      18     if len(review_per_goods) == 0:
#      19         continue
#
# Cell In[86], line 15, in get_reviews(item_payload)
#       5 while True:
#       6     data = {'itemcd': item_payload[0],
#       7         'pageIndex': i,
#       8         'order': 1,
#    (...)
#      12         'itemtypecd': item_payload[3]
#      13         }
# ---> 15     response = requests.post(url, headers=headers, data=data)
#      16     soup = BeautifulSoup(response.text, 'lxml')
#      18     review_count = len(soup.select('p.pdt_review_text'))
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Users\songhow53\anaconda3\Lib\site-packages\requests\adapters.py:520, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     516     if isinstance(e.reason, _SSLError):
#     517         # This branch is for urllib3 v1.22 and later.
#     518         raise SSLError(e, request=request)
# --> 520     raise ConnectionError(e, request=request)
#     522 except ClosedPoolError as e:
#     523     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='www.wconcept.co.kr', port=443): Max retries exceeded with url: /Ajax/ProductReViewList (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001F4C13F4950>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
