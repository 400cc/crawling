# %%
import time
from bs4 import BeautifulSoup
import pandas as pd
import requests
import json
import re

ITEM_COUNTS = 1

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36',
    'Display-Api-Key': 'VWmkUPgs6g2fviPZ5JQFQ3pERP4tIXv/J2jppLqSRBk='
}

# %%
middle_category_nums = ['10101201', '10101202', '10101203', '10101204', '10101205',
                        '10101206', '10101207', '10101208', '10101209', '10101210',
                        '10101211', '10101212']

# %%
def get_item_cds(middle_category_num, gender):
    url = 'https://api-display.wconcept.co.kr/display/api/v2/best/products'

    if gender == 'men':
        genderType = 'men'
    else:
        genderType = 'women'

    data = {
    "custNo": "",
    "dateType": "daily",
    "domain": 'WOMEN',
    "genderType": genderType,
    "depth1Code": "10101",
    "depth2Code": middle_category_num,
    "pageNo": 1,
    "pageSize": ITEM_COUNTS
    }

    response = requests.post(url, headers=headers, json=data)

    soup = BeautifulSoup(response.text, 'lxml')
    info = soup.string
    info = json.loads(info)
    info = info['data']['content']

    item_cds = []

    for item in info:
        item_cds.append(item['itemCd'])
        

    return item_cds

# %%
def get_item_payloads(item_cd):
    url = 'https://www.wconcept.co.kr/Ajax/GetProductsInfo'

    data = {'itemcds': item_cd}

    response = requests.post(url, headers=headers, data=data)

    soup = BeautifulSoup(response.text, 'lxml')
    info = soup.string
    info = json.loads(info)[0]

    item_cd = info['itemCd']
    medium_cd = info['category'][0]['mediumCd']
    category_cd = info['category'][0]['categoryCd']
    itemtypecd = info['itemTypeCd']

    item_payloads = [item_cd, medium_cd, category_cd, itemtypecd]
    
    print(item_payloads)
    
    return item_payloads

# %%
def get_one_review(i, soup, itemCd):
    # 구매 옵션과 사이즈정보 빼내기 용
    review_info = soup.select('div.pdt_review_info')[i]

    # 리뷰 id
    review_id = soup.select('div.product_review_reaction > div > button.link_txt.open-layer.open-pop_review_report')[i]['data-idxnum']
    
    # 구매 옵션
    try:
        option = review_info.select('div.pdt_review_option > p')[0].text.strip()
        option = option.split(':')[1].strip()
    except:
        option = None

    # 사이즈 정보
    try:
        cust_size_info = review_info.select('div.pdt_review_option > p')[1].text.strip()
        cust_size_info = cust_size_info.split(':')[1].strip()
    except:
        cust_size_info = None

    # 사이즈, 색상, 소재 빼내기 용
    try:
        sku = soup.select('ul.product_review_evaluation')[i]       

        # 사이즈
        size = sku.select('ul.product_review_evaluation > li > div > em')[0].text

        # 색상
        color = sku.select('ul.product_review_evaluation > li > div > em')[1].text

        # 소재
        texture = sku.select('ul.product_review_evaluation > li > div > em')[2].text
    
    except:
        size, color, texture = None, None, None



    # user id
    user_id = soup.select('p.product_review_info_right > em')[i].text

    # 작성 시간
    time = soup.select('p.product_review_info_right > span')[i].text

    # 리뷰 내용
    content = soup.select('p.pdt_review_text')[i].text.strip()

    # rating 정보
    rating_pct = soup.select('div.star-grade > strong[style]')[i]
    rating = re.findall(r'\d+', str(rating_pct))[0]
    rating = int(int(rating) / 20)

    # 좋아요 개수
    favorite = soup.select('button.like.btn_review_recommend')[i].text


    data = {
        'product_id': itemCd,
        'review_id': review_id,
        'purchase_option': option,
        'size_info': cust_size_info,
        'size': size,
        'color': color,
        'material': texture,
        'user_id': user_id,
        'written_time': time,
        'body': content,
        'rate': rating,
        'likes': favorite
    }

    return data

# %%
def get_reviews(item_payload):
    url = 'https://www.wconcept.co.kr/Ajax/ProductReViewList'
    i = 1
    one_goods_reviews = []
    while True:
        data = {'itemcd': item_payload[0],
            'pageIndex': i,
            'order': 1,
            'IsPrdCombinOpt': 'N',
            'mediumcd': item_payload[1],
            'categorycd': item_payload[2],
            'itemtypecd': item_payload[3]
            }

        response = requests.post(url, headers=headers, data=data)
        soup = BeautifulSoup(response.text, 'lxml')

        review_count = len(soup.select('p.pdt_review_text'))

        if review_count == 0:
            break
        
        for j in range(review_count):
            review = get_one_review(j, soup, item_payload[0])
            one_goods_reviews.append(review)
            print(review)
        
        i += 1

    return one_goods_reviews

# %%
def main():
    item_cds_list = []
    for gender in ['men', 'women']:
        for middle_category_num in middle_category_nums:
            item_cds = get_item_cds(middle_category_num, gender)
            item_cds_list += item_cds
    print(item_cds_list)

    item_payloads_list = []
    for item_cd in item_cds_list:
        item_payloads_list.append(get_item_payloads(item_cd))


    all_reviews = []

    for item_payloads in item_payloads_list:
        review_per_goods = get_reviews(item_payloads)
        if len(review_per_goods) == 0:
            continue
        else:
            all_reviews += review_per_goods


    df = pd.DataFrame(all_reviews)
    print(df['review_id'].value_counts())

# %%
if __name__ == '__main__':
    main()
# Out:
# ['305686017', '302746593', '301654812', '305788467', '301674166', '305701599', '305769311', '305785969', '302729896', '302765205', '305727613', '305792061', '302647079', '305812175', '302729897', '305659774', '305710164', '302742771', '305776360', '305218882']
# ['305686017', 'M83985861', '28', '15']
# ['302746593', 'M83985861', '44', '15']
# ['301654812', 'M83985861', '34', '15']
# ['305788467', 'M83985861', '39', '15']
# ['301674166', 'M83985861', '157', '15']
# ['305701599', 'M83985861', '122', '15']
# ['305769311', 'M83985861', '160', '15']
# ['305785969', 'M83985861', '164', '15']
# ['302729896', 'M33439436', '7', '17']
# ['302765205', 'M33439436', '328', '15']
# ['305727613', 'M33439436', '32', '15']
# ['305792061', 'M33439436', '33', '17']
# ['302647079', 'M33439436', '30', '17']
# ['305812175', 'M33439436', '24', '17']
# ['302729897', 'M33439436', '46', '17']
# ['305659774', 'M33439436', '39', '15']
# ['305710164', 'M33439436', '50', '17']
# ['302742771', 'M33439436', '62', '15']
# ['305776360', 'M33439436', '227', '17']
# ['305218882', 'M33439436', '235', '15']
# {'product_id': '302746593', 'review_id': '10242927', 'purchase_option': 'CHARCOAL, L', 'size_info': '167cm,54kg', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'na********', 'written_time': '2024.05.06', 'body': '오버핏임 깔끔하고 디자인 만족', 'rate': 5, 'likes': '0'}
# {'product_id': '302746593', 'review_id': '10231164', 'purchase_option': 'BLACK, L', 'size_info': '158cm,53kg,S/55,26inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'gi********', 'written_time': '2024.05.02', 'body': '가격대비 너무 예뻐요 어느자리에도 어울릴것같구요', 'rate': 5, 'likes': '0'}
# {'product_id': '302746593', 'review_id': '9897985', 'purchase_option': 'NATURAL, L', 'size_info': '180cm,75kg', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ze********', 'written_time': '2024.02.19', 'body': '좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '302746593', 'review_id': '9396328', 'purchase_option': 'DEEP BEIGE, L', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ch********', 'written_time': '2023.11.14', 'body': '시원하게잘입을것같아요', 'rate': 5, 'likes': '0'}
# {'product_id': '302746593', 'review_id': '9324109', 'purchase_option': 'BLACK, L', 'size_info': '180cm,80kg', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'hy********', 'written_time': '2023.11.07', 'body': '남편 신혼여행때 입으려고 구매했는데 잘 입고 다녔습니다 깔 끔 하고 여름반팔셔츠인데도 튼튼한 느낌이에요!', 'rate': 5, 'likes': '0'}
# {'product_id': '302746593', 'review_id': '8901493', 'purchase_option': 'DEEP BEIGE, L', 'size_info': '160cm,52kg,M/66,28inch', 'size': '큼', 'color': '다름', 'material': '비슷함', 'user_id': 'he********', 'written_time': '2023.09.09', 'body': '진해요 사진보다 한 여름엔 더울듯해요', 'rate': 4, 'likes': '0'}
# {'product_id': '302746593', 'review_id': '8828157', 'purchase_option': 'CHARCOAL, L', 'size_info': '167cm,58kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'wc********', 'written_time': '2023.08.24', 'body': '색상 예쁘고 맘에 듭니다!!', 'rate': 5, 'likes': '0'}
# {'product_id': '302746593', 'review_id': '8828156', 'purchase_option': 'DEEP BEIGE, L', 'size_info': '167cm,58kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'wc********', 'written_time': '2023.08.24', 'body': '아주 조아요 넉넉하게 잘맞아용디자인 예쁨.', 'rate': 5, 'likes': '0'}
# {'product_id': '302746593', 'review_id': '8825514', 'purchase_option': 'NATURAL, L', 'size_info': '160cm,59kg,S/55,29inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ms********', 'written_time': '2023.08.23', 'body': '선물했는데 너무 마음에 들어하네요 소재도 좋고 이쁩니다', 'rate': 5, 'likes': '0'}
# {'product_id': '302746593', 'review_id': '8820170', 'purchase_option': 'DEEP BEIGE, L', 'size_info': None, 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'fr********', 'written_time': '2023.08.22', 'body': '평범? 실제보다 화면이 이쁘게 나온 느낌. 그냥 소소', 'rate': 3, 'likes': '0'}
# {'product_id': '302746593', 'review_id': '8703560', 'purchase_option': 'CHARCOAL, M', 'size_info': '175cm,65kg,L/77,30inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'cl********', 'written_time': '2023.08.03', 'body': '따로 찍은 사진은 따로 없는데 핏도 예쁘고 컬러도 예쁘고 맘에 들어요 :)', 'rate': 5, 'likes': '0'}
# {'product_id': '302746593', 'review_id': '8660080', 'purchase_option': 'BLACK, L', 'size_info': '170cm,68kg', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ol********', 'written_time': '2023.07.24', 'body': '아들 178/78인 아들한테 매우 잘맞음', 'rate': 5, 'likes': '0'}
# {'product_id': '302746593', 'review_id': '8631849', 'purchase_option': 'NATURAL, L', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ho********', 'written_time': '2023.07.19', 'body': '린넨 소재여서 여름에 입기에 좋은거 같아요 맘에 듭니다', 'rate': 5, 'likes': '0'}
# {'product_id': '302746593', 'review_id': '8620718', 'purchase_option': 'BLACK, M', 'size_info': '170cm,60kg,M/66,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ea********', 'written_time': '2023.07.16', 'body': '남자친구 선물했는데 편하게 막입기 좋아요 약간 연한 카키? 민트느낌 좀 나서 더 좋고요 어깨 넓어보이고 재질도 시원해서 굿', 'rate': 5, 'likes': '0'}
# {'product_id': '302746593', 'review_id': '8608151', 'purchase_option': 'DEEP BEIGE, L', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'da********', 'written_time': '2023.07.13', 'body': '굿', 'rate': 5, 'likes': '0'}
# {'product_id': '302746593', 'review_id': '8436837', 'purchase_option': 'DEEP BEIGE, M', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ki********', 'written_time': '2023.06.30', 'body': '까끌한 마소재입니다 시원하고, 디자인도 이뻐요 색감은 똑갘습니다 다른 색도 구매하려구요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10250454', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'ab********', 'written_time': '2024.05.07', 'body': '박시하게 너어무 잘 입고 있어요!! 이번여름 교복입니다', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10245892', 'purchase_option': 'L', 'size_info': '163cm,48kg,XS/44,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'jm********', 'written_time': '2024.05.07', 'body': '귀엽네뇽뇽 귀여운브랜드를 알게돼서 기분젛아여', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10242296', 'purchase_option': 'M', 'size_info': '164cm,50kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'cu********', 'written_time': '2024.05.06', 'body': '데일리로 입기 좋아용ㅋㅋ', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10238226', 'purchase_option': 'M', 'size_info': '158cm,53kg', 'size': '적당함', 'color': '비슷함', 'material': '같음', 'user_id': 'ki********', 'written_time': '2024.05.04', 'body': '기여워용 사진과 같아용', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10237009', 'purchase_option': 'M', 'size_info': '169cm,59kg', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'eu********', 'written_time': '2024.05.04', 'body': 'L도 괜찮았을 것 같아요 :) M은 적당한 오버핏입니다.다른 종류 티셔츠는 L로 사보려고요!맘에 들어요!', 'rate': 5, 'likes': '1'}
# {'product_id': '301654812', 'review_id': '10236321', 'purchase_option': 'L', 'size_info': '164cm,53kg,S/55,27inch', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'ca********', 'written_time': '2024.05.04', 'body': '너무 에쁘고 편해요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10233176', 'purchase_option': 'M', 'size_info': '160cm,50kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'di********', 'written_time': '2024.05.03', 'body': '사이즈 넉넉하니 좋고 색상도 좋아욯 배송도 빠르고 감사합니다.', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10228302', 'purchase_option': 'M', 'size_info': '150cm,40kg,XS/44,24inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'gi********', 'written_time': '2024.05.02', 'body': '임신으로 인해 좀 박시한거 찾앗는데 사이즈 딱 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10225564', 'purchase_option': 'M', 'size_info': '173cm', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ji********', 'written_time': '2024.05.01', 'body': '예뻐요 맘에들어요 사이즈넉넉해서 편하게 입기 좋아요', 'rate': 5, 'likes': '1'}
# {'product_id': '301654812', 'review_id': '10224368', 'purchase_option': 'L', 'size_info': '171cm,60kg,M/66,27inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'ho********', 'written_time': '2024.05.01', 'body': '전에 있었는데 넘 마음에   들어 다시 구입합니다', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10218792', 'purchase_option': 'L', 'size_info': '168cm,57kg,S/55,28inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'yh********', 'written_time': '2024.04.30', 'body': '남자친구랑 커플로 구매했는데 재질도 좋고 사이즈랑 핏도 생각했던 대로에요~~ (남자친구는 L사이즈, 저는 M사이즈로 하니까 적당했어요)같은 디자인으로 후드티도 있는데 구매할 때마다 만족합니다 ㅎㅎ', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10216175', 'purchase_option': 'M', 'size_info': '165cm,57kg', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'c-********', 'written_time': '2024.04.29', 'body': '사이즈 넉넉해서 편하게 입기 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10209912', 'purchase_option': 'L', 'size_info': '160cm,60kg,M/66', 'size': '적당함', 'color': '비슷함', 'material': '비슷함', 'user_id': 'wc********', 'written_time': '2024.04.27', 'body': '빨래하니까 색이다빠저요', 'rate': 3, 'likes': '1'}
# {'product_id': '301654812', 'review_id': '10207558', 'purchase_option': 'L', 'size_info': '173cm,60kg,M/66,29inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'tk********', 'written_time': '2024.04.27', 'body': '꺄 바이커 쇼츠에 입으려고 라지 주문했는데 원하는 핏이예요♡♡', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10198611', 'purchase_option': 'M', 'size_info': '170cm,51kg,XS/44,25inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ku********', 'written_time': '2024.04.25', 'body': '완전 예뻐요 빈티지 느낌', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10197287', 'purchase_option': 'M', 'size_info': '158cm,49kg', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'sh********', 'written_time': '2024.04.25', 'body': '티셔츠 너무 예뻐요 색감이 특히 👍🏻오버핏으로 좋고 마음에 듭니다', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10192093', 'purchase_option': 'M', 'size_info': '158cm,46kg', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'su********', 'written_time': '2024.04.24', 'body': '크네요~ 편하게 이쁘게잘입을듯', 'rate': 5, 'likes': '1'}
# {'product_id': '301654812', 'review_id': '10178114', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '비슷함', 'material': '같음', 'user_id': 'ka********', 'written_time': '2024.04.22', 'body': '무난한 스타일로 편하게 입기 좋습니다.', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10174539', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'im********', 'written_time': '2024.04.21', 'body': '진짜 너무 예쁘고, 아무 옷이나  코디해도 어울립니다.질도 좋고, 두껍지 않아 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10172692', 'purchase_option': 'M', 'size_info': '166cm,53kg,S/55,27inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'wc********', 'written_time': '2024.04.20', 'body': '너무 귀여워요 여행갈때 편하게 입을수있을거같아요여름에 자주입을거같아용산책할때 입으면 찰떡룩이 될거같아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10165373', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'se********', 'written_time': '2024.04.18', 'body': '보자마자 프린팅 넘 맘에 들어서 구매했어요입어보고 좋으면 다른 디자인으로 더 구매하고 싶어요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10159820', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'su********', 'written_time': '2024.04.17', 'body': '루즈핏 티셔츠에요 편하게 잘입을거같아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10146844', 'purchase_option': 'L', 'size_info': None, 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'el********', 'written_time': '2024.04.14', 'body': '프린트가 많이 흐리긴해요빈티지한 느낌이 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10145786', 'purchase_option': 'M', 'size_info': '168cm,50kg,S/55,26inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'rh********', 'written_time': '2024.04.14', 'body': '귀엽구먼유 ㅋ 잘 입을듯 합니다', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10139194', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ji********', 'written_time': '2024.04.12', 'body': '캐릭터가 마음에 들어서 구매했습니다. 옷은 생각보다 얇아서 살짝 놀랐어요. 오버핏은 L이 좋을 것 같아요.', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10137098', 'purchase_option': 'L', 'size_info': '165cm,54kg,S/55,27inch', 'size': '큼', 'color': '같음', 'material': '비슷함', 'user_id': 'na********', 'written_time': '2024.04.12', 'body': '작년에 여기옷 5개정도 사서 잘입었어용 배송도 빨랐고 티는 박시하고 편해요. . 제가 하체통통이라 힙덮는기장 선호하는데 편하고 좋습니당 더구매할 예정입니당', 'rate': 4, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10134750', 'purchase_option': 'M', 'size_info': '168cm,56kg,S/55,26inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'he********', 'written_time': '2024.04.11', 'body': '이쁘고 소재도 좋아요.추천합니다', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10128577', 'purchase_option': 'M', 'size_info': '160cm,58kg,S/55,28inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': '2s********', 'written_time': '2024.04.10', 'body': '프린트가 귀여워서 삿어요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10119627', 'purchase_option': 'M', 'size_info': '155cm,58kg', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'op********', 'written_time': '2024.04.08', 'body': '평이 좋아서 구매했어요! 입고 나갔더니 다들 예쁘다고 하네요!ㅎㅎ남친이도 예쁘대요ㅎㅎ', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10099219', 'purchase_option': 'M', 'size_info': '160cm,58kg', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'da********', 'written_time': '2024.04.03', 'body': '너무 귀여워요! :)', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10089367', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'ye********', 'written_time': '2024.04.01', 'body': '생각보다 색이 많이 진하고, 길이가 길어요.', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10079193', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'ak********', 'written_time': '2024.03.29', 'body': '생각보다 프린팅이 연한 것 같긴한데빈티지하고 예뻐요! 휘뚜루마뚜루 잘 입어질것 같습니다!', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10070996', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'sk********', 'written_time': '2024.03.28', 'body': '화면이랑 비슷해요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10068349', 'purchase_option': 'L', 'size_info': '167cm,59kg,M/66,29inch', 'size': '적당함', 'color': '비슷함', 'material': '비슷함', 'user_id': 'ap********', 'written_time': '2024.03.27', 'body': '사진과 비슷해여잘 입을 것 같아용', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10038133', 'purchase_option': 'M', 'size_info': '166cm', 'size': '적당함', 'color': '비슷함', 'material': '비슷함', 'user_id': 'ub********', 'written_time': '2024.03.21', 'body': '길이도 적당하고 디자인도 예쁩니다', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10031109', 'purchase_option': 'M', 'size_info': '157cm,60kg,M/66,28inch', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'sw********', 'written_time': '2024.03.19', 'body': '박시해요 그림 귀여워요 색상 좋아요 항상 잘 입을듯요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10016784', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'zg********', 'written_time': '2024.03.16', 'body': '남편 입어도 적당해요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '10016781', 'purchase_option': 'L', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'zg********', 'written_time': '2024.03.16', 'body': '레깅스에 입으려고 라지샀는데 적당함', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9967752', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'ys********', 'written_time': '2024.03.09', 'body': '귀엽고 좋아요 소재도 탄탄합니다', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9946093', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'wh********', 'written_time': '2024.03.03', 'body': '너무맘에들어요색상이나 두께감도 편안함도 다 갖춘티네요', 'rate': 5, 'likes': '1'}
# {'product_id': '301654812', 'review_id': '9943774', 'purchase_option': 'L', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'to********', 'written_time': '2024.03.03', 'body': '운동할때 입으려고 샀어요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9942285', 'purchase_option': 'L', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'le********', 'written_time': '2024.03.02', 'body': '빈티지한게 너무 매력적이고 예쁘고 귀엽다고 칭찬 받았어요~~', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9924421', 'purchase_option': 'L', 'size_info': '157cm,53kg,M/66,28inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ji********', 'written_time': '2024.02.27', 'body': '편하게 휘뚜루 입을수있어요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9922775', 'purchase_option': 'M', 'size_info': '160cm,50kg', 'size': '적당함', 'color': '비슷함', 'material': '비슷함', 'user_id': 'js********', 'written_time': '2024.02.26', 'body': '원단도 도톰하고 빈티지 스타일 일이라 맘에 들어요', 'rate': 5, 'likes': '1'}
# {'product_id': '301654812', 'review_id': '9914700', 'purchase_option': 'L', 'size_info': '168cm,53kg', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'au********', 'written_time': '2024.02.24', 'body': '편한게 입기 좋겠어요 맘에 듭니다', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9907958', 'purchase_option': 'L', 'size_info': '161cm,58kg,M/66,28inch', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'wi********', 'written_time': '2024.02.22', 'body': '타 브랜드 보다 L사이즈가 많이큰 것 같아요!', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9904702', 'purchase_option': 'M', 'size_info': '161cm,58kg,M/66,28inch', 'size': '큼', 'color': '비슷함', 'material': '같음', 'user_id': 'ta********', 'written_time': '2024.02.21', 'body': 'M사이즈인데도 루즈핏?이라서 그런지 크네요만족합니다', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9884887', 'purchase_option': 'M', 'size_info': '166cm,54kg,M/66,27inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'kk********', 'written_time': '2024.02.16', 'body': '엠사이즈도 엄청 커요 평소 55 반 66 사이즈 넉넉하게 맞아요색도이뿌고 질도 탄탄하고 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9869309', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ji********', 'written_time': '2024.02.13', 'body': '배송이 아주 빠르고  원단좋고 예뻐요~~~~', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9825338', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'nk********', 'written_time': '2024.01.30', 'body': '세일해서저렴하게 잘 샀어요바랜 먹색느낌?ㅎㅎㅎ빈티지해요~~~ㅎㅎ', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9790472', 'purchase_option': 'M', 'size_info': '166cm,49kg,XS/44,26inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'wc********', 'written_time': '2024.01.21', 'body': '딱원하던 색감이예요. 사이즈는 약간 박시하네요.', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9778161', 'purchase_option': 'M', 'size_info': '162cm,49kg,S/55,26inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'ga********', 'written_time': '2024.01.17', 'body': '박시한 핏의 빈티지한 느낌 짙은 그레이?  편하게 입고싶어서 구입했구요 한번 빨았는데 목이 우네요 ㅎㅎ 그래도 가격도 착하고 귀여운 프린트랑 너무 얇지 않은소재가 맘에 들어요', 'rate': 4, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9699026', 'purchase_option': 'L', 'size_info': '163cm,58kg,M/66,27inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'pa********', 'written_time': '2023.12.30', 'body': '요거 넘나 컬러 이뻐요 살짝 빈티지한 느낌으러 먹색느낌으로! 청바지에도 잘어울리구 블랙에듀 잘어울려요. 페미닌한 치마에 믹스매치로도 잘 어울려요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9679566', 'purchase_option': 'L', 'size_info': '164cm,52kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'wc********', 'written_time': '2023.12.25', 'body': '너무이뻐요가격도맘에들고딱 원하는스탈이에요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9677260', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '비슷함', 'material': '같음', 'user_id': 'dl********', 'written_time': '2023.12.25', 'body': '색상이 빠져서 왔다는 이야기가 있었는데 저는 괜찮아 보여요 ㅎㅎ 이쁘게 잘입어보려구용', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9674815', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'gk********', 'written_time': '2023.12.24', 'body': '힙해보여서 조아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9653819', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'od********', 'written_time': '2023.12.19', 'body': '빈티지스럽고 예뻐요... 실내에서 운동할때 입을려고 구입했는데 조금 두껍긴하네요...', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9633508', 'purchase_option': 'M', 'size_info': '166cm,62kg,M/66,28inch', 'size': '큼', 'color': '같음', 'material': '비슷함', 'user_id': 'gd********', 'written_time': '2023.12.15', 'body': '빈티지해요 루즈핏이고 완전 한여름에는 더울듯 싶습니다', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9622119', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '비슷함', 'user_id': 'ji********', 'written_time': '2023.12.13', 'body': '제 키가 작은 것도 있지만 진짜 박시해요색상이나 프린팅은 사진이랑 똑같고요두께는 생각보다 좀 더 두껍고 약간 빳빳거리는탄탄한 재질이에요 한여름에는 더울지도?대신 목은 안 늘어날 거 같네용', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9609719', 'purchase_option': 'M', 'size_info': '163cm,50kg,S/55,28inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'nm********', 'written_time': '2023.12.10', 'body': '빈티지스럽고 좋아요 ㅎㅎㅎㅎㅎㅎㅎ', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9599511', 'purchase_option': 'M', 'size_info': '167cm,52kg,S/55,28inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'iq********', 'written_time': '2023.12.07', 'body': '조아요. 많이 좋아요. 재질 디자인 색감 핏이며 다다 맘에 드러요. 저렴하게 세일할 때 잘 샀어요. 막 편하게 입기 짱짱!!', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9573825', 'purchase_option': 'M', 'size_info': '157cm,61kg', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'wc********', 'written_time': '2023.12.05', 'body': '최근 주문하고 상품 검수가 잘못됐다고 올렸던 구매자입니다리뷰작성하고 몇시간만에 죄송하다고 연락주시고 빠르게 새 상품을 보내주시더라구요덕분에 주말에 예쁘게 입고 나갔습니다색상도 상세설명에 올라온 색과 같고 마감처리도 흠 잡을 곳 없이 깔끔했습니다옷 두께도 얇아보이지만 따뜻했어요빠른대처해주시고 기분상하지않게 충분한 답변해주셔서 감사해요제가 표현할 수 있는 곳이 요기뿐이네요😁자주 애용하겠습니다👍🏻🫶🏻', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9565071', 'purchase_option': 'M', 'size_info': '180cm,78kg,33inch', 'size': '적당함', 'color': '비슷함', 'material': '같음', 'user_id': '04********', 'written_time': '2023.12.03', 'body': '얇지않고 톡톡합니다. 색상 사진과 같고 사이즈도  오버핏으로 편하게 입기 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9511285', 'purchase_option': 'L', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': '5_********', 'written_time': '2023.11.27', 'body': '편하게 입으려고 샀어요 넉넉해서 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9494464', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ji********', 'written_time': '2023.11.24', 'body': '박시하게 입으려고 샀는데 프린팅도 귀엽고 후드랑 교복처럼 입었네요.. 활용도 굿~~ 이예요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9460814', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'Dl********', 'written_time': '2023.11.20', 'body': '지금은 잠옷으로 입는데 너무 편해요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9450563', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': '10********', 'written_time': '2023.11.18', 'body': '커플템임 편하게 입을꼬임', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9450558', 'purchase_option': 'L', 'size_info': None, 'size': '큼', 'color': '비슷함', 'material': '같음', 'user_id': '10********', 'written_time': '2023.11.18', 'body': '커플템임 편하게 입을꼬임', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9427082', 'purchase_option': 'M', 'size_info': '163cm,50kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ju********', 'written_time': '2023.11.15', 'body': '배송이 너무 오래 걸렸지만 세일가로 착하게 구매해서 괜찮아요. 겨울에도 이너로 입을 수 있을거 같아요!예쁩니다~^^', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9349973', 'purchase_option': 'M', 'size_info': '155cm,48kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'eu********', 'written_time': '2023.11.10', 'body': '초가을까지 편하게 입고 다녔어요 바이커팬츠랑도 찰떡이고 숏팬츠랑 입음 예뻐요 박시하고 핏이 예뻐서 뭔가 말라보임', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9349573', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'cb********', 'written_time': '2023.11.09', 'body': '편하게 입기좋아요 생각보다 박시해요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9343249', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': '19********', 'written_time': '2023.11.08', 'body': '낙낙하니 예뻐요먹색이 피부 뽀얘 보여서좋아요이염문제만 없으면 최고일듯합니다', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9327188', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'sh********', 'written_time': '2023.11.07', 'body': '박시하니 이뽀요 그냥 무심하게 입고나가기 좋음', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9307268', 'purchase_option': 'L', 'size_info': '155cm,56kg,M/66,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ro********', 'written_time': '2023.11.04', 'body': '사이즈넉넉하고빈티지한 멋이  있어요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9307181', 'purchase_option': 'M', 'size_info': '160cm', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'dp********', 'written_time': '2023.11.04', 'body': '한여름에 입기에는 약간 두꺼운감이 있어요 그래도 너무 귀엽습니다', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9295987', 'purchase_option': 'M', 'size_info': '175cm,78kg,L/77,33inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'oh********', 'written_time': '2023.11.02', 'body': '친구 생일선물로 줬는데 맘에 들어합니다', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9289074', 'purchase_option': 'L', 'size_info': '168cm', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'ma********', 'written_time': '2023.11.01', 'body': '일러스트가 예쁜데 실제로 보면 좀 어둡네요 다른점은 다 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9270831', 'purchase_option': 'M', 'size_info': '154cm,50kg,S/55,26inch', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'dl********', 'written_time': '2023.10.29', 'body': '진짜 너무 귀여워용!! 딱 이런 빈티지한 느낌에 귀여운 키치한 티셔츠 사고 싶었는데 구매하길 너무 잘한 것 같어요!! 고밍하고 계시다면 추천입니다!', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9270351', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'da********', 'written_time': '2023.10.28', 'body': '고민하다 샀는데 잘 산거 같아요 편하게 입기 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9268626', 'purchase_option': 'M', 'size_info': '155cm,45kg,S/55,26inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'nu********', 'written_time': '2023.10.28', 'body': '옷 너무 너무 이뻐요~~~ 올 여름 주구장창 너무 잘입었어요~~~', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9266042', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'eu********', 'written_time': '2023.10.27', 'body': '올여름 잘 입구 다녔어요 ㅎㅎ 세탁하면서 색이 좀 빠지긴 했는데 그래도 예뻐요 ㅋㅋ', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9259033', 'purchase_option': 'L', 'size_info': '167cm', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'dl********', 'written_time': '2023.10.26', 'body': '키가 큰 편인데도 엠사이쥬 하니까 커요 근데 크게 입으려고 산거라 오히려 좋이요 ㅇ엉덩이 다 가립니당 마르거나 키작으시면 원피스로도 입을 수 있을 것 같아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9258892', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ju********', 'written_time': '2023.10.26', 'body': '여름에 휘뚜루 마뚜루 편하게 잘 입음', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9257643', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'ju********', 'written_time': '2023.10.26', 'body': '여름에 교복으로 입고 다님 ㅋㅋ', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9252678', 'purchase_option': 'L', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ho********', 'written_time': '2023.10.26', 'body': '빈티지한 느낌이 맘에 들어요 컬러도 이쁘고 원단도 좋은거 같아요기장감도 좋고 👍🏻', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9252110', 'purchase_option': 'L', 'size_info': '172cm,65kg', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'hk********', 'written_time': '2023.10.25', 'body': '예뻐요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9249249', 'purchase_option': 'M', 'size_info': '170cm,58kg,S/55,28inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'op********', 'written_time': '2023.10.25', 'body': '박시합니다. 가벼운 소재는 아니에요. 편하게 잘 입어지네요.', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9247175', 'purchase_option': 'L', 'size_info': '163cm,52kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ta********', 'written_time': '2023.10.24', 'body': '낙낙하니 이쁘고 편해요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9245092', 'purchase_option': 'L', 'size_info': '171cm,63kg,M/66,28inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ha********', 'written_time': '2023.10.24', 'body': '편하게 입으면서 스타일리쉬 해지는 느낌이예요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9244410', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '비슷함', 'user_id': 'wl********', 'written_time': '2023.10.24', 'body': '이뻐요사이즈딱이고루즈핏이편해서입구나가기좋아요구매좋아요근듣', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9242659', 'purchase_option': 'M', 'size_info': '163cm,50kg', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'cs********', 'written_time': '2023.10.23', 'body': '자켓안에  입으려고 구매햇는데 탄탄한 원단에 목  라인도 넘이쁘게 빠졋네요..', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9237019', 'purchase_option': 'L', 'size_info': '164cm,65kg,M/66,30inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'yo********', 'written_time': '2023.10.22', 'body': '박시한스타일이 너무 맘에들어요~~', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9236566', 'purchase_option': 'M', 'size_info': '158cm,50kg,S/55,26inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'vi********', 'written_time': '2023.10.22', 'body': '사이즈 넉넉해서 편안하게 입을 수 있었어요 ㅎㅎ', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9233153', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'bk********', 'written_time': '2023.10.21', 'body': '여름에 오버핏으로 예쁘게 입기좋아요!! !!', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9229628', 'purchase_option': 'M', 'size_info': '165cm,51kg,M/66,27inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'gp********', 'written_time': '2023.10.20', 'body': '박시하게 입는거 좋아하는데 세일할때 구입해서 여름에 잘입고 다녔어요!', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9221329', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '비슷함', 'material': '같음', 'user_id': 'ke********', 'written_time': '2023.10.19', 'body': '공용사이즈라 좀 박시 합니다. 칼라 디자인 다 빈티지해서 좋고 제품 퀄리티도 좋아요. 단 프린트된 그림은 훨씬 흐리다고 보시는게 맞겠네요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9221266', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '다름', 'material': '비슷함', 'user_id': 'lo********', 'written_time': '2023.10.19', 'body': '프린팅 색상이 생각보다 너무 흐려요 ㅜㅜ', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9220726', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'dl********', 'written_time': '2023.10.19', 'body': '생각보다 꽤 커서 놀랬어요 그리고 두번째?세번째?까지입을때. 가려웠어요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9218024', 'purchase_option': 'M', 'size_info': '158cm,47kg,S/55,25inch', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'fl********', 'written_time': '2023.10.18', 'body': '오버핏으로 청바지에 입으려고 구매했는데 소재가 단단?해서 세탁햐고 늘어나지 않아서 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9154398', 'purchase_option': 'M', 'size_info': '157cm,50kg,S/55,26inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'jj********', 'written_time': '2023.10.17', 'body': '집에서 편하게 입으려고 샀어용다만 다른 빨래랑 같이 돌리면 물빠짐이 있어서 조심해야합니다 ㅜㅜ', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9149750', 'purchase_option': 'M', 'size_info': '168cm,52kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'gh********', 'written_time': '2023.10.16', 'body': '좋아요 가성비 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9149602', 'purchase_option': 'M', 'size_info': '165cm', 'size': '큼', 'color': '같음', 'material': '비슷함', 'user_id': 'to********', 'written_time': '2023.10.15', 'body': '생각보다 테디 프린팅이 약가누덜 핑크이지만 감촉도 좋고 사이즈 낙낙하니 편하게 입을 수 있겠어요!!! 레터링 귀여움', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9141602', 'purchase_option': 'M', 'size_info': '165cm,48kg,XS/44,25inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'he********', 'written_time': '2023.10.14', 'body': '힙하고 예뻐요! 잘 입고 다닐 수 있어서 좋았어요.', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9140837', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'gp********', 'written_time': '2023.10.13', 'body': '핏고 이쁘고 칼라도 이뻐서 여름에 너무 잘입었어요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9100411', 'purchase_option': 'M', 'size_info': '174cm,57kg,M/66,28inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'ca********', 'written_time': '2023.10.13', 'body': '바이크 쇼츠나 레깅스에 입을 때 엉덩이를 가릴 수 있는 기장 긴 티셔츠를 찾다가 구매했는데 엉덩이 확실히 가려집니다톡톡한 면재질로 한여름에는 살짝 두껍지만 그 외 날씨에는 단품으로 입기에도 좋고 맨투맨이나 후드티 속에 레이어드해서 입기에도 좋아요 세탁 몇 차례나 했지만 목부분 늘어짐없이 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9054979', 'purchase_option': 'L', 'size_info': '170cm,54kg,M/66,27inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'di********', 'written_time': '2023.10.12', 'body': '커플티로 샀어요재질도 도톰하고 루즈해서 핏도 예뻐요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9054975', 'purchase_option': 'M', 'size_info': '170cm,54kg,M/66,27inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'di********', 'written_time': '2023.10.12', 'body': '커플티로 입어요사이즈 크고 이뻐요 재질도 도톰하고 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9054476', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'si********', 'written_time': '2023.10.12', 'body': '원하던 색감이었고 티셔츠 프린팅이 귀엽고 착용감이 편해서 여름 내내 휘뚜루마뚜루 잘 입고 다녔어요.', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9053048', 'purchase_option': 'L', 'size_info': '173cm,93kg,XL/88,32inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'i_********', 'written_time': '2023.10.11', 'body': '남편이랑 같이 입으려고 주문했어요 사이즈는 살짝 딱 맞는거같은데 입고 다닐 수 있을거같아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9049329', 'purchase_option': 'M', 'size_info': '163cm,60kg,M/66,28inch', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'su********', 'written_time': '2023.10.11', 'body': '제가 가슴이 큰 편인데도 사이즈 작지 않아요기장도 엉덩이 잘 가립니다 ㅎㅎ 색감도 빈티지해서 막 입기 좋아요올 여름 제 교복이옸음 ^^..', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9042046', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '다름', 'material': '다름', 'user_id': 'ar********', 'written_time': '2023.10.09', 'body': '생각보다 더 박시하네요..! 박시해서 엄청 편합니다. 프린팅은 넘 귀여워요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9039950', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'km********', 'written_time': '2023.10.08', 'body': '진짜 손 잘가고 잘입어져요 색감도 빈티지하고 프린팅도 심심하지않고 너무 튀지도않아서 좋아요키 160cm인데 길이감도 적당히 길어서 딱 좋아요긴 팔도 살까말까 고민중입니다 ㅎㅎㅎ', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9037885', 'purchase_option': 'M', 'size_info': '170cm,48kg', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'gh********', 'written_time': '2023.10.08', 'body': '질도 좋고 색감도 이뻐서 자주 입게돼요 무엇보가 핏이 좋아서 꾸안꾸로 입어도 좋고 그냥 집앞마실용으로도 좋고 몇번 빨아봤는데 목늘어짐도 없이 좋더라구요 ㅎㅎ 체고', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9031550', 'purchase_option': 'L', 'size_info': '165cm,51kg,S/55,27inch', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'aa********', 'written_time': '2023.10.07', 'body': '오버핏 좋아하는 남편 입혔는데 딱이니오 님편 덩치 크지않아요~', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9031340', 'purchase_option': 'L', 'size_info': '163cm,53kg,M/66,28inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': '14********', 'written_time': '2023.10.07', 'body': '궈야워요 색깔도 맘에듬', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9030107', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '비슷함', 'material': '비슷함', 'user_id': 'js********', 'written_time': '2023.10.06', 'body': '박시한편이고 프린팅 그림이 귀여워서 구매했어요 길이감은 엉덩이 덮을정도로 길어요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9024877', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'si********', 'written_time': '2023.10.05', 'body': '박시한 티셔츠 구매하려고 했던 터라 사이즈는 딱 맘에 듭니다! 가리고 싶은 다리부위 확실히 가려지는 큰 사이즈~다른 색상이나 디자인으로 구매하고 싶을 정도예용 ㅎㅎ', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9020886', 'purchase_option': 'M', 'size_info': '164cm,54kg', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'da********', 'written_time': '2023.10.04', 'body': '오버핏 반팔로 사진이랑 색감이랑 핏 비슷합니다~ 편하게 막 입기 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9020569', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'eh********', 'written_time': '2023.10.04', 'body': '아주 만족스러워여', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9016664', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'lo********', 'written_time': '2023.10.03', 'body': '여름에 이곳저곳 편하게 잘 입구 다녔어요. 프린팅도 너무 귀엽고 박시하니 편해서 좋네요. 꼼파뇨 완전 팬될듯', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9012215', 'purchase_option': 'L', 'size_info': None, 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'an********', 'written_time': '2023.10.01', 'body': '사이즈가 커서 마음에 들어요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9011842', 'purchase_option': 'M', 'size_info': '162cm,52kg', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'hv********', 'written_time': '2023.10.01', 'body': '길이가 조금 길어서 줄이고 싶은거 빼곤 여름내내 잘 입었습니다! 사이즈 조금 크긴한데 페인팅이 힙해서 넘 귀여워요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9011520', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'ji********', 'written_time': '2023.10.01', 'body': '완전 휘뚜루마뚜루 잘입고 있어요!', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9011130', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'ru********', 'written_time': '2023.10.01', 'body': '원래 크게 나온 스타일이라 마음에 들어요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9009350', 'purchase_option': 'L', 'size_info': '170cm,52kg,S/55,26inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'ca********', 'written_time': '2023.09.30', 'body': '넉넉하게 입으려고 일부러 큰 사이즈를 샀는데 정말 크네요 ㅎㅎ 아주 편하게 아무데나 입기 편해요. 두께감이 얇지는않아서 한 여름에는 더워서 못 입고 지금 딱 입기 좋네요~ 티셔츠 레이어링해도 예뻐요!', 'rate': 4, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9008411', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '비슷함', 'material': '비슷함', 'user_id': 'oo********', 'written_time': '2023.09.29', 'body': '사이즈.편하게 입기 좋아요 면이.잘 늘어나지.않는 소재라.탄탄합니다', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '9005235', 'purchase_option': 'M', 'size_info': '159cm,46kg', 'size': '적당함', 'color': '같음', 'material': '비슷함', 'user_id': 'el********', 'written_time': '2023.09.28', 'body': '살짝 도톰한 편이고 박시해요. 프린트가 귀여워요!', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8998586', 'purchase_option': 'L', 'size_info': '160cm,60kg,M/66,29inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'ji********', 'written_time': '2023.09.26', 'body': '예뻐요.여름이 지나서 너무 아쉽습니다.착용감도 좋고 마감처리도 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8997287', 'purchase_option': 'M', 'size_info': '169cm,56kg,M/66,28inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': '00********', 'written_time': '2023.09.26', 'body': '넉넉하게 입는 거 좋아하는데 딱 예쁘게 넉넉합니당누구한테 얻어맞은 것처럼 보이지만 그건 아니고 그냥 역동적인 사진으로 픽했습니당처음 입자마자 기름을 묻혀서 지우려다가 더 엉망이 되어하나 더 구입하려고합니당 ㅠㅠ 예뻐요 힙해보여요(?)', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8996175', 'purchase_option': 'L', 'size_info': None, 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'tg********', 'written_time': '2023.09.26', 'body': '두께가 살짝 있어서 좋아요! 편하게 잘 입을 수 있을 것 같아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8993394', 'purchase_option': 'M', 'size_info': '156cm,50kg', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'dp********', 'written_time': '2023.09.25', 'body': '색도 예쁘고 프린팅도 예뻐요 예쁜 오버핏이에요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8976906', 'purchase_option': 'M', 'size_info': '160cm,48kg,S/55,26inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'je********', 'written_time': '2023.09.24', 'body': '정말 편하게 여름 내내 너무 잘 입고 다니고바이커 팬츠랑 매치해서 입으면넘. 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8975335', 'purchase_option': 'M', 'size_info': '158cm,48kg,XS/44,27inch', 'size': '큼', 'color': '같음', 'material': '비슷함', 'user_id': 'ao********', 'written_time': '2023.09.24', 'body': '귀여워용', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8973528', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '비슷함', 'user_id': 'eh********', 'written_time': '2023.09.23', 'body': '편하게 입으려고 구매했어요, 생각보다 재질이 좀 빳빳한거 같아욤', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8973373', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '비슷함', 'material': '다름', 'user_id': 'kr********', 'written_time': '2023.09.23', 'body': '재질이 두꺼워서 한여름은 어려워요. 좀 거친감도 있구요. 색감과 프린트는 이쁩니다.', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8971822', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'du********', 'written_time': '2023.09.23', 'body': '색감과 어우러짐이 너무 예쁘고 긴 기장감에 편하고 자주 입어요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8949903', 'purchase_option': 'L', 'size_info': '174cm', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'ka********', 'written_time': '2023.09.21', 'body': '커요 근데 가격대비 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8948814', 'purchase_option': 'M', 'size_info': '174cm,53kg,S/55,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'tj********', 'written_time': '2023.09.21', 'body': '여름에 너무 잘 입었어요 운동갈때도 길이가 길어서 엉덩이 반쯤 덮어주는 길이여서 잘입었어오', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8945316', 'purchase_option': 'M', 'size_info': '168cm,60kg,M/66,29inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'wj********', 'written_time': '2023.09.20', 'body': '호리호리하면 더 이쁠것같지만티는 정말 이뻐요.소재도 좋구요.이바지 저바지 다 잘어울려요.', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8944075', 'purchase_option': 'L', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'bo********', 'written_time': '2023.09.20', 'body': '커플티로 샀어요캠핑룩으로도 좋아요~', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8932655', 'purchase_option': 'M', 'size_info': None, 'size': '적당함', 'color': '비슷함', 'material': '같음', 'user_id': 'le********', 'written_time': '2023.09.17', 'body': '프린팅이 생각보다 흐려서 조금 아쉬운데 스모크블랙 컬러가 이뻐요 바이커팬츠에 핏도 딱이에요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8932345', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'tp********', 'written_time': '2023.09.17', 'body': '색상이 독특해서 샀는데 프린팅도 귀엽고 색상도 넘 예뻐요!! 다만 같은 색상으로도 다른 색상으로도 입으신 분 많이 봤어욬ㅋㅋㅋㅋㅋ 넘 많이들 입는 티셔츠라 사람 많은 곳은 조심 필수목부분은 잘 늘어날 것 같아요~', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8931323', 'purchase_option': 'L', 'size_info': '164cm,54kg,S/55,26inch', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'ar********', 'written_time': '2023.09.17', 'body': '박시해요 소재 생각보다 톡톡해요두꺼운편이라 소재 늘어짐 많이 없을것 같아요 요즘 캐주얼하게 스커트에도 이쁘구여청바지에도 어울리고 너무 잘입어요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8930369', 'purchase_option': 'M', 'size_info': '165cm,48kg', 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'lr********', 'written_time': '2023.09.17', 'body': '스모크블랙 처럼 블랙보다는 빈티지한 느낌의 색이에요넉넉해서 편하게 입기 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8929494', 'purchase_option': 'L', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'fr********', 'written_time': '2023.09.17', 'body': '차분한색 좋아해서 구매했고 사이즈도 넉넉하니 편안해요 그림도 많이 안튀어서 만족합니다 데일리로 무난하게 잘 입고있어요', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8927849', 'purchase_option': 'M', 'size_info': '158cm,57kg,M/66,30inch', 'size': '큼', 'color': '비슷함', 'material': '비슷함', 'user_id': 'wu********', 'written_time': '2023.09.16', 'body': '정말 이쁩니다... 어여사세요!', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8925105', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '비슷함', 'material': '같음', 'user_id': 'rl********', 'written_time': '2023.09.15', 'body': '프린팅 넘 귀여워요오버사이즈라 편하게 입기 좋아요도톰한 소재라 한여름엔 더울 것 같아요하지만 지금같은 환절기엔 딱이에요넘넘 만족더 빨리 사서 일찍 입을걸~~', 'rate': 5, 'likes': '0'}
# {'product_id': '301654812', 'review_id': '8921552', 'purchase_option': 'M', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'je********', 'written_time': '2023.09.15', 'body': '피그먼트 루즈핏 반팔이 갖고 싶었는데 그래픽도 예쁘고 해서 요걸로 구매했어요제 기준 소매는 팔꿈치 정도까지 내려오고 총장은 엉덩이 다 덮는 길이에요! (원피스용으로는 불가)소재도 탄탄하도 스티치디테일, 마감 다 좋아여영상엔 그래픽이 밝게 찍혔지만 실제로는 그렇게 튀지 않아서 무난하게 잘 입을 수 있을 거 같아요 ㅎㅎ 맘에 듭니다', 'rate': 5, 'likes': '0'}
# ...
# {'product_id': '305218882', 'review_id': '10065565', 'purchase_option': 'F_블랙, F_아이보리', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': '18********', 'written_time': '2024.03.26', 'body': '마른55인데너무 딱맞지도 너무 크지도 않아서 좋네요동남아 여행에서 잊으려규 샀는데넘 편할거 같아요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10065262', 'purchase_option': 'F_스킨, F_아이보리', 'size_info': '160cm,48kg,S/55,26inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'tu********', 'written_time': '2024.03.26', 'body': '늘 구매하는 마른파이브인데 짧은 걸로 첨 구매해요역시 편하고 좋습니다!!', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10064667', 'purchase_option': 'F_아이보리, F_아이보리', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'km********', 'written_time': '2024.03.26', 'body': '구입해서 입어보고 재질이나 촉감이 마음에 들어서 재구입했습니다^^ 마침 원플원이라 가성비 좋게 잘 산 것 같아요~~', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10064645', 'purchase_option': 'F_아이보리, F_블랙', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'j.********', 'written_time': '2024.03.26', 'body': '원쁠원으로 잘샀어요~ 촉감도 좋고 사이즈도 아주 좋아요! 만족합니다~', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10063923', 'purchase_option': 'XL_아이보리, XL_블랙', 'size_info': '163cm,54kg,M/66,28inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'wc********', 'written_time': '2024.03.26', 'body': '센세이셔널입니다~~~대박 만족해요. 다른데서 구매했던 캡나시에 가슴받쳐주는 고무밴드가 짱짱해서 여기서 구매하면서 쨍기지만 말아라~~했는데 웬걸 너무 편해요. (프리사이즈 했으면 찡겼을거같은데 Xl로 하길 잘한거같아요 ㅋㅋㅋ )그렇다고 너무 잡아주는 느낌 없이 허벌떵하지도 않고요!!! 딱 부드럽게 잡아주면서 캡이 안정적으로 가슴을 보호하고 가려주고 자연스러운 라인까지...! 모달이라 부들부들 찰랑찰란해서 여름에 활용하기 너무 좋을것 같고 이거 입다보면 진짜 브라 불편해서 못차고 다닐거같은데요?? 맘에들어서 1+1행사할때 한번더 구매하려구요 크롭이라 말려올라가면 어쩌나 싶기도 했는데 꼭 그렇지도 않은거 같구 👍😀', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10063816', 'purchase_option': 'XL_아이보리, XL_블랙', 'size_info': '159cm,54kg,M/66,28inch', 'size': '적당함', 'color': '비슷함', 'material': '비슷함', 'user_id': 'hm********', 'written_time': '2024.03.26', 'body': 'XL사이즈로 주문했더니 여유있게 맞네요 이런건 넘 쪼이면 불편해서 무튼 세일할때 사셔 잘입을게요', 'rate': 5, 'likes': '1'}
# {'product_id': '305218882', 'review_id': '10063610', 'purchase_option': 'F_블랙, F_아이보리', 'size_info': '160cm,50kg', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ha********', 'written_time': '2024.03.26', 'body': '편안하고 좋아요!!!', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10063434', 'purchase_option': 'F_그레이, F_아이보리', 'size_info': '168cm,58kg,M/66,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'se********', 'written_time': '2024.03.26', 'body': '딸아아와 함께 입으려고, 구매했는데, 후기보고 딸아이는 프리사이즈로 저는 xl사이즈로 구매했는데, 잘 맞고, 이쁩니다, 이너로 입기 좋네요.', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10063432', 'purchase_option': 'F_아이보리, F_아이보리', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'kj********', 'written_time': '2024.03.26', 'body': '일반 캡나시 주문해서 받고소재가 너무 좋아서크롭도 추가로 주문했습니다.', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10063424', 'purchase_option': 'XL_블랙, XL_아이보리', 'size_info': '168cm,58kg,M/66,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'se********', 'written_time': '2024.03.26', 'body': '딸아이와 제가 입으려고 두사이즈 함께 주문했어요. 질도 좋고, 제품 사이즈도 적당하게 잘맞아요. 후기보고 사기를 잘한것 같아요. 다른 속옷 제품도 입어볼 의향있어요', 'rate': 5, 'likes': '1'}
# {'product_id': '305218882', 'review_id': '10062667', 'purchase_option': 'F_아이보리, F_블랙', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'kj********', 'written_time': '2024.03.26', 'body': '사이즈도 딱 맞고 재질도 얇아서 여름에 잘 입을거 같아요! 흰색은 비침이 심해서 단독으로는 못 입겠지만 편하게 입기 최고에요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10060958', 'purchase_option': 'XL_아이보리, XL_블랙', 'size_info': '166cm,57kg,M/66,27inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ja********', 'written_time': '2024.03.25', 'body': '66사이즈라믄 엑스라지 사이즈가 편하고 넉넉하니 잘맞네요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10060561', 'purchase_option': 'F_블랙, XL_아이보리', 'size_info': None, 'size': '큼', 'color': '같음', 'material': '같음', 'user_id': 'ba********', 'written_time': '2024.03.25', 'body': '후기대로 품이 많이 크네요 ㅠㅠ신축성이 좋아서 더 작게 만들었어도 좋았을텐데아쉬워요!', 'rate': 5, 'likes': '1'}
# {'product_id': '305218882', 'review_id': '10059186', 'purchase_option': 'F_스킨, F_블랙', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'bb********', 'written_time': '2024.03.25', 'body': '너무 편안하고 패드 내장되어 있어서 간편하게 입기 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10056433', 'purchase_option': 'F_아이보리, XL_블랙', 'size_info': '173cm,68kg,M/66,29inch', 'size': '작음', 'color': '같음', 'material': '같음', 'user_id': 'in********', 'written_time': '2024.03.24', 'body': '모델컷보다 길이가 많이 짧아ㅠㅠ 키큰 저에게는 훌쩍 짧아서 크롭탑 느낌으로 입기는 어렵고 편한 브라렛 느낌인거 같아요. 세탁하고나서 얼마나 줄지는 아직 모르겟지만 잘 입겠슴니당', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10055609', 'purchase_option': 'F_스킨, F_블랙', 'size_info': '157cm,52kg,S/55,28inch', 'size': '적당함', 'color': '같음', 'material': '비슷함', 'user_id': 'wo********', 'written_time': '2024.03.24', 'body': '착한 가격에 득템 했어요~이너로 잘 입을거 같아요소재도 너무 얇지도 두껍지도 않네요~', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10053059', 'purchase_option': 'XL_스킨, XL_아이보리', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ye********', 'written_time': '2024.03.23', 'body': '넉넉하게 엑스라지 샀어요가성비 너무 좋네요보들보들 촉감', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10052163', 'purchase_option': 'F_아이보리, F_블랙', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'tp********', 'written_time': '2024.03.23', 'body': '포장 깔끔해서 좋아요~ 잘 입겠습니다 굿굿!!', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10050291', 'purchase_option': 'XL_스킨, XL_블랙', 'size_info': '162cm,55kg,M/66,28inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'al********', 'written_time': '2024.03.22', 'body': '요즘 살이쪄서 편한게 좋아서 구매했네요 가격도 착하고 1+1행사라 안살 이유가 없네요 모달이라 역시 부드럽고 텐션이 넘 좋아요', 'rate': 4, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10049976', 'purchase_option': 'F_그레이, F_블랙', 'size_info': '165cm,48kg,S/55,26inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'vo********', 'written_time': '2024.03.22', 'body': '편하게입기 좋을것같아 구매했어요~ 천도 부들부들하니 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10049975', 'purchase_option': 'F_아이보리, F_아이보리', 'size_info': '158cm,57kg,M/66,26inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'sj********', 'written_time': '2024.03.22', 'body': '부들부들하고 안에는 캡내장되있어서 쫀쫀하게 잡아줘요.저는 집이나 뭐 캠핑 이런거할때 편하게 입고싶을때 착용할려고 구매했는데 잘산것같아요.', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10049971', 'purchase_option': 'F_아이보리, F_블랙', 'size_info': '158cm,57kg,M/66,26inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'sj********', 'written_time': '2024.03.22', 'body': '부들부들하고 안에는 캡내장되있어서 쫀쫀하게 잡아줘요.저는 집이나 뭐 캠핑 이런거할때 편하게 입고싶을때 착용할려고 구매했는데 잘산것같아요.', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10047345', 'purchase_option': 'F_아이보리, F_블랙', 'size_info': '162cm,47kg,XS/44,25inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ej********', 'written_time': '2024.03.22', 'body': '짱짱하고 너무 좋아요 길이도 좋고 소재 가격 다좋네요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10040322', 'purchase_option': 'F_아이보리, F_블랙', 'size_info': '165cm,47kg,XS/44,25inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ss********', 'written_time': '2024.03.21', 'body': '편하게 입을 수 있을거같아요 마음에 들어요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10039018', 'purchase_option': 'XL_블랙, XL_아이보리', 'size_info': '170cm,60kg,M/66,28inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': '25********', 'written_time': '2024.03.21', 'body': '소재 부들부들해서 넘나 좋아용♡ 키가 커서 골격때문에 XL 하길 잘했네요~ 덕분에 편하게 입을 수 있겠어용 ㅎㅎ 많이 파인 크롭티랑 찰떡입니다!', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10037777', 'purchase_option': 'F_아이보리, F_블랙', 'size_info': '160cm,45kg', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ea********', 'written_time': '2024.03.21', 'body': '품절됐다고 배송이 1~2주 걸릴거라고 연락왔을땐 헉 했는데. 하루이틀 미뤄진 정도네요 다행히ㅋㅋ 브라탑같은걸 처음입어보는데 괜찮았음 좋겠네요ㅋㅋ', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10034323', 'purchase_option': 'F_아이보리, F_블랙', 'size_info': '160cm,48kg,S/55,25inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'hw********', 'written_time': '2024.03.20', 'body': '끈도 탄탄하고 생각보다 괜찮아요 근데 짧아요 배가 훤히 보임 ㅠ 이너니까 괜찮긴 한데 배 시렵진 않겠져?ㅎㅎ', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10031245', 'purchase_option': 'F_블랙, XL_아이보리', 'size_info': '164cm,46kg,S/55,26inch', 'size': '적당함', 'color': '비슷함', 'material': '비슷함', 'user_id': 'sk********', 'written_time': '2024.03.19', 'body': 'xl랑 프리랑 각각 시켜봤는데, 워낙 편하게 입는 걸 좋아해서 엑스라지도 잘 맞네요 부들부들 촉감도 괜찮아요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10026448', 'purchase_option': 'F_블랙, F_아이보리', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'mi********', 'written_time': '2024.03.18', 'body': '편하고 좋아요.기계세탁했더니 실밥이 좀 풀렸지만, 만족해요.', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10020481', 'purchase_option': 'F_블랙, F_스킨', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'wi********', 'written_time': '2024.03.17', 'body': '정말 가볍고 편해요. 촉감도 좋구요. 말도 안되게 작은 가슴을 가진 저로서는 패드의 볼륨이 조금 아쉽긴 하지만 대체로 아주 만족스러워요.', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10017623', 'purchase_option': 'F_아이보리, F_블랙', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'iy********', 'written_time': '2024.03.16', 'body': '편한 브라탑 찾다가 구매했어요! 아주 살짝 길었으면..', 'rate': 4, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10016543', 'purchase_option': 'F_아이보리, F_블랙', 'size_info': None, 'size': '작음', 'color': '비슷함', 'material': '비슷함', 'user_id': 'dd********', 'written_time': '2024.03.16', 'body': '평소 55-66사이즈 입는데 free 사이즈는 너무 타이트 해서 교환했습니다', 'rate': 5, 'likes': '1'}
# {'product_id': '305218882', 'review_id': '10013366', 'purchase_option': 'F_아이보리, F_블랙', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ha********', 'written_time': '2024.03.15', 'body': '소재 좋고 편해서 매번 여기서 구입해요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '10005358', 'purchase_option': 'F_아이보리, F_아이보리', 'size_info': '162cm,50kg,S/55,28inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'eu********', 'written_time': '2024.03.13', 'body': '짧은 옷 입을때 유용해요너무 간편하고 소재도 좋습니다부들부들해요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '9962398', 'purchase_option': 'F_아이보리, F_블랙', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'us********', 'written_time': '2024.03.07', 'body': '비치는 티 안에 입기에도 좋고 단독으로 입어도 좋을것같아요 마음에 들어요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '9958843', 'purchase_option': 'F_아이보리, F_아이보리', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'sm********', 'written_time': '2024.03.06', 'body': '입은듯 안입은듯 편해요!', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '9946125', 'purchase_option': 'XL_블랙, XL_아이보리', 'size_info': '172cm,60kg,L/77,29inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'wc********', 'written_time': '2024.03.03', 'body': '요즘 상의가 짧게 나와서 이너로 편해요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '9945544', 'purchase_option': 'F_아이보리, F_아이보리', 'size_info': '163cm,63kg,S/55,30inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 're********', 'written_time': '2024.03.03', 'body': '원단이 말랑말랑해서 촉감이좋아요여름에 이것만 입고싶어서 샀는데 입으면 패드가 굉장히 잘보여서 단독착용은 무리고 흰옷안에 입으려구요 그리고 패드가 좀 애매한 부분에 있어서 입고나서 손으로 위치조정이 필요해요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '9945337', 'purchase_option': 'F_블랙, F_스킨', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '비슷함', 'user_id': 'ni********', 'written_time': '2024.03.03', 'body': '부드럽고 좋아요. 길이도 적당해서 편안하네요. 이너로 착용하기에 좋아요.', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '9945334', 'purchase_option': 'F_아이보리, F_블랙', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '비슷함', 'user_id': 'ni********', 'written_time': '2024.03.03', 'body': '부드럽고 좋아요. 길이도 적당해서 편안하네요. 이너로 착용하기에 좋아요.', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '9915334', 'purchase_option': 'F_아이보리, F_그레이', 'size_info': None, 'size': '작음', 'color': '같음', 'material': '같음', 'user_id': 'se********', 'written_time': '2024.02.24', 'body': '와이어가 불편해 맞는 브라렛 찾는 유목민입니다 디자인은 귀엽우나 밴드 부분이 흉통을 죄여옵니다 그리고 흰색은 패드가 비춰서 흰티랑 못 입을 거 같아요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '9913052', 'purchase_option': 'F_스킨, F_블랙', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'co********', 'written_time': '2024.02.23', 'body': '날씨 풀리면 옷이 얇아지니까 미리미리 구매했어요.집에서 브라안하고 편하게 입기에도 좋아요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '9909144', 'purchase_option': 'F_스킨, F_스킨', 'size_info': '166cm,60kg', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'ke********', 'written_time': '2024.02.22', 'body': '브라캡 내장 런닝만 입는데 길이가 짧막한데 맘에 듭니다. 잘 입을게요.', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '9908503', 'purchase_option': 'F_블랙, F_스킨', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'vn********', 'written_time': '2024.02.22', 'body': '흰색 사보고 괜찮아서 1+1으로 다른색 구매해봤는데 역시나 편하고 좋네요여기저기 다양하게 활용 가능할 것 같아요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '9901250', 'purchase_option': 'F_아이보리, F_블랙', 'size_info': None, 'size': '적당함', 'color': '비슷함', 'material': '비슷함', 'user_id': 'gl********', 'written_time': '2024.02.20', 'body': '사이즈 잘 맞고 편해요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '9899806', 'purchase_option': 'XL_그레이, XL_스킨', 'size_info': '162cm', 'size': '적당함', 'color': '다름', 'material': '비슷함', 'user_id': 'Sh********', 'written_time': '2024.02.20', 'body': '그레이컬러..끈부분색이 너무 티나게 다릅니다ㅜ이럴줄알았으면 다른컬러사는건데ㅜ 결국 잠옷 입을때만 입어요ㅜㅜ편하긴해요', 'rate': 4, 'likes': '3'}
# {'product_id': '305218882', 'review_id': '9895479', 'purchase_option': 'F_스킨, F_그레이', 'size_info': None, 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'yu********', 'written_time': '2024.02.19', 'body': '생각보다 짧은데 여름에 잘 입을거같아요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '9887370', 'purchase_option': 'XL_그레이, XL_그레이', 'size_info': '160cm,47kg,S/55,25inch', 'size': '적당함', 'color': '같음', 'material': '같음', 'user_id': 'hs********', 'written_time': '2024.02.16', 'body': '엄마 사드렸는데 편하다고 좋아하세요', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '9809644', 'purchase_option': 'F_블랙, F_그레이', 'size_info': '165cm,52kg', 'size': '적당함', 'color': '같음', 'material': '비슷함', 'user_id': 'ji********', 'written_time': '2024.01.26', 'body': '신축성좋아 몸에맞게 핏되네요.편한게 젤장점인거같아요~~쭉입어보고 추가주문 ㅎㅎ', 'rate': 5, 'likes': '0'}
# {'product_id': '305218882', 'review_id': '9778652', 'purchase_option': 'F_아이보리, F_블랙', 'size_info': None, 'size': '작음', 'color': '비슷함', 'material': '비슷함', 'user_id': 'yu********', 'written_time': '2024.01.17', 'body': '캡이 달려있어 그게 최고 좋은거 같아요운동할때가볍게 집에서 모두 좋아요그리구 무엇보다 부드러워요', 'rate': 3, 'likes': '0'}
# 10242927    1
# 7917511     1
# 7924411     1
# 7923821     1
# 7922835     1
#            ..
# 9277946     1
# 9273399     1
# 9264936     1
# 9261489     1
# 9778652     1
# Name: review_id, Length: 3733, dtype: int64
